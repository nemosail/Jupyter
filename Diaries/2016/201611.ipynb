# %% [markdown]
# # 20161107 Monday
#
# > If I have my way... 认知是人类前进的唯一武器.
#
# > 属于别人的东西，我们不觊觎，但我们自己劳动创造的财富，也决不允许别人从我们手里抢走！ 无论豪夺，还是巧取，都不行！
#
# > 互联网的伟大是全人类的头脑风暴.
#
# ---
# #### 优化问题，optimization.
# 许多问题还会可以优化的，包括局部的优化和全局的优化，局部的优化，着重与体验，智能化替换原来简单粗暴的规则，使得更生活更加便利舒服;全局优化要着重系统级别的优化，使用全面的数据资料来平衡系统，提升效率，一是要有全面充分的数据(开放数据据互联？)，二是有足够好的优化算法。
#
# ---
# 美剧 真实的人类 Humans...
#
# 埃及的[货币问题](http://zhengshangcanyue.baijia.baidu.com/article/681847)，埃及的近年历史？
#
# UAV, 飞行器， 航电。
#
#
# ---
# FileZilla 还是挺好用的，用于传输文件等等，注意 FTP 与 SFTP 是有不一样的诶。
#
# FTP应该默认使用21端口，有没有加密诶？
#
# SFTP使用的应该是SSH协议上的，22端口，应该是加密好的.
#
# 虽然FileZilla和Xftp都无法链接到目标文件夹，但是不用担心，因为可以使用:
# `scp localfile user@ipaddress:/home/xxx/xxx..`
# 来实现同样的功能，没办法了。
#
# #### 有linux的工具，查看文件的encoding很方便的:
#
# `file -i` `file -I`
#
# (linux) (osx). That will output MIME-type information for the file, which will also include the character-set encoding. I found a man-page for it, too :)
#
# #### Python 中指定文件的encoding，使用对应的encoding写入，需要深入了解python的编码机制。
# ```
# #import codecs
#
# of = codecs.open('file','w','gbk')
#
# of.write(unicode('string', 'gbk'))
#
# ```
#
# 在python中。。。我的内存使用诶喂。。。内存曲线不漂亮，网络曲线不漂亮，如何优化？
#
# 发送模块去掉*ev，看看[]放在哪里好看。使用终端来执行程序，终端断开后，程序也被杀死了，如何在终端断开后程序依然在后台运行。如果实在不行了就使用crontab来做把。。。
#
# ---
# #### nohup solution
# solution: linux/unix 的nohup程序：他是在当shell中提示了nohup成功后还需要按终端上键盘任意键退回到shell输入命令窗口，然后通过在shell中输入exit来退出终端；而我是每次在nohup执行成功后直接点关闭程序按钮关闭终端.。所以这时候会断掉该命令所对应的session，导致nohup对应的进程被通知需要一起shutdown。
# ```
# # nohup sh shellscript.sh par1 par2 &
# # nohup xxx &
# ```
#
# shell下删除末尾的字符串还是不错的,直接:
# ```
# hello="hellowolrdims"
# nhell=${hello%"ims"}
# echo ${nhell}
# ```
#
# ---
# #### Debian or Ubuntu 下使用wifi热点很方便的
# 在这里有线上网后，在wifi的setting里就有work as hotspto作为热点启用wifi。。。网络功能还是听完善的。
#
#
# # 20161108 Tuesday
#
# > Jupyter Notebook 是自带了非常多的快捷键的。。。
#
# > 如何让路由器自带翻墙。。。
#
# ---
# 1. 修改短信格式，使用统一的格式，Content [module]
# 2. 都带上时间，让人指导时间
#
# ---
# #### 如何让路由器自动Ladder梯子
#
# #### Git 如何恢复某个文件，某个目录？
# 直接用 git-checkout 即可。理解起来稍微有点奇怪就是了。
#
# `# git checkout xxxxsha264code /path/to/file`
#
# 来源参考：
#
#     http://stackoverflow.com/questions/215718/reset-or-revert-a-specific-file-to-a-specific-revision-using-git
#     https://www.kernel.org/pub/software/scm/git/docs/git-checkout.html
#
# ---
# ### 作业到底有没有超时
# 如果判别，超时的定义是当天的这个时刻还没有完成，那么算是超时吗？
#
# ---
# #### Python 中读写文本文件[资料](http://blog.csdn.net/mrknight/article/details/9717995)
# 'w' 会被windows将 '\n' 换行符 替换成 '\r\n';
#
# 'wb' 不会被windows替换'\n'换行符
#
# \r -> $13_{10}$ -> $015_{8}$
#
# \n -> $10_{10}$ -> $012_{8}$
#
# ```
# # 查看文件里面是不是有\r换行符号
# grep -U $'\015' file.txt
#
# # 查看文件里面是不是存在\r\n这两个字符
# grep -U $"\015\012" file.txt
# ```
#
# Python 里面的len() 和 sys.getsizeof()是有比较大的区别的
#
#
# #### lanuncy 还是很好用的
#
#
# # 20161109 Wednesday
#
# > 膨胀螺丝:应该是解决方案。
#
# > 二进制打开文件与文本形式打开文件，它们是有区别的，与操作系统有点关系。
#
# > [Movie](http://dsmovie.baijia.baidu.com/article/685693)
#
# ---
# #### False alarm 错误的警报
# 明明改好日期了，为什么还是出错了？状态表不太对诶，因为这个作业执行后，状态又切换了，导致在23：00查询的时候，它不是停在成功的状态。。。如何解决，查询历史日记表吗？这样代价会便大的。Seem Done，反正一天查询一次，问题不大，那就简单了，查询log日志表，当天的23：00需要查询的是前一天的状态，那就，嘿嘿嘿...因为日切+状态导致不成功。
#
# #### 为什么程序在早上时候没有运行？
# 查看日志。。。 no space...?!
# Your shell is running out of memory processing that loop. shell变量占用太多资源。Shell running out of memory, because a file is simply too big. Reading it all to a variable or into main memory is stupid! 不小心把整个文件都读取到了变量中，文件太大了，自然用光内存了。。。很久没有底层编程，导致会犯错误，对底层熟悉才行。。。
#
# 加上ETL日期，日切系统查log，非日切系统查stat, 短信日期
#
# ---
# #### 字符定长 与 字节定长,  string 类型 VS unicode 类型
# 编码问题， GBK编码，utf-8编码
#
# [不错的资料](http://blog.csdn.net/feisan/article/details/1666876)
#
# 1. string直接用引号来表示，unicode在引号前加一个u
#
# 2. 直接输入的string常量会用系统缺省编码方式来编码，例如在GBK环境下，'你好'会编码成'/xc4/xe3/xba/xc3'，而在UTF-8环境下就成了'/xe4/xbd/xa0/xe5/xa5/xbd'。
#
# 3. len(string)返回string的字节数，len(unicode)返回的是字符数
#
# 4. 很重要的一点，print unicode不会乱码。
#
# ---
# #### Unix/AIX: Discarding output with the /dev/null file
#
# The /dev/null file is a special file. This file has a unique property: it is always empty. Any data sent to /dev/null is discarded. This is a useful feature when you run a program or command that generates output that you want to ignore.
# For example, you have a program named myprog that accepts input from the screen and generates messages while it is running that you would rather not see on your screen. To read input from the file myscript and discard the standard output messages, type the following:
#
# myprog < myscript >/dev/null
#
# In this example, myprog uses the file myscript as input, and all standard output is discarded.
#
# ---
# #### grep 的简单使用
# 平常常常只是用了到grep单个关键字，最简单的用法，但是肯定是可以使用复杂用法的。。。
# 1. 或操作
#
#   grep -E '123|abc' filename  // 找出文件（filename）中包含123或者包含abc的行
#   egrep '123|abc' filename    // 用egrep同样可以实现
#   awk '/123|abc/' filename   // awk 的实现方式
#
# 2. 与操作
#
#   grep pattern1 files | grep pattern2 ：显示既匹配 pattern1 又匹配 pattern2 的行。
#
# 3. 其他操作
#
#   grep -i pattern files ：不区分大小写地搜索。默认情况区分大小写，
#   grep -l pattern files ：只列出匹配的文件名，
#   grep -L pattern files ：列出不匹配的文件名，
#   grep -w pattern files ：只匹配整个单词，而不是字符串的一部分（如匹配‘magic’，而不是‘magical’），
#   grep -C number pattern files ：匹配的上下文分别显示[number]行，
#
# #### od 查看文件
# 如何理解文件和它的存储方式，使用od命令来把文件使用八进制/十六进制的方式展示出来，这样就能很好地查看文件了。
# od -c ; od -o ; od -x; od -b;  od -bc
#
# #### Linux 下的进制转换工具
# printf 类似C语言的东西; echo； bc； 都行，但是printf就很好很强大了
# ```
# printf "%d\n" 0xFF   #处理十六进制
# printf "%d\n" 010767 #处理十进制
# printf "%x\n" 123
# printf "%o\n" 123
# printf "%o\n" 0xAA
# ```
#
# # 20161110 Thursday
#
# > 与有肝胆人共事，从无字句中读书
#
# ---
# #### Shell script...
# cat file | grep content > file 这种行为应该会有点缺陷，导致只有当天的日志？？如何解决？
#
# 字符串拼接，应该这样子好点：
# `total=“${name}${email}${other}${haha}”`
#
# # 20161111 Friday
#
# > 300 stocks, each 200RMB, Knownology changes your life. Determination changes too.
#
# ---
# #### 人工智能，机器学习
# [AI, ML, Robot, Future](http://iyiou.baijia.baidu.com/article/687979)
#
# 先不管编码问题，使用简单方式实现，传参，落地就是iso-8859-1也先不管。
#
# 概率密度，选修课程啊。
#
# ---
# #### Python 与 Java 中的字节数与字符数目
# 要查看API看看，函数返回的数值所带的单位，，，这个数字代表的是字节数目还是字符数目.
#
# ---
# #### Shell 是有数组的
# 真的麽？动态数组吗？
#
# man grep: grep -E "^go$", what does that means.
#
# shell 应该是可以将字符串执行的，就是执行动态生成/拼成的字符串。Maybe dangerous...:
# ```
# str="echo hello world"
# eval ${str}
# nstr="echo reall"
# ```
# ---
# #### 以后可以去练瑜伽
# 有gear了，有装备拉，瑜伽垫+运动服，坚持对身体很好的拉，长时间坐，需要纠正，不然身体可能变形了。
#
# ---
# #### Git 要小心诶
# 使用git时候不小心把一个data数据文件也导进来了，太大了，导致以为git检查时候崩溃了，实际并不是，而是文件太大导致git花了很多时间，问题在于使用git status 和 git add要很小心，否则容易把一些不需要版本管理的也导进来，出问题了。。。remove掉，关键是如何在gitrepo去掉它？googleing
#
# ---
# #### Linux 查看ascii编码，或者转换，很简单的
# 1. man ascii
# 2. man ascii | grep 73 | grep `printf "%x" 73`
# 3. python > print( chr(73) )
#
# # 20161114 Monday
#
# > 巴甫洛夫's dog...
#
# > Is it all the articals you see is driven by some purpose?
#
# ---
# #### 信息安全管理体系
#
# (Idea, 我们有markdown来控制文章格式，使用文本文件控制就行，可以类似使用文本文件来画图吗？）
#
# Plan -> Do -> Check -> Action -> Plan 这是一个循环，需要不断做迭代。
#
# 敏捷开发， CMM， 用户安全权限， 某个用户可以使用的命令是一个集合{ls;cd;mkdr;...}
#
# 风险：
# - 高
# - 中 （高和中都是需要处理的，需要修复的）
# - 低 （低的是需要关注的)
#
# 控制要求，什么是控制要求
#
# VSS; SVN的权限; 备份自动化； 应急相应; 主备切换; 乌云。。。
#
# 堡垒机，日志无法删除，只能单向增加，如何实现的，真的智能单向增加吗？了解底层原理之后也许就能理解为什么了。
#
# 时钟同步，日志上面是有时间的，只有时钟是同步的时候，这个时间戳才是有效的，所以集群的机器是需要同步时间的，ATP时间同步？
#
# ---
# #### Shell 启动多个进程，并且等待Join... 可以吗？[可以的](http://bbs.51cto.com/thread-1104907-1-1.html)
# shell 好像支持for loop的。。 wait 函数，子进程，子shell，要搞懂程序才能按照要求运行
# ```
# # 这个是顺序执行，sleep了4次，耗时8s左右
# for((i=1;i<=4;i++))
# do
#     echo succeed
#     sleep 2
# done
#
# # 这个是并发执行，主进程等待，耗时2s左右
# for((i=1;i<=4;i++))
# do
#     {
#         echo succeed
#         sleep 2
#     }&
# done
# wait
# ```
# ---
# #### [Shell wait](http://blog.csdn.net/shuanghujushi/article/details/38186303)
# #### 在加入了 echo "xxx" | while read line do done 之后，shell不等待子进程就返回了
# 问题出在管道和[重定向](https://stackoverflow.com/questions/33255901/cygwin-bash-not-waiting-for-background-scripts-to-finish)
#
# This isn't cygwin specific. The pipe in bash starts its commands in subshells. Therefore, the background processes are children of the subshell, not the main shell. Avoid the pipe, replace it with the process substitution <( ... ):
# 注意 "\n" 和 '\n' 一个是字符串，有'\'和'n'这两个字符，一个是'\n'的换行符号，他们代表了不同的含义。
#
# ```
# echo "${var}${var2}" | while read line
# do
#     {xxx} &
# done
# wait
#
# # To This: 这时候就能正常工作了
# echo "${var}${var2} > tmp.data
# while read line
# do
#     {xxx} &
# done < tmp.data
# wait
#
# ```
#
# 原来的不会等待子进程就返回了，因为我使用了echo | 管道，导致的，在使用文件重定向之后，将字符串变量的内容先输出到文件中，然后将文件重定向到我的while read line 里面，这样cygwin的bash wait就能正常工作了，缺失对Shell编程不熟悉的。
#
# ---
# #### vim 的功能很强大，学学学
# :55,60s/^/#/gc
#
# ---
# #### notepad++ 修改 windows/unix/linux 换行
# 编辑 - 文档格式转换 - unix/windows格式
#
# # 20161115 Tuesday
#
# > I saw my phone went bad, I think of time travel, I think of vcs, I count 3,2,1, now I can wake up and tell  reality&dream
#
# > 时代变了！多学习才能更有钱途啊！
#
# ---
# #### Different of ctrl+z and ctrl+c
# ctrl-c sends the SIGINT signal, the default behavior of which is to terminate the process.
#
# ctrl-z sends the SIGTSTP signal, the default behavior of which is to pause the process. Paused processes are not scheduled until they are resumed via the SIGCONT signal. SIGTSTP is the same as SIGSTOP except the latter cannot be ignored or handled.
#
# ```
# Ctrl-D : Used to terminate input or exit the terminal or shell
# Ctrl-z : Used to suspend foreground processes
# Ctrl-c : Used to kill foreground processes
#
# #sleep 20 &
# #sleep 20 &
# #jobs
# #fg %1
# #bg %!
#
# sleep 20 & 将会开启一个子进程来运行代码，放到后台，shell不断调用其他程序，肯定要fork自己，生成新的进程，而且就是子进程
# jobs 查看后台的工作情况，有些是 running表明在后台运行态，满足运行条件，一直运行，但是又stop的状态，它处于等待状态，不满足运行条件，一直在等待序列，不能够运行。
# bg %num 这个的动作是向后台程序发送SGNCONT让后台继续
# fg %num 这个是将后台程序搬到前台来，
#
# ```
#
# 注意：
# - jobs 查看这个shell的子进程的情况
# - fg # 将某个子进程放到前台运行
# - bg # 放到后台？
#
# ---
# #### Python 集合的运算set
# set应该是无序不重复的元素的集合，集合操作主要有 union(并), intersection(交), difference(差); Python表示交集使用的是"&"，并集使用的是"|";
#
# ---
# #### 新任务到了
# 直接映射的，一般就不用什么处理了。。直接干就好了。。。
#
# ---
# #### Gnu, Linux, Debian 下看视频
# gnome-mplayer 貌似非常好用，中文字幕完美支持。。哈哈哈
# 1. apt-cache search gnome-mplayer # if can not find, or timeout update your software source/repo
# 2. apt-get install gnome-mplayer  # use 163 or soho or xmu or qinghua source...
# 3. mouse right click - play with gnome-mplayer, subtitle is great
# 4. edit - set subtitle - choose you subtitle. support chinese very well... HAHAH
#
#
# ![Haskell](http://www.vaikan.com/wordpress/wp-content/uploads/2013/03/functional-progamming-560x337.jpg)
#
# # 20161116 Wednesday
#
# > Rockabye
#
# > Don't sweat the stuff you don't understand immediately. Keep moving!
#
# > “只是因为三轮车好学，你就要一辈子骑三轮车吗？” – Douglas Englebart
#
# ---
# #### Datastage 定长的时候，为啥会被拒绝了?
# 最后一列都加上分隔符，效果是  AAA | BBB | CCC |，貌似是他们的datastage作业的问题，修正好的datastage作业应该没有太多问题,最后一列要不要加上分隔符。。。
#
# notepad++ 查看所有符号： 视图 - 显示符号 - 显示所有字符
#
# DataStage 导入dsx 作业， 导入 - DataStage组件 - 选文件导入后 - 出现在 TMP 下面。。。
#
# ---
# #### 数据库 where 为什么
# ```
# select * from aaa where id = '123' #但是数据库里面明明是'123   '但是却找出来了，why
# select * from bbb where id = '123' #但是数据库里面明明是'123'   找出了是正常的
# ```
#
# 然后 select * from aaa inner join bbb on a.id = b.id 这时候他们是连不起来的，why，这东西确实是存在的，Google IT.
#
# ---
# #### Haskell arrived
# [materials](https://www.zhihu.com/question/20193745)
#
# ---
# #### 命令行参数错误问题，PyCharm是可以给程序参数的，在运行和调试的时候都可以
# 在Pycharm - Run - Edit Configurations - Script parameters : 给程序参数，然后使用 sys.argv 获取，记得python是从0开始计数，0是程序本身，1是程序的第一个参数，2... 如此类推
#
# 注意区别: 他们获取得到的是不同的，"" 给程序的是字符串的内容，''会把'也给程序了，所以一般是使用""更多
# ```
# python hello 'hha' 'ha ha' 'm m'
# python hello "hha" "ha ha" "m m"
# ```
#
# # 20161117 Thursday
#
# > I am scared... Don't know what to do... Just be bold.
#
# ---
# #### 消防培训
# 30层的楼层，  一般中间15就是防火层。 knowledge. 绳子的构建，使用了。
#
# ---
# #### I am angry!  I am not supposed to work something repeat not technical challenging work, but to tell the machine what to do...
# 如何让机器能够理解我们的非结构化信息，对于结构化信息，明确的，没有二异性的，使用规则/编码能够让机器很好地完成工作，但是对于有点非结构化的文本信息，格式不是一直的，有自然语言的，硬编码时间会很复杂很麻烦，如何让机器更好地学会像人一样处理这些。
#
# ---
# #### 实际表与给出的数据字典不匹配，怎么办？
# I don't know. I told them. 反映过了，后续关注把。
#
# ---
# #### Aix 如何查看进程数量，资源占用情况
# topas
#
# 日期 的ETL-DATE -> 如果表里面有标准化的平台时间，就使用它，虽然可能是多个表join的，但是应该是一样把
#
# 建表，建视图，不能漏掉comment啊。。。搽搽搽
#
# DataStage维护
#
# 分组是什么意思啊？
#
# ---
# #### 分组调度算法，如何实现，轮流平均？ Can You? 有现有的做法吗？Google it... 或者苯苯地发明轮子。。。
# 问题描述：
#
# 现在有 1,2,3,4,5,6,7 编号的人，然后两个人一组进行值班，尽量使得值班分配比较平均，个人值班时间尽量分开，就是上次是(1,2)值班了，然后就先不要放(1,3);(2,3)等了,如何设计算法分配值班任务？
#
# 想法，已有的排班作为一个图（集合），从待选队列里面挑一个距离图最远的，或者最不相似的，可以码？定义距离/相似度; I need some one to talk to, communicate with...(贪心算法，可以设计全局的最优算法，就是不是一步一步，而是直接在全局中找出最优解？How？根据规则/启发式规则来，还没到现代的AI水平诶。。。)
#
# python 中类似 matlab 里面的nchoosek，这个排列数计算可能要考虑比较多的东西，溢出/时空效率/近似算法 等等。 scipy的misc.comb函数
#
# scipy.misc.comb ，但是import scipy, scipy.misc.comb时候总是失败，根据[stackoverflow](http://stackoverflow.com/questions/13062484/scipy-misc-missing)的提示，大概为导入scipy的方式不太对，The modules inside scipy aren't accessible as attributes of the base scipy package. You need to do import scipy.misc or from scipy import misc. 使用 from scipy import misc 这样才能使用misc包。。。好吧
#
# ---
# #### Will AI reall change the world we know?
# [we don't knot yet](http://www.bilibili.com/video/av7138419/)
#
# # 20161118 Friday
#
# > Lots of things remain unfinished.
#
# > Practices yoga and meditation. Tired but exciting...
#
# ---
# ####
# 需要 创建表 创建视图 之后需要 做好检查和映射。
#
# 从Excel -> SQL 也是很容易出问题的，为什么还有用容易出问题的人类来完成。。。为啥不用program
#
# 我们使用的 ETL-date 到底使用什么？ SYS_BIZ_DATE 还是 to_char(sys-time, xxx)，那个才是正确？？
#
# DSM -> 建立view (数据类型检查，源表等级字段与数据库字段是否一致;一一映射的数据类型和长度是否一致;DSM->TDA的长度检查)
#
# DSM - > TDA 映射
#
# #### 需求/测试 讨论
#
# what is iBOCA？
#
# JDBC 连接数据库的Char
#
# 使用正则表达式来检查输入的数据，给定了正则表达式，然后对用户的输入数据进行检查过滤;
#
# 如何实现自动分类，使得同一个类的分在同一个系统里面，这样就很好用，很人性化;
#
# 环境： 开发 - 测试 - 生产; 如何使用docker部署，bug管理等等？
#
# 交互UI设计，流程设计，状态转换，设计合理的流程应该是用户友好的，易于理解的
#
# 程序执行后，应该返回适当的信息，譬如成功执行多少行，警告多少行，失败多少行等待，这样的错误信息有助于提醒系统的使用人。
#
# 历史记录，能够看到自己做过什么，记录痕迹，trace
#
#
# ---
# # 20161120 Saturday
#
# > Miss. Ren drived me home today...WoW! 好担心好害怕却又好开心 =.=
#
# > She is so nice... I cannot resist... Her handwriting is lovely... Whatever she says, I can't say no...
#
# > Be 开心，快乐，世界是你们的，也是我们的，但终究是属于长寿的，学会养生啦啦啦，打坐...
#
# ---
# #### 银行国学/企业文化 2016.11.19 Be awared...be careful... not to make mistakes. 许多都是关键词，可以Google展开...
#
# 正经读书，就是遇到一本好书的时候，正襟危坐，像向作者请教一样。。。
#
# 优秀的传统文化～
#
# 八端(孝、悌、忠、信、礼、义、廉、耻。这是孔子他老人家的德育内容的全部精髓简介); 忘八端 ～= 王八蛋
#
# 西学东渐 的思潮
#
# 哲学(善) - 历史(真) - 文学(美)   就像数学一直追求充分必要， 追求事物真实不容易。。。
#
# 企业的凝聚力。。
#
# ###### 虽未能至，心向往之...
#
# ```
# （学习）   （锻炼）  （修）
# 文化/知识 ； 能力  ;  智慧
#
# 都不容易，坚持拉
# ```
#
# ###### 大道至简， 对待事物，可以跑向极端的至繁至简; 对人就要看着办，中庸之道，恰到好处，
#
# 文字是记录语言的符号，但是汉字还有更深层次的含义，它不仅仅是记录，更有更多古人的智慧。
#
# 国学： 从训开始，  周易 64 卦/  谦卦 != 实事求是
# - 一个中心
# - 三个基本点
#
# 对人类的一种分类方式(?): 真至圣贤庶 ... 教化众生... 天垂相 示
#
# 多聆听别人把，偶经常犯的错误诶。。
#
# 天地人 三才之学
#
# 理解命运， 周礼, 剖析事物, (1,2,3...,10） 名 相
#
# ###### 恭敬心 养生
#
# 易：
# - 变化部分
# - 不变部分
# - 简单
#
# 化繁为简  奥卡姆剃刀 Simple, but not too simple.
#
# - 制造变化的   : 先知先觉
# - 感知到变化的 : 后知后觉
# - 不知道变化的 : 不知不觉
#
# #### 打坐/思考/冥想 Just do it.
#
# 阴阳对立统一
#
# 相由心生， 玄学？ 不是，知识拉近人与人之间距离的套路。。。都是套路，要有洞察事物的能力才行诶。。
#
# #### 知其然，知其所以然
#
# 伏羲
#
# ```
#  权     衡
# 变化   不变
# 方法   目标
# 灵活   原则
# ```
#
# 唐僧团队的研究， 团队中的定位
#
# 忧患意识， 吸引力法则， 纳于言敏于行
#
# 仙，佛，贵，贱，腐-> 政==府 不要盯着肉看.. 肉..内人... Oh my god...四目相望
# <- 这个是可以很好解释的，对不？ 不会 欠拟合 和 过拟合 (对规律/Pattern寻找的恰到好处)
#
# 追求，最优化
# < min ----- max >
#
# 鼓掌， 掌的构造来说，经常鼓掌是件好事，不管是对别人还是对自己
#
# 大事将原则，小事就灵活处理啦。。。
#
# #### 要把学习到的知识应用啊。。。自带干粮，自带电池，就像python自带源码一样，哈哈哈
#
#
# 朋友圈 like pagerank，好久没有看论文和思考算法了，不行啊，要锻炼锻炼。。。
#
# Miss Ren 是个有原则的人，赞。
#
# 瑜伽-普拉提-超级累，多坚持坚持，坚持是美德too，就像耐心...
#
# ---
# # 20161120 Sunday
#
# > A secret plan occured to me... blue(bilibili), subtitles, code, movie with clock... Just give me some time.
#
# > [learn](http://gold.xitu.io/entry/581fe92d2e958a0054f2e61e)

# %%
# Jaccard Similarity & Distance, it is not a i.f.f sentence, be awared that set is disorder and no repeat elements...
a_name = "Arnold Weber".lower()
b_name = "Bernard Lowe".lower()

a_set = set(a_name)
b_set = set(b_name)

# Becareful of dividing, we may encounter the divide zero error, define empty set empty set is one
numater = len( a_set & b_set ) * 1.0
denomater = len( a_set | b_set )

if 0 == denomater:
    sim = 1
else:
    sim = numater / denomater
    
print(a_name + " and " + b_name + "\nJaccard Similarity: " + str(sim))

print("\nBut it doesn't look like anything to me.\n")

# using sort all the element is used, repeat elements can be seen here
# be careful that a.sort() act on a and return nothing, while sorted(a) does not act a and return a new list
a_list = list(a_name)
a_list.sort()

b_list = list(b_name)
b_list.sort()

print(a_name + " sorted: " + str(a_list) )
print(b_name + " sorted: " + str(b_list) )

if len(a_list) != len(b_list):
    print(a_list + " length differ " + b_list)
else:
    # reduct( fun, map( fun, a_list, b_list ) )
    n_diff = reduce( lambda x,y: x+y , map( lambda x,y: (ord(x)-ord(y))*(ord(x)-ord(y)), a_list, b_list ) )
    print("\nEuclidean Distance Square: " + str(n_diff) )
    
import itertools
from scipy import misc # This must happen this way, why?

# Try Arrange People In Group to work... DW daily work
people_lst = range(1,8)

# Distance far == similarity low, 
# Thought:
# 对于已经值班的人构建一个图（集合），使用这个集合
print(people_lst)

print(misc.comb(len(people_lst),2,exact=True))


# Here we can test code above...

import datetime
import os

# Here put the xdotool code, will be put into /tmp/xdotool_date file
file_content = """
hhhh| this is | what?
what this happen | kjk | aaa
I am | really | scared
What am | I supposed to | do
Please | help | me
Miss Ren | is a lovely | girl | I have never seen before |
But I am really scared.
nothing can | stop me | from | sleeping |
"""

file_content = file_content[1:]

# write content to file
print("FileContent:\n")
print(file_content)

cur_date = str(datetime.datetime.now().strftime('%Y-%m-%d-%H%M%S'))
file_in_tmp = "/tmp/" + cur_date + ".file_content"
print("Writing content to file " + file_in_tmp)

with open(file_in_tmp, 'w') as fct:
    fct.writelines(file_content)

# execute shell code
shell_code = "head -n 4 " + file_in_tmp + " | sed 's/[^|]//g' | awk '{ print length }'"

# run
process = os.popen(shell_code)
output = process.read()
process.close()
print(output)

# execute shell code
shell_code = "cat " + file_in_tmp + """ | sed 's/[^|]//g' | awk '{ print length }' | cat -n | grep -ve "2$" """

# run
process = os.popen(shell_code)
output = process.read()
process.close()
print(output)

# Testing join function in python
# It is powerful... IMSE, you know nothing...

str_lst = list()
str_lst.append("Hello")
str_lst.append("World")
str_lst.append("IMSE")
str_lst.append("Miss.Rong")

print(str_lst)

to_str = ",\n".join(str_lst)
print("\n" + to_str)
# Out:
# arnold weber and bernard lowe
# Jaccard Similarity: 1.0
#
# But it doesn't look like anything to me.
#
# arnold weber sorted: [' ', 'a', 'b', 'd', 'e', 'e', 'l', 'n', 'o', 'r', 'r', 'w']
# bernard lowe sorted: [' ', 'a', 'b', 'd', 'e', 'e', 'l', 'n', 'o', 'r', 'r', 'w']
#
# Euclidean Distance Square: 0
# [1, 2, 3, 4, 5, 6, 7]
# 21
# FileContent:
#
# hhhh| this is | what?
# what this happen | kjk | aaa
# I am | really | scared
# What am | I supposed to | do
# Please | help | me
# Miss Ren | is a lovely | girl | I have never seen before |
# But I am really scared.
# nothing can | stop me | from | sleeping |
#
# Writing content to file /tmp/2017-07-03-230613.file_content
# 2
# 2
# 2
# 2
#
#      6	4
#      7	0
#      8	4
#
# ['Hello', 'World', 'IMSE', 'Miss.Rong']
#
# Hello,
# World,
# IMSE,
# Miss.Rong

# %% [markdown]
# # 20161121 Monday
#
# > It seems that I get cold... Please...
#
# > 时间才是真正的战场... en！ 喜欢战争的没脑子，忘记战争的没良心。
#
# > Victory - Two Step From Hell - Beautiful
#
# > Amaranth: 【植】苋菜; 【诗】不凋花.
#
# > 兔子在天宫里面种菜和打太极 = .= 闹太套... 阁下何不同风起 扶摇直上九万里
#
# ---
# #### Small Mission， 分系统进行参数化
# OH MY GOD... 改改改， 心塞诶。
#
# ---
# #### 源 -> 目标
# 源的数据字典， 目标数据字典， 然后从源到目标的就是 mapping？ 注意检查一下，因为如果是做好了标准化的时候，正常来说他们的类型是一致的，不会不一样的，如果真的是不一致了，那么就登记一下，去修正问题。
#
# ---
# 有空得花点时间去学习[spark](http://geek.csdn.net/news/detail/124168)，估计将来都是使用它来处理数据，用于机器学习算法的实现了。哈哈，从单机算法都集群算法。。
#
# 微信小程序，控制平台，控制入口，控制用户时间，这有点像老罗的互联网的下半场国民总时间Gross National Time，了解事物，分析事物。
#
# ---
# #### 要熟悉基本程序的输出才行... wc
# ```
# # wc /etc/passwd
#  46    66    2027  /etc/passwd
# 行数  单词数  字节数    文件名
# ```
#
# ---
# #### 存储过程建表？
# 应该是用存储过程导入数据，手动建立一个表就行了把，？
#
# 当mapping需要引用到的表/视图不存在的时候，需要的去建立表的sql里面查找，可以把整个文件夹下载下来，然后使用系统自带的查找功能查找对应的表名得到建立表的sql语句，然后在开发环境中建表，这样就可以搞定了。
#
# [Interseting Answers 关于球。。。](http://www.guokr.com/question/409005/)
#
# [AI 进步了不少诶。 keep learning](http://www.guokr.com/post/763761/)
#
# ---
# # 20161122 Tuesday
#
# > AIX上安装python现实吗？
#
# ---
# #### cx_Oracle datetime timestamp different
#
# ---
# #### 开发完要测试
# 1. 有数据
# 2. 逻辑没问题
# 3. 数据内容正确
#
# 上面的如何理解，需要更加详细化，因为这样子执行才容易，可是为啥要我们去执行啊，明明我们是敲代码高速计算机去执行的。。。
#
# 开发环境 和 测试环境 使用不同的service name,在开发环境开发完，没问题了就可以附属到测试环境就行了，然后在测试环境做简单的测试检查，看看开发的view或者表或者存储过程是不是正确的。
#
# 貌似他们对指标和属性区分比较大，但是对于AI和ML区别有那么大吗？都是用来描述一个事物，就像一个User Profile，有了这些特征就能够做很多事情了。。哈哈，但是以往都是人工来收集这些特征，现在都开始用深度学习来自动学习特征了，哎呦为，快跟不上时代了，看看看。。。
#
# BAS的需要修改 etl日期，这个日期从主表里面出，从B表里面出就会可能存在连接不上而导致的null，但是在生产环境，数据库设计满足范式约束，那么应该是可以连上的把，因为都on的条件应该会存在。
#
# gzip -h 可以查看选项，然后使用 -f 应该可以强制覆盖输出文件，这个当然需要验证拉，很容易的。
#
# #结束日期# #开始日期# 这类是类似一个参数，使用函数获取，结束日期就用当前日期就行了，而那个开始日期可以使用函数往前面推3个月，应该是可以实现的，这些日期的标准化，格式，规范，统一使用'YYYYMMDD'就好了，因为是要用来比较的，需要统一格式才能比较对吧!
# ```
# # 在Oracle中，查询当前日期：
# select to_char(sysdate,'YYYYMMDD')
# from dual;
#
# # 修改时间间隔，当前时间减去3月的时间
# select to_char(sysdate,'YYYYMMDD'), to_char(sysdate - interval '3' month, 'YYYYMMDD' )
# from dual;
#
# # 计算两个日期之间的间隔天数，注意是不是有 off by one的问题，是不是把问题弄复杂了？
# select trunc( sysdate - to_date( to_char(sysdate - interval '3' month, 'YYYYMMDD'), 'YYYYMMDD' ) )
# from dual;
# ```
#
# ---
# #### 尝试在AIX上搞python环境，Can I?
# 没怎么搞过，担心被我玩坏了，诶... 不拍，大不了删库走人。。。 嘿嘿嘿
#
# ---
# #### 开发的视图/过程
# 可以根据理解来组织，也就是只要结果一样就好了，具体那种实现方式都是可以的，但是应该选择更加高效的把？
#
# ---
# # 20161123 Wednesday
#
# > Breath and Life. Beautiful.
#
# > 和任萌妹纸跑步，她好厉害。。。
#
# > 国家主权的数字货币，What is going on? We will see.
#
# > May you rest in a deep and dreamless slumber. 愿你陷入一夜无梦的沉睡。 早点睡啊傻妹子
#
# > [Haskell](www.haskellcn.org) 函数式编程的思维方式，有助于理解程序/算法的本质。
#
# ---
# #### 视图是可以使用CAST来强制进行类型转换的
# ```
# select CAST(12 as decimal(20,4))
# from dual;
# ```
#
# 注意到，一般来说FDM是已经标准化了的，如果出现不一致，就要让hhj和chq来处理，只有那些是赋值/case when等的才能直接使用cast，
#
# ---
# #### HHJ司机的RTX想法
# 我们经常跟合作公司交流，通过RTX交流，提问是比较痛苦的事情，因为在一个群里问问题，然后大家会相互刷屏，导致不好解决问题，如果能够像问答网站的形式，每个问题都可以开一个入口，解决了就关闭，这样就不容易出错了，可以很好地管理开发中遇到的问题。
#
# ---
# #### 高级语言的两个阵营
# - 命令式/顺序式/过程式: C/C++/Java/Python/Scala..
# - 函数式: Lisp/Scheme/Erlang/Haskell...
#
# ---
# #### 不是Group By表达式
# 刚开始是以为我理解错了，其实是理解得不够透彻，为什么select只能放group by的列和对应的聚集函数，放了其他列，就会又二异性，导致不能成功;
# - 翻翻书，查看一下理论，需要理论只是支持;
# - 动手实践一下
#
# group by字句中的一个或者多个属性是用来构造分组的，在group by字句中的所有属性上具有相同价值的元组将被分在一个组中。select 后面+聚集函数 或者 group by的属性，不能放其他东西，少用数据库就真的很容易出错误。这就是我们需要注意的一点，如果在返回集字段中，这些字段要么就要包含在Group By语句的后面，作为分组的依据；要么就要被包含在聚合函数中。我们可以将Group By操作想象成如下的一个过程，首先系统根据SELECT 语句得到一个结果集，如最开始的那个水果、出产国家、单价的一个详细表。然后根据分组字段，将具有相同分组字段的记录归并成了一条记录。这个时候剩下的那些不存在于Group By语句后面作为分组依据的字段就有可能出现多个值，但是目前一种分组情况只有一条记录，一个数据格是无法放入多个数值的，所以这里就需要通过一定的处理将这些多值的列转化成单值，然后将其放在对应的数据格中，那么完成这个步骤的就是聚合函数。这就是为什么这些函数叫聚合函数(aggregate functions)了。
#
# ```
# # 这个没问题的，要注意到select后面的列，要不是group by的列，要不就是聚集函数
# select a, sum(b)
# from student
# group by a
#
# # 这个就有问题了，应该会报“不是Group By表达式”的错误
# select a, c, sum(b)
# from student
# group by a
# ```
#
# 在DSM层的视图，如果mapping里面字段长度不一致，这种应该要修改，因为FDM层就应该标准化了，然后登记在问题反馈就行了;然后开发完需要测试，测试按照上面的要求来可以了，检查出字段长度/精度不一致的也是登记在xls就行了，坑跌啊，这什么鬼啊.
#
# 数据发散问题，就是join的问题， left join，左表有300w，根据连接条件，如果有重复数据，就会导致结果出现多行，也就是结果集比左表更多了。。。
#
# ---
# #### Wiki 一下UTC，理解程序的时间输出
# 例如Git里面输出为: Date: Wed Nov 23 15:34:07 2016 +0800
#
# 这个表示什么，这个时间是零时区 +0800 小时的那个地区的时间为 2016 11 23 星期三 15:34:07  （这个需要验证)
#
# ---
# #### 建造智慧的软件，Free People From Labor Work
# 人工做这些重复的东西太累了，为什么不能让机器来完成啊？
#
# ---
# #### I changed my keyboard color...
# 看起来好像很文艺的样子。。。可是还是掩盖不了我哈士奇般的内心。。。
#
# ---
# #### Latex 属于 PDF时代，那么在epub mobi时代，有新的latex吗？
# markdown可以完成吗？排版问题重来都不容易。
#
# ---
# # 20161124 Thursday
#
# > I make too many mistakes. I promise, I won't do that again. I'm so sorry.
#
# > 多少人曾爱慕你年轻欢畅的容颜
#
# > <太空旅客>
#
# > I am scared. 我可以拨开层层的迷雾，找到事物的真相吗?
#
# > The Constant... 当你找到自己的常量，方程就可以平衡，也就不会迷失(lost)在时空之中。
#
# ---
# #### linux 下的bc如何计算小数，总不能天天使用R吧
# Bash内置了对整数四则运算的支持，但是并不支持浮点运算，而bc命令可以很方便的进行浮点运算，当然整数运算也不再话下。手册页上说bc是An arbitrary precision calculator language，即一个任意精度的计算语言，注意是一种语言，它提供了一些语法结构，比如条件判断、循环等，可以说是很强大的，但是我在实际中还没有找到需要这个用途的场合 。另外一个用途就是用来进行进制转换。
# 常用参数
#
# 如果需要bc不输出提示信息，可以加上-q参数：
#
# bc -q
#
# 如果要使用强大的数学库，比如计算三角函数，需要加上-l参数：
#
# bc -l
#
# 因为bc本身是一个命令解释器，要退出它只要直接输入quit回车或者按Ctrl+D终止。
# 使用示例
#
# 示例一 命令行方式使用bc
#
# [root@localhost centos39]# bc
# scale=2;3/4      # 保留小数点精度只对除法、取余、乘幂有效
# .75
# 3/4
# .75
# 3%4
# 0
# scale=0
# 3%4
# 3
# 3^4
# 81
#
# 示例二 通过管道使用bc来计算
#
# [root@localhost centos39]# echo 3 * 4 | bc
# (standard_in) 1: parse error
# [root@localhost centos39]# echo "3 * 4" | bc
# 12
# [root@localhost centos39]# echo "scale=7; 355/113" | bc
# 3.1415929
# [root@localhost centos39]#
#
# 示例三 进制转换
#
# [root@rhel55 ~]# echo "ibase=16; FFFF" | bc
# 65535
#
# [root@rhel55 ~]# echo "obase=16; 1000" | bc
# 3E8
#
# #### 真心的学学ps的用法，
# Process Stat 非常重要，因为整个系统就是围绕进程这个概念来运行的，ps不同的选项给出了不同的输出列表，需要理解他们具体含义，才能很好地监控自己程序，知道程序的状态，其实我们已经很幸福，工作在高级的状态，不需要管那么多 底层/平台/系统 相关的细节，但是那些都是最难最复杂的，一堆大牛已经帮我们铺好路了，我们只要做的是多看看书，多去实践，多去思考跟上大牛的步伐。
#
# ---
# #### 推荐系统 Recommender System
# 从简单的过滤，用户过滤，物品过滤，到矩阵分解，现在来到网络流的feed，兴趣feed。
#
# [EdgeRank](http://geek.csdn.net/news/detail/125433)前时代、EdgeRank时代和EdgeRank后时代。
#
# 在EdgeRank前时代，按照Facebook首席产品官Chris Cox的说法：“最初，NewsFeed排序就是在拍脑袋，给照片加点权重，给系统消息降点权重。”我们的算法工程师们读到这些，想必要会心一笑：今天高大上的Facebook，又是人工智能又是深度学习，竟然也是从这个时代走过来的。
#
# ---
# #### Haskell的环境根据书本来就好了
# www.haskell.org 使用 Haskell Platform 就包含了所有用到的工具了，至于IDE，有空再找找拉。
#
# Debian 下安装Haskell...Good News..
# `sudo apt-get install haskell-platform`
#
# 但是直接使用apt-get install 提示依赖报错，然后使用 aptitude install 然后强制更新依赖包，然后在安装，等待状态中。貌似安装正常，ghci 和 ghc 都正常打开了，但是确实应该尝试使用docker，使用新科技嘛.
#
# ---
# #### 这是SQL to_char的什么用法啊？
# ```
# # 大概是指定宽度的意思吗？
# select to_char(5, '00000')
# from dual;
# ```
#
# 定义视图的出现循环定义问题，一般就是from的表不存在。。。
#
# ---
# #### 下次周二周三打羽毛球 和 项目经理 合作公司
# 可以跟俊彦他们在RTX上面说一说，在8点多可以一起打打羽毛球，讨论一下问题也是可以的。
#
# ---
# # 20161125 Friday
#
# > 任萌妹纸要离开了，淡淡的忧伤～
#
# ---
# 知识密集型，资本密集型... 你的名字
#
# 什么是美元指数，人民币指数
#
# [找到正确的打开方式，可以干自己喜欢的事情同时又可以Make Some Money的，哈哈](http://36kr.com/p/5057435.html)
#
# ---
# #### Oracle中查看表定义，表结构
# - desc table_name;
# - select COLUMN_NAME,DATA_TYPE,DATA_LENGTH from user_tab_cols where table_name='TEST';
#
# Remember:  CASE aa WHEN '1' THEN '0' WHEN '0' THEN '1' ELSE '0' END
#
# ---
# #### Haskell 函数，不断抽象/升华
# 简单来说，我们可以使用数学的方式来完成对复杂问题的描述，那怕是递归。其实，这并不是新鲜的东西，这是Alonzo Church 和 Haskell Curry 上世纪30年代提出来的东西，这个就是 Y Combinator 的玩法，关于这个东西，你可以看看下面两篇文章：
#
# [The Y Combinator (Slight Return)](http://mvanier.livejournal.com/2897.html)
#
# [Wikipedia: Fixed-point combinator](https://en.wikipedia.org/wiki/Fixed-point_combinator)
#
# ---
# #### 为什么不能用CSV来协作？为什么要用excel...?
# 存在更好文档协作方案吗？原来的方式太容易出错了，根本原因来自使用了二进制文件来进行协作。可以像markdown一样开发新型轻型但是又足够使用的类似xls的格式吗，要求 tsv < new text format < xls 不需要xls那么强大的功能，但是又不能太简单，要求是够用但是又够简单，应该不难的，由于使用文本文件来做的，所有使用版本管理就很好了，这样的信息如何发布出去，抛砖引玉，集思广益，看看广大的程序员如何讨论，我们需要这样的一个平台啊，类似github，类似kickstart的方式，多看看他们的模式，也许我一个人解决不了，但是你会慢慢了解，其实许多问题都是一个人解决不了的，大家一起解决就好了，对不？
#
# 还是因为excel表来工作导致的问题，非常恶心，让人们重复劳动，协作就不应该使用这个功能，就是天煞的. Problem Seem Found, We are right... Because Of excel 因为excel的二进制，有人不小心修改，回退就会导致问题。
#
# 当多看看硅谷他们的自传，他们的故事，大概能找到一个模式，或者一种方式去改变世界，虽然我还不能改变世界，但是可以改变自己的。
#
# 1. 设计新的类似xls的格式，使用文本方式打开，这样会就没有问题了。
# 2. 修改csv的代码，专门给xls登二进制文件来特殊处理，修改文件前要经历 update - get lock - modify - commit 步骤，但是在分布式的情况下，还能正常工作吗？
# 3. 去老外的reddit/stackoverflow/quora上面讨论讨论，我觉得我需要的是一个可以相互讨论的环境，需要的是动手！
#
# ---
# #### 有时候真心得停下来看看自己，想想自己
# 低头拉车，更要抬头看路嘛，不然跟只会执行指令的机器有什么区别？审视自己的工作，审视自己的行为，看看那个可以优化的地方，那个可以自动化的地方。。。
#
# ---
# #### 智能家居的概念出来很久了，但是还是没有多少资本
# 明显感觉到工具/家具将会越来越智能，智能得更加适合个人习惯/模式，更好用更加环保...
#
# ---
# #### Functional Programming
# 函数可以理解为从参数到结果的一个映射，比如 T1 -> T2，每一个函数都符合这样的定义，只不过T1或T2可能代表着更复杂的类型，T1或T2若未函数，那么T1->T2可以称为高阶函数(High order function)
#
# ---
# #### 柯里化函数 Curried Function
# 一次性使用元组全部给出参数，等价与一个一个连续地给出
#
# 多态函数，由于强类型的存在，使得实现一个普通的功能需要许多个函数，因为他们的类型不一致，但是这样子不能继续抽象函数的行为吗，就像模板函数一样，多态也是减少编码，重用，减少错误的好用法。考虑这种用法fst的定义就是这个(a,b)->a，但是a，b是可以任意类型的，也就是(a,b)->a是一个抽象的，而不是具体的实现，a=Int,b=Double都是它的实例，(a,b)->a相当于这些实例函数的类.
#
# 看看 fst 和 snd， fst是将(x,y)这样的2个元素组成的元组里面提取第一元素，snd是将(x,y)这样的2个元素组成的元组里面提取第二个元素，这样子的函数在强类型里如何实现，每个类型都写一次吗？太累，代码重复，错误容易扩散，使用多态来实现，用机器自动去推导，用机器去实现，只要理论与规则定好了，代码很少不会重复，减少错误。 **定义，感觉FP就是定义，fst的定义就是取出元组里面的第一个元素，对吧，就是这个定义，计算机根据这个定义来执行就行了，不用人去编码告诉它如何具体/细节地执行**
#
# ---
# # 20161126 Saturday
#
# > I don't know what to do, really... I am so stupid. Where is my constant.
#
# ---
# #### Haskell
#     在函数编程语言中, 函数是一个中心概念, 常数也可看作是常函数. 如下语句:
#
#      f = 3
#
#     定义了一个常数. f 被定义为3后就不能重复定义 f=5 ,任何时候调用f, 它都返回3. 这就消除了一些边际效应,减少了出错的可能性. 以下代码在函数编程和命令编程中具有完全不同的含义:
#
#     a = 2
#     b = 4
#     c = a + b
#
#     在函数编程中解释为: 定义常数a为2, 定义b为4, 定义c为a,b之和.
#     在命令编程中解释为: 给变量a赋值2, 给b赋值4, 求a,b之和赋给c.
#
#     定义和赋值的区别在于, 定义不分次序, 赋值有次序, 以上程序在Haskell中完全可以倒过来写:
#
#     c = a + b
#     a = 2
#     b = 4
#
#     另外, 定义并不计算, 比如:
#
#     d = 3*5
#     e = 1/0
#
#     在命令程序中, e=1/0会引发一个错误, 在Haskell中只有当计算e时才引发错误.
#
#     Haskell的思维更像是人脑的思维而不是机器的思维.
#
# # 20161128 Monday
#
# > When you are tired of me someday, please please tell me, I can fade away silently. But I hope that it will never happen.
#
# > 不会再担心害怕了，很高兴一路上我们的默契那么长...
#
# > A secret makes a woman woman...
#
# > A secret makes a man man, too...
#
# ---
# #### 当遇到Mapping有多个黄色分组
# 这个可以细看mapping的含义，分组里面的目标都是一模一样的，大概意思是这个视图的内容是多个表合并起来，应该使用union all的动作，注意到union和union all的具体动作，当没有又具体指明的时候，分组之间使用union all就好了。
#
# 为什么我的TDA mapping出错了？因为这个表做得比较匆忙，关键是没有按照整个流程走下来，其实这种体力活已经知道它的整体，整个流程，实现细节，等等，只要按照自己理解并设计好的流程来走的时候，一般是不会犯错的;再一次，这东西就应该给机器来完成啊，搽。
#
# mapping 里面出现了 字段来自 table_a / table_b ，这种一般的意思是这个字段是这两个表union起来的意思.
#
#
# ---
# #### 社交网络，这类电影确实要看看拉
# 社交应用的一生，始于约炮，兴于炫耀，衰于鸡汤，亡于电商。把握关键，洞察事物，关键在于下半场，国民用户时间的争夺.
#
# ---
# #### Oracle 或者 DB2 经常用到了双竖线
# ||是连接符号，Oracle中还有一个concat函数可以连接两个字符串
#
# concat(a,b)
#
# ---
# #### Stop & Think
# 想想我们每天在干什么，的确需要停下来，打坐&冥想，我们人工阅读这个xls手册，然后根据手册生成需要的建表/建立视图需求;这个需求应该在不少公司都有应用到，然后解决这个需求，解决这个问题，提供服务提供思想。。。等等，诶？这样子也应是算创造价值的，为什么？再一次使用机器/程序来扶助人类，大大加少开发中遇到的压力，从繁重的劳动中释放人类，释放生产力啊，想想我们现在的工作，自己的工作挺累的，但是你是理解这个工作和如何实现任务的，但是当新人来了之后，你就去教会新人去工作/去解决问题/去完成任务，看看这个过程，实际是知识的传递，人只是执行机构/足够聪明的机构，但是一直都需要人去完成，人去执行，能不能将知识教会教给程序/机器，然后这个过程就不再需要人类去完成，从而释放人类，让人去干更加exciting的任务，对不？
# 当如如果按照非常严谨的定义去做，得到应该是结构化的协议，但是现在越来越多的程序面对的就是半结构化的数据，我们如何让机器去理解半结构化的数据，甚至去理解非结构化的数据？
#
# > 有时候想，多希望现在发生的一切是一场梦，我从梦里醒来，发现自己还在高三的课堂上，望了望窗外的紫荆，一切都是那么的熟悉，我说好美，同桌说我白痴，要我好好听课，不要胡思乱想。。。现在不想醒来拉，因为这里有任萌妹子，你问我愿不愿意，肯定愿意拉，你知道你问我什么的，你也知道我会答什么的。
#
# ---
# #### 值班相关
# 当ods或者dw作业出错了，出问题了，它会自动重做三次，重做还是失败就会发短信，这时候值班的人员就需要查错，去生产环境的监控里面查看相应的作业信息，下载出错作业的日志，查看是什么问题而导致的失败，根据错误码去修正问题，注意到我们的也是层次式的结构，这样就一层一层来好了，从下面的层一层一层开始解决问题。注意使用监控页面，有搜索功能等等。 为什么用正确用户密码都无法登录，因为之前的作业用错密码，导致那个用户被锁定了，所以后来即使使用正确的密码也无法登录了。导致后来正常的作业出错了。。。用户被锁了，为什么不给每个系统一个用户来分割他们？就像水平分割一样，减少错误的传播。
#
# 其中的两个作业出错了，不是因为权限问题，而是标定没有做好，需要定位都一个表： SCHEMA.TABLENAME 这样才能标定一个表，不然会提示ORA-00942就是找不到表了，不一定是没有查询表的权限。然后在开发环境修改好作业，编译/运行/测试，成功没有问题之后,可以使用DataStage将需要的作业导出，注意导出的选项，导出的文件应当包含源文件和可执行文件，导出落地后导入到生产环境，这样子就能修复问题，修复正确的作业了。
#
# 开启严谨模式，warning警告 将当成 fatal error，也就是作业出现警告了，就得停止作业，abort....
#
# ---
# # 20161129 Tuesday
#
# > The answer is always yes....
#
# > 本周五上午 weblogic 学习
#
# > 见家长？啊啊啊啊啊，好害怕
#
# ---
# #### GNU Operating System...
# [GNU Operating System](https://www.gnu.org) Stallman's Law
#
# While corporations dominate society and write the laws, each advance or change in technology is an opening for them to further restrict or mistreat its users.
#
# ---
# #### Huge Error...
# 在S层是贴源的，落地文件，不改动的;到达D层之后，就可以灵活变通了，自己去实现不用被源系统拖累了;在F层也一样，要按照自己的理解去实现，去做了，然后注意到，一般就是主键才需要非空，其他非主键的一般就不用要求非空了，这个问题会导致源系统为非空，然后只有" "空格作为值的时候，取出空格会导致null，无法插入到对应的字段中，因为我们要求了这个字段不能为空的。
#
# 主键外的都改成可空。。。遇到在F层遇到了ETL_CALL ORA-01400 ??? NULL ?? 大概就像表定义字段非空，然后我们写入NULL的数据导致的违法约束报错。
#
# 关键是这是由于数据导致的原因，所以在开发环境的数据是少量的，在开发环境可能没有奇怪的数据，导致开发完，在开发环境没有问题，能正常运行，但是到了生产环境各种奇怪数据，就导致问题了。。。 **由于 开发环境 测试环境 生产环境的存在 导致一份数据/定义 有多个副本导致问题是如何同步？不同的环境之间同步。**
#
# 之前已经试过了，在调用存储过程时候，是可以使用sql developer调试程序的，来发现问题，之前的缺失右括号，问题在于在建立了索引的时候缺少了索引而导致的，但是我已经修改，而且的确提交和修正。。。但是从svn版本管理，我的修改被覆盖了。。。
#
# DataStage作业报错 WARNING Invalid character converting string 意思是编码问题吗？ from codepage ASCL_GB2312 to Unicode substituting ，尝试解决：到结构的时候不要勾选Unicode?
#
# 一般进赌场都是先赢后输，一般进股市都是先赚后赔，一般被骗都是先被告知中了大奖...这也太精炼了，都是深深的套路。
#
# Ford:"An old trick from an old friend.'
#
# ---
# #### Linux SED And AWK 简单的字符串处理问题
# 我要在一个文本文件中，尝试每一行中某个字符出现的次数， 例如我要 得到 一个文件中每一行'|' 符号出现的次数，结果是一个向量vector而不是一个实数real..
#
# ```
# 文件内容:
# hhhh| this is | what?
# what this happen | kjk | aaa
# nothing can | stop me | from | sleeping |
#
# 期望输出:
# 2
# 2
# 3
#
# 一种实现方式:
# # sed 's/[^|]//g' filename | awk '{ print length }'
# ```
#
# **异常分析， 找出离群点**， [Anomaly detection](https://en.wikipedia.org/wiki/Anomaly_detection)
# 这个深究，我现在做得是简单粗暴的规则，使用逻辑规则来实现，机器实现也是很高效，问题是这个很hard，很专注某个领域，而且是面对结构化数据的，对于半结构化和非结构化的数据无能为力，必须使用更多的数学知识/模型/优化来找到soft的解决方案，都是尝试找出奇怪的样本，找出不太合群的数据，对吧？
#
# 为什么会出错了，分隔符问题，换行符问题，源系统 源数据 自带了分隔符和换行符后 如果没有做好定长，那么它就会导致导入失败，reject，这里可以看到如果是正常的，文件一行表示数据库里面的一行记录，那么文件一行里面的分隔符的个数应该是常数Constant:
# ```
# 某行记录是正常的，不包含分隔符也不包含换行符号    ->    文件中这行对应的分隔符是个常数Constant:
#
# **逆否命题**
#
# 文件中这行对应的分隔符不是固定的常数    ->    某行记录是不正常的，包含分隔符 或者 换行符
# ```
#
# 过程:
# ```
# # 输出正常一行的分隔符的个数，这里的分隔符是 | ，正常来说应该得到了4个一样的数字 num233
# head -n 4 filename | sed 's/[^|]//g' | awk '{ print length }'
#
# # 尝试找出分隔符数目不一样的行，如果这个文件有错误，应该会找出一些分隔符不一样的行
# cat filename | sed 's/[^|]//g' | awk '{ print length }' | grep -v num233
#
# # 好了我们现在指导一些行的分隔符是不一致的了，找出它所在的行，假设它的分隔符数目为233 $$这个符号为
# cat filename | sed 's/[^|]//g' | awk '{ print length }' | cat -n | grep -e "233\Dolor"
#
# ## 优化，得到了正确的数字 num233 后，就好办了，意思是先数出每一行分隔符的个数，然后带上行数，然后找出不以num233结尾的行
# cat filename | sed 's/[^|]//g' | awk '{ print length }' | cat -n | grep -ve "num233\Dolor"
# ```
#
# ---
# # 20161130 Wednesday
#
# > Miss Ren is so lovely... 她真的挺累的，我会好好好好珍惜的。。。
#
# ---
# #### Python 的字符串 format {0} {1} {name}
# 挺好用的，哈哈哈，好害怕！！！
#
# ---
# #### 字符串的日期
# 字符串的日期可以比较大小，但是不能直接相减的。
#
# "20160101" VS "20151231"
# 看看这两个日期，比较大小，使用字典序没有问题，问题在于 两个日期之间的间隔是无法直接相加减的。
#
# ---
# #### 企业的数据库设计平台
# 现在遇到的问题是表变多了，字段分散在数据库表中的各个角落，然后出现了非常多不一致的情况，导致问题是实现/维护很困难，要是有一个可以扶助/推理的数据来扶助，能不能使得系统更加一致，减少人力，降低劳动/时间成本。不仅要适合传统的数据平台使用，也可以适应将来分布式数据平台的使用，这也会是理性/强迫症的胜利吗？ 在我看来，人是不可靠的，会犯错误的，这都不是问题，问题是应该设计/使用工具来辅助/规范/约束，这样子就没有问题了。。。
#
# 企业应该往扁平管理来，金字塔式的管理会导致信息传递不充分，效率地，走流程时间长，跟不上变化，赶不上时代了。。。
#
# ---
# #### 恍如隔世
# 为啥他们做事情这么烂。。。
#
# ---
# # 20161201 Thursday
#
# > December has come...
#
# > 还记得当时我不让你翻我的日记本吗？并不是不想让你知道我的秘密，而是我害怕你笑我的日记太傻了 = .=
#
# > 始于颜值，陷于才华，忠于人品。 How far can I go? I don't know. Just be bold...
#
# > Tring to finish the small secret plan, can you keep doing that?
#
# > <精益创业> 是「Andrew 书房」推荐的第一本书，吴恩达的[书籍推荐](http://36kr.com/p/5057956.html)？
#
# >「我不知道人类的大脑究竟是如何运作的，但这太神奇了——当你阅读了足够多的书、或者与足够多的专家们交谈之后，当你的大脑中输入了足够多的内容之后，新法子就这样产生了。据我所知看上去这种事在很多人身上都发生过。」
#
# >「我阅读很多东西，我也花很多的时间与人们交谈。我认为最有效的两种学习和获取信息的方法就是阅读和与专家对谈。所以我在这两件事上都花了不少的时间。我的 Kindle 上有快到一千本的书，我差不多已经读了其中的三分之二。」
#
# >「如果你真的要想成为一个伟大的研究者的话，你得大量阅读。」
#
# ---
# #### excel
# 根据 空格 tab 逗号 切分列， 选中列 - 数据 - 分列 （注意分列的选项，数值型可能会溢出，使用文本类型）
#
# 然后排序
#
# ---
# #### 现在技术发展，公众号就很方便啦
# 关注一下快递的公众号，然后就能联系他们，寄快递了。。。哈哈哈，依然是那句当你知道事物是如何运作的时候，你就可以嘿嘿嘿
#
# ---
# #### 测试库的数据有问题
# 数据有问题是很正常的，为什么，因为导入数据时候不满足约束/规范会导致数据有问题，有问题的数据又会在系统中传播，可以加强格式的审核，减少错误数据导致的问题，我的日期数据应该是8位的varchar类型的，也就是YYYYMMDD的格式，但是居然给个0这个数值，开玩笑，这样我就无法直接使用to_date(xx,'YYYYMMDD')函数来转换成日期类型，然后使用日期类型的减法来计算两个日期的间隔天数了。。。
#
# ---
# #### 一个模糊定义的问题
# 如何从一个任意复制的sql查询中找到用到的所有表的表名？？？如何实现？
#
# ---
# #### 如果我的记忆没错
# Story shall begin at 20161111. This idea has been put to Ideas... It won't take me much time to finish the small program.
#
# ---
# #### 以往的做法
# 就是人去理解事物，去接触，去动手，然后找到规律/规则后，知道如何解决问题了（建立数学模型或者得出算法），就通过计算机语言来教计算机去完成任务，这是以往一直沿用的做法，现在问题来了，就是使用AI/ML/DL的方式来解决问题了，让机器去理解/感知世界的变化，这样也许许多问题就不再需要人工去干预，这应该是现在和将来的顶级水平把，看看啊啊啊, IMS...
#
# ---
# # 20161202 Friday
#
# > How to tell True from False? How to tell right from wrong? Truth sometimes can be confusing.
#
# > 真实真诚很重要...  From Miss. Ren.
#
# > 互联网上的镜像，有时不过是营销和求助人对信息要素处心积虑的人工剪辑和排列组合————你第一眼看到的，只是他们想让你看到的。
#
# > “共享模式”是基于对社会闲置资源再次调动和分配基础上形成的一种商业模式...模式 Pattern.
#
# > Remember. I remember now. She once said: "I saw your code. Your code was telling a story, a story about you, about yourself, you were talking to yourself... But I couldn't find myself in your story. I know the answer, I am just your friend, bye..."  T.T
#
# > 任妹子好特别啊。。。居然说不喜欢零食。。。org...她跟我认识的妹子都不一样，怎么办？
#
# ---
# #### 自媒体 做好一件事情 肯定要 数据 和 算法 支撑的...
# 其实之前也看过不少BuzzFeed出的视频，质量其实真的挺高的，其实没有去深究它为什么能出那么多受人喜欢的PGC，原来也是有 数据 与 算法 的支撑的.
#
# 国外有家被称为是“媒体行业颠覆者”的新闻聚合网站BuzzFeed，每月高达50亿次的恐怖浏览量，在美国商业杂志《Fast Company》3月刊评选出的《全球50大创新公司》中，BuzzFeed位列榜首，上榜理由是为全球媒体行业带来了革命。排在后位的则是Facebook、Uber、Netflix、亚马逊、苹果和谷歌（Alphabet）等企业。
#
# BuzzFeed的成功在于其处理数据上非常厉害，能够基于数据创作出在社交媒体上令人疯转的内容。不久前，Buzzfeed揭秘他们异常神秘的大数据工具Pound和Hive。
#
# Pound 是Process for Optimizing and Understanding Network Diffusion（网络传播优化及理解流程）的缩写，Pound技术能展示在线内容是怎么一步一步从下游的网站访问开始传播的，不论是点对点的邮件还是社交媒体，都能被这项技术所捕捉。
#
# ---
# #### WebLogic 中间件
# Oracle, WebLogic Server
#
# 部署问题
#
# 域 Domain 同样版本的机器,  (管理服务器-分配工作; 受管服务器-实际工作) 就像一个集群一样,管理/控制/利用 集群的力量, 管理-受管理,这个有点像中央与地方的关系,也是管理集群的一个常见模式,还有其他管理模式吗?
#
# 集群 cluster
#
# 逻辑表示 与 物理表示
#
# 通用机器人平台,可以编程,可以学习
#
# 有想法的时候,去实现,要有背景知识,实现细节.
#
# 开发 - 测试 - 生产   (也是常见的工作模式,可以提出新的模式吗?)
#
# 中间件 weblogic vast
#
# 确实,没有source code就无法控制机器了,只能接受别人控制的机器,但是有source code就不一样了.
#
# 错误码 的设计
#
# 宽字符 CST 时区
#
# 状态机 Markov链
#
# nohup & 后台运行,断开shell继续运行 nohup.out为程序输出,标准输出,标准错误输出.
#
# **我也搞个产品部,Product? 如何控制?**
#
# 训练抽象思维的能力
#
#
#
# ---
# #### 使用excel公式生成的代码
# 使用代码生成的数据要比人工生成的要来得工整/规范,结构化, 但是人工生成的部分是灵活,非结构化,如何衡量它们, 或者使用机器来替代人类?
#
# ---
# # 20161203 Saturday
#
# > It's been a looooong day.
#
# 去见了任妹子的家长，担心自己表现不好。。。好害怕
#
# 陪她去看 你的名字 ，很好看，真的很好看，任妹子超能吃。。。但是也好萌好可爱，和她去走灯湖路，第一次牵她的手，好幸福 =.=
#
# # 20161205 Monday
#
# > Miss U.
#
# > Haskell: 如果定义的是函数,那么这个函数的行为在运行过程中也是不会改变的,对于某一个特定的输入返回的结果总是确定的,这样的函数为纯函数.
#
# ---
# #### 如何识别使用签章认证doc的文字
# 想法是能够识别里面的文字之后,我就可以使用固定的逻辑来教程序完成任务,关键还是在识别文字和识别里面的意思. It seems I still have many things to learn and practise.
#
# ---
# #### 在最后一层
# 可以在xls里面添加自己的校验逻辑吗,应该很简单的,嘿嘿嘿
#
# AND（条件一，条件二.条件三....)      条件一  二  三 。。。都成立时返回   TURE  否则返回  FALSE
#
# IF(条件，条件为TURE时返回值，条件为FALSE时返回值）
#
# IF和AND 嵌套使用：
#
#     =IF(AND(A1>60,B1>60,C1>60),"及格","不及格")
#     当  AND（A1>60，B1>60，C1>60） 为 TURE时 返回  “及格”
#     为FALSE时  返回 不及格
#     AND(A1>60,B1>60,C1>60)    当A1，B1,C1 都大于60时 返回TURE
#
# ---
# #### 想搞懂基尼系数定义
# 搞懂定义,实现代码,然后运行计算指标.
#
# ---
# #### 很多表导入数据后出现问题
# 在那个日期没有数据,或者join表后没有数据,要定位问题,解决问题.
#
# ---
# #### 如果真的要值班了
# 监控系统运行的情况,可以使用程序来自动化监控就好了,我知道至少可以使用python和R来完成数据读取,数据处理,数据展示功能了...嘿嘿嘿,动手不?肯定动手啊...
#
# 计算机，展示电脑工作原理，尝试使用软件方式/游戏方式实现？ MC的红石电路...等等
#
# ---
# # 20161206 Tuesday
#
# > 有时候很担心,但又好开心,好矛盾啊... T.T
#
# > Westworld S01E10 Shocking...
#
# > 信息安全体系,检查,需要配合与动手,1212?
#
# ---
# #### Books From *classic shell screpting*
# *Learning the UNIX Operating System*
#
# *sed & awk*
#
# *Mastering Regular Expression*
#
# *人类简史* *未来简史* *信息简史*
#
# 一说它极有可能在出版后席卷科技界的朋友圈——毕竟，每隔一段时间，中国互联网界就会集体对一本书产生某种“膜拜”之情，《未来简史》进入“膜拜书单”绝对是大概率事件。何时才有自己对世界的真实想法,有自己的结论...
#
# ---
# #### 如何使用存储过程实现
# 为了可以使用参数来控制返回结果,使用视图是无法实现的,所以我们需要使用存储过程实现,使用参数... 检查一下,然后使用存储过程实现把.
#
# 使用存储过程可能需要使用PLSQL Developer,因此可能要用到tnsnames...我和HHJ的都很难登上,然后使用YZM的就好了,哈哈哈...
#
# Oracle PL SQL Developer Path:  Oracle\product\11.2.0\client_1\network\admin\tnsnames...
#
# 善用工具,善用excel可以提高工作效率;人也是,虽然人不是工具,但是人可以看作工具.
# 查看了一下数据,在sql里面出现了 那个 关键字 就可能要修改为使用存储过程实现,这样才能传参数...
#
# From HHJ:
# 1. 搞懂了数据字典,使用数据字典生成table:  create table xxx () ...index tablespace...
# 2. 搞懂mapping,生成正确的 select xxx from xxx join xxx where... group by... having... 开发/测试 一步一步做
# 3. 然后去pl/sql developer 里面依葫芦画瓢...
# 4. 测试存储过程...
#
# 尽量自动化,能使用工具程序自身完成就用,减少宝贵的人类时间...
#
# 在PL SQL Developer里面有Procedures入口,然后存储过程,然后调试/测试就好
#
# **PL SQL Developer 也是可以调整字体背景的** 开发人员的眼睛啊...
#
# TOOLS >> PREFERENCES >> USER INTERFACE >> FONTS
#
# 菜单栏->Tools(工具)->Preferences(首选项)->User InterFace(用户界面）->Fonts(字体)
#
# **DataStudio也是可以配色的,只是也是一般般,没有特别用户友好,或者没有用户来贡献配色,导致使用不方便/单调**
#
# ---
# #### Excel 的宏编程 应该要比公式来得更加强大
#
# 可是不想用excel来宏编程,但是对他们公司的效率又实在不能忍了, Python来吧...哈哈哈,使用百度来的资料的确会快,但是不够深入,不够专业,更多是个人博客加工过的文章,学习快,但是学得不够深,google来的资料/源文档,枯燥,但是更专业,更考验人. 三轮车很好学,但是不能一直骑三轮车吧?
#
# HQ的问题,在创建存储过程的时候,自己写好的select,insert的都没有问题,但是放进存储过程之后,一直显示无效,红色xx,问题可能是引用表名的时候使用了Schema.Table的标定/限定方式而导致的.
#
# 我的Python输入输出还不是特别熟练,编码太少拉...
#
# windows下python打开中文路径文件出现问题,中文路径,中文编码,这东西都不容易啊...[熟悉熟悉呗](https://my.oschina.net/letiantian/blog/224218)
#
# Python read xls and write create table statement is not yet finished, need to go back. Listen to her voice...
#
# ---
# # 20161207 Wednesday
#
# > 所有的相遇都是久别重逢 -- 你的名字
#
# > 她又漂亮又聪明,可是我好平凡,担心Hold不住啦...How far can I go?
#
# > Current algorithm is smart, but not smart enough.
#
# > 以前喜欢一个人,现在喜欢一个人...
#
# ---
# #### Python list 字符串 使用join就能很好解决拼接问题
# 问题在于这个 " ".join(list) 里面是不仅能放单个字符,例如"," "." 等等的,还可是放字符串的 ",\n"... 动手的时间太少啦...
#
# **Think & Practise... You have work both... To stay alive, stay young.**
#
# ---
# #### Anti Virus Software in Linux... Why you have to do this...
# [Intro](http://www.linuxidc.com/Linux/2016-08/134610.htm)
#
# #### PL SQL Developer 很好很强大,但是需要学习
# 动手去做... 执行存储过程之后,要注意存储过程的输出...存储过程输出报错,注意是不是违反约束,主键约束,是不是你的select语句出现了问题,或者join而导致的数据发散,从而导致了主键约束...
#
# ---
# #### [闲花照水录](http://blog.donews.com/sunnyliang/)
# 名人博客,如何像他们一样厉害...
#
# ---
# Walk with you... I really enjoy being with you... You are so beautiful and lovely... I am still learning...
#
# ---
# # 20161208 Thursday
#
# > You know, I will never hurt you. 但是要把我绑在家里,你想干什么,什么鬼,好口怕...
#
# > 喜欢就会放肆,但爱就是克制...
#
# > 演绎 与 归纳
#
# > 早上喝点红茶,不会太困拉...不然又要被LD点名了...
#
# > **Think, Stay Young, Stay Hungry, Say No To Them.**
#
# > 任菇凉还没去过白云山? 嘿嘿嘿~~
#
# > https://www.gitbook.com/ 有趣的网站,它跟Git是什么关系诶?
#
# ---
# #### AI/ML/DL DataMining, Predicting
#
# ---
# #### 互联网金融的争夺战至少要几年后才能看出端倪。现在的领跑者只是暂时领先，好戏还在后面。
# [多看文章,多写文字](http://maomaobear.baijia.baidu.com/article/713905)...You have many tasks to do, please do not give up so easily.
#
# 在互联网时代，传统金融机构在运营模式上依然领先，但金融的变革仍需要技术创新。银行的后台数据已经有计算机处理，但是前台接柜的柜员依然在干着100年前，200年前银行柜员相同的工作。银行对大部分客户一无所知，除了征信系统，银行的所有信息依然依赖于用户填写的各种表格。银行对客户的授信来自于管理人员对用户填写信息的判断与验证，客户经理，层层审批的管理人员都为之耗费大量精力。一些金融机构甚至要在街头巷尾摆摊，如同街头小贩一样推销理财，保险产品来获客。
#
# 如何利用新技术来带来变革?银行只有自己的内部数据,内部数据库,但是还可以利用其他外部的数据信息,融合这些信息,银行就可以对客户更加深入的了解,就可以更好更高效地营销,决策...
#
# 淘宝的支付需求产生支付宝，然后支付宝沉淀资金的需求产生余额宝。
#
# 淘宝和阿里巴巴的商户有资金需求，产生小额贷款业务。淘宝的用户有消费信贷需求，产生花呗、借呗这种小额消费贷款。现在支付宝几乎是半强制的让用户购物必用花呗，这样商家就要支付一笔手续费。阿里的金融日子很好过。
#
# ---
# #### Find Good [Haskell Website](http://fleurer-lee.com/lyah/introduction.htm)
#
# ---
# #### 电子签章
# How things function?
#
# 不是要自动化的吗? 换个思路,换个角度,可以看到我们的流程,都是他们主动发起生成文档,然后走流程,文档的格式由他们指定,导致很难结构化/格式化,因此我们需要的是把文档格式的主动权收回来,他们根据自己的需求使用我们的系统点击生成需求文档,然后这些数据就能很好格式化,然后文档走流程,但是实际数据其实在系统中,而不是在文档中,这样当文档到达之后,只需要读取系统结构化数据,然后执行就好了,减去了让机器识别各种格式的自然语言的文档,这样的思路其实可以适用到许多系统中,也算是一个框架吗?可以做一个统一的平台,然后新增系统/新增任务可以非常简单,然后就能大大减少人类的体力劳动了...
#
# 可以画流程图,等等,的图来扶助理解,辅助编码,系统应该尽量简单好用,足够简单,足够好用.需要有很好的系统分析,需求分析能力. 也许刚开始写出一个复制系统很麻烦,但是根据那几本书的模式,写个简单的系统,原型,简单好用就好了,迭代迭代出更好的产品也行...
#
# ---
# #### 写小程序来提醒自己要干什么
# 譬如定时扫一下自己的待办,自己的出勤情况等待,就是使用程序来替代我日常需要做的任务,这样又能解放我的生产力,又不用怕我会忘记了...
#
# Google的阴影效果,有立体的感觉,好真实好漂亮...
#
# 可以调整PL/SQL的布局,使得程序更加人性化,更加好用.
#
# ![LittleBird](http://fleurer-lee.com/lyah/img/bird.png)
#
# ---
# #### Haskell 资料
# Haskell 趣学指南 [公开课](https://courses.edx.org/courses/course-v1:DelftX+FP101x+3T2015/courseware/8049e2e3f2b44c7e874497b73908de49/c136e207fcc4430e8d55afbb4c40be29/) [Github](https://github.com/fptudelft/FP101x-Content-2015)
#
# The world is a wonderful place, isn't it?
#
# ---
# # 20161209 Friday
#
# > [神奇又好玩的Jupyter](https://www.zhihu.com/question/37490497)
#
# > 如何修改Jupyter代码,使得修改文件排序方式...
#
# > It has been a long week. It's my fault..
#
# > Stay young, Stay simple.
#
# > 为啥她会发现我在上Bilibili....什么鬼啊,在办公室一周就周五这个时间上...好心塞啊 = .=
#
# ---
# 我觉得年轻人有很多优点：做事不设条条框框，没有太多自我要维护，经常能打破常规，非常努力、不妥协、不圆滑世故。
#
# 10年过去了，有的年轻人，依然保持着这些很好的特质。我觉得这就算“Stay young”。
#
# “Stay young”的人基本没有到天花板，一直保持着自我的成长。相反，很多人毕业后提高了技能，但到一个天花板后，就不再成长了。
#
# 海边的曼彻斯特： 我们都曾深陷泥潭,片中角色或多或少都曾经挣扎于痛苦的泥潭之中，他们有的深陷，有的逃离，但一样的是，都带着一身泥泞，继续前行。
#
# ---
# #### How To Solve The Information Security?
# 使用不同的实现方式, 外在都是一样的,但是内在实现是完全不一样的,因此需要的Hide Myself, and Reveal Themself...来达到我们的目的.
#
# 其实只看系统的外部,不打开系统来观察,深入了解,是很难认识到藏在内部的珍宝...就像设计一样,只有你打开机箱,才发现设计的人已经考虑到许多扩展的情况,对用户非常友好,细节都考虑到了,能用到得心应手...
#
# 如何部署啊,自己安装系统,安装环境好坑跌啊... 部署,从0开始的,这样就大大减少人类重复劳动了...难怪docker的概念那么火.
#
# 安装Win7,忘记格式化了硬盘分区,因此进入系统之后要到 管理 - 系统磁盘管理 - 格式化 - 然后添加盘符 - 就可以正常使用了
#
# 很久没有装系统了,心累啊,好烦啊...新机器,新系统,要装各种驱动,好麻烦啊,有新的解决方案码? 就是UEFI能解决吗?让硬件自带驱动了...不用重新装个系统就各种驱动下,各种安装...虽然又驱动精灵/驱动人生等等解决方案...可以有更好的通用/开源/公共/协议好的解决方案吗?
#
# ---
# # 20161211 Sunday Windy
#
# > Be with you. I feel myself. I feel love...
#
# > 遇上你，也许真的花上所有运气啦～希望我们能走好远好远...
#
# > 我真的不怎么会哄妹子。。。抱着她真的好开心，她好轻，我要多练力量才行。。。。。
#
# > This weekend, let go back to where we start college life...原来任菇凉也会害羞的，哈哈哈，她还是很可爱，有点像个长大了的小萝莉。。。
#
# > She is just like drugs. I could not resist... May we rest in a long deep dreamless slumber.
#
# > 抱着你就真的好开心了， I want to hug you as long as I can, I won't get tired of it, will you?
