# %% [markdown]
# > Svn 提交失败。。。
#
# 在整合完文档之后，要把过程文档提交到svn上面，可能是版本高1.9.4的问题，点击commit就程序崩溃了，正在换成1.8版本的svn.
# **更换成1.8.9**后成功commit...
#
# ---
# 代码转换，代码标准化，针对源数据字典，对于字段值（varchar(1),int）等，值为代码的字段，新增标准化已经相应的转换代码，增加到数据库。(转换到统一的代码，整个数据平台使用统一套代码规范 )
#
# ---
# 20160920 会议小记录, csv/comma seperate values
#
# SVN -> 文档 规范 / 如何多人合作完成xls等文件的编辑，svn能管理好xls等二进制文件吗？
#
# 需求 -> 实现 -> 测试
#
# 源数据数据 -> 接入 数据平台 -> 提供数据
#
# | STA | SDM | FDM |
#
# 自己去源数据环境 了解/分析
#
# 什么是SOA?
#
# ?? SVN 对于二进制文集，先update，修改先Getlock?...
#
# 写文档/配置，然后自动生成代码执行，不需要写多少代码？ 自动化工具
#
# （行很多/重复的 -》 宽表）
#
# 拉链算法，抽取后是贴源的，与源系统一模一样， 数据平台/基础平台 如何保留历史 /快照/拉链， 程序其实能自动理解了？）
#
# 分词，自动分词，替换，词根，如何统一去表示/统一标准;  开户行|行号 => oact_bank_num， | 人为分词标记，如何让机器自动完成，机器自动完成得更好？
#
# 使用数据服务层 对外统一提供数据，与外围程序打交道，区分好系统边界，什么是平台内部的任务，什么是平台之上应用的任务; 什么是数据服务层。
#
# ---
# SDM 层设计， 5个文档+1个程序: STA也要更新那个 备注 + 状态
# - 代码标准化，针对源数据字典，对于字段值为代码的字段，新增标准化已经相应的转换代码，添加到数据库;
# - 完成 SDM层数据字典/ 这个SDM层的数据字典，用来描述SDM中数据库中的表，数据库中的表应该是按照整理规则规范化，与STA的有区别了;（有了数据字典，可以到数据库建表，自动化建表）
# - 完成 Mapping/ 这个Mapping意思是从STA中的落地文件到SDM数据库表的映射关系，在这一层需要做T，转换/标准化
# - 完成 DS 作业开发测试，
# - 完成作业信息表
# - 完成索引信息表
#
# SDM中有主键的才索引，其他普通索引就抛弃了，现在已经与源分割开了...
#
# STA层检测编码，根据编码的说明给出STA层的编码,由于是源的编码，多点也没问题。。STA层的数据字典  | 搞定后在SDM数据字典统一编码
#
# #### 小技巧：在DataStudio 可以在左边Servers直接输入表名，可以直接找到表了。。不用上拉下翻。。。
#
#
# ---
# 什么是真实，什么虚假，如何判别？
#
# 从全民炒股，到全民炒房现象的上演，还是离不开资金逐利的现象。但是，当某一领域的投机色彩过于浓厚，乃至达到了疯狂的状态，则往往预示着风险的来临。
#
# 不过，纵观多年来，国内疯狂的房地产市场，似乎给人带来一种“只会上涨，不会下跌”的错觉，而在“越调控越上涨”的怪象下，房价的过度投机现象却依旧显著，其投机性质已远远超越其本身的价值。不过，退一步来说，对于国内狂热的房地产市场，如果其投机现象持续过浓，且货币政策得以形成拐点，加之地方对其真实态度发生转向，则对于严重透支其本身价值的东西，终究还是会有一个价值回归的过程。 价值总会回归吗？
