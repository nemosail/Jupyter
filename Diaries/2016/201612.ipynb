# %% [markdown]
# # 20161212 Monday
#
# > Can't sleep, I have so many things to say. But whenever I meet you, my mind just go blank.
#
# > If I were a book, 那肯定有嬉笑怒骂, 酸甜苦辣, 绝望过, 渴望过, 也哭也笑过...这才是人生麽? 慢慢翻阅,再决策也没问题的. I will always 尊重你的决定的,哈. I will always be there waiting for you... 记得有问题一定要跟我说啊，不要藏在心底里，要听我的解释，我是理性的喵，做事情，做决定都是有理由有原因的，如果上次我说I kissed other时候你跑了，不听完我的解释，估计就要出大事了，又要上头条新闻了= .=
#
# > 如何才能平静,温和而又深邃...?
#
# > 就像密室逃脱, At the right time, At the right place, with approriate items, they become the key to unlock my secrets. 你就能解锁我仅剩的秘密. Hints:a picture, then I will tell you about my grown up, my family, parents, sisters, my fundations, my basic rules, why I behave like this, become like this. Life is not easy, it never is, it is heavy somehow but stay alive, stay young.
#
# > Glad that I talked with my parents. They make too many mistaks at small problems, but always right at the big ones. You have to be confident, be yourself. How can you love someone if you can't be yourself or love yourself? No matter what happens, what is there is still there. LOST: what happened happened. But the future is not yet set, be bold and move on, don't be afraid of making mistakes. Human evolve by making mistakes, no one is faultless. We learn fastest when we are terribly wrong. Observe, read, learn, write, program. Take back the future.
#
# > 看来任菇凉还不懂得如何读GitHub, teach you next time...
#
# > Like what happens in the WestWorld, when you say 'Analysis Mode', you can ask questions, I will answer them as honest as I can.[Source](http://westworld.wikia.com/wiki/Analysis_Mode)
#
# > Are you going to 投毒 me? 什么鬼啊,好可怕,你这个疯子...
#
# > 始于个人魅力,陷于才华,忠于人品. Views From MS. RongRong... 如何才能提升个人魅力啊啊啊啊 T.T 我也要当疯子...
#
# > 偶真的很单纯,很不做作,不是什么妖艳贱货. Please Please don't lie to me or hurt me. Promise me.
#
# ---
# #### 兔子又发观察卫星,各种各样的卫星...
# 有这么多好用的卫星,好多的数据渠道,兔子可以利用这些来增强自己的硬实力,也又软实力等等,不要那么天真那么笨,对待他们就应该要有套路,有兵法.如何获得这些原始的观测数据,还有市面上的物价数据,各类属性/指标等等数据?有人专门收集这些数据吗?只知道Wind就是收集数据/整理数据/提供接口这个商业模式,但是我们能用集体智慧编程的思维,互联网思维,社交化/共享经济的思路,开源/机器/自动/大家共同提供数据成为一种新的开放数据互联解决方案,提供平台,用户提供数据等等,有了足够的原始数据,充足数据,就可以做很多很有趣的事情了. 从IT到DT,如何改变世界,利用这些数据来改变观念,改变看法,负责任的,有远见的LD,因为又更多更高层的视觉与自信/数据,因此可以看得更远更准. GA抓人,落网,思考,其实也是利用数据,分析问题,利用用户特征就应该能够很好分辨,这是个分类问题,离群点分析问题,自动归类/打标签问题,这些都是AI/ML能很好解决,很好提高效率,释放人类的问题,多想多看,当然聪明的家伙也是可以反分辨的,这是个攻防问题,肯定有论文拉...(If you don't know what tuzi or baitouying is, I can send you one...)
#
# ---
# #### Get OFO or 小黄车
#
# #### Python 网络编程, 用python来接入面向人类的接口,解决自动化问题,这样做虽然可以,但是好烦~机器什么时候才能像人一样聪明.
#
# ---
# #### 禅道
# 应该是一个工具,来控制开发,记录问题,修改问题的地方吗. Just Google IT.
#
# 收拾手头上的开发工作,准备介入禅道ZenTao,数据测试,等等流程,都不难,走完这个流程把. T应该是我们可以修改的,D应该是不能修改的,D涉及好多模型设计ER模型,各种范式考虑等等,但是T应该是跟着D来的,为什么呢?不要知其然,还要知其所以然...
#
# SVN装完之后真的不出现在右键上面, 在svn setting - icon layout 点击了那个什么only directory - 然后重启电脑就出现了...seems solved.
#
# **禅道的学习使用:**
# 左上角的Bug GO?就可以找到所有的bug,可以去解决了,虽然不一定是指派给你的.但是应该尽量分工合作,提高效率,减少重复劳动把.
#
# 项目管理系统,开发管理,流程管理,测试管理,bug管理等等...
#
# 有时候只能得到表的中文名,表的英文名,这是一个key-key 一一对应的关系, 肯定可以简单快速实现的,直接一个kev-value对就搞定了...这个小功能应该很快把,这样得到其中一个就能快速得到所有的相关的数据信息...这就是真正的用户需求..! Let our program more smart, more user-friendly.
#
# 分析模型,开发&单元测试,后面实际测试...
#
# 需要有数据,数据正常,测试通过,**先搞懂你在干什么,怎样干,为什么这样干,都搞懂就好办了**
#
# 在禅道上 测试 - bugs - 就能看到项目目前的bugs情况,然后可以选择一个bug指派给自己,这样就不会发生重叠性工作,然后根据bugs情况去修改,修改了的sql/文档/表结构等等信息需要记录在txt/excel上...
#
# 其实这个应该就像项目管理软件一样,都是一些列的原子性操作,应该使用软件自动化来管理来解决,像Miss Ren说的一样,你不能指望没个人都是特别勤奋/准确,要用管理的角度来控制/发挥他们的能力,而不能让他们自发懒散执行,这样结果往往不是局部/全局最优的.
#
# ---
# #### Jupyter 上如何使用VIM插件啊
# 有vim插件,我就可以上天了....Try to solve it. Man!!!
#
# Anyway, RTX sucks...
#
# **要善于观察,善于利用,善于个性化...Say No To Them,这样才能改变自己,不要平庸,才能改变世界**
#
# ---
# #### 任何一个公司内部的软件仓库
# 如果都是简单使用ftp或者共享文件夹或者共享数据的方式向内提供软件服务,都是简单粗暴不负责任的,应该使用一套管理软件等等的方式来管理啊,特别是到了大数据时代了,分布式平台,分布式文件系统时代了,不能落下了,使用一套软件来管理这些软件,就查找,版本管理,各种东西都能自动化,智能化,这样的工作才是让人满意的啊...不然都人类来维持维护,好累~
#
# ---
# #### 测试人员反馈Bugs
# 然后选中bugs,把这个bugs的原因找出来,然后就好办了...又是数据出现空值问题, A表有数据, B表也是有数据的, A表join B表之后,就空了,肯定的是join连接失败,连接不上; 但是为什么了,可能是 关联键 真的没有相同的值, 二就是可能有值,但是尾部或者头部空格导致了问题的发生. 这个跟DataStage的有关系吗?
#
# 尝试解决问题, 看看是不是关联键真的不对应,还是空格为问题, order by一下也许就能解决了...
#
# 其实就是 select 字段 where order by 两个表,然后对比下是不是有相同数据的出现, 正常情况下应该是有一样的key的,这样应该是可以连起来的,但是仔细看源数据,类型 od 直接查看它存储的数据,发现是多了' '空格的,空格不容易肉眼看见,但是使用od直接看ASCII数字,就知道比较起来就会不一样,导致无法连接, An old trick from an old friend. You guys still leave it there?想办法解决啊...我去呢...
#
# 停下来看看,我在干什么? 知道有Bugs了,解决这个bugs的套路应该是差不多的,因此我们可以设计实现程序来自动找到bugs吧,这样不用每次都要我动手写sql查询,程序使用我的思路/套路来尝试解决问题就好了,找不到我再另外花时间/精力去解决问题,对吧? We have the responsibility to change our self, our world.
#
# ---
# #### 业界更普遍的观点，是把人工智能分为三种：弱人工智能、强人工智能，以及超人工智能。
#
# ---
# # 20161213 Tuesday
#
# > She keeps peeking my diaries...宝宝心里苦啊 =. =
#
# > Small secret failed this time... Things didn't happen the way I expected... T.T
#
# > 越来越喜欢跟她呆在一起怎么办,就像毒品诶~~
#
# > 在最好的时光遇到了最好的人,How can I give up so easily?
#
# > Gini Index In Economy VS Gini Impurity In Machine Learning
#
# ---
# #### 应该可以写个存储过程/程序
# 实现我的简单需求,就是给定一个名字xxx_xxx_xxx的形式,我不知道它是 视图 表 存储过程 ; 希望程序能够自动帮我判断,而不是每一次都是我自己手工去查询,这是小工具的范畴,应该是简单的.
#
# ```
# select * from user_tables where table_name = 'xxx'; #查询这个名字是不是属于表格的
#
# select * from user_views where view_name = 'xxx' ;  #查询这个名字是不是属于视图
#
# select * from user_procedures where procedure_name = 'xxx' ; #查询这个名字是不是属于存储过程
# ```
#
# Bug提出的问题算是找到了, 目标表的几个字段出现全为空白null的现象,原因是目标表由主表 left join 其他表而来,如果on的条件连不上,肯定就会出现null,连不上的原因是尾部有空格,没有做好去空格导致的,临时解决方案是在join on的时候trim()掉空格试试,毕竟是视图,比较容易.
#
# Oracle有 ltrim() rtrim() trim()函数的啊...?
#
# 默认情况下trim()会同时删除字符串前后出现的空格。
#
# trim()完之后还是出现了很多null, 因为 from 后面有好多 inner join, left join 这样子,而且on 后面跟了许多条件,导致可能链接不上,一层一层排查把...
#
# 原来的问题是尾部有空格导致链接不上,然后现在是 日期没有相同的导致无法连上...
#
# 简单粗暴的方式就是 update table set date = 'xx' where date = 'yyy' 修改辅表的日期,让他们链接起来,但是这样手工修改数据,对吗?要是以后出了什么问题,怎么办?
#
# 为什么我在何时的场合,合适的环境,就能想起好多东西,能够说很多东西,可能这些是关联记忆吧,就是不像计算机一样可以单独独立存储一样事情,这样简单可控,但是关联方式存储的时候,关系复杂不好分析,但是用起来却很有优势,这也许还是Human这神奇的秘密把?
#
# 在开发环境可以改数据,改表等等,先不用同步到测试环境,反正他们也没有好的工具来同步开发环境和测试环境,导致初始肯定是一致的测试环境和开发环境,在热力学第二定律自然作用下,肯定divert越来越大,熵也越来与大,距离/差别也会越来越大拉.
#
# 为什么有时候 Comment ON VIEW 可以,有时候 Comment ON TABLE 才行,是Datastudio 和 PL/SQL developer的细微区别吗,毕竟各种软件的实现是有细微区别的,不是统一规范下的区别在使用的时候就会慢慢体现出来,代码无法直接跨越各种软件执行..
#
# DataStudio的SQL美化功能很久没有用过了,虽然它自带的美化功能不是特别强大, 但是还是可以的拉...
#
# 在数据库中的 CHAR(10) 和 VARCHAR(10) 和 VARCHAR2(10) 它们的差别在哪里? CHAR(10)是当插入的字符串长度不够10字节时候,那么会自动在后面放入' '空格吗? GOOGLE IT.
#
#
# **动手做过一段时间之后,就能知道禅道的用法了,就是项目里面各个成员交流管理渠道...当然测试bugs只是项目的一个环节**
#
# 提出Bugs的礼貌,方式:
# - 你的程序出Bugs了,程序员:天杀的怎么可能,你会不会用我的程序啊,我的程序怎么可能出bugs?
# - 你的程序在xx输入情况下输出有点不符合预期诶?程序员:我去,我的程序出bugs了,我去改改改...
#
# 同样的问题,换种说法,事情就好办多了,其实就是掌握好人性的弱点,洞察人心...或者经历过,嘿嘿嘿
#
# T是落地成文件,然后为什么是这样子的流程,这样子的行为啊? 框架这样设计的理念是? 健壮Robust的框架才是正解啊. 我们也有许多系统的数据,如何设计范式/ER模型来保存这些数据,日后可以使用这些数据来做有趣的研发?
#
# 开发视图 - 测试视图 - 落地 - 检查 - bugs反馈 - 修复bugs - 检查库 - 落地 - 提交bugs  大概流程,这样也很长很复制啊啊,虽然使用了禅道来处理,还是一点点麻烦啊...
#
# **既然又excel表格那么很简单了,使用python程序读取xls就可以让他自动执行需要执行的程序,关键就是正确,不出错...如何使用python远程连接到服务器,然后在服务器上执行我需要执行的命令,觉得这个很好用啊,因为不用人为去打开程序做各种细节,我就需要给出表名等等参数就ok了,对吧?**
#
# 走流程,肯定是并行走流程要比串行走流程来得快拉.看看现在的解决方案,写文档-提交-审核-执行,没有用系统/平台来管理,效率低,不要用,需要花费大量人力物力,这类工作最时候教给机器来完成的,对不?对!
#
#
# ### If we have a good enough, useful enough text xls format/protocal, who is going to use dummy binary xls format??? Put it to RFC or something...
#
# ---
# # 20161214 Wednesday
#
# > Remember. Something only can be stored in your mind. Can't say or write it out. Hide it.
#
# > Arnold: 思维不是金字塔式的自底向上,而是像迷宫样的自外而内. What?
#
# > Learned Gini Index & Gini Impurity... Lots to things that I still need to read, understand, practise.
#
# > 什么样的决策才是好的,如何分析? 货币的时间价值(time value of money),它表达这样的一个观点,即今天100元的价值大于一年后的100元. 投资收益能使现在的钱比以后同样数额的钱更有价值,不过获取这样的投资收益需要有能力.请注意,通货膨胀这一概念与此无关.通货膨胀是我们无法控制的一种外部影响,而投资和采购决策是我们能够控制.计算理解货币的时间价值能够帮助我们在这个方面上做更好的决定.
#
# > It seems each fourteenth has a meaning?
#
# > 我不过像你像他,像那野草野花,绝望着,渴望着,也哭也笑平凡着,,,她居然不知道是歌词~~~
#
# > Next time I meet my classmates or pre-colleges, I can bring you, are you going with me?
#
# > LOST 里 Penny 和 Desmond 常量 始末
#
# ---
# #### 还不太清楚他们是如何工作的
# xls的文档应该是程序执行时候信息的来源,核心,就是这些xls是人工修改好的,然后程序负责执行就好了,问题在于xls是人工设计,有问题时候会导致程序开发失败,或者测试失败,而导致了数据异常,关键是层式设计是为了隔离各个层之间的关联,那个高内聚,低耦合,层与层之间应该尽量不相互影响,这样才达到框架设计的目的,你们达到了吗???
#
# 禅道上的bug有值太大,实际是10,最大是7,这个问题是 要插入的数据字段长度 超出 数据字典设计长度, 但是超出的原因又有很多,居然又是空格!!解决方案,修改视图,加入trim()和CAST()...
#
# SQL美化和规范 有作用的...修改的时候好看很多,用datastudio自带的美化功能吗?
#
# 空格问题困扰了很久啊,在DataStage的使用过程中,是一定会有去空格的过程的,这样的时候,就会没有问题,出了主键本身带有空格?我去...
# Key: '123' and '123 ' 其实在经过去空格的步骤之后,还是会出现问题的,怎么解决,怎么办?
#
#
# ---
# #### 在经济学相关论述中,经常发现他们会使用现金流图来可视化支付过程...
# 其实从数据上看,逻辑上看,已经记录了这个过程,但是使用可视化加工的方式展示给人看,信息整理/利用起来就不一样了.
#
# ---
# # 20161215 Thursday
#
# > 有时候觉得还是不明白,She is beautiful and clever,我不高也不帅,很普通很平凡,不是大众眼中的欧巴,为什么她会看上我...Still Confused.
#
# > “墨菲定律”（Murphy's Law）是这样说的：Anything that can go wrong will go wrong. ：“凡事只要有可能出错，那就一定会出错。”
#
# > Are we eating too hot last night? I am so sorry... I am so stupid... IMSE you know nothing... She is unconfortable... It's my fault. I can not make that kind of mistake again, keep it in mind.
#
# > Like Aronld's Maze in Westworld, you are approaching the center of the maze. Are you sure that you want to know the answer?
#
# > 今天有点不耐烦,心情不是很好,导致表现好糟糕...I don't know what to do. Be active. You can do it...
#
# > 看一个人拥有的多少,不是看他拥有的多少,而是真正拥有的多少...What? I am lost...
#
# > It seems that she has a meeting every Thursday...May be a routine?
#
# ---
# #### 禅道上面项目提出的Bugs...
# 字段又超长了,原因? 从 32 -> 7 的长度转变正常来说会有问题,特别是原来是 char(32) -> varchar(7) char好像一定会占用满它的空间,貌似会自动加入空格?Google it.
#
# 它们做的事情超级多,也超级烂/糟糕,本来不应该是出问题的地方都出问题了,虽然根据墨菲法则,可能出错的地方一定会出错,你们能想办法用数学,用理论,用框架,用程序来保证人们不出错吗,或者尽量减少差错麽? 坑爹啊啊啊
#
# D层的字段相对多,然后T层的字段相对少了,这样的时候,是不是落地的时候也应该要好好注意呢,不能随便select * 把,这样很可能会出问题啊?
# Solutions To This Problem... : 问题就在于D层与T层数据字段不是一样的,也就是他们需要用select field1, field2, field3 这样的落地文件才能正确导入把...
#
# 开发存储过程步骤: 一般带有 日期参数的那种就要使用存储过程了
# 1. 使用我的python程序生成create table的语句就好了,检查下数据类型等等基本问题.
# 2. 根据mapping部分生成select语句,
# 3. 在pl/sql developer生成存储过程,编译
# 4. 测试...
#
# 视图是没有主键约束的,导致出现了主键重复也没有办法自动提示...这个怎么解决?
#
# **Oracle 如何计算当年有多少天 (365/366)**
# ```
# select add_months(trunc(sysdate,'year'), 12) - trunc(sysdate,'year') from dual
#
# ADD_MONTHS(TRUNC(SYSDATE,'YEAR'),12)-TRUNC(SYSDATE,'YEAR')
# ----------------------------------------------------------
# 366
#
# select add_months(trunc(to_date('01-jan-1999'),'year'), 12) - trunc(to_date('01-jan-1999'),'year') from dual
#
#
# ADD_MONTHS(TRUNC(TO_DATE('01-JAN-1999'),'YEAR'),12)-TRUNC(TO_DATE('01-JAN-1999'),'YEAR')
# ----------------------------------------------------------------------------------------
# 365
# ```
#
# Handle registeration, record problem to get data...to test, just write a xls for yourself...
# 觉得我也需要软件来管理我的任务了,比如要干的事情,还没干的事情,等等...最好就是使用txt来的,这样我就不用担心版本管理问题了..
#
# ---
# #### 用Python写一个网页?
# 相当于收藏夹,把常用的网站都放在那里,加入描述信息,因为人类容易记住的是字符串,名字,而不是机器的IP地址/数字,当然这个程序应该足够智能化...
#
# ---
# # 20161216 Friday
#
# > I really don't know how to fix a cellphone.
#
# > Sometimes, I worry. I am so bored, not so funny. I may not be able to make you happy...
#
# > The more I think, the more I realise we have so many difference. I am like three leaves, you are like loong in 'Your Name'. If we can reverse, I may not have any problems, I would have nothing to be afraid of. It is not your fault, it's my problem...
#
# > Big News Again: 双眼皮,大眼睛,皮肤好,身材好的HHJ原来是因为长得帅才招进我们部门我们组的,OMG...哎 =. = 我也想卖身啊,哭晕在厕所..
#
# > TwoStepFromHell:Victory: 我家的狗听了,从它的眼神中看出,它想骑着我去战场... 风中凌乱... 把正常思维倒转过来,笑死我了....
#
# ---
# #### Sometimes I need to collect files from each person
# 简单粗暴的方式是在群里公告个信息,然后让他们发送文件过来,我定时轮询状态,等待他们交完文档,或者在轮询过程中催他们行动; 低效!!! WTF,多浪费人力无力,还得我轮询等待,等待时候不好干其他事情,想想其他解决办法: 建立公共文件加,让他们放到那个文件夹就好了,但是问题只是减少我收集这个步骤,文件命名格式,文件什么时候收集完,这个都是没办法把握的,还是我要定时轮询状态； 如果像其他软件一样加入提示就好了,就是我发起一个收集文件的需求,给出要求/格式,这时候软件自动提示他们去交材料,然后软件轮询状态,有空就提醒没有交的人,不再需要人去参与这个无聊的过程,然后软件检测符合结束条件,就中断一样,通知发起人,这样就能简化流程了...
#
# ---
# #### Some many bugs to fix...
# What are they doing? OMG...
#
# 字段是不是有发散,
# ```
# select count(1) from 主表
#
# select count(1) from 结果表
# ```
# 如果 结果表 数量比主表多,可能是有发散情况了,就是必要条件, 但是结果表<=主表也是可能存在发散的情况,这个就隐藏很深了,只是视图的很难检查主键冲突的情况,如果是表的,那么就好办了...视图的只能想其他办法解决了...
#
# ---
# ####  Are you guys crazy?
# 居然叫我手工去查询100+个表的存在不存在情况,有病啊...程序员的时间好宝贵的好不好,重复的劳动让我来做这是侮辱我好吧,天煞的!!!教计算机教他们做人...O(n)的时间复杂度对于人类是很难的了,对于计算机来说复杂度完全可以接受.
#
# Mission: Use Python to read the xls table and query info from database. 注意错误信息,返回结果可以是csv把,肯定不写xls表...
#
# #### Python 的包管理软件
# python的包管理好重要啊... 我的Anaconda帮我安装了xlrd,但是没有安装cx_Oracle包,于是使用Anaconda解释器的时候能用xlrd但是没有办法使用cx_Oracle,使用普通安装的Python2.7能使用cx_Oracle,但是就无法使用xlrd;解决方案,因此需要的是再安装xlrd,很方便,在官网下载tar.gz包,解压缩,然后在cmd去到对应的路径,然后python setup.py install就应该好了...去测试下.. Pycharm 换成普通的python2.7就能使用了,嘿嘿嘿
#
# ---
# #### 使用Python 写的CSV表格出现乱码,表现不正常了
# 使用因为CSV是特殊的格式,使用文本编辑器就能很好地解释,但是使用excel打开,使用更多功能的时候就会发现不行,格式错乱,乱码,需要修正:
#
# CSV也是一种表格文件，但是它的编码方式默认是ANSI，所以有些旧版本的EXCEL打开时中文就会显示乱码。那么如何解决Excel打开CSV文件乱码呢.
#
# 使用windwos的记事本打开csv文件, 然后 另存为 , 注意保存的时候使用ANSI编码就好了,然后再使用excel打开就好了.
#
# ---
# # 20161217 Saturday
#
# > Overtime today...
#
# > 旋转门的旁边一般都有外开门...Why is this... It has stories and reasons...
#
# ---
# #### Recipe...
# 1. 每个字段值的最大长度,和TDA的数据字段做对比;
# 2. 确定每个字段都有值,没值的说名原因
# 3. 确定主键是唯一的.
#
# 建议可以根据TDA的数据字典,建立临时表,然后插入数据到临时表,看看有没有报错...
#
# 至于存储过程,查看是不是有传入的参数,运行存储过程,然后看看返回码,看看是不是有空值,有主键冲突等等问题,检查结果表格.
#
#
# 检查主键问题很简单的,在数据字典的 主键否 选择筛选,然后选出主键的行,然后复制进去我的检查是否主键重复sql就好了,
# 当然这些小问题,使用小工具就应该很快能够搞定和出结果的,都是靠人工,做几次还好,多做多错...Human makes mistakes, machine doesn't.
#
# ```
# -- 这样查找主键是不是重复是可以的...但是对于字段长度的问题...需要另外修改...
# select pk1,pk2,pk3,count(1)
# from table
# group by pk1,pk2,pk3
# having count(1)
#
# -- 使用python读取它的数据字典,然后就建立临时表,然后select DSM的过去看看是不是成功,由于是表,有主键约束,长度约束,应该就很正确了
# insert into tmp_table
# select *
# from table
#
# -- 或者字段数目不一样,导致不能使用select * 因此需要额外指定顺序,其实这些都是可以使用程序自动化完成的,我去,改变世界啊啊啊..
# insert into tmp_table(xxx,xxx,xxx)
# select xxx,xxx,xxx
# from table
# ```
#
# 思考到这样的时候,在后来修改bugs的时候,也许数据就能正确的,但是这时候往往忘记了更新文档,导致文档与实际又不一致的,对吧,这样的时候怎么把.
#
# ---
# # 20161218 Sunday Walking Around
#
# > Be with you, stay with you, afraid no more...
#
# ---
# 我也许还不是特别会瞎BB的人，但是跟你呆在一起，感觉是做自己，不用特别去做作，跟你在一起好自由，好舒服，我会默默地支持你，相信你，喜欢你的，越了解你，越喜欢你～～～
#
# 手机也许修不好了，但是和你走走，和你去喝喜茶，和你一起经历，一起嬉笑怒骂，好幸运，原来不是阴差阳错，而是命中注定，你在我的手上写了'喜''欢''冯'...哈哈哈...始于颜值，陷于才华，忠于人品，Are we approaching the final step? We will see.
#
# 多跟你拍照才行～～
#
# Two small cats... One with you. One with me.
#
# 平安夜没啥事情干,再看一遍WestWorld,从相遇到相识，从相识到相爱，一路走来，就像梦一场。和三叶和泷一样，都找不知道什么时候开始相爱，也许这就是缘分。它不仅在过去，在现在，也在将来，是两个心有灵犀的人命中注定，而不是阴差阳错。原来所有的相遇都是久别重逢。平安夜发。。修改下，不露骨又有深度，哈哈哈2333
#
# 平安夜, 就看看那西部世界,翻翻书本,但是总觉得怪怪的...subtitle & 0111 0106 0157 0157 0154 0131 0157 0165 012
#
# echo "Hello World" | od -bc
#
# echo "I Await You" | od -bc
#
# Well, you can buy all the material online... for special purpose... Ask the merchant..
#
# ![Picture For This Week](http://image.beekka.com/blog/2015/bg2015051703.jpg)
#
# # 20161219 Monday
#
# > 跟你在一起,生活开始有色彩...↑
#
# > Do something amazing, awesome. [Stay Hungry, Stay Foolish](http://www.ruanyifeng.com/blog/2015/05/stay_hungry_stay_foolish.html).
#
# > Be yourself, always be yourself and free. Don't forget who you were, who you are, who you are going to be. As honest as a compass.
#
# > Promise you, be confident. 蓝色妖姬,不完美的美
#
# > 因为喜欢所以了解,也因为了解所以喜欢.
#
# > Computer Science & Technology usually prefers iterative numerical solution. Because we may not be clever to find out the closed-form solution. But you can, amazing.
#
# > 静若处子，动若脱兔. Can you? Can I? It might be tough, just don't give up.
#
# > 当年你有空了,教你用GitHub写日志啦...这样就不怕丢失数据了,很好,在一起,要很多东西要学,也许很累,累并快乐着吧...
#
# > 只是因为三轮车好学，你就要一辈子骑三轮车吗？” – Douglas Englebart.
#
# > Bring back tripod and buy a small platform...Find some interesting pics, take some interesting pics.
#
# > Why...感觉她神经比较大,或者还在关心她的手机和数据,我故意给点线索给你看我的笔记本秘密的,伤心的是我故意翻开一闪而过的设计你没看到~,庆幸的是你还是喜欢结果,哈哈哈.
#
# > 昨晚我在秋名山输给了一个华工小伙子，他用惯性漂移过弯，他跑的很快，我只看到他有个北校自动化老司机的招牌，如果知道他是谁的话，麻烦你们跟他说一声，礼拜六晚，我还是会在秋名山等他的！
#
# > 她游200米,我800米...什么鬼啊,好可怕!
#
# > 喜欢你，那双眼动人，笑声更迷人...
#
# ---
# #### SQL distinct 的用法
# 默认来说,一般distinct就应后面多列都是distinct了,但是Google英文资料更加靠谱...
#
# Mapping的xls还是很好用的,上面左右的返回按键,但是数据字典的就只有右上角的,不行诶...
#
# 当修改数据字典/mapping等等文档之后,如何同步,通知他们等等? 不应该让人来干这些事情对吧?繁琐,容易出错...版本管理工具可以码?就是提示那部分发生修改了...
#
# 使用更好用,更智能化的浏览器提高效率,把常用的网页地址放在首页,直接点一下就好了,不用那么复制的查找/填写操作.
#
# ---
# # 20161220 Tuesday
#
# > Miss you so much.
#
# > Next time, I might ask a lot of things/reasons when I don't understand.
#
# > I don't know how to describe this feeling, this state.
#
# ---
# #### 写出检查表字段名字,字段类型,字段长度的Python程序
# 这样使用程序就能完成大量的工作了,嘿嘿嘿
#
# #### null vs empty string in Oracle
# 空值NULL 和 空字符串 他们的差别是? 他们能比较码?但是null应该只能用 is null 来比较,而不能用其他来比较...
#
# #### 供给侧改革
# 经济增长的三架马车: 投资,出口,消费； 这是经济增长的需求侧,还记中央银行的两个重要职能和对应的两个工具吗,稳经济增长,防范金融危机的发生. 当需求端这个方面已经优化很久了,边际效应下降,也就是函数导数接近0+了,甚至过犹不及,从多变量函数优化的角度看就是往这个方向优化到头了,应该换个方向了,虽然没有理论保证,但是在实际的数值优化中往往能work得很好,对应在经济领域就是换个角度,换个方向去稳经济增长(这样的大国,不稳住经济增长会在怎样?思考后果),那就去另一边:供给侧 去优化把,这个想到与咨讯公司差不多,是领导层的团体分析经济形式得到的解决方案,决策,虽然这些方案不一定成功,一是可能方向错了,而是可能方向对了,决策与执行之间的鸿沟足够不行了...
#
# ---
# # 20161221 Wednesday
#
# > 多花点时间看书啊,傻妹纸,别担心那么多啦,怎么我俩反过来了...
#
# > 感觉我是相对"安全的投资",相对稳定但是收益率低,没有太多的风险溢价...
#
# ---
# #### 在公司机器也搞个Jupyter
# 因为有些信息是无法写在这里的,但是如果做好的会议记录只能放在纸质版上的,会有问题的,纸质版本会丢失呢,那么就在办公机搞个Jupyter+GIT,问题是这些记录的信息要找回来才行啊,就是需要有查找功能...
#
# 对数据库的权限管理要比较严格...给自己限制,给别人限制,的确是为了保护自己保护他人的...dota it.
#
# ---
# #### Oracle 的empty string VS NULL  value
# 看来Oracle里面并没有''空字符串的描述方式,就只有null的记录,当向表插入''空字符串的时候,其实实际上是插入了null值,因此并没有''的存储方式,这时候where field = '' 这样的表达就无法取回行了,只能使用 where field is null的条件上取回行...
# [Source](https://www.techonthenet.com/oracle/questions/empty_null.php)
#
# This is because Oracle has now changed its rules so that empty strings behave as null values.
# It is also important to note that the null value is unique in that you can not use the usual operands (=, <, >, etc) on a null value. Instead, you must use the IS NULL and IS NOT NULL conditions.
#
# ---
# #### 《12大投资谎言》
# “很多成功都可归因于消极策略。大多数投资者都无法抗拒不断买卖的诱惑。”  --沃伦·巴菲特
#
# ---
# #### Haskell
# 在我掌握haskell之前的学习曾经失败过两次，它看起来太不可思议，难以理解。不过随后突然灵光一闪，马上就开窍了，往后的学习也就变得游刃有余。我想说的就是：haskell很棒，如果你喜欢编程，那就得好好学学--尽管在咋一看它可能会显得很别扭--它迫使你换个脑筋思考，很有趣！
#
# ---
# # 20161222 Thursday
#
# > 挽手说梦话...
#
# > 抱得很紧是很因为很喜欢,很舍不得...
#
# > 喜欢就会放肆,但爱就会克制,看来那家伙还没搞懂含义~~~
#
# > 金融公式 数学表达 与 其对应的生活/自然语言/含义 ; 在研究的时候就遇到好多啦,自然语言描述易于人类对事物的了解,感性认识;而对应的数学公式表达是对事物的理性精确描述...它们是关联起来的,一起来理解会容易很多...
#
# ---
# #### Bugs又出现了,我的天啊
# Oracle 的 substr 函数 substr('HelloWorld',,1,5) substr('HelloWorld',0,5) 好像是一样的,查查手册拉
#
# Oracle 的 intersect 求交集.
#
# D和T的顺序不一样,是不是数据落地的时候,使用select * 从而导致的数据错位?
#
# ---
# #### Haskell
# 同一性 和 相等性... 比较上的差别.
#
# 编写一些简单的函数，然后将其组合，形成一个较为复杂的函数，这样可以减少重复工作。就像构建数学世界一样,使用简单的基本公理,然后构建出整个王国.
#
# 它实现的是 “同一性” identity。而非 “相等性” equality
#
# 就像三明治一样，用两个参数将它夹在中央，这被称作中缀函数。而其他大多数不能与数夹在一起的函数则被称作前缀函数。绝大部分函数都是前缀函数，在接下来我们就不多做甄别。大多数命令式编程语言中的函数调用形式通常就是函数名，括号，由逗号分隔的参数表。而在haskell中，函数调用的形式是函数名，空格，空格分隔的参数表。
# ```
# succ(8)
#
# succ 8
# ```
#
# 作为一门交叉学科，机器翻译涉及到认知科学，计算机，信息论，语言学等多学科，其理论路径同样经历了螺旋状上升：从最久远的“翻译备忘录”到后期基于规则，基于实例的机器翻译，再到被视为机器翻译重要转捩点的统计翻译模型（SMT）——后者是科学家初次察觉到通过大数据消弭信息不确定性是攻克“智能”的好办法。
#
# 而最近两年，机器翻译正在拥抱另一个更重要的技术转折点——基于神经网络的机器翻译（NMT：Neural Machine Translation）。
#
# **字典序** Search And Read...
#
# ---
# # 20161223 Friday
#
# > 那不是充分必要的,是既不充分也不必要的,只是是PAC,Probably Approximately Correct...
#
# > 许多东西都没有理论保证,可是实践很好,很work,但是如果能追求理论保证,肯定要去做...
#
# > This week if you are interested, I can teach you time complexity... sorting $O(n^2)$ $O(nlogn)$
#
# > Jupyter 写公式也是很漂亮的,貌似支持很多排版工具,譬如Latex...哈哈哈
#
# > 支付宝的 AR/VR 红包模式 “LBS+AR” 尝试了解他,技术,与技术所带来的营销效果,目的,后果等等.
#
# > 要想办法搞定Miss Ren的强盗逻辑 = .= 哈哈哈哈,笑~
#
# > [图灵等价/图灵完备](https://en.wikipedia.org/wiki/Turing_completeness),也就是一切可以计算的问题都可以计算...xls应该不是图灵等价的...
#
# > 计算理论研究什么时候一个问题是可被计算的. PAC学习理论,或者说计算学习理论主要研究的是什么时候一个问题是可被学习的。
#
# ---
# #### 自动化测试,回归测试
# 如何更好地开发,更加自动化,更加智能化,使用自动化测试,回归测试
#
# ---
# #### 程序是可以帮你写藏头诗的...
# How is it done? 如何使用程序写出简单的藏头诗,就是给出我要的语句,然后构建诗句....
#
# 支付宝, AR project, 3 cats, 3 special meaning digits...
#
# 写个Python刷分...估计要出大事... 厚积薄发...
#
# ---
# #### Lots of things to read
# 国务院近日印发《关于激发重点群体活力带动城乡居民增收的实施意见》，要求进一步减轻中等以下收入者税收负担，一直以来个税负担重，免征额比较低的弊病有望这一次得到些许缓解。
#
# 到2020年，城乡居民人均收入比2010年翻一番。意见同时要求，进一步减轻中等以下收入者税收负担，发挥收入调节功能，适当加大对高收入者的税收调节力度，堵塞非正规收入渠道。《意见》里洋洋洒洒说了很多，最重要的一条就是，短期和中期目标要求对年应税所得12万元及以上或者收入来源多元化的纳税人实施综合计征，同时引入差别扣除项目，长期方案则是要建立各个社会管理部门之间的信息自动汇总的机制。换句话说，年收入12万以上的，注意这里是税前收入。将被视为高收入群体，估计这次是重（zai）点（jie）调（nan）节（tao）对象。看到12万元就算高收入了，跟之前几百乃至上千万的房子被抢购一空的新闻对着看，有一种懵逼的感觉，这真的是同一个国家？
#
# 宏观税负 -- seen many times.
#
# 社交网络是去中心化的，它是对真实生活的模拟和追赶，选民更喜欢真实的即使粗糙即使有缺点的活生生的总统。
#
# How to catch the uncatchable fish? -- Big Fish 好电影啊,好想重温一次...
#
# If somebody says "my new thing is Turing Complete" that means in principle (although often not in practice) it could be used to solve any computation problem.
#
# 在可计算理论里，一个数据操作规则的系统（比如：指令集、编程语言、细胞自动机）被称作图灵完备或者通用计算的，当且仅当它可以被用来模拟单带图灵机。
#
# 在可计算理论里，有一个很相关的概念叫图灵等价。当计算机 P 和计算机 Q 是图灵等价的，当P可以模拟Q而且Q也可以模拟P。因此，一个图灵完备的系统可以模拟图灵机，但是这个术语（即图灵等价）常常被用来指与图灵机等价。
#
# 图灵等价有两个意思，一个是指两个计算系统在可计算性上计算能力相同；另一个，也是常用的一个就是指一个系统的计算能力与通用图灵机计算能力相同（在可计算性的意义上）。而图灵完备是指能够模拟通用图灵机的计算系统。而所有已知的图灵完备的系统都是图灵等价的，这也增加了对丘奇-图灵论题的支持。因此，在现有的计算机系统（编程语言、指令集等）上，使用图灵等价和图灵完备是一个意思。
#
# **可计算理论**:其实很多理论往往都是在实践的时候它就会若隐若现地浮现,只是有没有心和能力去跳出自己的循环,观察自己所遇到的问题,找出隐藏的理论,写代码解决问题多了,可计算问题会自然而然地冒出来,多思考,多问问题就会得到同样根基->这个问题的理论...不变的部分...
#
# 一般概念上图灵不完备指的是计算能力不如图灵机的。当然也存在计算能力可能更高的，比如说非确定图灵机。但是到底高多少，还是本质是一样的。应该没人知道，这也就是P和NP的问题。
#
# ---
# # 20161224 Saturday Christmas eve...
#
# > Merry Christmas.
#
# > Desmond called Peneloped on 12.24 Christmas eve.
#
# > 其实不是不想抱着你啦，可能是我真的是太理性，7年来学习/锻炼/习惯/或者已经作为基本准则了T.T，太不了解妹子了，当你说嘴唇干燥，不适合～的时候，我是当真的，而且走在总行附近，我自然反映就是和她在这附近要克制～，要矜持～，之前她提到过的啊。。。然后送你到楼下了，你问我应该说什么，我当时候就懵了，圣诞节是明后天，还没算到～，还有其他东西我忘了吗？我快速寻找我是不是错过了什么东西，不过好像没有诶！快要超时了，赶紧回答了：喜欢你 这个简单有效的说法。。。可是feel到她一丝丝的不开心，看到她脸上一闪而过的失落，啊啊啊...为什么碰到任菇凉就运转不过来了啊。。。
#
# > 以后发现宝宝累了，别说话，抱住她，亲她～～～
#
# > 我说话比较少，比较谨慎，也许是这些年来的经历，写论文/做Report，不能瞎BB啊，说话做事尽量要有理有据，把事物原理了解透彻了才可挺直腰杆，说话才有底气。所以我很少轻易答应别人，因为我会思考下，我能不能90+%来完成，一旦答应了，一般都会做到，不是随口说出来骗你哄你的，它们会实现，只是要点时间。有时候你发现我有点迟疑，犹豫，那么大概可以知道我在思考运算，在评估结果了。。。
#
# > 在见到她之前，纵然有千言万语要说，可是见到她就又一片空白了，想好的东西全都消失了，What does that mean?
#
# ---
# # 20161225 Sunday Merry Christmas
#
# > 因为我的没有考虑全步骤，对长期没有更好的认识，导致犯了个错误。。。Don't make that kind of mistake again. Anyway, figure out a way to fix it.不能太按部就班，许多事情可以改变的，改变下思路，找找解决方案。。。
#
# > PS. 移动的139邮箱还是挺好用的，可以使用139提供的许多服务，例如：发短信等等。。。其实这些都不难实现，难的想到可以这样做，与这样做的理由/价值。
#
# ![NicePicForHer](http://a.hiphotos.baidu.com/news/w%3D638/sign=322fd8fb05f431adbcd2403a7337ac0f/9c16fdfaaf51f3de3417840d9deef01f3a297935.jpg)
#
# # 20161226 Monday
#
# > You are already in my world. 上面的图片不错，你喜欢不，我们去拍照把～
#
# > 那个,我的复式记帐法还没搞懂,什么期初借方,期初贷方,发生额,期末等等的...
#
# > 生活也要有仪式感,恰如其分,叶公好龙... 你是我的镜像吗?
#
# > 我的办公机需要类似Markdown的功能,不想使用word了,我受够了world/xls了,虽然他们挺好用,但是见识过更好用的工具,就曾经沧海难为水,除却巫山不是云...
#
# > 从字里行间认识你,了解你,喜欢你...
#
# > 我们要的不是相对论，而是诞生相对论的那个大脑。我们要的不是金蛋，而是下金蛋的那只鸡。
#
# > 送给你的礼物,希望TA能够成为你的常量,不要再迷茫迷失...
#
# > 基本准则是持证上岗,安全行驶,No Accident~ 一般来内部的锁都是建议锁,而不是强制锁...
#
# > “人是目的,而非工具“ -- 康德（1724-1804）强调人不应该像物一样被用作工具或手段,而应该被视为目的. 原文："除了上帝之外,人是至高无上的；人是我们生活的全部目的,人就是目的." 原来是有出处的,难怪是自然而然从脑子里面冒出来,多看书,多看书.
#
# > You are my princess...忒喜欢像任菇凉那样很单纯很不做作的妹子...
#
# > 一个人的成长 就像蝴蝶破茧成蝶 痛苦是注定的 就像一句俏皮话 痛并快乐着 成长也是充满快乐的 青春散发的活力永远是金钱无法买到的 珍惜大好年华 好好把握 相信你会找到自己的快乐 相信自己 脚踏实地 仰望星空 抬头看路 低头拉车 这样的人生才是完整的。
#
# > “什么是小程序：小程序是一种不需要下载安装即可使用的应用，它实现了应用「触手可及」的梦想，用户扫一扫或者搜一下即可打开应用。也体现了「用完即走」的理念，用户不用关心是否安装太多应用的问题。应用将无处不在，随时可用，但又无需安装。” -- 也就是用户更加友好，更加好用，这才是好産品，智能产品...小程序解决的是用户的烦恼，用户的安装APP的烦恼，这个相当于是一个需求，就是用户为了某个功能必须下载-安装-更新-APP的过程，这个过程繁琐，也有副作用，所以是肯定有优化，提升用户体验的机会，这就是机会～
#
# > 所见既所得 -- 门槛低，大众化，用户友好，市场广阔，但是水平则会参差不齐，相对一般
#
# > 所想既所得 -- 门槛高，精英化，学习曲线陡峭，相对高质量专业化制作，水平一般很高， What do you want?
#
# > 辞海 - 大辞海？？
#
# ---
# 不要轻易脱实向虚,找准市场/世界的发展规律.
#
# ---
# 开始学会查询业务请求,注意到ODS/DW的设计理念,要知其然知其所以然,OLAP 与 OLTP 的区别,我们已经脱离源系统,不会对源系统的有影响了...
# 流程是了解查询业务的需求,然后熟悉几大主题,然后数据字典,然后sql,然后验证/测试,给出结果...Done
# 我觉得权限问题一直很严重诶...
#
# ---
# 360的IE浏览器,去掉广告过滤就行了...这样就能正常使用报表页面了,它只是当成广告被屏蔽了,计算算法有问题,不是100%正确分类,犯了混淆矩阵的里面的FP,FN部分...
#
# 产业制造业转型升级,从低端到中端到高端,成本高见效慢的投资,从人口红利到人才红利要好远好远...
#
# 他怎么说其实不是那么重要,重要的是他是怎么做的,才体现他真正的想法,企业家用钱投票，走了，税率就是高。
#
# ---
# # 20161227 Tuesday. It is getting cold.
#
# > 要有直面人生的智慧与勇气.
#
# > 多思考,多想肯定是要的啦,生于忧患,死于安乐嘛,但是过分担忧,想太多,闷闷不乐就不好了~~ 把握好程度啦
#
# > 贪婪求解只得到贪婪意义下的解,不一定是全局最优解,甚至不是局部最优解...
#
# > Remember: We learn fastest when we are badly wrong...
#
# > I really don't know whether she like the present or not...I am still learning...
#
# > 生活也许是一场冰与火之歌的旅行...
#
# > 哭晕在厕所了...说好的双xin,现在只剩下伤心...
#
# > 小问题是会有的,麻烦是会有的,但是相信,生活总会回归正轨...
#
# > 人总会犯错误,机器也会犯错误,但是如果是在学习,在成长,那么随着时间t和经历e的增长,犯错误/函数应该是趋向收敛到常数,而不是发散,那就足够好了,对不?
#
# > 了解挺多,但是常常只能知道问题,找到问题,却无法具体去解决问题...We all do...
#
# > 教她弄弄电脑,弄弄Github,写写日记?有时候能用上好的工具,就会像上瘾了一样,不知道是你在驱动工具去工作,还是工具驱动你去工作一样~
#
# > 和你在一起,不仅仅是为了快乐,更是柏拉图~,一起成长,一起面对...朦胧的美,娓娓道来,而不是一来就太突然了,就像成长是个过程,不能一蹴而就...
#
# > <太空旅客>
#
# > 就像*西部世界*里面提出的问题一样,你现在的行为,你所做的决定,是自由思想的你所做的,还是你的基因所决定的?代码和基因有多相似,是怎样的一样的不一样...My gene tells me to, but my mind tells me not to...
#
# > 许多脏问题都要鼓起勇气,挽起袖子亲自动手去解决的,不能永远干干净净的纯理论派, 理论 与 实践, 科学 与 技术.
#
# ---
# #### Linux ImageMagick Convert [Source](http://justcoding.iteye.com/blog/2022467/)
# 在认识ImageMagick之前，我使用的图像浏览软件是KuickShow，截图软件是KSnapShot，这两款软件都是KDE附带的软件，用起来也是蛮方便的。在一次偶然的机会中，我遇到了ImageMagick，才发现Linux竟然有如此功能强大的图像软件。
#
# 你将会发现，大部分的操作，你只要在终端下动动键盘即可，省得你用鼠标点来点去。
#
# 下面，我对ImageMagick的主要功能做一个简单的介绍，其中覆盖的大都是人们常用的一些功能，如果你要全面的了解它的知识，你可以看看它的man手册。
#
# convert
#
# convert顾名思义就是对图像进行转化，它主要用来对图像进行格式的转化，同时还可以做缩放、剪切、模糊、反转等操作。
#
# ---
# #### 无人潜航器是 AUV（Autonomous Underwater Vehicle，自主式水下交通工具）
# 关键在于 Autonomous, 这个单词在许多书本都提到过了,明显它根AI/ML/DL一样,都是未来的技术方向了...
#
# ---
# #### 斯多葛主义?
#
# 根植在互联网的p2p平台，并未改变金融业的本质，而风控永远是金融业的命门。
#
# 风控与效率的矛盾。
#
# 很多用户去p2p平台借贷，要么是被银行拒绝，要么是嫌弃银行放款太慢。p2p平台审批快，因此，对于p2p平台来说，极速审批，是其竞争优势之一
#
# 在移动互联之后，谁将是新的互联网热点?众多互联网大咖已经给出了答案，那就是AI(人工智能)。移动互联网的时代即将结束，我们将迎来智能互联时代。AI产业从数据、算法、计算能力上都有很大的进展，公众也意识到AI时代快要到来了。各大厂商也纷纷布局人工智能行业，谷歌、facebook以及微软等，都已经提前在人工智能中走在前列。
#
# 互联网每隔一段时间就会诞生一个很火很有将来的概念,从3D打印到大数据,到O2O,到AR/VR,到AI,变化实在很快,有点像信息过载的节奏...
#
# ---
# # 20161228 Wednesday
#
# > New day, New place, New life.
#
# > Taking her home...A little bit nervous..
#
# > 微信小程序貌似接近了,找找资料,这又是一场颠覆或者革命?还是像以外互联网来得快也走的快的事物?
#
# > 微信的收款功能,投票功能,这个可以做好啊,就是群的功能等等...
#
# > 有没有在 单机/集群 上弹性的并发编程语言,类似一次编码,然后到处编译执行的思想,不管具体硬件平台是单机单核,单机多核心,多机多核心的平台上都能很好地工作... 思想 与 实践
#
# > 移动互联网的大潮汹涌而至(不是已经末期,新的风口准备来?)，人与人之间最大局限在于思维模式??
#
# > 确实应该常常跳出自己的循环loop,作为第三方来观察自身的行为,换种思维方式去优化现有的问题,而不是一味地接受这个世界的设定,改变自己,改变世界.
#
# > 不能浅尝辄止,有时间,有精力,则深入了解,持之以恒,贵在坚持嘛.
#
# > 眼见未必为实，Lots of things stay hidden... Treasures stay hidden.
#
# ---
# #### 如何直接从建表SQL或者存储过程中自动分析出使用到的表? 貌似Oracle等等数据库都已经很好地管理了这个拓扑图
# Google it, 貌似是有解决方案的...[Oracle官方有解释这个Schema-Ojbect-tables,views,procedures](https://docs.oracle.com/cd/B28359_01/server.111/b28318/dependencies.htm#CNCPT1859)
#
# **Schema Object Dependencies**
# If the definition of object A references object B, then A depends on B.
# 这应该是一个拓扑图,然后我们要找的就是这个拓扑的结构...深度优先和广度优先
#
#
#
# ---
# #### 为什么都是SQL语句,有时候是需要这个全部大写,才行
# 例如这个sql查询的是给出的视图view或者存储过程procedure直接依赖的表/关系等等,然后可以使用程序自动生成所依赖的所有表
# ```
# select *
# from dba_dependencies
# where owner='xxx' = and name = 'xxxxxxxx'
#
# -- 注意到这里,xxx如果大小写不对,结果不对了,为什么啊啊啊?
# ```
#
# ---
# #### Get Access To Google
# First Priority...
#
# ---
# #### Excel 只保存一个工作表,很简单的
# 在需要单独保存的工作表上右键，弹出菜单选 择移动或复制 ,然后选择 新工作薄...相当于单独保存就好了.
#
# ---
# #### Linux 下可以使用ethtool工具查看网卡的工作状态
# 同一跟网线,使用windows就能上网,使用linux就不行了,为什么啊?以为不是网线的问题,现在换了新的自制网线,就搞定了,是系统底层支持不好的节奏吗?不同在哪里?区别在哪里?
#
# 奇怪,换了网线,但是没有重启电脑,上github,push,pull不了,XX-Net也是无法启动,上不了Google,然后实在是找不理由了,就重启下(重启,果然是简单粗暴,但是那也是无奈的做法),真的是重启之后就改变了,能push/pull,也可以上google了,嘿嘿嘿
#
# ---
# #### Python图表绘制：matplotlib绘图库入门, Google it, Matplotlib & Seaborn 都可以,就用大众都喜欢的吧
#
# matplotlib 是python最著名的绘图库，它提供了一整套和matlab相似的命令API，十分适合交互式地行制图。而且也可以方便地将它作为绘图控件，嵌入GUI应用程序中。
#
# 它的文档相当完备，并且Gallery页面中有上百幅缩略图，打开之后都有源程序。因此如果你需要绘制某种类型的图，只需要在这个页面中浏览/复制/粘贴一下，基本上都能搞定。
#
# 在Linux下比较著名的数据图工具还有gnuplot，这个是免费的，Python有一个包可以调用gnuplot，但是语法比较不习惯，而且画图质量不高。
#
# 而 Matplotlib则比较强：Matlab的语法、python语言、latex的画图质量（还可以使用内嵌的latex引擎绘制的数学公式）。
#
#
# ---
# # 20161229 Thursday
#
# > 注意大部分问题都是你自己的思维约束,不是物理约束,数学约束...
#
# > 规划好,一步一步来吧~ 要准确到精确, 模型清晰,数据准确,逻辑有力~
#
# > 不要因为走得太远而忘记为什么出发,也不要因为未来未知太遥远而畏于前行~
#
# > Docker is not a 镜像,它不是纯粹的数据,而是像元数据,描述如何构建指定的镜像/状态.
#
# ---
# #### Git & Search URL 如何认识URL协议
# 由于原来是这样的, 我的PC机器作为git server的origin, 然后自己机器同时clone,这样进行同步保存,因为设计就是跟其他一起同步的,这个模式没有太多问题.一直以来都工作得很好,但是由于某种原因,IP地址发生变化了,这个时候clone的就无法访问服务器了,导致了错误,在解决中
#
# git remote rm origin && git remote add origin ... ? How to fix the problem.
#
# Note that Git, as well as other DVCSes, use slightly different concepts than centralized SVN or CVS systems. In particular, the normal usage is not to "check out" but to clone a repository, downloading its complete history instead of just the head – in other words, the fact that your server has "gold copies" is only political, and any clone can be used as a "gold copy" easily. This is not very important right now, but worth remembering nevertheless, in particular when you forget to do backups...
#
# Find out what software was used to set up the server – was it Gitolite, Gitosis, or just a custom ssh + git-daemon setup? 启动一个GitServer方法有很多种,注意的是由于是Git是分布式的,它同时是server也同时client,所以不用太特殊的就行,注意它的工作模式.
#
# Git Probelm solve, 由于我用的是 Copssh + Git程序 来搭建我的git分布式版本管理(去中心化一直都会的),一直以来都是自己的PC机器当server,然后自己clone一份工作,搞定了就push过去,登他们都会用上git了就可以完成分布式的版本管理的布局了,很方便的...
#
# 但是出问题了,问题在于我的ip地址发生变化了,是需要做相应的修改才行了,不然就会push失败, 一定要专业,思想要专业[fix by google/stackoverflow](http://stackoverflow.com/questions/10391522/git-does-not-appear-to-be-a-git-repository)
#
# https://segmentfault.com/q/1010000002468937
#
# I will assume you are using ssh to clone your repo.
#
# That means you need the full path of the repo on the server in your ssh address:
#
# git clone ssh://sshuser@serverIP/full/absolute/path/to/my_repo
#
# Note: if your 'my_repo' is a bare one (to allow pushing), that would be:
#
# git clone ssh://sshuser@serverIP/full/absolute/path/to/my_repo.git
#
# The stdin: is not a tty simply means that in the .bashrc of the sshuser account, there is something expecting an input.
#
# **我的实现方式**
# 0. git remote -v #查看当前的remote情况
# 1. git ls-remote
# 2. git remote rm origin #删除旧的remote
# 3. git remote add origin ssh://user@xxx.xxx.xxx.xxx/Home/Xxx.git
# 4. git ls-remote
# 5. git clone/push/pull
#
# ok了...嘿嘿嘿
#
# ---
# #### 数据库 测试环境 生产环境 同步
# 同步这个麻烦的动作应该是使用工具来完成的,不应该个使用人手来完成,人工来做这个问题,也是容易出错的...如何编写自己的SQL来完成同步? 同步,它要充值
#
# #### Oracle 查询某个表的建表语句,很容易的
# ```
# SELECT DBMS_METADATA.GET_DDL('TABLE','TableName')
# FROM DUAL;
# ```
#
# #### 如何自动检查表的数据情况,给出结论,
# count(1) 是不是行记录数目, 或者是不是又空值null,是不是有全空等等,违反约束等等
#
# 如果要获取表、视图、过程的定义。在ORACLE中，可以用下列语句实现：
# ```
# SELECT DBMS_METADATA.GET_DDL('TABLE','TB_TEST') FROM DUAL;
# SELECT DBMS_METADATA.GET_DDL('VIEW','TB_TEST') FROM DUAL;
# SELECT DBMS_METADATA.GET_DDL('PROCEDURE','TB_TEST') FROM DUAL;
# ```
# 当然也不要忘了设置LONG、PAGESIZE和LINESIZE
#
# #### What is a 标签机?
#
# 可以朴素，但是有点仪式感，不能太单调...
#
# ---
# # 20161230 Friday. 2016 is leaving, what have you done? Are you growing?
#
# > 逻辑表示 与 物理表示...
#
# > 调度,资源分配,系统/算法,这个应该也是个大学问...
#
# > 人生也许是一个带约束的最优化问题,代价与成本是离不开的一直要Handle的,数值解与解析解,Keep thinking, Keep Learning.
#
# > Little shu zi, little one can give away, big one can't, because then I can do it at dorm...hahaha
#
# > 许多问题都是01分类问题,分类准确率,FP,FN,混淆矩阵,利用好这个认知,已经好会玩了~
#
# > 办公室可以养些什么比较个性化的花花草草?Google&ZhiHu&TaoBao... T.T
#
# > 要看懂那几大主题,如何分,如何关联,表的数据字典,业务如何关联,事实与维表,**RFC:设计不用excel但是文本形式的格式来保存数据字典**
#
# > 那个数据结构就是一棵树,我知道你一定在这棵树的某一片叶子上,我只要遍历这棵树就行了,Remember:遍历的意思是访问所有的节点,而且每个节点均做一次且仅做一次访问,精确,数学/算法之美... 也许这种形式的美是我一直追求/要求的,也许这也是我仅能追求的了~
#
# > 现在对许多用户来说都是使用工具,就像锤子/刀子一样的,而不是去设计工具,但是对自己要求高点,既要善于利用现有工具,还要有能力去设计出色的工具.
#
# > 跟他们讨论问题,就会发现这类问题是大家共有的,公共的,这就像大家的需求一样,这就像一个市场,如果能够提供很好的解决方案,那就创造了很大的价值了,锻炼自己发现问题,解决问题的能力,动脑与动手~
#
# > 上集群啊,上分布式啊,走向未来,解决这些小问题,不能让这些无关通痒的小问题阻挡我们的步伐,应该走的更深更广,不能止步不前...
#
# > 做人不能走向数轴的两个极端,但是研究做事则需要走向极限,走向极端...What is right, what is wrong? What am I supposed to do? Tell right from wrong...
#
# > “serialization” 串行 "parallelization" 并行；  串行是简单可控的,并行相对复杂涉及同步互斥,但是真实物理世界应该是更趋向与并行,更加高效,更加复杂~ Do be scared...
#
# ---
# #### Win7的新功能
# 睡眠 + 休眠 -> 混合睡眠, 让电脑自动进入休眠,进入关机状态,但是又保存了系统的工作状态,这样启动起来就跟睡眠直接唤醒是一样的,导致非常好用,几乎可以不使用关机的功能了,嘿嘿嘿...结合机器BIOS的计划开机/定时开机功能,那么我晚上离开时候主动/被动让电脑进入休眠状态,然后早上由于有定时开机,又自动恢复得到我的工作状态了,这样在又省电又用户很有好,一直保存好系统的工作状态,不需要额外动手启动程序等等的等待过程,如果是SSD那就更快更好用了,**其实这种这么好的功能/模式,应该好好利用,好好推广**,这是很聪明很有效的做法,这个模式大赞啊,Gnu/Linux貌似还没有??? Dota it.
#
# 数据库数据量太大了怎么办? 索引空间也用了不少,如何解决? 有时候删除数据时候,删除太多行,就会导致超时/溢出而导致回滚,导致日志越来越多问题,如何加入监控规则等待,把它的失败操作来处理...
#
# ---
# #### Learn Python, Learn Banking
# The beauty of an art lies in the message it conveys. At times, reality is not what we see or perceive. The endless efforts from the likes of Vinci and Picasso have tried to bring people closer to the reality using their exceptional artworks on a certain topic/matter.
#
# Data scientists are no less than artists. They make paintings in form of digital visualization (of data) with a motive of manifesting the hidden patterns / insights in it. It is even more interesting to know that, the tendency of human perception, cognition and communication increases when he / she gets exposed to visualized form of any content/data.
#
# There are multiple tools for performing visualization in data science. In this article, I have demonstrated various visualization charts using Python.
#
# ---
# #### DB2 database 用法很多都是还不熟悉的,需要找找资料,打印下资料等等...偏向数据库管理/监控部分
# db2top 天马行空,类似进程状态的top, 能够看到在db2里面的数据库进程,是不是锁定别人,或者被别人锁定,各种状态,执行sql等等
#
# ---
# #### 建议锁 强制锁 [Lock in Computer Science](https://en.wikipedia.org/wiki/Lock_computer_science)
# 1.建议性锁机制是这样规定的：每个使用文件的进程都要主动检查该文件是否有锁存在，当然都是通过具体锁的API，比如fctl记录锁F_GETTLK来主动检查是否有锁存在。如果有锁存在并被排斥，那么就主动保证不再进行接下来的IO操作。如果每一个进程都主动进行检查，并主动保证，那么就说这些进程都以一致性的方法处理锁，（这里的一致性方法就是之前说的两个主动）。但是这种一致性方法依赖于编写进程程序员的素质，也许有的程序员编写的进程程序遵守这个一致性方法，有的不遵守。不遵守的程序员编写的进程程序会怎么做呢？也许会不主动判断这个文件有没有加上文件锁或记录锁，就直接对这个文件进行IO操作。此时这种有破坏性的IO操作会不会成功呢？如果是在建议性锁的机制下，这种破坏性的IO就会成功。因为锁只是建议性存在的，并不强制执行。内核和系统总体上都坚持不使用建议性锁机制，它们依靠程序员遵守这个规定。（Linux默认是采用建议性锁）
#
# 2.强制性锁机制是这样规定的： 所有记录或文件锁功能内核执行的。上述提到的破坏性IO操作会被内核禁止。当文件被上锁来进行读写操作时，在锁定该文件的进程释放该锁之前，内核会强制阻止任何对该文件的读或写违规访问，每次读或写访问都得检查锁是否存在。也就是强制性锁机制，让锁变得名副其实，真正达到了锁的效果，而不是像建议性锁机制那样只是个纸老虎。= =！
#
# To avoid such issues locking is used to ensure “serialization”. "parallelization"
#
# The following are the two types of Linux file locking:
# - Advisory locking  建议锁
# - Mandatory locking 强制锁
#
# ---
# # 20161231 Saturday
#
# > Why do you think I will hurt you...?
#
# > 那种赤果果的展现，在开始无疑是刺激爽翻直冲云霄，但是多尝试几遍就会容易饱和，容易腻了;而那种酥胸半露欲遮还休的气息却会不断刺激你，让你爱不惜手，欲罢不能，不能自拔～～～[Source](http://www.bilibili.com/video/av5808730/)
#
# > 那个不是欲抱琵琶半遮脸，而是细水长流～～ 哎呀上面那个是引用Bilibili女司机的啦，别想太多，只是觉得有点道理，就信手沾来。。。
#
# > 就像网易音乐，电台音乐，越听越了解你，推荐越成功，底层对应的算法就是学习算法，矩阵分解，你的兴趣爱好就在特征空间里面表示，让我学会找到你的特征向量吧～
#
# > 看看那我们的打卡记录展示。。。就是最纯粹最原始的数据，没有前端展示的过程，如果打卡记录展示像Github一样漂亮。。。我的天，那还不上天了，多看，多学，多尝试，多思考，改变～
#
# > 她说她可能是男的？！什么鬼啊，虽然现在男女不好分，可是我的混淆矩阵表现一直都很好的啊，天那，难道我一直都是抱错人了，细思极恐啊，问题是她的问题，还是我的问题～
#
# > 2016说走就走，2017说来则来，时间如白驹过隙。这年我毕业了，这年你毕业了。这年我从喜欢一个人到喜欢一个人，从想一个人到想一个人，想陪你从东校到南校，再从南校回东校。这年我也t不过像你像他像那野草野花，绝望着，渴望着，也哭也笑平凡着～
#
# ---
# # 20170102 Monday
#
# > 原来有某种形式美的事物和人都吸引我，只是我感兴趣的就会让我欲罢不能，某种美就在你身上，也许看不见，摸不着，闻不到，它就在那～让我～
#
# > 不管爱一个事物还是恨一样事物，都要有原因，不能无缘无故，要比别人更了解它才能谈上爱与恨[LuoPangGDT演讲](http://www.bilibili.com/video/av7791464/)
#
# > 很少去沉迷某种人说的话或者事，而是沉迷数学/理论/逻辑，因为它不是告诉你去相信，而是告诉你去怀疑，去独立自主思考，这样大家出来一致的结果才是真实可靠的～
#
# > 可乐鸡翅，need to fix minor bug： 煎的时候一个一个放，因为会倒进原来腌制的酒/酱油，影响过程; 鸡翅需要部分解开，入味～
#
# > 劲炫， XRV， 博越。。。
#
# > **期望效用函数理论 什么东西?**
#
# > 啊啊啊，什么时候你变得不自信了，也许我们的经历跟别人不太一样，别担心，别害怕，会来的一定会来的～
#
# > 爱情也许没有固定的路，没有那么多的充分必要，相信我拉，这样能陪你走属于我们好远好远的独特的路～

# %%
# %matplotlib notebook

### Write some code for her... = .=
### Sing xi huan ni ... practise
### Tell if i win no call me da shen, wo bu guo xiang ni xiang ta xiang ni ye cao ye hua jue wang zhe ke wang zhe ye ku ye xiao ping fan zhe
### Zhe cai xiang yi chang bing yu huo zhi ge de lv xing, cheng zhang shi tong bing kuai le zhe, zhe cai shi ren sheng.
### You are a princess, but... I am afraid that I might not be your prince...Because it violate my design, my understanding...
### Sometimes what I write does not express what I really mean... If they upset you, please tell me and I will explain them to you.
### 难怪昨天你有点不开心了,是因为我不小心写的,我会解释给你的... 不小心穿越。。揉xiong，揉dao？我去===
### JiaoShou: Ni De Ming Zi, BaoZhen, BuCuo Ei! Learn how to touch Opai...keep in mind.


import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 1000, 10000)

# O(n) time complixity
y = x

# O(n^2)
z = x*x

# O(nlogn)
a = x * np.log(x)

# O(2^n)
b = 2 ** x

# O(logn)
c = 25 * np.log(x)


## Plot area

plt.plot(x,y,label="$O(n)$",color="red",linewidth=2)

plt.plot(x,z,label="$O(n^2)$",color="green",linewidth=2)

plt.plot(x,a,label="$O(nlogn)$",color="blue",linewidth=2)

plt.plot(x,b,label="$O(2^n)$",color="black",linewidth=2)

plt.plot(x,c,label="$O(logn)$",color="yellow",linewidth=2)

plt.xlabel("Input Scale")
plt.ylabel("Computation")
plt.title("Which curve belongs to us?")
plt.xlim(1,800)
plt.ylim(0,800)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
