# %% [markdown]
# #### 20200901
#
# > GreenPlum 重跑历史的问题， 有个 minibatch 函数最好了， 分小批执行， 小批成功后commit，然后继续执行；遇到错误则退出，不在执行，后面的也不执行
#
# ```
# CALL MY PROCEDURE
# CREATE OR REPLACE FUNCTION print_notice(msg text)
#   RETURNS integer AS
# $$
# DECLARE
# BEGIN
#     RAISE NOTICE USING MESSAGE = msg;
#     RETURN null;
# END;
# $$
# LANGUAGE 'plpgsql' IMMUTABLE;
# ```
#
# > 同花顺： 其他收益
#
# > 华泰： 我的现金
#
# > 数据集成平台  测试环境 和 开发环境 需要保持一致
#
# > postgresql 的大小写可能区分带来问题  select "ID" 和 select "id" 和 select ID 和 select id 会导致不一样的行为....
#
# #### 20200908  If and only if , 充分必要；  中英都是一样有的
#
# > Scratch 被禁用了，风险还是有的； 由于XX的原因，Scratch全面被禁止； 在2020的黑天鹅满天飞，的时段，风险无处不在哎。。。 直接用 scratch的可能要处理不少问题了.
#
# > 充分必要条件，等价的思路，数学工具，抽象思维非常强大.......  A->B == -B->A;  B->A==-A->-B； 因此两组挑一个出来组合，得到的都是 A是B的充分必要条件， 也就是AB互相等价；
#
# > remeber ： A是B的不充分不必要条件， 必要不充分条件， 充分不必要条件， 充分必要条件
#
# #### 20200910
#
# > 自然科学 长期的生产力提升，是整个群体的做大蛋糕； 社会科学，更多是短期的再分配； 问题是人太短了。。。所以结果是显然的。。。。 对应普通人，人X馒头太好吃了。。。。。。
#
# > 既然在炒股，那你就应该明白，上班的工资就是普通个人最好的现金流。....
#
# > https://www.cnblogs.com/r00tgrok/p/hex2char.html
#
# #### 20200914
#
# 能不能做融资？
#
# 最近集思录里有很多融资亏损的朋友，大多仓位过重，9月上旬回调，部分坚信着牛市来了的同学们，带着颇高的仓位开始冲刺。当然炒股和做生意一样，没想明白怎么做就盲目扩张，导致的只有加速灭亡和负债累累。
#
# 通过增大风险来增大收益可能这不并是我们的风格。
# 这个市场比的不是谁一把赚的多，而是比谁活得更长久。
#
# >将军赶路,不追小兔
#
# > 父母的家庭教育。。。对于追求性价比的JSLer来说，这真是一笔低投入、低风险，中高回报的事情。
#
# > 人无远虑必有近忧啊。。  === 重要紧急， 紧急不重要， 不紧急不重要， 重要不紧急； 也是类似的。。。其实已经是相关系了，和人生很相关，
#
# > 规划、策略， 战略，视野。。。 How TO?
#
# > 管理的书  项目管理的书
#
# #### 20200922
#
# > mysql 的 int(5), int(10), int(50) 的坑， ()里面的数值表示的是显示宽度，不是存储字节、不是存储字节、不是存储字节！！！
#
# > In MySQL, INT(5) does not mean that values are limited to 5-character values. It only means that MySQL will try to pad these values with spaces/zeroes when returning them.The numeric range of any signed INT including INT(10), INT(5) or any other INT(n) is: -2,147,483,648 ... 2,147,483,647, which is 10 digits at most.
#
# #### 20200914
#
# > 数据仓库，告诉你的是已经发送过去的了的事情，如何预测将来？
#
# > 数据预览功能；  一次性的点对点执行任务;  postgresql的支持
#
# > mysql  binlog 目录空间不足， 导致数据库锁住了， 导致数量不够？   binlog设置时效
#
# > mysql> show binary logs;   | you are not using binary logging
#
# > https://www.cnblogs.com/martinzhang/p/3454358.html mysql的 binlog 说明
#
# #### 20200928
#
# ![OLTP OLAP HTAP](https://img-blog.csdnimg.cn/20200410102901131.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2NjMTk0OQ==,size_16,color_FFFFFF,t_70)
#
# > 2020 改变了一切的  Cov19 ， 网课， 家长买了很多打印机， 打印机需求暴增，价格涨了不少， 对应的打印机厂商、相应的配套厂商 等等，可以根据逻辑链，找到对应的生产链，到公司链的 地方？
#
# #### 20200930
#
# >在一秒钟内看到本质的人和花半辈子也看不清一件事本质的人，自然是不一样的命运。 铃木敏文的成功，主要是因为他看到了本质，抓住了核心。便利店的本质，就是提供便利，即满足消费者不断变化的需求，尽全力给消费者提供便利。
#
# > https://xueqiu.com/5720458993/160256948
