# %% [markdown]
# #### 202010
#
# > 免费的东西也是隐藏成本的?
#
# > FastDFS 提供了比较正式的三个小工具： 上传文件， 下载文件， 删除文件； 需要提供 /etc/fdfs/client.conf配置
#   上传文件：/usr/local/bin/fdfs_upload_file  <config_file> <local_filename>
#   下载文件：/usr/local/bin/fdfs_download_file <config_file> <file_id> [local_filename]
#   删除文件：/usr/local/bin/fdfs_delete_file <config_file> <file_id>
#
# #### 20201016
#
# > Waymo首次公开自动 waymo 自动驾驶，材料？ 交流的网站，地方等等？ Group where we can contact？ 这些信息?
#
# > 互联网 IT 等等， one 创新模式，走之前没有见过的商业模式； two 旧的商业模式，用数字化智能化技术替换原有的公司，换位
#
# > 生物化学？ 生物制药？ 工程？
#
# #### 20201019
#
# > pdd 只能买两种东西.
# - 第一种,这个东西不可能是假的,这个东西造不了假,或者极易分辨真假.例如苹果手机,耳机.显卡,cpu.
# - 第二种,我不在乎这个东西是真的假的,例如水果.
#
# > 新媒体运营（公众号、小程序方向、教育行业），业余写代码，开发开源工具，做淘宝客，做网站运营.
#
# #### 20201020
#
# > InfluxDB（时序数据库），常用的一种使用场景：监控数据统计。每毫秒记录一下电脑内存的使用情况，然后就可以根据统计的数据，利用图形化界面（InfluxDB V1一般配合Grafana）制作内存使用情况的折线图；可以理解为按时间记录一些数据（常用的监控数据、埋点统计数据等），然后制作图表做统计；
#
# #### 20201026
#
# > 清包，自己买材料直接找干活的工人，宁愿多付点工钱给工人，自己要做功课了解施工要点，不至于让工人偷工。项目经理找的工人价比你自己找的便宜些，他要赚啊，他还会在材料和项目计算上在你不了解/不懂的地方挖坑给你跳的，你防不胜防。  工程落地的方式不一样？
#
# > WARN :
#
# > DEBUG :
#
# > ERROR :
#
# #### 20201028
#
# > find /zork/data/datax/job -type -f -ctime +5 -exec rm -f {} \;  删除指定目录超时文件
#
# > 利用 unix 特性， 多个简单程序组合方式达到实现爆炸的需求... amazing.
#
# > crontab -l 查看crontabl定时 ;   crontabl -e进入编辑    CRUD
#
# ```
# 24 10 * * * find /zork/data/datax/job -type f -ctime +5 -exec rm -f {} \;
# 0 4 * * *  root find /data/ -type f -name "*.ts" -ctime +7 -exec rm -rf {} \;
# ```
#
# #### 20201029 还是异构数据库对 varchar 不同长度的问题？
#
# ```
# 　　PostgreSql数据库中varchar类型与sql server中字段用法有差别，PostgreSql中如果字段设置为varchar类型长度为10，则无论存字母、数字或其它符号，长度最大为10个，也就是字母和汉字占的位置是一样的。
#
# 　　Sql server中如设置字段类型为nvarchar类型长度为10，则存汉字最大为5个，字母为10个，字母加汉字混合时，字母和汉字占的长度一样
# ```
#
# #### 20201030
# > mysql 5.7 |  mysql 8.0 是大版本的区别， 旧版的 mysql connector 能连上 5.7， 连8.0就会报错，报错是 用户密码错误，无法连接数据库，请检查账户、密码、数据库名称、IP PORT，但是实际是5.7 8.0的巨大差别导致 connector连接不上， 替换驱动connector文件？ 或者修改 jdbc连接字符串试试？
