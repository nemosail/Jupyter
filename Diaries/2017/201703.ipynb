# %% [markdown]
# ![KeepLearning](https://pic.36krcnd.com/avatar/201703/10060153/ku9lbk1515kc6ilp.jpg!heading)
#
# # 20170306 March has come, has little quota again...
#
# > T字型人才把,就是专业方面的必须足够专业,精益求精,这方面是有准确精确答案的;但是对待其他事物,待人接物,这方面就没有那么多的错与对,可能更多是模糊的,都是对的,都是正确的,开阔思维,多见识见识,了解了解,别限制自己了.
#
# > 有空多去找找同学们聊聊,了解了解,虽然不在他们公司,他们行业,但是也可以去了解,去接触,用心去了解了解,什么都去干干,想想,接触接触,市场走进去逛逛对吧? 脸皮厚点,不要怕他们打骂,怕什么呢, 身心,身体与灵魂都得锻炼...
#
# > 读书与读社会, 读书,也要接触社会,了解无字天书, 两方面都要考虑平衡顾虑统一...
#
# > 要了解好多,认识好多,思考好多 才能正面刚外家啊... Anyway, just say yes man!
#
# > priority switch to the JiXiao System...
#
# ---
# #### 两台主机实现共用一个鼠标一个键盘
# 有软件实现了...搽
#
# 硬件实现应该就是KVM切换器了.... find one...
#
# 带电源USB-HUB 致动手柄...
#
# ---
# #### Gray Code 格雷码,有印象,这个东西在编码的时候是有用的
# 挺神奇的为什么呢,就是刚好满足条件,而又刚好用完二进制的编码[hehei](https://en.wikipedia.org/wiki/Gray_code)
#
# 为什么好多其他的东西也关联了格雷码,汉诺塔也是,二进制...Binary
#
# - 迭代生成
# - 数学公式生成
#
# python 定义内部函数...
#
# ---
# #### crontab 定时任务
# 学会定时,注意到不同的系统可能使用到不同的标准,使用最简单最通用的可靠,可以查看相应的man文档...
# ```
# crontab -e 这应该是用来编辑当前用户的
# 45 * * * * if [] -ef ; then sh  >/dev/null 2>&1;
#
# crontab -l 这个是查看当前用户的
#
# man crontab 看手册...
#
# ```
# 又是一个用 [GitHub写书的](http://linuxtools-rst.readthedocs.io/zh_CN/latest/index.html)
#
# ---
# #### 同时在 ods 和 dw 查询数据
# 对比结果,安心~
#
# ---
# # 20170307 Tuesday, Girls' Day...
#
# > 本书使用的reStructuredText标记语言，相对Markdown来说，在写书方面更有优势... What is reStructuredText
#
# > 牛顿迭代法,又再碰到牛顿迭代法了,记住的是牛顿迭代是用来找函数的根,零点的, 然后优化的地方用到, 求开方用到,是因为 f(x)=0; f'(x)=0;构建函数
#
# > Python 的数据确实好灵活, list 实现 stack 和 queue...
#
# > 在资产价格普遍过高、货币越来越不值钱的今天，年轻人期待的工资不升反降，这等于说，年轻人正在不断变穷。当下，年轻人对于工资期望偏低，原因来自两方面。一方面是社会与同伴给他们的真实回馈，那就是，现在的公司能开的工资真的不高，因此求职时要现实点。第二是因为年轻人自己对于财富已经显得越加没有信心，甚至对此一副不在乎的样子，不少人选择钱少但不累的工作，待在自己熟悉的“舒适区”。[可怕](http://sunxiaoji.baijia.baidu.com/article/790850)
#
# > 年轻人的日子越来越不好过，似乎已经是一种共识。 尝试透过层层迷雾,看得更广,更高,更深,更远,更准确吧,不用能放弃,Just Can't Quit.
#
# ---
# #### DB2
# with ur 的意思是脏读...?
#
# #### DB2 csum checksum problem
# 在使用 DB2 的csum 来计算MD5 SHA1 的时候,发现总是提示
# ```
# cat: cannot open checksums
# diff: checksums No such file or directory
# Checksums do not verify
# You must reload groups ...
# ```
# 但是关键是用这些错误去找Google,什么东西都没有出来,然后想办法解决啊, man csum 得到的结果和 IBM 官方的教程一样,这个那么简单的命令,不会错
# 然后想是什么问题,为什么csum 不是按照我的想法去工作呢? 不是所想即所得, csum的工作不对头啊, 是不是被覆盖了? 因为名字一样的程序太多了,
# ```
# which csum
# whereis csum
# 发现他们是不一样的,什么鬼啊? 路径不对,还是Path,环境变量的问题,应该是被其他的程序掩埋了,所需要的是找到我心爱的/usr/bin/csum就搞定了
# ```
#
# 灵活的思路,开阔思维,不要被表象所迷惑,你能看清事物的真相的...
#
# ---
# # 20170308 Wednesday. Women's day.
#
# > 当结果数据too big, too many, 只能使用 db2 export 语句进行导出了,然后结果文件太大,可以打包压缩下...
#
# ---
# #### 好久没有看过 量子计算机的资料了,什么时候我也可以为量子计算机编程了
# 量子竞争
#
# 量子计算机利用亚原子物理学的反直觉特性，其中称为量子位（quantum bits）或量子位的信息位（qubits）可以同时承担多个状态，而不是简单地表示0或1，如经典计算中的位（bits）。 从20世纪90年代开始，理论物理学家（包括IBM的一些人）已经开发了基于量子比特的算法，理论上可以以比传统计算机更快的速度执行某些任务。
#
# ---
# #### 网络效应
# 几年前，描写Facebook发家史的书《Facebook效应》和以扎克伯格为原型的电影《社交网络》风靡全球时，对Facebook和扎克伯格的神化几乎是互联网行业的政治正确，就连谷歌也得让道，这不仅仅是因为它的用户规模和价值的火箭般蹿升，更是因为人们对这样一条原则的迷信：网络效应。
#
# 网络效应，简单的说就是一个产品或一项服务的价值随着使用这个产品或服务的用户规模的增加而增加。具有网络效应的产品或服务，通常对拥有先发优势的公司有利，而Facebook提供的社交网络服务被认为是一种典型的网络效应，而且先发优势巨大。
#
# ---
# #### Aqua Data Studio 导出表数据还是很好用的
# 直接在 工具 - 导出 - 然后多选表名就ok了, 它会自动导出到目录下,然后每个表明自己一个csv文件,嘿嘿嘿
#
# 只是这个功能又,但是不是 特别好用 和 特别自动化, 智能化,要是能够开放程序api给来,就无敌了...
#
# ---
# # 20170309 Thursday
#
# > Maybe I shall celebrate 3.7?
#
# > 在快速排序中, pivort 将数组分成了 左 pivort 右, 但是在kth largest element中,它可能是 左边最小, 右边最大, 同时最小最大登,不一定能够将数组分成两部分,导致递归的规模不会缩减,就无穷递归了,解决不了问题,所以要想办法最糟糕情况要以常量1的规模递减...找出解.
#
# > 对于大部分人来说，我们每天都在低头赶路，却忘记了抬头看天。 人无远虑,必有近忧. 如何理解和执行啊,啊啊啊!!!
#
# > 福无双至,祸不单行... 那个...韩国..?
#
# > BST: property, 当BST使用中序遍历的时候,访问顺序就是从小到大的排列...
#
# ---
# #### Kth largest element, In more computer science and technology Selection algorithm
# Main Idea 主要思想是利用分治,然后细节方面慢慢细心补完,保证正确执行得到结果, main idea是保证时间/空间复杂度的全局最优,而细节方面是保证能够得到问题的正确解,要解决问题,一定要保证解的正确性,然后尽可能地接近全局最优... 这样就又对又快解决问题,而且是理论上最优,上界或者下界.
#
# ```
# # 后悔无期
# "这衣服比刚才的没有那么好看"
# "这衣服不合身,你以为我有的选啊"
# "诶,那个,你要去哪?"
# "下一部戏,你呢"
# "下一段旅程"
# "下一道难题"
# ```
#
# ---
# #### 确实可以使用 crowdfunding, 即大众筹资或群众筹资
# 这一个来执行something funny?
#
# ---
# #### What? They already teach kids to program... Oh!
# 2016 年是少儿编程赛道开始升温的一年，有业内人士认为，这个赛道的升温是“巨头重现”和“家长需求”共同作用的结果。比如在 2015-2017 年间，微软、Apple 和 Google 分别推出了自己的少儿编程工具，开始抢夺下一代开发者入口，英美等 STEAM 教育相对成熟的国家开始把编程纳入公立学校的教学体系中。在国内，编程教育的爆发期虽然还没有到来，但是这阵风已经刮了起来。
#
# Strach, C++, Python... Haskell
#
# ---
# # 20170310 Friday
#
# > 毕竟是学习计算机,学习算法,学习优化的人,要又策略,又方法地去解决问题,别盲目,别迷失掉...
#
# > 从心理学角度,人们有时候会低估一种坏事情的发生概率,因为人们潜意识里就不希望它（这其实也暗示次贷危机爆发的原因，因为大家都不愿看到房地产市场泡沫破裂，因此也就不相信它会发生了）
#
# > 暴利的一元购买,毕竟人家是出来“赌”的，作为庄家，目的就是把赌徒手中的筹码全部赢光。
#
# > 网易一元购等这些平台 遇到的问题跟比特币遇到的很类似,可以使用比特币的方式来解决吗, How to appy to solve the problem?
#
# > 有点屁股决定思维,位置决定思维的感觉,就是因为身上背负的责任/债务,导致他们无法做出正常的决策了,即使是违背道德,违背法律,他们也必须要做到,因为他们的处境已经是背水一战,没有退路了... 尽量别让自己没有退路把...?
#
# ---
# #### 云工厂 模式,就是通过网络的方式, 平台方式,  关联  需求  和 供给
# 这个类似淘宝模式,或者共享经济模式, 使用计算机技术提供技术支持,来解决这个 市场 问题...
# [36kr“云工厂”](http://36kr.com/p/5065441.html)
#
# 汽车的功率? 导致 计算机的运行能力, cpu + gpu VS cpu + fpga ? [Intel的自动驾驶方案](http://36kr.com/p/5066415.html)
#
# ---
# # 20170311 Saturday
#
# > A strange/norval idea comes to my mind. A Book of our story...Record: happened, happing, going to happen...
#
# > Tell a story, a story of 酸甜苦辣,嬉笑怒骂.
#
# > Hide the ring and other stuff inside...
#
# > Natural language, programming language, assemble language, machine language... In side the book...
#
# > 故事的开始, 偶然的相遇, 碰巧的相识 ... The beginning of to life line, the cross of two life line...
#
# > Binary Tree 0 1 2 4 8 16 ... $2^n$ Power of 2
#
# > Algorithm, Logematic... $log_2(n)$
#
# > Pattern Recognotion, Machine Learning, Artificial Intelligence... classification/regression...
#
# > About her experience...her study...? In SYSU?
#
# > May not be easy, just try...
#
# ---
# #### 他们的信息到处乱放啊..
# 都是备份,出现更新异常了把...混蛋...!! 应该参考数据库范式设计,放在公共事实表,然后修改维表就好了...
#
# #### NS 的 NS剪纸解谜游戏《Snipperclips》新演示 一起来咔擦
# 适合一家人玩的 益智游戏， 想象力，创造力， 不给固定的过关思路，只要达到效果就行， 结果导向，然后看看 人们 天马行空，能干什么。。。？
#
# 移植到手机上，然后联机网，也很好玩啊，，，？现在手机这么发达。。对不？
#
# 引入众筹的模式，开放API，开放设计，WEB2.0 WEB3.0 模式，让用户来参与设计游戏，然后评分，推送，分享。。。
#
#
# ---
# #### 独角兽
# 所谓“独角兽公司”是指那些估值达到10亿美元以上的初创企业。
#
# ![俺这么土,为啥她喜欢](https://pic.36krcnd.com/avatar/201703/14125418/ejz3p03p1tewe2eo.jpg!heading)
#
# # 20170313 Monday...
#
# > 卡自助循环贷款(个人消费) 这个是什么东西诶?
#
# > 有空多跟她聊聊...?
#
# ---
# #### 信贷数据对不上的问题:
# 卡自助循环贷(个人消费贷)的问题,这中贷款可能导致变动?
#
# 最后发现自己踩坑了, 没有his的表是状态表,记住是状态表,状态是可以发生变化的；然后应该要查询的是历史表,因为查询的是以往的记录...
#
# ---
# #### 报表平台又坑我了...
# 问题在于在平台输入的数据,正确的字符串,然后保存后变化了,化了,了... 什么鬼啊,导致我每次登记完,然后得重新进去,看数据有没有自动跳变了,我搽++
#
# 码单!!!!
#
# - 第一步是发现问题,找到问题,知道现象;
# - 需要的是第二步,找到问题根源,解决问题...
#
# ---
# # 20170314 Tuesday, another valentine's day || Also $\pi$'s day
#
# > Airbnb为例，刚起步时，它的目标是建立一个聚合供求双方的市场。一方面，只有当房源足够时，游客才会去用这个平台；另一方面，只有当客源充足时，屋主才会对出租感兴趣。
#
# > 总有一天,我会开着我心爱的水柜,把他们碾压在历史的车轮下....
#
# > 准确,精确的考核,逻辑应该是不多不少,不重不漏,充分必要,恰到好处,分类/判别 准确率100%, 混淆矩阵对角, 定性分析, 定量分析.
#
# ---
# #### 韩国的总统事情... 现代版本的 '纸牌屋' ?
# 众所周知，韩国的政治和经济被诸多财阀深深掌握着。
#
# 财阀的影响力遍布韩国每个角落，韩国人日常生活根本离不开他们。财阀产业涉及各个方面，从重工、车船、化工、电子、通讯到房地产、金融、食品、酒店、游乐场，几乎包罗万象，每个财阀旗下都有好几十家公司。
#
# 真可谓是，从韩国人的出生到死亡，都由财阀包办了。
#
# ---
# # 20170315 Wednesday
#
# > 学习,参考,模仿 他们额模式,也许将不同的类型的企业放到不同的地方更好? 经济中心, 政治中心, 娱乐中心, 创新中心, 不同的更加均衡,而不是自然发展而成的马太效应, 自然很好, 但是可能会带来不少问题, 也许需要人为地调整, 组织, 大城市的挤出效应, 吸引人来, 但是挤出人们, 你们需要的是什么, 你们定位是什么, 怎样去解决? 这样做是你们要的吗? 短期目标与长期目标...
#
# > 接项目,和业务部门接触, **需求分析**, 这个是很重要的,交流清楚,交代清楚,问题从大方向到细致落实,都要解决的,不能忽视...
#
# > 如何做好一个项目/一个系统,需要**实践 && 理论**,实践就是具体参与项目建设,自底向上,自上而下,整个系统,全面认识; 看书就是来看看其他人的经验,开阔自己的眼界,借鉴他们的经验/想法...
#
# > **数据分析,使用业务,程序,数学,理论来参与解决问题,这个一定要锻炼自己**
#
# > 植保无人机服务商,使用无人机来参与实际工农业,第一产业,[第二产业...](http://36kr.com/p/5066784.html)
#
# ---
# #### 把数据库里面的Schema 用日常生活来解释,来比喻,类比...
#
# 在学习SQL的过程中，会遇到一个让你迷糊的Schema的概念。实际上，schema就是数据库对象的集合，这个集合包含了各种对象如：表、视图、存储过程、索引等。为了区分不同的集合，就需要给不同的集合起不同的名字，默认情况下一个用户对应一个集合，用户的schema名等于用户名，并作为该用户缺省schema。所以schema集合看上去像用户名。
#
# 如果把database看作是一个仓库，仓库很多房间（schema），一个schema代表一个房间，table可以看作是每个房间中的储物柜，user是每个schema的主人，有操作数据库中每个房间的权利，就是说每个数据库映射的user有每个schema（房间）的钥匙。
#
# 我们访问一个表时，没有指明该表属于哪一个schema中的，系统就会自动给我们在表上加上缺省的sheman名。在数据库中一个对象的完整名称为schema.object，而不属user.object。
#
# ---
# #### 当使用IE来打开报表, Congnos 出现了 Cognos Viewer Security Rejection
# Cognos Viewer Security Rejection. Your request was rejected befor ... log Please contact your administrator.
#
# 这个问题都是 IE 安全设置导致的,或者360浏览器,都是通过 工具 - Internet选项 - 安全 - 自定义级别 - 启用XSS筛选器 - 禁用它 OK
#
# 刷新,登录看看就好了
#
# **其实干了这些运维的一段时间后,感受最深,或者最有效解决问题方式,跟着他们业务部门人员一样,做一样的事情,有一样的权限,执行跟他们一模一样的流程,然后体会下他们遇到的问题,然后结合自己的计算机经验/思维,就能很快定位问题,开阔思路,灵活思考,就能很快地解决问题了~**
#
# ---
# ####
# 感知、决策、执行,是无人驾驶车与外部环境交互的主要流程。目前典型的无人驾驶感知系统由多种传感器构成，包括毫米波雷达，多线激光雷达，图像传感器，超声波雷达等构成，其中图像传感器和激光雷达是完成障碍物识别和定位的主要部件。[做产业配套啊,产业链那么大](http://36kr.com/p/5066094.html)
#
# ---
# # 20170316 Thursday
#
# > Market Share vs. Market Penetration || Search on Google...
#
# > 短期看金融,长期看供需...
#
# > 什么是集算器?
#
# > 沉没成本理论...沉没成本和机会成本
#
# ---
# #### 无人机 UAV Drone... 飞控
# 10年以前，搞无人机的十个人有八个是航空、气动、机械出身，更多考虑的是如何让飞机稳定飞起来、飞得更快、飞得更高。如今，随着芯片、人工智能、大数据技术的发展，无人机开始了智能化、终端化、集群化的趋势，一大批毕业于自动化、机械电子、信息工程、微电子的高材生们投入到了无人机研发大潮中，几年的时间让无人机从远离人们视野的军事应用飞入了寻常百姓家、让门外汉可以短暂的学习也能稳定可靠的飞行娱乐。不可否认，飞控技术的发展是这十年无人机变化的最大推手。[飞控](http://36kr.com/p/5066951.html)
#
# ---
# #### Books From 36kr
# [金融](http://36kr.com/p/5066461.html?from=related)
#
# ---
# #### 知易行难
# 第一，不要把自己的财富增长寄托在资产价格泡沫上。在过去一段时间里，需求侧刺激走过了头，对老百姓造成了误导，使得老百姓认为只有炒房炒股炒汇才会致富，现在必须转变这个思路，因为政府的政策方向变了，所以投资房产股票外汇千万要谨慎，不要去做“接盘侠”。
#
# 第二，国家政策将向实体经济倾斜，将为创新创业提供更多支持。这一点对于年轻人来说尤为重要，是将希望寄托在幻想“快速致富“的投机手法上，还是踏踏实实地去创造属于自己的财富，值得年轻一代好好思考。
#
# 能改变人群中的理念吗?大众都一致看涨,这个方向扭力好大?如何改?
#
# ---
# #### Divide & Conquer... 分而治之 ... 6翻了...
# 整体Revierse, 然后局部Reverse... 反转再反转
# 16
# 8
# 4
# 2
# 1
# ```
# class Solution {
# public:
#     uint32_t reverseBits(uint32_t n) {
#         n = (n >> 16) | (n << 16);
#         n = ((n & 0xff00ff00) >> 8) | ((n & 0x00ff00ff) << 8);
#         n = ((n & 0xf0f0f0f0) >> 4) | ((n & 0x0f0f0f0f) << 4);
#         n = ((n & 0xcccccccc) >> 2) | ((n & 0x33333333) << 2);
#         n = ((n & 0xaaaaaaaa) >> 1) | ((n & 0x55555555) << 1);
#         return n;
#     }
# };
# ```
#
# ---
# # 20170317 Friday, Good To Go.
#
# > 别那么容易绝望,总有一天我会开着我心爱的水柜,把他们碾压在历史的车轮中.
#
# > 使用更高效率的工具,不用天天加班,释放自己的时间...嘿嘿
#
# ---
# #### 商业
# 中国最可怕一件事，就是人、公司绝大多数都陷入同质化竞争。其实每个企业必须回答的问题是：自己到底跟别人有什么与众不同之处？
# [Baidu](http://skylei.baijia.baidu.com/article/800290)
#
# ---
# #### Impossible? Possible!
#
# > 中国要培养工匠精神的最大难点，其实是爱的缺乏。工匠精神的精髓，就是专注、严谨、耐心、注重细节、追求完美、淡泊名利。
#
# > 时寒冰：中国最大的危机——人性危机...?
#
# 中国培养工匠精神，几乎不可能? Stay Tone.
#
# 金字塔一定不是奴隶建造的，因为带着仇恨的人不可能建造出如此精美的金字塔，只有带着爱的人，才会有如此完美的创造。
#
# 热爱生活、珍爱生命的人，才会对工作专注，才会精益求精，才会去追求完美，才会一丝不苟，才会做出精品。
#
# 培养去爱,而不是去仇恨...
#
# ---
# #### 何以安居乐业?
# 高房价从三个方面影响消费：其一，高房价成为许多家庭沉重的负担，那些需要买房而没有买房的人，也需要通过节衣缩食来积攒买房的钱。其二，房价飞涨，拉动房租上涨，房租的成本将纳入到商品中从而导致商品价格上涨，从而，抑制消费。其三，推动房价上涨的一个重要因素是货币贬值，而货币贬值会稀释民众的财富，稀释民众的购买力，从而影响消费。[时寒冰](http://kongfuf.baijia.baidu.com/article/799799)
#
# 贫者的上升之路被封堵，都比贫困本身所带来的后果显得更为严重。
#
# Keep Reading... Keep Thinking... Keep Writing...
#
# ---
# #### ofo 和 芝麻信用
# 征信,信用评价体系建立, 也是某种程度的布局???
#
# ---
# # 20170318 Saturday, 虽然不是从小玩大, 但也不要好久不见,有空多见见面吧~
#
# > Sleep & Arrive ShenZhen in HeHe's House...
#
# > Start At 18:30 Friday From 南海城市广场 To 深圳大学北
#
# ---
# # 20170319 Sunday
#
# > Start At 15:30 Sunday From 深圳白石洲B出口 To 城市广场 直接在深圳白石洲B出口登,在马路边就能听到他们说去佛山~
#
# > Arrive Home & Stay with Miss Ren. She seems a little upset... How can I make her happy?
#
# ![Debian](https://dn-linuxcn.qbox.me/data/attachment/album/201703/12/092323vd0x27xmu00xd5x1.jpg)
#
# # 20170320 Monday
#
# > 更多的自动化,更好,更快,更高,更强~
#
# > 话说如何用技术解决 各地 公交 地铁 出行 不方便问题? 手机就能解决,怕是当地的财团,利益集团阻力太大,无法实施,就像共享单车一样收到破坏,如何破局,从年轻人,地铁等更加公平的入手,然后布局推广?
#
# > 全民炒房的时代，努力一辈子也不如炒房一套，别说工匠精神，现在连踏实工作都已经不易了。
#
# > 清清楚楚地难过,迷迷糊糊地快乐;当年轻人都选择麻醉自己地过日子,这国家就可能出毛病了,而不病的不轻.
#
# > 轻资产,小,低,可靠,可用,够用,物联网时代,World Of Things...
#
# > 线性思维 与 非线性思维; 简单近似,粗暴,但是好用易于理解; 复杂,难理解,但是更接近现实,减少黑天鹅?
#
# > 金融从来都不是事实,而是人们的预期,人们的信心; 但是事实终归是事实,总会又回归理性的时候, 需要的是看得更深,看得更远, 了解更多更多!
#
# > My mom and dad always said: 穷则思变,穷则生变, 别那么绝望,总有一天站撸他们!
#
# ---
# #### Kindle 阅读器 PDF 裁剪 加工 Linux
# [PDF平台好用](https://linux.cn/article-8299-1.html)
#
# ---
# #### Respbery Pi, Orange Pi
# 随着开源驱动的硬件越来越成为主流，比如 Arduino 和 Raspberry Pi，这些开源硬件的成本不断下降，给那些全新且具有创新性的物联网和STEM（LCTT译注：STEM 代表科学，技术，工程，数学）类软件打开了大门。
# [Source](https://linux.cn/article-8308-1.html)
#
# ---
# #### 说好的工匠精神呢?
# What do you guys want?
#
# ---
# #### 货币贬值
# [深度好文诶](http://zhengshangcanyue.baijia.baidu.com/article/802070)
#
# 都对,都看
#
# - 中产屌丝化：以土地恢复阶级划分。中产和屌丝的区别是谁的负债更多一点。
# - 货币信仰裂痕：人民币信任度屡创新低，排列在房产、美元、食品之后。这年头连老太太都不敢存钱了，几乎全民押注人民币持续贬值，纷纷用资产来和央行对赌，去拼命购买无法印刷的土地。
# - 阶级门票高涨：教育成为阶级军火，从幼儿园开始的新科举之路，一线城市一个孩子上学的开支等于买一辆解放军99式主战坦克。
#
# 对计算机程序来说,也是耗用 **时间与空间**, 其实对于现实世界的我们,也在抢占 时间与空间, Time & Space...
#
# 以前,财富集中在土地中,也就是成了地主阶级; 现在,财富集中在房子里,也就成了房东阶级?
#
# 从静态走向动态,一般会变得更加厉害,更加牛...
#
# 重视教育并不是亚洲家长的偏执，而是社会发展的必然：
#
# 高薪工作所需的技能和知识壁垒在不断加高
#
# 技术的进步在加速阶层的洗牌和分化，高知阶层碾压底层是常态
#
# 保持足够强的学习能力是保持在本阶层的关键。
#
# [全球年龄中位数,数据说话](http://b.hiphotos.baidu.com/news/w%3D638/sign=73ea4b24e9fe9925cb0c6a530caa5ee4/960a304e251f95ca980bc157c0177f3e66095250.jpg)
#
# 市场:
#
# 这样的技工岗位面对动辄几百上千万的房价的时候，自然想到了转行。不是不热爱，实在是热爱的成本太高。代价太大。换句话说，实在热爱不起，工匠精神的机会成本太大。看着同学们转行大把大把赚钱，看着别人买房买车，你还能踏踏实实的在技术工人的岗位上精雕细琢吗？显然很难。技术工人虽然好就业，但大家都知道，他的上升空间有限，你进入一个工厂，很容易就看到了天花板。知道即使干到了高级技工也就那么点收入，更何况那是需要时间作为积累的。需要一步一步的走过去。相比于互联网IT又或者金融从业者，动辄工作几年就月薪几万，这让技工们实在是有点眼红。
#
#
# 日本的?不太信把? 我们的现在/将来 缩影?穿父母穿过的衣服，甚至外出租衣服，平时乘坐最便宜的巴士，吃最粗淡便宜的食物……原本应该大手大脚花钱的年轻人却处处节省，把省下来的钱存进银行。即使日本的银行实行超低利率，甚至一度出现负利率，但想要老百姓主动把钱从钱包里拿出来买买买，依然是一件非常难的事情。
#
# ---
# # 20170321 Tuesday
#
# > 需要等等,64位,多核心CPUs, 单个8GB内存的 小版机器,然后运算, 可以自己设计这样的板子吗? 由于有开源的硬件了,改造它, 只为那个目的,就是构建个人的学习分布式平台, 支持Java,64位,计算能力ok,内存够,然后运算~ 如何衡量分布式平台的计算能力? 能正面抗PC构成的集群麽?
#
# > 这个需要找资料,需要耐心,是个系统的决策过程...
#
# > 金融大鳄索罗斯的教诲在此依然振聋发聩：世界经济史是一部基于假象和谎言的连续剧。要获得财富，就要认清假象，投入其中，然后在假象被公众识破前退出游戏。
#
# ---
# #### 我的 String Tools 很好很强大
# 就是一个小的python程序,把我日程需要处理的字符串需求都实现了,直接粘贴复制就搞定了,heiheihie...
#
# ---
# #### Kaggle
# 不管是初学者还是大魔王，只要浸润过数据科学和机器学习界，那么对于Kaggle一定不陌生。各路英豪在这个平台上实战练习、膜拜大神、打怪升级，用某个媒体人的一句话，“简而言之，Kaggle 是玩数据、机器学习的开发者们展示功力、扬名立万的江湖。
#
# ---
# #### 货币的非国家化, 由中央银行的集中式 走向 分布式的数据库, 像市场一样, 来得到最好的货币
# 比特币涨上了天，引来了三种人：炒币的、挖矿的、卖矿机的。
#
# [StoryOfBitCorn](http://hstl.baijia.baidu.com/article/803147)
#
# **Tech Or Ideas That can change the world.**
#
# **如何使用BlockChain来改变现在的世界,现代的社会?哪里又不舒服,用户不爽的地方,可以优化的地方?可以应用的地方**
#
# 但站在金融业最前沿的人，已看清了比特币革命性的区块链技术，并力图用其改变世界。
#
# 区块链不玄乎，就是个去中心化的超级数据库，用它能打造出像比特币一样全球化、全天候、公开透明可追溯的交易系统，是互联网化的“信任利器”。
#
# ---
# #### Windows 的AHK, linux下的xdotool,  它们就是开源版的按键精灵的实现
# 我们需要的是为他编写代码就行了,注意过程的准确性,因为这是模仿鼠标/键盘,人类的行为的,但是人类行为的模糊不确定导致机器可能犯不少错误...
#
# 其实就是想批量删除 微薄 上的僵死粉丝,被灰色,黑产搞上了,破解了我密码??? 以后一定要管理好我的密码多了,设计安全的密码一律每个独立,使用自己的脑来记忆,不能这样子下去了,不安全...(安全!!!)
#
# 由于微薄某些原因,不提供注销什么的,需要批量删除,但是系统没有自带批量删除选项,因此需要用自己人手来删除,太痛苦了, 因此需要写的是 程序 来帮我完成这个任务,方法其实有很多:
# - 使用python的网络编程,读取网页的api等等,然后调用他们,达到我的目的,但是这还是不熟悉,需要时间,其实这个想法很好,很好解决用户需求,节约用户时间,释放用户手工,应该是能够创造不少价值的.
# - 使用xdotool等等的鼠标/键盘模拟程序,模拟人工的行为,这样就好办了,有点难的地方就是验证码,幸亏这个没有验证码,哈哈,需要的是搞定验证码!!
#
# anyway, 最后搞定噢!
#
# ```
# # xdotool 好好玩,一定要用 Goolge + English 来search,这样子才能找到更加专业,精确答案,没办法
# # 生活小问题问百度, 工作专业的问Google ... Always try to sovle problems correctly.
# xdotool mousemove x y click 1 #鼠标左键点击
# xdotool mousemove x y click 2 #鼠标滚轮点击 wheel
# xdotool mousemove x y click 3 #鼠标右键点击
# xdotool mousemove x y click 4 #鼠标滚轮往上滚动1个单位1 unit wheel
# xdotool mousemove x y click 5 #鼠标滚轮往下滚动1个单位1 unit wheel
# ```
#
# ---
# # Wednesday, Lots of problems..
#
# > System is work delay, and my sms failed to capture the state... what am i suppose to do? Be smart, be clever, try to read source and solve the problem...
#
# > 真正有良知有水平有见解的经济学家是一定是基于客观数据分析，不屑于为了迎合大众口味而发表论调，时寒冰，郎咸平，宋鸿兵，都是顶尖的营销人员..
#
# > Be an observer ，rather than a simple follower… 使用更多书籍,数据,模型,数学,事实来支撑你的观点,你的世界...
#
# > 思考: 区块链可以如何改变世界,改变该死的现在?
#
# > Bit Manipulation. ^ ! & |, point is there are many ways to solve pros, which is the best in space time...
#
# ---
# #### Elon Musk 的自传,看看他们的书吧,多看看~~  [坚持与努力与奋斗](https://zhuanlan.zhihu.com/p/20129091?columnSlug=kungfucharlie)
# 接下来是我更加关心的问题，为什么 Elon Musk 这么猛？ 他如何跨学科学习的？他的思维模式是怎样的？
# 1. 他极度勤奋且酷爱学习在看他的自传里，很多时候描述就是：他每天都在思考和阅读，经常几个小时就可以读完一本书，然后挑里面的关键内容再花一天时间精读；
# 2. 他创业的方向一直是他从小热爱的东西这很重要但是容易被大家忽视。兴趣是最好的老师，而做感兴趣的事情才是可以坚持一生的事情。不管是火箭，外太空旅行还是可再生能源，这些都是 Elon Musk 在孩提时期就很着迷的事情，另外更加重要的是，它们对整个人类发展有重大的意义。可能我们没有这么好的机遇或者本钱去做改变人类命运的事情，但是我们应该学会去追求自己儿时一直喜欢的兴趣，并想方设法将兴趣和自己的工作相结合，亦或是出来做自己喜欢的创业项目。
# 3. 他的学习方法和思维模式在TED的采访中，他坦言自己最赞同的思维模式是 “First principle thinking”。 “First principle thinking” 的详细解释和如何运用我会在另外的问题专门回答。简单说来，First principle thinking 就是从事物最基本的公理为出发点来进行推导的思维方式。其对立的方法是 Analogy（类推法），简单说来就是别人或者其他事物如何如何，所以我也要如何如何。举例说明：“现在我有1万刀的现金想投资股票，我应该买什么股票？”Analogy ：“别人家之前买了这几支股票，赚了不少，或者我旁边有个股票大神也买了这几个股票，赚了，所以我也准备买这几个股票。”First principle thinking：“首先去弄明白股票的原理，看清股票涨跌的本质，然后分析公司的背后价值，接着根据自己的需求，看自己是想长久投价值，然后在A股市场利用趋势捞一波。当然也有可能，在分析过程中发现股票市场的风险大小超过了自己的承受范围，从而放弃投资股票。转而杀入债市或者定期投资等。”从上面可以看出几点：First principle thinking 对一个人的学习能力要求很高，同时分析问题的过程冗长；类推法则很方便，直接O(1)出解，只是并不知其所以然，并且缺乏对本质问题的理解。这两种思维模式的选取是一个辩证的问题：在大部分的问题上可以采用 Analogy，节约时间。但是对于重要的可能决定自己命运轨迹的问题，则采用 first principle thinking（比如创业 方向？模式？，长期投资等）。
#
# ---
# #### Read [常坐电脑前面，这些健康问题你注意到了么](http://blog.jobbole.com/110628/)
# [joble](http://blog.jobbole.com/category/programmer/)
#
# ![不去偷不去抢,也不会让你们来偷和抢](http://img.mp.itc.cn/upload/20160819/88cbf16050cf4f40aa06cdfb6c53099a_th.jpg)
# ---
# # 20170323 Thursday
#
# > 一座城市的活力，是由三个“要素”构成的：年轻的人、热钱和新技术...
#
# > 做人要有追求,不然根咸鱼有什么区别? 做人要又野心,也要让能力能够支撑自己的野心, 能力不足了,就应静下心来学习,思考,成长了...
#
# > 《21世纪资本论》
#
# > 《贫穷的本质》
#
# > 购买力,可分配财富,获得感, 什么是个好社会/国家? 市场自然自发收敛的是吗? 历史的是吗? 我们定义的是吗? 公平公正公开,有希望,有梦想,有盼头,不断创造财富,创造价值...
#
# > 要恨一样事物,要比爱它的人更加了解它...
#
# ---
# #### 年轻人, 可怕地发现早已经是中年人? 握草
# 贫穷的表面原因是因为财富的匮乏，但其深层的原因是因为社会机会的不平等。为贫穷的人创造一个更良性的社会经济环境，为他们提供更多的机会，这才是我们应有的扶贫逻辑。
#
# 近日，年轻人“变穷”的话题成为许多媒体关注的热点。
#
# 年轻人穷很正常,买不起也很正常,可是变得越来越穷困潦倒,越来越难过,是什么情况...
#
# 作者：孔雀饲养员
# 链接：https://www.zhihu.com/question/47143502/answer/109078236
# 来源：知乎
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。
#
# 贸易保护、劫富济贫、孤立主义实行起来很痛快，甚至在短期内会有一定效果，但从长期来看一定是不利于国家发展的。
#
# 根本出路在于让年轻人向上流动
#
# 阿比吉特·班纳吉和埃斯特·迪弗洛在《贫穷的本质》提出一个重要观点：贫穷的表面原因是因为财富的匮乏，但其深层的原因是因为社会机会的不平等。而这种机会的不平等会让那些原本有可能凭借自身的智慧和能力改变经济状况的穷人失去重要的脱贫机会。
#
# 什么叫做机会不公平？作者举例说，当人道组织为非洲贫困地区的农民提供化肥援助时，使用化肥的贫农都获得了较好的收成，但第二年持续使用化肥的贫农数量却远远低于预期。调查人员一询问，才知道很多获丰收的农民第二年依旧难存下足够的钱购买化肥。越是贫穷的人群，意外开支越大。因此，最重要的不是现在的年轻人是否比以前更贫穷，而是他们有没有机会可以改变这种状态。但正如调查所显示的，多数人对此比较悲观。72.4%的人自认为其收入增长速度既很难跑过通胀速度，也很难跑过其他人群。
#
# 在一个社会里，最重要的是社会阶层之间的流动性。只有保证人人皆有成功的机会，那么即使现在年轻人处于相对贫穷的状态，那又有什么可怕的呢？真正可怕的是，即使年轻人意识到自身的贫穷，却是无论怎样的努力和勤奋都不足以改变，这才是最为可怕的事。
#
# ---
# #### 在程序员的, 在CS的世界,
# 经常遇到二分, 就像 命令式编程 VS 函数式编程
#
# 解决一个问题,一般是:
# - 模拟:简单地实现,一步一步安装认识/认知来实现,不需要深入了解关系/内在模式pattern,容易理解,实现简单,但是time/space时间复杂度高,BAD
# - 数学:更简单实现,但是相对难分析和理解,需要对问题要有透彻研究,理论基础够好够扎实,有着最好最优的time/space COST...
#
# Like exploit gravity to open the coco nut...
#
# **几乎是最省力,最节约Energy,在许多可行的方法中,这是某种形式的最优,最好啦,思考,利用,改变世界**
# 使用自己的力量去打开椰子很困难,可以利用自然重力,像猴子一样,搬起石头,砸椰子的头和尾部,纤维自然就分开了,然后剩下的nut内核,注意到三个dots,观察到它的结合,硬辅助线,它的脆弱点就应该是这条先的中间,刚好和核的赤道,最大的圆教程+, 有个point,敲击到相对平而长凸的石头,bang! Problem solved perfectly...
#
# 就像解决算法问题,
# 1. 首先想到的,很自然,很trivial平凡的想法就能解决问题,但是往往花很多的time/space时间和空间;
# 2. 然后应该是静下来认真思考/认识问题本身,发现他的内在的数理逻辑关系,然后就一般能够使用最优或者接近最优的解决方法了...
#
# ---
# # 20170324 Friday
#
# > Need to help her to get access to cnki database paper database...
#
# > Try to solve problems...
#
# > 许多都是LBS应用,也就是常常都是一种新事物/技术出现,利用好它,用它来解决现在的需求,那就好办了...
#
# > I'm sorry for lot's of things...
#
# > 市场， Market, How to understand market? 如何使用你学到的知识，运用，利用它们来改变这个操蛋的世界。
#
# ---
# #### TMD被混蛋们逼着改变，现实拍拍拍地打我的脸，我还会保持初心吗？我还会坚持吗？真大不知道了，但我肯定会客观理性，不管我成为坏人还是好人，或者根本就没有好与坏，总有一天干翻他们。。。I am getting greyer, darker... NO MORE LIMITS...
#
# #### 学习学习，成长就是痛苦的，有啥可怕的，干它丫的！
#
# #### 学习国信GX的开源节流啊，使用各种新技术来节约平时的耗电啊。。。
#
# #### 人其实也是在跟 时间 和 空间 做斗争。。。What can we do?
#
# #### 关键整个过程，这知识手段，引导用户使用智能化设备，减少人力成本，相当于杠杆，利用小利益去驱动更大的利益，目标
# 互联网思维，营销，推广，利用人性，（线上，奖励，可以使用更高的利率，知识牺牲细微的收入，获得了大量的用户，然后用明显标语推出的免费服务，酒香也怕巷子深，线下就使用相对低的利率，**鼓励与惩罚**
#
# #### 构建，建立一个稳定的平台，提供机会给用户来自由完成所有他们想要的，只是提供一个场地，然后各个市集，各个市场
# 分享信息，PC 与 手机端， 数据库，卖方，买方。。。供给与需求， 让天下没有难做的生意，农产品交易，使用你学过的知识去修正这个丑陋的世界啊。。。然后有数据就好办了，做记录，做分析，上数学，上模型，
#
# #### 记住，你是可以全栈的，什么都可以干，什么都应该认识的，SAY YES... Dota It.
#
# ![Don't give up, fxxk them all one day](https://pic.36krcnd.com/avatar/201703/28145302/4enq371mfogd9pr4.jpg!heading)
#
# # 20170327 Monday
#
# > 找到问题,定位问题,解决问题,思路,独立自主,独立思考
#
# > I am so bad. Do it no more...
#
# > 货币乘数,存贷比, 这些东西都在银从里面,看看看
#
# > 国有大计划,人有小目标...
#
# ---
# #### 民间借贷,高利贷,是有司法定义,
# 需要借钱的人没有办法从银行和大金融机构成功借到钱，就只好求助于民间金融系统，同时，民间社会的钱缺乏投资渠道，因此选择进入高利贷。高利贷的借方贷方，就是如此接上了头。 供给与需求,同一类商品所有交易起来就是市场,民间借贷市场.
#
# 媒体曝光的个别高利贷催债事件就像是蟑螂，当你在客厅发现一只蟑螂的时候，去你的厨房看看，那里应该已经生长了许多蟑螂。
#
# 两个一结合,就像自持续的化学反应,根部停不下来...
#
# #### Linear & Non-Linear Thinking, Search On Google.
# 线性思维是一种直线的、单向的、单维的、缺乏 变化的思维方式，它的好处是有助于深入思考，探究到事物的本质，弊病是无法认识复杂的事物。
#
# 非线性思维是无须经过大量资料信息分析的综合系统，不受逻辑思维和线性思维局限的多维度的跳跃性思维，是互相联系的非平面、立体化、无中心、无边缘的网状结构，类似人的大脑神经和血管组织。它能拓宽思路，看到事物的普遍联系。非线性思维能弥补线性思维的局限性，有助于认识事物的本质，有助于认识复杂的事物。
#
# 西方的科学家认为，线性思维是目的，非线性思维是手段。
#
# ---
# # 20170328 Tuesday
#
# > 商业银行经营全解析之FTP（内部资金转移定价）, Found Transfer Pricing...就是计价,存放/使用这些银行内部资金的价格,不能产生利差(对外),但是可以分割利差(对内)...
#
# > 小目标, 你的野心和你的能力,当你的能力不足够支撑你的野心的时候,就要静心学习,增长自己的技能,而不能整体瞎BB了...
#
# > 在我的编程生涯早期，读过的最为振奋的一本书是《UNIX编程环境》，和其他基本UNIX世界的大部头比起来，这本书其实还是比较小众的。
#
# ---
# #### Jupyter 神器, 多逛逛,多了解,多接触他们,然后才能跟上时代步伐... One day, I will drive my tank to rule them all
# [Jupyter](http://python.jobbole.com/87527/)
#
# 左手程序员，右手作家：你必须会的Jupyter Notebook.......
#
# ---
# #### GUI 和 命令行 各有它们自己的定位把..
# 优秀的程序员借助命令行的特性，可以成倍（有时候是跨越数量级的）提高工作效率，从而有更多的时间进行思考、学习新的技能，或者开发新的工具帮助某项工作的自动化。这也是优秀的程序员之所以优秀的原因。而面向手工的、原始的图形界面会拖慢这个过程，很多原本可以自动化起来的工作被淹没在“简单的GUI”之中。[其实强人工资能出来了,会改变](http://blog.jobbole.com/110690/)
#
# **What makes a programmer excellent?**
# 要给优秀的程序员下一个明确的定义无疑是一件非常困难的事情。擅长抽象思维、动手能力强、追求效率、喜欢自动化、愿意持续学习、对代码质量有很高的追求等等，这些维度都有其合理性，不过又都略显抽象和主观。
#
# ---
# # 20170329 Wednesday
#
# > 成长,尝试独当一面...
#
# > Don't be afraid to fail... We all fail... 伟人之所以伟大是因为他们会审视自己的错误和弱点，然后找出如何规避的办法。所以我知道了那些在遭遇现实，尤其是痛苦的障碍时取得最大进步的人，能够学到最多并且比不这么做的人更快得到自己想要的东西。我知道这些人是非常棒的人，是我希望出现在我周围的人。
#
# > 如何制造出最好的灭蚊器具???
#
# ![Where is beauty?](https://dn-linuxcn.qbox.me/data/attachment/album/201703/28/234957khs4m35meeum46hm.jpg)
#
# ---
# # 20170330 Thursday
#
# > 办公设备,基础设施,等等这些部分的docker化,就是使用程序或者代码自己搞定所有配置,作为用户,用户友好,或者傻瓜化就好了,细节底层都交给机器或者程序员来搞就好了...
#
# > 通用的方式/算法 就能搞好安装打印机驱动等等这些小CASE,很容易,但是对于不熟悉,不了解,不需要知道这些的人,应该使用更加智能化,用户友好的方式去自动帮他们安转,解决他们的需求,作为工具一样,捡起来就能用了...用得很方便,很爽?
#
# > Don't be fooled by what you see, try to figure out the underlying hidden true variables...
#
# > Apache 的 climate 工作台,类似 科学 工程 模拟软件... How do they do that?
#
# > Windows赢了桌面，而Linux赢得整个世界...懂得从小培养用户的windows,即使不是特别专业,但是用户友好,解决能用好用的问题,就98%的PC市场;而注重DIY,钻研,科学/工程的linux可以说什么都能干,还特高效特牛X,但是必须要足够专业了,就相对小众了...
#
# ---
# # 20170331 Friday
#
# > 南辕北辙, 缘木求鱼, C Govement干太多SX事情,或者根据就是为了自己目的而进行的...哎,什么时候大家都抗不住了,要闹那个的时候...
#
# > 如何才能足够聪明,战胜它们...只能承受而不能反抗吗?
#
# > 不仅要发现问题,更要分析问题,和解决问题...Can you do it?
#
# > 今天看到最又道理一句是: 结婚前以为一起都好办,结婚后才发现那么不容易...
#
# ---
# #### We have dealt with Uncertainty for a long time, keep fighting it, use math, use your intelligence, use you algorithm.
# 不管在哪个行当、不管收益多还是少，聚会中几位朋友对未来的感受却相当一致：**不确定性**
#
# 一个关于“不确定”的故事：比北京房价更意外的事将连续发生
#
# 最近两年，出现了一连串让人意外的变化，它们改变了逻辑、改变了预期、改变了故事的讲述方式。所谓的“黑天鹅”正发展成为“黑天鹅湖”。
#
# ---
# #### 确实需要使用更好的工具(hammper锤子) 来提升自己的效率,然后把节省的时间花在思考,自我增值上面去...
# [来自SMZDM](http://post.smzdm.com/p/545857/)
#
# 我觉得应该花点时间找找Google,找找类似想法的程序员们,精英们的工具,学习他们,使用它们,应该会又开源版的程序实现的...
#
# - 本地/本机搜索软件: Everything/xSearch
# - 桌面日历
# - 思维导图软件: xMind ()
#
#
# ---
# # 20170401 Saturday
#
# > T+1 -> T+0 有延迟 向 无延迟 实时发展， 集中式中央式 向 分布式零碎式 发展
#
# > SQL关键词的全部大写，在DataStudio直接 ctrl + alt + p 就可以了，关键其大写，notdpad++呢？ Google IT.
#
# > Tell her how I/man feel about her, when you know, seeing this situation and you dress/behave like this, it really can't control yourself biologically... you just want to do it, like a devil inside you force you to crime...
#
# > 毕竟是身体,那是最重要,不能乱来的,没有第二次机会的,不能让无知伤害了身体,所以关于身体健康的部分,必须找充分必要的信息,才能决定!
#
# > 量化支持，量化意思是 用户 提出了一些需求，问题，然后想得到答案，然后查询下这个量化指标/能力就能自动达到他的答案了，就像自动驾驶汽车的分级L1 L2 L3 L4 L5 等等，直接看等级/数值，就能知道具体情况了，如何让算法/机器学习来计算这个量化指标，以前都是人工认识问题，分析问题，提供指标计算方式，现在应该使用智能，更多数据，更大计算量的机器去完成了。 譬如：我想问问我用树莓PI能不能完成我的日常工作，上上网，浏览网页，看最小的视频，等等，如果这些用户动作所需要的计算量可以直接量化，然后再查询下树莓PI的计算能力，就能得出自己的结论了，不需要自己具体去实践了，因为他们已经实践量化好了，我们只需要使用这些计算好的治标/知识就能够很好地得出问题的结论了。。。
#
# > 开源，社区，群众思维，如何使用现在/将来流行的模式来解决问题，SQL格式化，标准化，这样SQL看起来大家都看懂，好看好用。
#
# > .ai 和 .com 投资人的想法，头脑灵活，逻辑清晰，信息把握准确，模型精准...
#
# > 人生需要有目标，特别是那些让我们翘首仰望，要使劲踮踮脚、甚至拼命跳起来才能够到的目标。它激励我们一路向前，不断学习，不停生长，蜕变成一个更优质、更强大的人. 但当你的才华撑不起梦想、能力配不上欲望的时候，你一味学着别人花花花、人前显贵人后受罪，那不是励志，只是虚荣。**需要培养自己，投资自己，让自己的能力能够支持起自己的野心，去实现全局宏大的目标，找到全局最优解**
#
# > 目前聊不过，玩不过组长啊。。。她抛了一个小砖头，我就开心得暴露自己了。。。
#
# ---
# #### 这个很有道理 [爱花钱和会花钱](http://jinrongbaguanv.baijia.baidu.com/article/814371)
# 爱花钱，和会花钱，根本是天壤之别...
#
# 真正会花钱的人，都有会赚钱的思维。
#
# 他花的每一分钱，都是在投资自己的知识、能力、品位、眼界、格局。
#
# [阶级固化问题](http://trj.baijia.baidu.com/article/813245)
#
# **更优越的家境，使得他们在刚开始的是不用担心太多，考虑太多目前的问题，而是有时间积累，让你在更长的时间尺度上做出更正确的决策。。。**
#
# ![新一代的社会百态](http://d.hiphotos.baidu.com/news/w%3D638/sign=c23880168b025aafd3327dc8c3ecab8d/8718367adab44aed3d587832ba1c8701a08bfbd6.jpg)
#
# ---
# #### Oracle 和 DB2 的不同
# ```
# select round( 1/3, 3 )
# from oracle_table;
# --- 结果为 0.333
#
# select round( 1/3, 3 )
# from db2_table;
# --- 结果为 0
#
# 可能他们执行不同的策略，oracle把两个整形都升级到浮点数，然后让他运算了，得到小数/浮点数结果，
# 但是DB2它当成了是两个整型运算，需要浮点运算的时候需要明确告诉db2需要执行浮点运行，*1.0就好了
# ```
#
# ---
# #### 元气白米饭
# 富含阳光的能量，能够照亮心底最深的地方，以及放肆背后的心酸。。。这一次洋葱放多拉。。。
#
# 也许东西真的不多，但是学会利用好手上的资源，用心做出朴实巧妙的饭菜也够了，对不？
#
# ---
# #### 清明 == 清风日月明？
