# %% [markdown]
# # 20170704 Saturday & Sunday
#
# > Visit Of An Old Friend... 本科 小涛子又来 high了。。。 赵工头太忙，没时间逛，大家都不容易啊。。。
#
# 能别裸辞就别裸辞把。。。
#
# 工作了，要有自己的项目经验，独特的贡献，独特的看法了。。。
#
# 不要怂，学会怼那些混蛋，吓那些换人，毕竟我们都是死人堆里出来的，为啥害怕他们这些魑魅魍魉？
#
# 阿里小号。。。
#
# 有空去老同学们聚聚，交流学习，换个城市看看~~~
#
# 代码发展 和 知识发展都是一样的，都存在副本之后的更新异常，错误传播，由于 copy 过来的一份代码/知识，然后加工，有副本的存在，导致一个代码的bug随着时间/复制的变多，分布更加广泛，发现之后很难修改，修要层层修改，其实像数据库的范式，相同的东西，整个系统就一份就好了，不会更新异常，一次修改，出处可用，然是这样子适合oltp，不太适合olap的方便可用。。。更多修改，如何理解等等的，目前就只能靠程序员来修改完成，麻烦，痛苦，摧毁人的创造力啊，如何让程序自己/机器自己去完成这些事情。。。?
#
# 充分竞争，自由的市场，内在驱动性会使得利润率慢慢降低到社会平均水平，不会暴利，也慢慢自然选择/进化出优质的商品，但是某些土工的权力导致的稀有商品，或者人为人工明显的部分会不使用学到的，以往的经验归纳总结，导致部分行业是暴利的，不合理的，正常应该是 创业 发展 成熟 衰退 这样一个流程，对应它的利润率，刚开始会高点，然后有更多资本进入，人往高处走，水往低处流，资本往利润率高走，就像一个势能空间，人为然后总体概念的自发形成...
#
#
# # 20170703 Monday
#
# > 禅饶画～ 《零基础创意禅绕画》 Book Or Video 在线教程...
#
# > Python... 自动下载网页上面我要的某些信息到本地硬盘，爬虫干的事情，嘿嘿。。。
#
# > Python 网页编程...
#
# > 企业知识图谱集中统一管理，企业知识天然分散，零碎，模糊不一致问题。。。？
#
# > Markdown 与 PDF，文档发布。。。Latex...
#
# > 应该注意到 People + Time 可以产生巨大的价值，实实在在的物品 与 感受到的服务/知识
#
# ---
# #### 创业的几大离散分类：
# 1. 模式一：“YC模式”
#
# 初次创业 + 有限的专业经验 + 行业/产品专家
#
# 我称这种模式为YC模型，因为许多Y-Combinator孵化的团队符合这个模式：职业生涯前或职业生涯早期创始人的第一家创业公司，但他们具备的编程和/或产品经验与他们想要颠覆的行业相关。在我们的投资组合中，有两家公司在这种模式中脱颖而出：
#
# Farmlogs：给农民的软件。他们实际上是一个YC团队，两位联合创始人在学校就创办了公司。 两人都是黑客，其中一个在农场长大。
#
# Shipbob：简单、快速、便宜的实现电子商务。另一个YC团队， 这两位联合创始人在职业生涯早期都是开发者，一人来自我们投资的另外一家公司，另一人来自德勤。他们在创立Shipbob之前曾涉足电子商务领域，创立Shipbob就是为了解决他们曾经遇到过的问题。
#
# Terminus和FourKites的情况类似，都是相对早期的职业团队，在他们的市场上有直接的产品经验。
#
# 为什么这种模式通常是可行的？早期的职业生涯、第一家公司，这样的团队几乎没有可失去的。 他们通常是未婚，没有孩子，灵活的。 尽管根据定义，这些团队在工作上有很多需要学习的，但早期他们通常是有现金效率的，他们不需要或想要高薪带来的稳定，他们习惯于自己动手。在哪些已经开始了职业生涯的团队中（不是直接从高中或大学毕业创业）他们可能是单个的贡献者，而不渴望自己建立大型团队。 最后一点 ，同样重要的是，这些年轻的团队只有足够的经验看到并希望解决一个行业的问题，而不会因为需要改变的规范而受干扰。 向YC致敬，将这一模式产品化。
#
# 因此，“YC模式”的团队可以有效地找到匹配市场的产品，同时保持资本效率。他们灵活敏捷。不稳定的方面是在招聘，管理和组织机构方面缺乏经验，不了解复杂的市场动态和与投资人合作，他们倾向于在找到匹配市场产品后进行业务扩张。 他们也可能不擅长企业级销售，这是一种需要多年经验的技能，因此即使不适合，也默认使用更轻的销售模式。 我很高兴地说，我们上面的团队都通过这些挑战。
#
# 2. 模式二：“成功创业，再来一次”
#
# 成功退出了的创业公司 + 广泛的专业经验 + 行业/产品专家
#
# 这个模式看上去比较无脑。成功做过一次，那就再来一次。
#
# 我们的投资组合中最好的例子是G2Crowd，B2B软件领域的Yelp，其创始团队创立并出售了Big Machines。我们投资了一些这种模式的公司，包括Truss, Hubdoc, Lookbook, Catalytic,和Upfront Healthcare.
#
# 虽然这些团队可能会烧更多的钱，但他们在职场上需要学习的东西是比较少的，所以是有效的平衡。他们也为投资者赚了钱，因为这样才能获得资本。 作为拥有丰富创业历程的创始人，他们也知道如何吸引人才，组织机构，向大客户销售，开拓市场，与投资者合作。 最后，如果他们自己名气足够大，他们以前的行业角色可能有助于让业界注意到他们。
#
# 然而，这种模式并不是没有风险。 经验丰富的团队也会犯错误。 一个常见失误是融资过多，过快，估值过高。这限制了公司的选择，如果团队没有达到投资方的要求或者烧钱太多就会出现问题， 虽然经验丰富的团队更有可能打好计划，但它仍然是一个创业公司，有很多不确定性。
# 还有哪些可行的模式
#
# 三个维度，每个维度两个级别=8种模式，我们目前只谈了其中两种。 其他6种怎么样？ 事实证明，当团队在目标行业中不具备行业和/或产品经验时，我们几乎从未看到成功的案例。 罕见的例外是新兴市场，在消费级创业公司中（想想2005年的社交）更常见，但B2B就很少。
#
# 3. 模式三：“CXO转为创始人”
#
# 初次创业 + 广泛的专业经验 + 行业/产品专家
#
# 这比较难的一种模式。这种团队经常有一堆CxO（经理或“领导”），他们一开始他们从一开始就想要高薪水，员工为他们做所有事情。 他们了解很多关于管理现有组织，但这和寻找PMF或可扩展销售无关。 这些团队快速烧钱，经常失败或很快解散，因为他们的财务和情绪不和谐，冒着真正的风险将他们重新投入到公司的工作中。 我们很少在这种模式下看到成功，从中可以看出企业管理者和创业公司领导者之间的一些根本性差异。 请注意，我刚才所说的一切都适用于“IT”软件初创公司。 生物技术和医疗器械是非常不同的 - 资历和多年的科学经验和知识是很重要的，而且经常有漫长的学术和企业经营。
#
# 4. 模式四： “明星创业者”
#
# 创业公司成功退出经验 + 有限的专业经验 + 行业/产品专家
#
# 即使这种类型的团队还很年轻，缺乏经验，但他们经历过成功，而且经常可以再次成功。他们第一次退出可能是体面的甚至卓越的。但现在他们想要一次更大的成功。主要风险是傲慢或错误归因。 年轻的成功创始人（以及追逐他们的投资者）可能将成功归为在正确的时间正确的地点做正确的事情。做正确的事是容易复制的，来自于判断和技巧，而不是运气。更成熟的团队往往会避免这种错误归因。 作为投资者，这是也是评估的关键。
#
# 请记住，这些只是经验法则。 总是会有例外出现。 我喜欢被证明是错误的，我知道很多人会证明我所说的都是错的。
#
# ---
# #### A sense of lost...
# - 观念落后，设备落后，行为落后，劳动力密集型，人家都往智能化发展了，自己的自动化还是一塌糊涂，大量人肉运维管理，浪费人力，效率低，产出少
# - 资本本位，资本密集，对人才的忽视，毕竟人多，这么多年来，都是靠粗放的经济增长带动资本增长，人才不重要，随时换点人就能干，平凡普通人才就有极高的可替代性，当人就是流水线上的工具，要不更换，要不绑定他，让他只好给自己打工
# - 多年来积累下来的习惯，风气。。。有点点不乐观。。。Ji Zhong Nan Fan...
#
# ## 重新整理自己这一年来的Jupyter笔记，感触良多
# - 最近代码写得便少了，需要改改，IT 与 金融 两条线都得走，都得熟悉，拿起来就干
# - 找回刚和她在一起的时候的日记，哈哈，有种说不出的羞涩和幸福～
# - 开始时候还是要规划好的，至少简单的数学计算，对工作量的衡量，大O需要计算出来，对Cost有概念，然后就知道怎么选择了，要长远看规划
# - 看看今天的工作量，其实开始的时候就可以大概估计，知道需要的时间了，还是很多的，该果断果断，有花堪折直须折 莫待无花堪折枝
# - 最近网络管控严格了，公众号和百度百家的文章相对便少了，所以最近自己看得文章也相对少了，难怪总缺了点什么，找个地方可以看高质量文章，还有是像日程哥那种会折腾，熟悉新鲜事物的才行啊，It's My Life, Stay Hungry, Stay Foolish, Stay Young.
# - 刚才整理文档的时候，都是自己人肉手工加工制作，辛苦啊，做少量的熟悉还是可以的，但是量大的时候，只能找人或者机器来替代进行批量操作，要是我有个很简单的方法和机器交流沟通，告诉它我的需求，然后它就自动帮我完成转换加工就好，自动化/智能化的思维一直都要有。
# - 回顾这毕业的一年，成长不是很多啊，抓紧时间啦啦啦！
#
# ---
# # 20170704 Tuesday
#
# > 就像 ODS -> 中短期，检测，监控，浅度分析; DW -> 长期，决策，规划，深度分析
#
# > 人肉填写，这么长的数字填写有误，很正常。。。毕竟是人啊，如何解决？
#
# > 自动化的思维，把目录数据导出来，然后 python 把我想要的结果匹配显示出来就好了。。。
#
# > 这些作业的代码库呢？ 如何设计和保证存活？ 生产有一份，开发有一份，版本管理软件有吗？ 版本管理服务器有数据备份吗？
#
# > 我靠，真正人肉运维，直接让你导入 几十个作业，一个一个导！！！ O(n)，而且n不少。。。天煞的。。。
#
# ---
# row by row，一行一行，一条一条地导入，累死人的，应该同时提供 一行一行 和 批量操作，或者提供个 一行一行的 API也行，我自己导入，好不好，你TM的。。。作业就一个个躺着在那，你却无法全部选上一次性导入，绝望。。。CTM...
#
# 太多东西低效，没有自动化，需要大量人力来保证没有问题，结果是需要很多人手，然后人还干得很辛苦，却产出价值非常低的东西，年轻人受不了啊，不想成为旧一代，过时的，自己讨厌的人啊，不干了啊，传统这些该被市场淘汰的制度/公司，应该就被淘汰，好事情,这很合理，也很正常。
#
# 可以用软件来做的东西，软件测试，自动测试，给出返回码，他们用人来做和保证了。。。MD
#
# 干得很累，却没什么收获，产出投入比低，效率低。。。
#
# 企业，个人，都 Trap 在各种琐碎的小问题，小细节，并没有释放生产力，只要释放出来，是巨大的价值/市场/提升。
#
# 企业内部知识分散，没有什么渠道很好地共享，使用。。。 以前可能是最原始的 文档（静态）- 论坛（动态）- 新设计（如何很好的实现静态，动态，分享？）
#
# 软硬健，何司机经常犯错误，许多问题的根源就是只有一个小屏幕的原因所导致，但是如果又两个大屏幕，那就效率高，准确率变高好吧！
#
# 它精打细算地控制成本，但是完全没有考虑到使用好点的设备，好点的待遇给员工，所带来的效率提示，导致更高的利润和利润率。。。它就是这样子，找到的解非常局限，没有在 空间/时间 更广 更深 地找到解。。。
#
# 这时候就多学多问，多增长自己发现问题，解决问题的能力把。。。
#
# 其实看见见，显式的错误很好办，一般又办法解决，更可怕的是看不见/隐藏的错误，你以为是成功了，但是实际是又错误，有问题，这时候数据质量很难保证，常常在使用的过程中才会发现问题，但是还不一定找到错误的原因。。。
#
# ---
# #### 产业，和它配套/周边的产业，和人
# 《王者荣耀》刺激了直播、电竞、周边等多个产业的发展，“养活”了一大批人。除了这些摆到明面上来的《王者荣耀》周边产业，代打这项处在灰色地带的产业也分得了一杯羹
#
# ---
# #### 乐视模式，互联网+电视，它的商业模式是很好的，就是玩资本玩歪了
# 乐视电视强调的是性价比，通过电视搭载的广告和互联网视频内容获得的收入补贴硬件，给国内电视市场造成了很大的冲击。在乐视电视的刺激下，传统电视品牌海信、TCL、创维纷纷推出它们的互联网电视品牌。
#
# **什么是互联网思维？**
#
# 他们的确是看到了这个国家，人民 的本质把，或者看准了市场需求，相对低价的硬件，但是质量又要有保证，于是把成本隐藏在其他地方，在广告里面，或者在付费节目里面，会员付费模式 是国外的 netflix 模式，然后广告模式应该是互联网厂商常见模式了，他们就是看准了人们长期/历史的心里，便宜，免费，和传统的电视厂商不一样，他们对同一个广告电视的看法/分类 不一样的结论/看法 导致了他们不一样的行为，也导致了不一样的结果，作为一个局外人，或者第三方，如何看待这个结论，谁对谁错，自己不好判断就让市场自然去选择把，时间/市场 会给你答案的，但是如果你能够 碰巧/真实 能够预测这个结论，那是666，如何看一个分类器的准确率，要看它的混淆矩阵，但是矩阵的数据需要很多次测试得到，是平均情况下得到的，而不是少量次数得到的，可是一个人的一生，重要的机会就真的只有那几次。。。
#
# ---
# #### 确实，在过了烧钱期后，大家用滴滴变少了，是成本实在降不下来，还是人民没钱了，还是滴滴作为竞争垄断方拿太多了
# 滴滴说，动态调价后的费用全部归司机所有，滴滴不拿群众一针一线，这种自证清白的辩解实在好笑：从滴滴叫来的车、在滴滴上付的款、最后你滴滴把锅甩给司机，你们这是在做生意还是作案？群众已经被放血了，TA管你是国军还是伪军。
#
# 过去三年，随着滴滴的不断壮大，用户对滴滴的「好感度」是在逐步递减的，从最早的「我擦，这么便宜」，到后来的「出租车之外幸亏有滴滴」，到「滴滴叫车还是出门拦出租车」，再到后来的「滴滴叫不到车，出门也拦不到出租车」，直到最近的「宁愿马路边等出租，也不叫滴滴」……就像儿时吹过的牛逼，眼见着一个接一个破灭了。
#
# 一家公司，用了不到5年时间，烧了上百亿资金，歼灭了一个又一个强敌，最后统一了江山，但几乎同时也失去了民心，到底发生了什么？
#
# 互联网领域的一个通用法则是，赢家通吃。当一个产品、一家公司在某个市场占有绝对垄断地位的时候，它就有了定价权。比如百度，自从2010年谷歌退出中国之后，它就在搜索市场一家独大，超过80%的市场份额，各种姿势的赚钱，别说三个自信，三十个自信都有。
#
# ---
# #### Agar.io 很反映社会现实的小游戏
# BAT 就像里面的超级巨无霸，各个小点就是个人，然后相对大的是中小企业，中小企业靠某个风口突破，想跟上BAT步伐，达到同一个数量级还是有差别的，很大差别，网网就被BAT布下的局/陷阱 给坑死了，市场的马太效应，如何破局，如何实现，当你在研究前沿方向，在研究AI的时候，他们也在研究，而且更多的资本，更多的人才，更多的时间;你就只有机会窗口，相对灵活，创新，如何像AlphaGo一样刚他们？
#
# ---
# #### 看看现在社会上低头看手机的 小孩，年轻人，中年人，老年人
# 人手一台，而且是零碎时间占有，总体来所有人口，还有人的时间，还是消费品，消费升级，难怪那么多厂商在之前就布局手机，应该是前沿研究出来的结果，就是有相应的分析企业/部门/人员 在研究这个手机到底会成怎样的规模，将来是什么样子的，这个投资值得不，等等。。。
#
# 人机交互，人机接口，VR，AR，眼镜，可穿戴设备...
#
# VR 应用，譬如置身完全虚拟的世界，这个跟现实世界没有任何区别，譬如你可以直接处身与太空，火星中，游戏方面的应用多。
#
# AR 应用，半真实半虚拟，立足与现实世界，然后可以用软件的思维与现实世界互动，虚拟成分，成本低，就像在 软件 和 硬件结合，软件相对成本低，硬件相对成本高，但是由于有虚拟成分，可以在构建硬件前就可以 所见既所得，在硬件量产/实际动手前 就得到了产品的结果图/体验，所想既所得 在精英层更多，威力更加巨大，理论能力更强; 但是根据99%的原理，绝大多数人还是喜欢/只能 所见既所得，也许就是 office 要比 latex 流行多的原因之一把（更有可能是微软的阴谋啊，从小到大免费的office，后来你发现你被放长线钓大鱼了，免费馅饼的陷阱，失去是使用更好更自用的latex，套路/策略/诡计，我们更需要的是独立自主可控，开放包容，在全社会全人类全互联网的头脑风暴中找到更优更好的解，而不是局限于效率低下难看难用的office，Long Live RMS!） 这个跟低成本的3D打印机类似，开放了硬件设计的源代码，使用3D打印机就能快速低成本地做出产品原型，然后根据使用，错误/误差 快速迭代得到更好的产品。。。或者是开源硬件 Arduino 它也终将以开放硬件，开放平台，快速迭代，教育，用户个性化，创意，不断迭代出更优更接近用户的产品，走出一片天地。。。
#
# **软件思维，设计模式，互联网思维把？ 开源硬件** 开放设计，开放所有资料的时候，给予所有自由度，结合创意与时间，能出现很多神奇的东西。
#
# 手机成了大家的必备品，我们要么把它拿在手里，要么揣在兜里。然而，未来的年轻人们可能会像听古老传说一般对此感到讶异。多年之后，人们可能只需向隐形的麦克风低声轻语便可下达指令。要是想开个会什么的，我们无需到达现场，耳机就会自动从我们耳侧出现，每名与会者的眼前还会同时出现虚拟屏幕，显示会议状态。
#
# 到那时，手机将不复存在。或者说，我们人类自己将与手机「合二为一」，全天候彼此互联。
#
# XD 84 的小猫好搞笑，很萌，偷画一只给她拉...
#
# ---
# # 20170705 Wednesday
#
# > 写个自动备份我的 sh SQL 后缀的代码，扫描硬盘，发现这个后缀的，自动备份到我指定的目录，Simple Python. 其实还是版本管理的问题，害怕丢失源代码，丢失数据，使用Git就好了，用Git来管理，结合Git Ignore，忽略不需要的文件，只要自己的文件，那就好办了。。嘿嘿嘿
#
# > 堡垒机的又被我锁了。。。搽，以后搞小事情要谨慎，狡猾得像一只狐狸，糖衣炮弹，吃了糖衣，让掉炮弹。。。
#
# > 百度了下 PBT 的自行染色过程，键帽 + 染料 + 教程 + 思考，低成本，简单漂亮～
#
# > Python 网页编程，批量下载，自动下载，爬虫般的应用。。。或者桌面提示，相当于日历。。。
#
# > 很久没有上过 scholorpedia 了，类似 wikipedia 的地方，不过更像是学术的
#
# ---
# #### 百度的AI大会，想做AI时代的Android？
# 有空的了解下，外面世界的发展啦。
#
# ---
# # 20170706 Thursday
#
# > 不小心用脚本把自己的帐号锁了，基本的安全还是需要的，幸亏这个锁不是永久锁，是暂时锁，嘿嘿嘿。。。
#
# > DataStage 的输出阶段，生成落地文件应该是可以该编码的？ 简短 NLS映射，改成 utf8 可以不？
#
# > 如何判断文本文件的编码格式... windows, linux ??? google it. file -i can do it... UltraEdit can do it...
#
# > 我需有一个好用的 OCR助手，把区域内的文字识别出来，识别成一行一行的 txt 也是极好的。
#
# > 其实大部分企业员工都在 复制 - 粘贴 中，如果有个很聪明的AI帮那你自动复制粘贴，heihei!
#
# > 自动在多个文件里面进行匹配对应。。。给颜色提示，绿色100%，蓝色，红色？ 好好用，给用户用得爽，就像那个王者农药，用户打得爽。
#
# > 愿我出走半生，归来仍是少年... 你出走半生，归来仍是少年吗？
#
# ---
# #### 大部分学生都是 Consumer 模式，工作之后才是 Producer 模式
# Consumer当然爽啊，花钱买服务; Producer是化精力赚钱，苦逼，但是要是真正又自己的贡献，自己的产出，创作的快乐也是存在的。
#
# Excel 等这些二进制文件作文多人共同协作 做数据字典，是个噩梦，需要的是一种纯文本的，类似 csv 等等 Json？格式，好用，方便，漂亮，CREATE SOME RFC...
#
# ---
# #### 玩了下属于 STEM 游戏的 纪念碑谷
# 好玩，哈哈哈，需要不少的想象力，虽然看似不可能，毕竟不是真实空间，或者在更加高维度的空间，在低维度许多不可能的事情变得可能了，然后所以才有所说的降维打击，高维度的企业（新生企业，互联网企业）会有降维打击传统企业的情况，这时候许多在传统不可能实现的被打破。 就像人类在自己常用的长度，质量，时间 在常见长度，常见质量，常见时间 内能够很好地处理事情，但是处理质量更大的车，船，飞机，恒星，我们无能为力，处理小尺度的例子，量子，甚至连细胞，病毒等小生物，我们也无能为力;在时间尺度上，长期的生物演化我们看当前/短期更重，长期，全局的能力相对较弱，也有一定的因素。。。
#
# ---
# #### 以后回来赶紧洗个澡先，清醒好多啊，哈哈，别浪费时间了。。。
# 同学说得对，现代的企业厉害在于在工作的时间就榨干了你的体力/脑力/精神，所以回到家里面就想行尸走肉了，不想动了，不想动脑子了，就像摊着/躺着玩手机/平板，连对着电脑的也不想了，对了一天电脑了，就想看那些只会让你笑的娱乐/游戏了，有水平，需要思考，高级的知识反而不流行，不重视了，他们研究深刻啊，所以把资金都很久就投向 手机/平板/娱乐/游戏/直播/短视频 因为他们在更加高维/高阶的维度去思考，看到人们工作累了，回到家就是不想对着PC，对着更好控制的手机/电视就好了，考虑到这个现象/趋势，果断适应他们啊，自己的产品就是针对这个现象的，就像游戏都是针对人的心理的，就是想你越吃越想吃，越玩越想玩，需要你的人，需要你的时间，需要你的消费。。。
#
# 但是作为一个能够回顾/自省的人，常常回首自己的过去，看看别人的过去，看看自己的现在，看看别人的现在，我们应该能感知到这趋势，同时别人设下的产品，糖衣炮弹，应该能够克制自己，虽然自然发展让我们更偏向最近，相对近视和贪心，但是应该想办法在更广的空间和更长的时间尺度上去找出更好的解，一层一层地深入，观察，作为三方，上帝视觉一般地跳出自己所处的环境/整体，去观察，去思考, AS An Observer... 提升自己，让你的对手慢慢从普通人到精英到上帝，如何胜天半子？ Improve Yourself... 有策略，有规划去实现，长期规划，中期规划，短期规划。。。
#
# 机械键盘真心好用，青轴 啪啪啪，茶轴 中庸也不错，现在感觉敲起字来，停不下来啊，不知道是思绪停不下来，还是键盘让我的手指头停不下来了。。。
#
# ---
# #### 唐老总还是看了好多文章，交流不少的
# 分布式计算的主要理念，跟 CS Foundemental 存储的等级架构 Memory hierarchy 对计算的速度也要有概念，多少ns，多少us，多少ms，多少s，人类对时间的大概也就是50ms左右，小于个间隔，感性认知的人类就分辨不了了，虽然在数值上是可以分辨的，等等，有体验，有记忆，才会对**单位和数量级**有概念。
#
# cpu 寄存器
#
# L1 Cache
#
# L2 Cache
#
# Main Memory
#
# Hard Disk
#
# NetWork
#
# 有个老外把 比喻 恰当，恰到好处 把自己当成cpu，寄存器就是台面的的书，然后L1 L2旁边的书架，MM就是隔壁堆书的书房，Hard Disk就是本市的图书管，NetWork就是坐个去另外一个城市图书馆拿完书在飞回来，最关键的，和cpu对比，数量级的比例是一样的，神了，从比例的角度来看，从人的时间尺度就有感觉了。
#
# 搬数据是计算机常常做的事情，数据搬来搬去成本很高，在同一台机器总使用内部各种总线协议来搬数据已经很慢了，然后如果通过网络来搬数据，也就更加慢了，但是计算能力很好搬啊，以前是把数据搬到计算密集的地方计算，现在分布式是把计算搬到数据处，就是尽量不通过缓慢的网络来搬数据，而是尽量把计算放到靠近数据的地方，越靠近数据，成本越低，时间越短，响应更快.
#
# 同理，在我们的人类社会，同样有 memory hierarchy 效应，都是 快速的优质的服务价格贵，然后中等的服务价格还好，中低的服务价格低。
#
# 程序的局部性，时间的局部性，空间的局部性，因此cpu里面有分支预测的部件，原来的应该是基于专家的规则，然后越到后面是复杂的机器学习算法带来更加准确的预测了，更好的性能，更快更准。。。
#
# 住房公积金异地转移接续平台全面投入使用，使住房公积金在全国范围内实现了“账随人走，钱随账走”，达到了让信息多跑路、群众少跑腿的目标，提升了住房公积金服务效率。同样的道理是搬动数据要比搬动人的容易得多，成本低的到。。。
#
# Cost-Based Optimization <-> Oracle
#
# Rule-Based Optimization <-> China Tradition Enterprise
#
# Book: CSAPP, Computer Science, A Programmer's Perspective:
#
# [The Memory Hierarchy](http://www.wowotech.net/basic_subject/memory-hierarchy.html)
#
# ---
# # 20170707 Friday
#
# > 南京烽火星空通讯 的IM 加上自定义收藏的表情啊，不然每次自己点多3-4次，去找，去浪费用户精力/时间去发表情，体验糟糕，需要极致体验，最优化。。。
#
# > 经常遇到的不一致，就是 生产环境 和 开发环境不一直，不同不，程序智能在生产环境才能跑，开发环境根本跑步动。。。
#
# > 怎么可能让这些小问题破问题，困扰我，阻挠我前进，碾压/碾碎他们。。。Fight For Something Big Really Big...
#
# ---
# #### DEVOPS 这样可行吗，直接使用容器可行码？
#
# #### SCP SFTP WinSCP + Putty，现在这些小工具，真心要去Google+官网才是正解，百度+不明出处 == 灰色产业 坑爹变现骗钱
# ssh上的传输文件的好工具。。。
#
# ---
# 现在技术的发展趋势是，少数人+机器 可以很好地服务地球上的绝大多数人，以往的传统是因为人的经历是有限的，只能接触服务相对少的人，而又根据经济学常见的28原则，社会80%的财富被集中在20%的人手里，所以传统银行都会很好地服务高净值的VIP人群，这样也合理，比较资本也是贪婪的，在有限的人力成本下最大地获取利润，但是这样普通人群就很少有相应的服务，这是相当于没有开发的市场，还有很多机会在这里，或者就是之前提出的长尾理论，就是市场上还有很多没有得到服务的人群，服务好他们，也是一个风口，利润增长点; 但是由于技术的发展，使得少数人+机器就能服务人群几乎没有边界，它的技术能够弹性水平扩展，使得传统的问题都不是问题，增加新用户的成本接近零，所以用户越多，他们还是没有管理压力，没有人手不足的压力，这样普通人群也就有了以往没有的服务供给，这样需求方和供给方 顺利连接起来了，市场自然起来了，也许不再符合28定律了，利用长尾里面集聚的财富，也许能够超过传统的28里面所获取的利润了。。。
#
# 回顾人类发展史，在新技术的革命下，又各种巨大的风口和增长点。但是当技术发展一定之后，技术平台就这这，技术平台无法跃迁，只能在这个平台上面小修小补，属于细节优化的部分，寻找更优的解，未开发或者未服务好的市场，像长尾和共享经济。。。
#
# 依然是技术革命和技术改革的区别，导致整体上层的区别 ，联系上了，技术短期并不是带来收入或者地位的，它影响人类长期发展的基石，长期到许多人的生命周期并不能体会到，所以技术也就不那么重要，在短期中起作用的更多是非技术层面的事物，例如？
#
# DataStage 的设计如何进行版本管理？ 它的源代码也是文本文件形式码？不能进行版本管理。。。我去。。。
#
# IBM的所谓。。。伪并行，伪集群把，把代码放到很多台机器中，但是实际只有一台机器运行统一份代码，其他机器会运行其他代码。。。达到资源利用的目的把，但是跟分布式计算中的把计算搬到数据处，同一份代码同时运行有着本质的差别。。。
#
# 多分代码，多分副本，人工运维，必然会出现不一致情况，必须使用工具，使用软件来保证这些代码的同步一致，就像用数据库保证ACID一样。。。
#
# ---
# #### 纪念碑谷 玩完了 几何 挺好玩的
# 这个很不错的小游戏，关于几何，立体几何的，有历史出处的，利用视觉的错位，做到了在3维世界无法实现的事情，很好玩，也很益智，难道总体来说难度不是很大，在于相对短期/贪心的策略就能做到很好，规则/规律简单，整个搜索树深度不是很深，使用几个简单的套路和贪婪策略就可以求解，有些游戏是需要思考深度很大的，博弈树走的比较深入，高度比较高才能找到问题的解，这个还好拉，毕竟要考虑面向的群体，你想干什么，太简单，没人玩，太难，也没人玩，如何恰到好处，难倒一些人一段时间，然后他们实际又是可以解决的，有成就感，在游戏中感到快乐，自我肯定，心理学的东西，生物的东西too，分泌幸福多吧安？ Anyway, 关键是它把 相对枯燥的数学知识，结合了讲故事的背景，讲了一个引人入胜的故事，小公主的任性，贪玩，盗取了神圣几何，导致整个王国陷入困境，小公主需要打破几何层层的困局，逐个归还神圣几何，最终成功解救了王国，自己也赎回错误，最终成长为真正的Prince... 话说，那个图腾真的是亮点啊，他们应该也是有头脑风暴的，相当于有个游戏的idea，加上不错的讲故事能力，还有BGM和设计，不贵的价格，可以火的，或者出个 IP 来也是一大方法啊。。。
#
# 常常跳出来，作为第三方的观察者，上帝视觉搬地看自己，看看别人，总结归纳，不仅作为游戏的参与者，更可以作为游戏规则的制定者，或者与人做对手，最后与上帝为对手，来博弈啦～？
#
# 或说 以后对APP的权限要高点了，不能随便让APP什么都读取，APP发短信给联通就让我交了10块，交学费了，因为我把APP的权限限制了，不能发短信，各种什么的，就无法扣费，也就没有那么多恶意软件了，说实话好的软件，创意，值得付费的，只是我们思维还没有转变，只会看见的的物质，摸得着的事物才需要付费，实际来说知识/软件，其实背后是纯的人类劳动力，也是脑力密集/劳动力密集的，成本一点也不低的，如果不给这些钱支付与支持鼓励，最终后果就是现在我们PC上面的工具，都是免费，但是实际捆绑了许多恶意软件，都是想办法搞灰色收入了，导致你郭开发的软件不入流，和世界一流企业差很远，正如微软的对个人用户免费盗版视而不见，实际也是策略，它用这个策略抢占了市场，从娃娃抓起，导致更好用，更自由，更自主可能的开放开源linux系统，被扼杀了，它没时间没人没市场去成长，微软是应在了起跑线，输给了中途杀出的开源软件的自由好用前途，但是最终是笑着躺在了终点线。
#
# 怎么看咪蒙？ 她的套路高深啊，对人性的洞察，如何控制人群的思维，知道人们想要看什么听什么，引导他们想什么，这个跟自然科学可以正伪不一样，自然科学会告诉你它所有的方法，你去实验验证把，推翻还是验证都是你的胜利，不是说我对就是对，没有额外的目的，感觉她是带有一点私货，整篇文章，或者前后的文章的背后的背后有一层层的目的，这个隐变量我找不出来，但是大概感觉到吧，就是那种看他不爽，但是又说不过他的感觉，人家的牛也是体验在这个地方啊，写了很多东西，逻辑还是很严谨，你就是找不到问题，只是感觉到有问题。。。
#
# That is why I like something is pure and simple, not so good at handling complicated human...
#
# ---
# # 20170708 Saturday
#
# > Work with Jupyter & Git AT HOME...
#
# > 如何 翻墙 找到 facebook的移动端测试方案，比较好的测试方案，包括性能测试，兼容性稳定性什么的。。。
#
# > 有个妹子想翻墙找些学习资料，但是说实话，配置XXNet不容易，他们写出来，很多人是跟不上的，如何做成一个后台服务的，然后想链接的人自动给他们服务就好了，其实也有人做好了，只是我们做得好的可能被cut了，使用暗网 dark web 的特性用得上码？
#
# > Git的分布式，离线工作，离线版本管理，offline时间机器，太好用，太爽了，去天涯海角，继续工作，继续commit，上线再push/pull，完美。
#
# ---
# # 20170710 Monday
#
# > 小学生放假了，真的少了很多车麽？
#
# > 在机器本地中构建了自己的仓库，可以使用，但是远程仓库依然是在本地，同一个实体硬盘，不同的逻辑分区，这样子的问题是逻辑上是有备份的，但是在实体上是没有区分开，他们都在同一个实体上，注意到 实体 和 虚拟的 巨大区别，你可以虚拟许多东西，几乎没有成本，没有伤害，但是实体成本很重，实体的毁灭会导致虚拟无载体可以依赖。。。
#
# > 工具不好用，用户体验不好，设计就是不好用，实现也是不好用，验收也随便，导致就是大家都很懒，没有约束和要求来得到好的产品，好的用户体验。。。
#
# ---
# #### 分化，多样性，Divertsity.
# 在我们出生的时刻，每个人类个体就开始人生树里面不同的分支，不同的路，区别甚至在born之前就存在，只是树的后面好多好多路，我们都看不清而且，就用自己所熟悉的去归纳总结，如果不能了解到整棵树，结论往往不可靠，要看他所在位置，所看的广度/深度，还有高度，引入更多维度，降维打击，但是维度不是随便加的...
#
# ---
# #### 感觉我需要写个 Python 工程，设计好框架，用这个框架能够快速得到我想要的结果了。。。
# - 运行报告。。。
# - 固定查询。。。
# 找出他们的内在规律/联系，然后使用程序工程来完成。
#
# ---
# 在互联网公司，可以不懂产品，不懂用户体验，但是一定要会做PPT，会吹水扯淡，每个公司每个人都在做生态，做平台，做水电煤气网络等基础设施，消费品，因为大家都看到了老大们都是这个套路啊。。。
#
# Being a boss must be tough... because facing a godlike enermy is much easy than being with pigs...
#
# ---
# # 20170711 Tuesday
#
# > I am confused...
#
# > 破系统，坑人，没走完的流程很明显没有提示，没有提示员工需要干些什么，因为他们思维不一样，思维方式是员工应该去遵守，去记住，但是明明是系统去提示员工，去帮助员工。。。
#
# > 愿所有远方终将抵达
#
# > 愿你爱的人一直都在
#
# ---
# #### 财务软件，excel走起，还是自己动手编程，嘿嘿
# 适合个人/家庭的记账方式？ 理财配资？
#
# #### Planning to 杭州？
# When, How?~~~
#
# #### Something come over my mind.... search on taobao?
