# %% [markdown]
# ![Here should have a nice picture, find it.](http://img.mihuwa.com/mhwimg/2013/03/20130319132551.jpg)
#
# # 20170103 Tuesday
#
# > I am losing control...
#
# > DataStudio 上面的菜单栏很好用的,方便很多,学会使用工具,学会设计工具~
#
# > 存在适合个人项目进度的管理软件嘛?不需要像ZenTao那样大型的项目管理功能,就用简单的就好了
#
# ---
# #### 依然是数据库同步问题,这个需要统一解决的把?
# 定义好规则,写代码就能自动同步东西了;
#
# 同步完之后同时肯定能够自动测试数据质量怎样了...
#
# ---
# #### 注意到许多高级的数学工具是直接支持Latex编写的,因为它就使用文本形式表达,很方便很好用
#
# 作者：王火火
# 链接：https://www.zhihu.com/question/30557267/answer/48623150
# 来源：知乎
# 著作权归作者所有，转载请联系作者获得授权。
#
# 数据挖掘：也就是data mining，是一个很宽泛的概念。字面意思就是从成吨的数据里面挖掘有用的信息。这个工作BI（商业智能）可以做，数据分析可以做，甚至市场运营也可以做。你用excel分析分析数据，发现了一些有用的信息，然后这些信息可以指导你的business，恭喜你，你已经会数据挖掘了。
#
# 机器学习：machine learning，是计算机科学和统计学的交叉学科，基本目标是学习一个x->y的函数（映射），来做分类或者回归的工作。之所以经常和数据挖掘合在一起讲是因为现在好多数据挖掘的工作是通过机器学习提供的算法工具实现的，例如广告的ctr预估，PB级别的点击日志在通过典型的机器学习流程可以得到一个预估模型，从而提高互联网广告的点击率和回报率；个性化推荐，还是通过机器学习的一些算法分析平台上的各种购买，浏览和收藏日志，得到一个推荐模型，来预测你喜欢的商品。
#
# 深度学习：deep learning，机器学习里面现在比较火的一个topic（大坑），本身是神经网络算法的衍生，在图像，语音等富媒体的分类和识别上取得了非常好的效果，所以各大研究机构和公司都投入了大量的人力做相关的研究和开发。
#
# 总结下，数据挖掘是个很宽泛的概念，数据挖掘常用方法大多来自于机器学习这门学科，深度学习是机器学习一类比较火的算法，本质上还是原来的神经网络。
#
# **传统的计算机组成,更多是逻辑,离散数学,接近底层实现,接近技术/实践领域; 而机器学习,更多的是数学建模,连续数学,接近顶层实现,接近科学/理论.**
#
# 国家的快速发展大家有目共睹，但背后付出的惨重代价又有多少人能看到?
#
# ---
# ##### Start To Handle Queries... Learn Business, Understand Them, Kill  Them. The Future Belongs To Us/Programs/Machines.
# 什么是日均存款余额,如何才能精准计算? 分清楚状况,你是要100%精确计算呢,还是PAC的大概准确计算就够了,就像算法/数学一样,是要做到全局最优还好局部最优,累死机器没问题(好像累死机器也是有大问题...),不然会累死自己...
#
# 日均存款余额是将一个季度内一个账户每天的存款余额累加，然后与存款的总天数相除得出的平均数（每季度总天数按90天计算）。平均每日存款额，是金融部门衡量账户日常业务水平的指标。用简单平均方法计算，以某一时间段（如一月、一个季、半年一年）的某账户每日存款余额之和除以该段时间的累积天数，如：把一月内每天的存款余额之和，除以30或31天得出的数就是月日均存款余额，把一年内每天的存款余额加在一起，然后除以365,得出的数就是年日均存款余额。
#
# 计算这些指标,查询Query的时候,不仅要知道精确定义;还有能够无差错的精准实现;更要知道用在哪里,怎么使用等等.
#
# **使用 文字 + 图片 记录我的代办,工作内容等等,算是日记/日志,更是为了后来使用程序/机器学习算法的提供原始数据积累,更是给自己跳出来,作为第三方观察自己的行为,改变自己/改变世界的一种重要方式.得经常观察外界人与事物,同时得学会用上帝视觉来观察自己内在/工作,找出他们/自己的规律/模式,思考要全面全局,对战略方式要把握准确,对具体细节也要深入了解,但是不能因为只把握大方向而忘记了让你翻船的细节,也不能因为卡在细枝末节而忘记继续前行,就是全局/局部同时把握,T两个方向同时要做到,可能很累,Anyway, that is life, isn't it?**
#
# 分主题来查询,自己学习总结,然后慢慢使用简单程序帮我完成基本部分的工作,我自己来完成复杂最难的部分;下一步将会使用更加智能/聪明的程序来代替我的工作,释放我出来,所以罗胖其实很对,未来的风口,AI/ML/DL 这个大方向是很对的了,如何学习理解,应对将来,动脑动手吧,少年~
#
# 发现问题,思考问题,解决问题,不仅有眼前的苟且,还有诗与远方.
#
# 曾经沧海难为水,除却巫山不是云,见识过更加优美,更加精确,更加哲学,更加学术的人和物,其他一般的事物就很哪让我神魂颠倒了.但是她除外,她是高维空间里面的异常点,不知道如何量化描述可视化,但是一旦碰到她我就抛出异常了 =. =
#
# ---
# # 20170104 Wednesday
#
# > 恰到好处的距离,朦胧的美,才最让人心醉嘛~ 虽不能至,心向往之~
#
# > 开发/测试/生产 这里一般分成了逻辑上的3个部分,它们应该是一致的,但是由于同一样的信息有大于1的副本,导致会出现不一致的情况,需要做同步策略,这个应该是根数据库紧密相关的,这个应该是很重要的部分,许多企业都需要用到这个功能的,有现成的产品了不?Google IT.
#
# > 光学字符识别,使用传统技术可能十分困难,但是使用新的ML/DL方法,这个问题好像很容易就实现了
#
# > 专门的文本形式的数据字典,抛弃使用xls作为数据字典的载体,设计新的RFC,协议,更通用,更好用~
#
# > Mapping, OCR 光学字符识别,加上可编程部分,那就很好玩了,譬如加入到我的电话里面,能够自动更新,就接到电话,能够识别来电号码,然后查表,给出对应人物,这样不就可以实现很多类似Google Glass的科幻功能了,哈
#
# > Maybe she needs badminton shoes...?
#
# > Maybe she needs Firefox account to sync websites...把一些可以公开又重要的网页同步到firefox服务器上,类似云,程序和数据都放在了云上面,这样就能一次收藏,到处都能够使用,复用,很不错的想法来的,当然是公开的资料,毕竟数据是保存在人家手上,对吧?
#
# > **类似Docker的docker file文件,可以使用编程的方式来控制环境的搭建,程序的安装配置,这样只需要得到源文件+文档就能十分好地重现环境,设计/实现这种语言,思想? World will be more beautiful...或者这就是一个需求啊,减少人类劳动,机会?**
#
# > win7 自启动程序,在控制面板-系统和安全-计划任务-新增,注意有Hidden,有触发器,有命令行才能正常运行
#
# ---
# #### Machine Learning
# [Keep Reading, Practising](http://www.csdn.net/article/2014-06-27/2820429)
# 中文资料/英文资料, 书本, 博客, Wiki ~
#
# 切片表,拉链表? 不同的计算方式啊
#
# ---
# #### Install Jupyter On Windows 7
# 1. Install Anaconda,安装新版Anaconda之后就自带了Jupyter Notebook了,有了Python环境,可以写Markdown做日记/展示,也可以直接敲代码.
# 2. 记得设置Jupyter启动时候的 工作路径 + 默认不打开浏览器, 让它在后台默默监听等待就好.
# 3. 让Jupyter 跟系统自启动: 控制面板 - 系统和安全 - 计划任务 - 创建任务 - Hidden - 加上触发条件 - 加上命令行参数
#     `jupyter notebook --notebook-dir=u'F:\aaa\Jupyter' --NotebookApp.open_browser=False`
#     注意还有添加jupyter.exe 所在的目录,也就是程序的起始位置.
# 4. 继续安装 MS_Git + Github,就可以欢乐地玩耍了拉
#
# ---
# # 20170105 Thursday, SQL 优化是个大头诶?How to do it?
#
# > **Focus On Improving.** Kindness in words creates confidence... Kindness in thinking creates profoundness... Kindness in giving creates love... Dream and Enjoy work&life~
#
# > 尊重科学家，是AI从业者的基本常识。
#
# > 罗振宇跨年演讲带来的最大认知收获：让那些平常不看电视的小中产们打开电视，比起让那些追星族们守住频道不转台，流量可是大太多了。有空得多看看电视新闻呗~
#
# > Knowledge representation, Knowledge graph...知识表示,知识拓扑,知识图...
#
# > 中文OCR,光学字符识别,要找找用用才行了,好多东西都好坑
#
# > 上市银行的财报，拐点背后是传统商业银行的经营模式正遭受巨大的挑战。利率市场化深度推进，银行息差持续收窄，对其经营模式构成挑战。部门老总也提到过，一时半刻还是活得可以，但是长远来看，都是找死或者等死？Always be prepared.
#
# > 从依靠规模转向普惠金融，无论是四大行还是中小银行都站在一个十字路口。一念天堂，一念地狱？
#
# > 这个逻辑是任何一个工具都是帮助用户提高效率，用最高效率的方法帮助用户完成任务，这是工具的任务和使命。微信也是一个工具，微信的使命是用最高效的方法帮助用户完成任务，用最短的时间去完成任务。这就是用完即走的含义。设计工具与使用工具。。。
#
# > 虚拟经济与实体经济
#
# ---
# #### Jupyter  Notebook 还有好多强大的东西没有使用到呢,嘿嘿嘿,幸运
# [Come & See](http://www.cnblogs.com/giserliu/p/4997144.html)
#
# **使用DataStudio自动美化SQL,好统一好好看~ Stay With It.**
#
# ---
# #### 开始查询业务相关信息了
#
# #### Git .gitignore 有时候会失效,不是失效,而是底层
#
#
# 利用.gitignore过滤文件，如编译过程中的中间文件，等等，这些文件不需要被追踪管理。
#
# 现象：
#
# 在.gitignore添加file1文件，以过滤该文件，但是通过Git status查看仍显示file1文件的状态。
#
# 原因：
#
# 在git库中已存在了这个文件，之前push提交过该文件。
#
# .gitignore文件只对还没有加入版本管理的文件起作用，如果之前已经用git把这些文件纳入了版本库，就不起作用了
#
# 解决：
#
# 需要在git库中删除该文件，并更新。
#
# 然后再次git status查看状态，file1文件不再显示状态。
#
# ---
# # 20170106 Friday
#
# > My warry and contridition.
#
# > How to grow up? Then I will be afraid of nothing...
#
# > Docker File, unix/linux/windows 上都能通用的协议可以嘛? 就是步骤,数据可以重现,不用人工去动手去再次安装配置,好麻烦...
#
# > 如何评价异常,异常点检测...
#
# > 远程挂在自己的[本地磁盘](http://www.tiejiang.org/2050.html)很简单的,在远程连接选项-本地资源-详细信息-驱动器-选上就可以了
#
# ---
# #### 事实表与维表
#  数据仓库的物理模型较常见的操作型数据库的物理模型有很大不同。最明显的区别是：操作型数据库主要是用来支撑即时操作，对数据库的性能和质量要求都比较高，为了防止“garbage in，garbage out”，通常设计操作型数据库的都要遵循几个范式的约束，除非少数情况下为了性能进行妥协，才可能出现冗余。而数据仓库的建立并不上为了支撑即时操作，或者说，数据仓库的数据是来源于即时操作产生的数据，而不是直接来源于即时操作。所以它的数据质量是由操作性系统来保证的，而不是由几个范式来保证的。而且为了更好的跟踪历史信息，以及更快的产生报表，数据仓库的物理模型中存在着大量冗余字段。
#
# 数据仓库的物理模型分为星型和雪花型两种。所谓星型，就是将模型中只有一个主题，其他的表中存储的都是主题的一些特征。比如货物销量的主题仓库中，每次出售记录是事实表，而时间，售货员，商品是维度，都和事实表有联系，组织起来就是星型。而如果更细化来看，商品是有种类，产地，价格等特征的，从这个角度来看，有两个主题，一个是商品出售，一个是商品本身。组织起来就是雪花型。实际项目中，由于操作型系统业务的复杂性导致本身产生了大量的数据，所以，组织起来也以雪花型居多。
#
# 有时候会不会想为什么我们/我都叫你大小姐,这个并不是我们随便起的,他们根据你的行为举止,大概得出的结论是的确是小公主,爸妈对你很好,你的世界大部分都是一帆风顺,很美好,就像偶像剧里面的从头甜到尾.我看的剧大部分都是不是从头甜到尾,甚至不是喜剧收场,因为这更贴近现实,更贴近我所认识的现实,现实的无奈与残酷.你有点像你口中的温室中的花,我有时候觉得为什么不继续呆在计划里面,让合适人去保护,你父母比你了解更多,为什么不多听听他们的建议.和我一起,可能要面对很多问题,很多事情,这可能很痛苦,手都可能没有那么漂亮了,可能不习惯,怕你枯萎,怕你慢慢发现不合适,不开心,不能像以前一样那么漂亮/活泼/开心...年轻,任性,很多事情考虑不是很全.我是挺好的,但是根据你的描述,符合你父母的要求,我应该还差很远很远,我知道我会努力去学习,去成长,但是可能我的上限也远未能达到你父母的下限,我的经历/教育告诉我不希望你为了我而和你父母吵架,不希望你难受,我未必能给你提供足够好的平台去发展,我的确是很普通很平凡,你多对比下就会发现了,所以我想多给时间给你,我对你是很好的,这个不用担心.这些重大决策,其实没有100%的把握,我是不敢去做的,也不应该去做的.我希望的是你去经历更多,了解更多,对比下,才最终从内心决定眼前的我是不是那位能陪你走最远路的人,经历过很多,从内心决定的事情,你就不会再担忧了...
#
# 也许是大学/研究生期间都是理工男,都差不多,比较相似,比较宅,比较闷,玩的不多,一般节假日有空才出去玩,平时都是宿舍/实验室,看论文,敲代码,所以专业技术理论只是比较好,这都是靠时间和努力堆出来了,然后人际交往方面不是很好,不像你,不像你的环境,所以我担心,害怕.

# %%
# %matplotlib notebook

## Testing matplotlib
## [Place](http://blog.csdn.net/u011497262/article/details/52325705)


from pylab import *
import numpy as np

n = 1024

X = np.random.normal(0,2,n)
Y = np.random.normal(0,2,n)
scatter(X,Y,color="red")

a = np.random.normal(4,2,n)
b = np.random.normal(4,2,n)
scatter(a,b,color="blue")
show()

import datetime

#print(datetime.datetime.now())

begin_date = '20150620'
end_date = '20150919'

bd = datetime.datetime.strptime(begin_date,'%Y%m%d')
ed = datetime.datetime.strptime(end_date,'%Y%m%d')

print("Days Interval Is : " + str((ed - bd).days))
# Out:
# <img src="data:image/png;base64,...">
# Days Interval Is : 91

# %% [markdown]
# <span id="index"></span>
# ## 目录
# - [Monday](#Monday)
# - [Tuesday](#Tuesday)
# - [Wednesday](#Wednesday)
# - [Thursday](#Thursday)
# - [Friday](#Friday)
#
# ![Topological](https://pic.36krcnd.com/201701/12060136/djsaukns0yf8qh6a!1200)
# ---
# <span id="Monday"></span>
# # 20170109 Monday
# [返回目录](#index)
#
# > Win7 的计划任务后来运行失败了,为什么? 可能那是环境变量没有生成正确,给出程序所在位置就ok了..
#
# > 自信点,能解决的,相信自己,这些年多困难都过来了.
#
# > Life might be tough, but please try harder, can not quit easily.
#
# > Please be yourself, control yourself.
#
# > 微信小程序上线了,感觉挺不错的思想,学学,体验体验~
#
# > ML/AI/DL/Math/Programming 自己的根基不能丢掉，然后也不能被时代落下.
#
# > **SEARCH/Google 拼写SQL好用的编辑器,更方便,更少错误...Always be a better man...设计更好的工具,使用更好的工具,改变自己,改变世界**
#
# > 如何把休眠的选项放到开始->关机附近,这样就不用关机了,直接使用休眠就Perfect
#
# > **远程登录好多hop,好多跳,都要输入自己的信息,等等,破坏我的速度,破坏我的生产力,如何使用python去自动化,点击就自动登录所有动作!!!**
#
# > **登录后又用计划任务让他自动打开我需要的应用程序,注意是每次我登录就自动打开,全自动化,不再需要人工人手去参与,程序就是要走向极端**
#
# > 一个常见事实：一个复杂的程序（过程）总是由一大批相对简单的过程组成的...Lots of things happen this way.
#
# ---
# #### 查询中经常使用到了 left outer join,这种情况下注意null值出现带来问题,要考虑使用NVL函数了
#
# **DataStudio 是能够直接将数据导出成CSV/XLS格式的,然后配合挂载驱动器,这样就能直接将查询好的数据导出来了,非常方便**
#
# SaveResults -> Optinos ->  Data Format Excel, 名字, Include columns as first row
#
# 注意到上面的行为是将查询返回的结果集导出成excel,这个没有问题,问题在于导出增个表table时候,先select然后导出,会可能超出内存限制啊.
#
# #### Thoughts:
# 机构原来逻辑上就是一棵树,Tree,只是不一定是二叉树,而不不规则的多叉树,Anyway,理论上都是可以转变成二叉树的.
#
# 机器自动化,如果机器也能够理解人类自然语言(估计需要NLP,DL的支持),并做到了生成SQL的程度,这就代替了很多人的人脑工作了,自动化不仅能够从繁重的体力劳动中解放人类,也慢慢地从脑力劳动来释放人类,甚至超越人类(类似AlphaGO),这也许是人类的胜利,站在胜利的一方,跟上时代,去设计AI/ML,去引领革命,而不是被革命,Keep Learning, Don't be afraid. You can do it.
#
# 模块化的查询来处理查询请求,类似聚类分类,把一整堆的查询请求进行自动(人工实践很好很简单,但是没有理论支持,还是机器数学来出来来得好),把这些查询进行分类出类,就像Unix哲学一样,使用很多很好很准确的小程序/小零件,使用这些小零件就能够建很复杂很困难的查询,这就是一直我们在做的,如果这一步做好了,我们也能轻松高效解决问题,然后结合更加智能的AI,我们就能下岗了,对程序员的目的就是让自己下岗,让机器去完成自己的繁重劳动,让自己去做更大更广阔的事情去,Can you do it?
#
# #### 微信小程序
# Webapp VS Nativeapp ？  类似 BS架构 和 CS架构 的竞争？
#
# 张小龙却总是替微信赋予工具产品的愿景（微信是一个工具，为了提高效率而生），颇为相映成趣。但是，和多数人理解的工具品类——锤子、剪刀、直尺这些——不同的是，如果微信作为工具，只会是瑞士军刀这种，看似小巧精致，但是适用场景极为丰富，从而实现了从应急品到必备品的质变。
#
# **时间窗口 Window ，每个人的时间窗口，留有的风口，机遇都是十分有限的，在到来之前要准备好，到来的时候别犹豫，生活就是一场更大的博弈～**
#
# ---
# <span id="Tuesday"></span>
# # 20170110 Tuesday
# [返回目录](#index)
#
# > 简单点,单纯点也很好,真的~~~ 有时候觉得自己好坏好坏,怎么会做出这样的行为,Please...
#
# > 我们某种意义上都是还没长大的孩子啊~好好珍惜...
#
# > 许多问题都是判定问题:如何判定当前时刻某个单位客户是不是贷款客户?如何精确判断,充分必要,不多不少,混淆矩阵FP,FN?
#
# > 艾伦-图灵 读了《儿童必读的自然奇迹》，他告诉母亲，这本书让他打开眼界，让他知道了世界上还在一种知识，叫做科学。这本书，不仅让他认识到什么是生命，而且也改变了他的生命之路。读书很重要, 读到有缘分的书更重要哈.
#
# > 普林斯顿
#
# > 上学的时候就听教授提到过的 开放数据互联, 也就是能公开的数据公开给大众来学习研究,这样我们就能使用程序来获取各种公开有用的数据,研读研读
#
# > 弄一台64位的4G内存的小机器,然后放在我的路由器之后,这样子可以不?搭建自己的小服务器,关键在于不一定过得了监控~啊啊啊
#
# > 有问题多交流,多聊聊啊,多问问队友才能更快进步,一个人抗不住个金部那么多丧心病狂的查询问题啊...我去..
#
# > Jupyter Markdown 如何在同一个页面内转跳,类似目录的功能,这样子做Presentation就更加漂亮~
#
# > **Markdown is simple but yet powerful.**
#
# > 用客观的眼光去了解，分析事物～
#
# > 老罗的GNT就是给出了问题的约束，然后如何理解这个约束，根据这个约束去解决问题，优化问题，是我们要做到的~
#
# ---
# #### 处理完FL的第二个请求
# 没有太多的问题,但是还有业务细节,为什么这么做等等的地方,肯定还会有疑问的.
#
# ### Jupyter Notebook 的强大应用,
# 由于是在本地localhost机器上搭建了一个服务器,而且使用的是B/S的框架,这样只要服务器开着,配置好服务器,就能到处使用我提供的服务,计算,记录等等.
#
# 关键在于如何使得我的Jupyter在其他机器上也能正常运行就行了,Browser只是提供入口,真正的数据等等都在服务器上呢.
#
# `Jupyter notebook --help-all | less`
# 可以看到 [配置Jupyter作为一个网站服务器](http://www.cnblogs.com/zhanglianbo/p/6109939.html) OR GOOGLE IT
# ```
# --generate-config 生成配置文件 | 修改配置文件
# --config=u'' full path to config file 差不多就够了,然后许多东西都能在config file 搞定了
# --NotebookApp.config_file_name=u'' 这个才是正解?!
# ```
#
# **关键问题: 路径中文问题 u'中文string' 还是 'ascii string'**
#
# 是这个问题导致Jupyter工作不正常好吧, --config='c:\users\...' 是完全可以工作的,关键在于u,这个编码问题,python编码问题...
#
# 所以只要
# 1. 配置好 jupyter_config.py 这个配置文件,指定服务器的各种行为;
# 2. 在启动jupyter的时候指定这个配置文件,就能正常工作了,好强大;
# 3. 配合win7自带的那个计划任务,配置好程序行为,就能使用好强大的工具了
#
# 结果:
# 1. 能用localhost本地访问自己的JupyterNotebook
# 2. 还能用内网地址 http://xxx.xxx.xxx.xxx:xxx/tree 来远程访问写日记,写代码,运行结果等待,嘿嘿嘿~不过肯定要密码保护的
# 3. 以后做Presentation,运行代码给结果,就很方便了,能访问内网就能搞定
# 4. 配合了MS Git搭建了自己的服务器,感觉好完美,下一步缺的就是可重现,就像docker一样,让我的计划/软件组合/能够一次编写,到处重现.
#
# ---
# #### Markdown 实现类是网页目录,转跳,书本的功能
# Markdown 实现页面内部跳转,其实就是页面内部转跳,页面内部的目录
#
# 1. 先定义要跳转的锚点
#
# ```
# <span id = "anchor">锚点</span>
#
# 注: id是您随意取的,当然必须是唯一的.
# ```
#
# 2. 跳转
#
# ```
# [锚点](#anchor)
# 注: []内是要填转的按钮显示的文字,小括号内#后面是跟的id值.因为跳转是根据id跳的.
# ```
#
# 有了这个之后,每周的日记格式就可以直接拿模板来了,因为格式都是一样的,只是内容改变了,哈哈. 通用,泛式思想,往抽象上去思考,往具象方面去实践.
# 使用Markdown做最简单的排版就能做很多事情了,虽然没有latex那样专业,不过也够用了,嘿嘿嘿~
#
# notepad++ 可以设计字体大小,背景颜色等等的~ 需要找到更加强大的SQL编辑器,嘿嘿嘿
#
# Jupyter 的 Markdown 转跳在本地是可以的，但是在Github上就失败了，没办法拉，能用就好拉～
#
# ---
# #### 可以像一个协同工具一样，在Jupyter上建立我的工具箱/零件/模块
# 就按各个人的理解去写sql，放在上面，大家共享，交流，等等，这将是我们的武器～更多的是往前一部的程序机器自动化～
#
# FSY\_企业\_年均存款.sql
#
# ---
# <span id="Wednesday"></span>
# # 20170111 Wednesday
# [返回目录](#index)
#
# > 认识你的第二个月,第61天~
#
# > 我不仅有三只小猫,更是它们三个基态的叠加态,好复杂,好矛盾,当然也挺好玩,哎~
#
# > 我的教育,我的认知,我知道我不应该这样子做的,但是我的本能却又告诉我要~ 啊啊啊,Please stay the course.
#
# > 对于支付宝和微信来说，它们要的就是将移动支付的概念植入大众心中。将一种思想/习惯植入人群中是很难,同时又具有巨大潜在利益的,就像培养用户习惯一样,培养用户思维也一样,这是平台所追求的,但是作为个人的你,更应该独立思维,找到客观正确的答案.
#
# > 水中月，镜中花, 中央 与 地方 的博弈,貌似历史一直以来都有提到过.
#
# > 杭州~?
#
# > Breath & Life -- By Audio Machine
#
# > 理财的份额, 对应的余额, IN CNY/RMB
#
# > 每个人头脑中都有自己的想法,它不是可以直接观察的,就像隐变量一样,要观察他的语言/行为来捕捉/推导,Tough but funny...
#
# > In daily life, 我们往往只发掘/发挥了事物的60%功能,还有很多可以去发掘,发现,会玩,有想法的人往往能够200%地利用事物,去创造更多价值,更多快乐~ 想法方面,真的不需要给任何限制,反正也是大脑虚拟的世界,虚拟的空间,没有任何成本,物理约束...
#
# ---
# #### 老化 与 保养
# 老化是真实存在的,保养也是需要的; 只是他们不好量化,不好衡量,导致人们往往对他们都是定性分析,很难定量分析,也就会让人感觉很玄,实际上如果很好量化,有数据,有模型,有实例,很好比喻,他们就老实了...
#
# ---
# #### 在内网处理/记录查询请求
# BG的GJB请求,弄死我了呢...
#
# ---
# #### 平时我们的确是这样子做得,但是要跳出来看看自己的行为,看看有没有另外一条路去走,不能一条路到天黑...
#
# 写代码,写SQL,代码与注释,真的好难平衡,太多的代码,太少的注释,看不懂; 太少的代码,太多的注释,看什么.
#
# 正确做法是在Jupyter Notebook上写的应该是问题分析过程,少放SQL或者只放骨架,在Notepad++写的是详细的SQL,SQL的细节,各个零件,这样的区分大概是
# - 全局高层看待问题
# - 局部细节处理问题
#
# 这样子也就不会出现副本问题,因为代码/细节都只会在SQL文件里面,分析过程只放表明,思想,这样就就不用人肉同步了,真的要学会迭代,学会优化,才能更加轻松,更加高效
#
# ---
# <span id="Thursday"></span>
# # 20170112 Thursday
# [返回目录](#index)
#
# > 宿舍鼠标出小问题啦, Simply fix it. Search for some tutorial and just do it. It is not tough.
#
# > 8848的营销方式?...
#
# > 组合,Combination, Mathmatical Models, compute...
#
# > 我现在使用我会的知识去制造各种小零件,小工具,每一个都是简单而正确,然后使用这些小模块组成的武器就应该能够很好地对付大魔王~
#
# > 足够简单以致明显找不到缺陷,足够复杂以致找不到明显的缺陷. 当然是选第一个.
#
# > Keep reading all kind of information, trend, 趋势,未来,不变与变.
#
# > 牛X的源代码/资料,不是自己做备份,而是全世界来替你做备份 -- Linus Torvals
#
# > 注意我们字典协议(代替excel的文本协议Protocal)需要很好地支持查询
#
# > 吃掉最后一个铜板这种思维在投资上是极度不可取的?
#
# > Yahoo! is gone? 它也贡献过不少开源代码,不少算法,不少论文~ What is right? What is wrong?
#
# > 代表著作有《An Introduction to Statistical Learning with Applications in R》与《Machine Learning for Hackers》，其中的实例是用 R 语言实现的。
#
# > 你的坚持,总会有一天开满鲜花~
#
# > 蓉魔王: 理财是怎样买卖的?我可以买了,然后在期间继续购买吗?或者买了的期间强行撤回呢,就是理财的业务逻辑/流程是怎样的?我才能计算啊.
#
# ---
# #### 继续构建小零件
#
# ---
# #### 查找一张表,它的某个字段,某个代码的含义
# 如何完成这个需求,这个功能, 给出表名,如何知道它来自哪里?
#
# ---
# #### 傻IMSE,你总是分不清ODS 和 DW....我去  查看表  字段 含义 开发人员 答疑
# FD层的某个表,某个字段,某个编码不明白 --
#
# 去 SM 层找到对应的表,某个字段,某个编码 --
#
# 去 ST 层找到对应的表,字段,编码,
#
# 如果到这里还搞不明白,就说明要到源系统了,要看源系统设计,设计开发人员问问才行,问师兄/前辈/组长 - 然后找到推荐的开发人员, 套路~~
#
# ---
# #### Win7 的远程链接如果无法全屏, 解决
# 就在使用 mstsc 进行远程链接,然后在 选项 - 显示 - 推到极右
#
# ---
# #### Stay Constant, 要知其然,更要知其所以然,
# 为什么想到了SQL的复制计算,使用UDF? WTF
#
#
# ---
# # 20170113 Friday
#
# ![AI](http://b.hiphotos.baidu.com/news/w%3D638/sign=3f2399b9f41f4134e037067d1d1e95c1/8694a4c27d1ed21b97c92abfa46eddc451da3f63.jpg)
#
# > Jupyter 还是有不少可以改进的地方的,譬如我想修改,按回车Ente之后,为什么输入光标不是在当前行? 而且对VIM支持不是很好
#
# > 企业文化是一座围城？ 文化 与 环境,对人的影响也是极大的~
#
# > Under certain condition, the system has bugs...
#
# > “存贷比”应该称为“贷存比”，是银行贷款余额与存款余额的比率。从银行盈利的角度讲，贷存比越高越好，因为存款是要付息的，即所谓的资金成本，如果一家银行的存款很多，贷款很少，就意味着它成本高，而收入少，银行的盈利能力就较差。
#
# > 蓉魔王: 保险箱,贵金属,代收付熟悉不? 嘿嘿嘿
#
# ---
# #### KPI, OKR,绩效管理的
# KPI（Key Performance Indicator关键绩效指标）我们应该不陌生，绝大部分企业都会用绩效考核我们每月、每季度、年终的工作成果，KPI就是其中最常用的管理工具，类似的还有OKR（因谷歌而闻名）、BSC等。
#
# 简而言之，KPI就是一种将企业战略落实到具体执行策略的管理工具。它能将大目标拆解为小目标并落实到个人上进行可量化的管理。
#
#
# 李开复预测，从事翻译、新闻报道、助理、保安、销售、客服、交易、会计、司机、家政等工作的人，未来十年将有约90%被人工智能全部或部分取代。不用担心将来如何如何,看准方向,努力学习成长,思想/能力跟上时代,总不用害怕的,又有什么好害怕的,对吧~
#
# ---
# # 20170114 Saturday
#
# > 学会如何保养角质制品～
#
# > 当计算机有人类的理解能力，配合它的强大计算能力，真的许多事情都不用劳烦人类了。。。
#
# > 供给侧改革，中国制作，中国创造，走出去？
#
# > 不是所有人都理解这个行业，不是所有人都说真话。
#
# ![Haskell_recursive](http://coolshell.cn//wp-content/uploads/2016/10/drawing-recursive-768x522.jpg)
#
# # 20170116 Monday
#
# > 一个着眼现状,一个放眼未来,既要把握现在,也要胸怀大局,开拓进取.
#
# > Making mistakes is ok, the point is to learn from it, grow with it.
#
# > 如何让机器在断电的时候待命,不会丢失状态,也就是机器把当前状态保存好了,就不害怕断电了,但是如何待命,如何处理用户响应,(轮询VS中断)
#
# > 用 按键精灵 或者 AHK(AutoHotKey) 这类更加高级好用的脚本能语言,因为它对编程的要求没有那么高,也足够完成任务,能用够用!
#
# > Jupyter 是集合了 修改 和 显示的功能,但是我能不能继续搭建类似 NBviewer那个,只能看,而且看得很漂亮的界面~?
#
# > 年初五 2017.02.01 需要在家远程RPC/VPN跑一些脚本, What? Why is this happing? Always be prepared...
#
# > Search & Read 深度复制 与 浅度复制
#
# > 无法打开页面,提示错误,按照错误提示来search,一般就是IE登浏览器的安全配置导致的问题,修改下配置就好了. 一般在 工具 - Internet属性 - Internet - 自定义级别 - 启用XSS(禁用)
#
# > Prepare things 1.fix mouse(Tools Kits); 2.fix lens()Tools Kits; 3.小而可靠的硬盘作为Git资料备份; 4.USB多分器
#
# > Currently, program is not magic, we all wish it was. but it is not. So we will nedd to tell it what to do. This process is called "Scripting".
#
# > 不懂业务的时候,去办个业务试试,问问题试试???
#
# > 和任菇凉解决了那个 小网站 打不开的问题，的确应该考虑到小网站对IE的支持，新一点的浏览器就可能不支持了，使用旧的浏览器才能支持，使用兼容模式等等才行～ 应该看看这些网站上下左右的提示，这种问题太长见
#
# ---
# #### 配置权限还是有点小瑕疵
# 因为对源系统的原理/底层不熟悉,所有容易犯错误,不过没有太大问题了,经历基础错误,几次投诉,我应该大概知道怎么办了,不会犯大错误,小小错误也会越来越少,嘿嘿.
#
# ---
# #### Auto Hot Key
# [AHK](http://www.ahkscript.org/) 可以使用这个类似 按键精灵 的开源工具来干更加有趣的事情了,这类**工具**应该很多的,不过能够跨平台就好了..嘿嘿嘿...
#
# AHK 可以发送普通字符串,也可以发送普通的按键,发送字符串... 发送 Enter, Tab, Sleep, Arrow Down 等等...
#
# 就是 Simulate Human Inputs... 这个工具应该能够模拟所有 键盘/鼠标操作,这样使用足够聪明的程序就能够替代人来的 键盘/鼠标/输入
#
# 现在可以一件远程机器(AHK 开源程序完成任务), 登录远程机自动打开Datastudio...一键无忧,嘿嘿嘿~
#
# Auto
#
# 不担心自动断开了,远程原来是不会自动断开的,自动断开是因为网络中断了,或者本地机器进入睡眠/休眠状态,导致链接断开,所有连不上...
#
# ---
# #### 汇率转换表
# not have everyday; 注意标价形式, 应该是 1USD : 6.7RMB 的基准汇率,就是 原来我有 10.2 usd 直接乘以那个基准汇率就行了..
#
# 注意还有
# - 钞买价
# - 钞卖价
# - 汇买价
# - 汇卖价
#
# ---
# #### DB2 与 Oracle 数据表示  空字符串 与 NULL 的区别
# 貌似 Oracle 的空字符串是底层使用了NULL表示,但是对于DB2,空字符串是不是使用这个NULL还是?
#
# 连接几K行的SQL,人会疯的,数据也容易发散,坑跌啊,如何控制好数据质量,控制好SQL复杂度,这是个系统级别的工程啊...
#
# 我的AI/ML/DL可以用得上?
#
# ---
# #### 同一样的概念,
# 同一样的概念,在不同的系统的编码往往是不一样的,因为这个原因,所以不能直接链接起来的,需要的是标准化,或者中间件来链接,才能得到答案
#
# 譬如ID类型,这个编码,在两个不同的系统里面,意思一样的,但是就是不一样嗯...
#
# ---
# # 20170117 Tuesday
#
# > 你不可能要所有的东西，所以你只能要你最重要的东西，你要知道什么东西最重要，你就需要对你心内的那些欲望和抱负有清晰的认知，不然，你就会在纠结中度过。
#
# > 房地产价格其实就两个点一句话，那就是短期看金融,长期看供需.
#
# > 2017预期会碰到各式各样的问题,错误. Anyway, 撸起袖子就是干~.
#
# > 百度是连接人和信息的工具，而腾讯（微信和QQ）是连接人与人的工具。人与机器,人与人 的网络,图拓扑(Graph Topological),社交网络
#
# > 过程式的编程范式叫做 Imperative Programming – 指令式编程，而把函数式的这种范式叫做 Declarative Programming – 声明式编程。
#
# > 我深深地发现，对于我国这样从小被父母和老师安排各种事情长大的人，当有一天，父母和老师都跟不上的时候，我们几乎完全不知道怎么去做选择。We all have to learn to make decisions and take responsibility someday, somehow.
#
# > 能和那些有梦想有追求有能力的人一起去经历那些最有意义的事情，那些能够造福社会、改变世界、创造历史的事情。Hope to be with you, grow with you.
#
# ---
# #### SQL 中的行转列...
# 列转行...好像用的比较少
#
# 一般就是 CASE WHEN 来控制,只是?
# ```
# SELECT
#       UserName,
#       MAX(CASE Subject WHEN '语文' THEN Score ELSE 0 END) AS '语文',
#       MAX(CASE Subject WHEN '数学' THEN Score ELSE 0 END) AS '数学',
#       MAX(CASE Subject WHEN '英语' THEN Score ELSE 0 END) AS '英语',
#       MAX(CASE Subject WHEN '生物' THEN Score ELSE 0 END) AS '生物'
# FROM dbo.[StudentScores]
# GROUP BY UserName
# ```
#
# ---
# #### 不懂就问拉,人肉加标签,只是规则来自哪里,
# 应该来自同一个出处,同一个数据来源,才能大家一致; 或者是分布式的知识理解,大家的理解都是一致,或者不是模棱两可的,就可以了.
#
# Datastudio 不需要 where rownum < 1000 || fetch first 100 rows only 这样数据库专用的链接了,使用它自带的MaxResults就可以自动fetch...
#
# ---
# # 20170118 Wednesday
#
# > 是否可以搭建个人的Search搜索系统,搜索特定目录下的文件内容,譬如我像找我的日记的某些内容,是不能通过文件名查找的,而是文件内容查找.FIND可以?
#
# > 要知道ODS和DW是如何工作的,为什可以这么做而不会影响核心交易系统... 眼界/经历/平台
#
# > 为什么在SQL查询 'xxx   ' 这个行的时候 where field = 'xxx' 就可以了,但是 join 的时候却不行.
#
# > 自己写美化/规范SQL的代码, GitHub Project? read source code, think, write. 作为开放源代码,然后就能嵌入都各个编辑器/工具中.
#
# > 经常写错schema....注意点拉
#
# > 处理规模小,数量小的问题很简单,很容易,但是不能这样满足现状,需要的是走得更远,处理更复杂,更困难,更抽象,更通用的问题.对自己狠点,要求高点.
#
# > 有空告诉我 客户号  帐号  卡号,存折 这些拉
#
# ---
# #### Oracle 监控,优化 培训资源入口, 也应该翻翻我的书了,虽然有点落后,但是可以基本就在那, 书 + Internet + Practise
# Youtube上面有的. OLTP, OLAP,
#
# cpu 负载率, LOAD, AWR, ET 外部表, external table, 就是用来关联文件,然后就可以select等操作了,这种不用bulk load,效果还很好?
#
# 中午12点左右要看看执行的那四个有没有完成,可能要去生产那边监控下情况了,网络不开就悲剧了...反正远程失败就说明不行了...
#
# ods 和 dw 都可以登录查看,对比查看,看看数据是否一致,是否可用?! 会计科目, 表内, 表外
#
#
# # 20170119 Thursday
#
# > Jupyter 是有点缺陷的,还是可以优化的,作为一个深度用户,就会感觉到它的不足,缺陷,可以改进,变得更好的地方.
#
# > 人们的意识开始变化,理财意识,互联网理财,门槛低,直观方便,对比一行理财,更多人可能倾向互联网理财,银行如何才能像互联网一样方便直观,使用户更容易接受.
#
# > 时间对于人类来说,太宝贵了,
#
# > 想法设法改进SQL的效率,利用索引
#
# > 为什么有的字段末尾有空格,但是有的字段末尾又没有空格,搞什么鬼啊...
#
# > 如何搞自己本地的搜索系统,自己本地的知识图谱表示,知识表示,知识存储,知识取回, It is all about Knowledge, Information.
#
# ---
# #### Between and 应该是有明确定义的
# The BETWEEN operator is inclusive.
#
# From Books Online:
#
#     BETWEEN returns TRUE if the value of test_expression is greater than or equal to the value of begin_expression and less than or equal to the value of end_expression.
#
# ---
# #### 源系统改版了,数据结构发送变化了
# S层改 -> D层改 -> F层改  (应该注意到是否有历史表可以使用?)
#
# 注意到 F层修改数据库需要 DB2 alter table && reorder table?
#
# 改完还得该svn,好的 ==
#
# DataStage 长时间修改作业之后,无法保存,关闭再保存把? 还没解决...
#
# 无法读取文件,路径问题(文件夹有没有对应上,文件名没有对应上... 参数对不对,DS这些作业要小心,小心,标准啊)
#
#
# ---
# #### SVN 提交失败,需要重新设置用户名秘密
# TortoiseSVN客户端重新设置用户名和密码,清楚掉历史记录就行了,因为改了用户名密码的缘故.
#
# ---
# # 20170120 Friday
#
# > 支付宝又要集齐福...啊啊啊
#
# > DataStage作业出问题了,可能是作业参数,路径问题,往往都是路径,注意到ods和dw的区别,不能直接用,作业日期,大小写,路径问题可能有很多. 可能要手工创建路径.
#
# > DataStage一直有点小问题,无法保存,编译的时候提示保存作为,问题在于重启.
#
# > 参考对比其他作业,其他参数啊,字符宽度和字符最大宽度不一样!!! FIX LENGTH 固定长度,都是用** 字符宽度 不是 字符最大宽度**
#
# > 唯一的办法是接受再培训。一辈子做一件事已经不可能了。
#
# > 发达国家迫切需要更多的科学、技术、工程和数学（简称STEM）毕业生，以保持竞争力。 -- 科学 与 技术
#
# > Play with open source AI/Platform. TensorFlow/Cafe/Or something like that.
#
# > 第三方存管, 内部账户, 如何分析流水得出. 不能全词匹配...
#
# ---
# #### 项目新版本上线
# 注意其实使用版本管理系统就方便了,因为版本管理就已经管理好各种文档,各种源码的,只要备份好版本管理的系统就好了,(要是使用GIT,那更加不用说了)
#
# 所以上线前一般都会备份生产环境的所有资源,然后把新的版本才能放上去,防止出了差错无法解决. 这个应该也是一个标准的流程,可以使用程序/软件来自动化管理了,就是函数式编程/泛型编程的思想,比较高层,我只关心这个程序能够实现的大方向功能,具体实现让机器自己去推导,去完成.不容易,但是是可以的,特别是更加智能的程序/模型的出现.
#
# 先写好流程文档,在这层就想好如何上线/解决问题等等,然后上线的时候再去直接执行就好了.尽量减少问题的发生.
#
# ---
# # 20170121 Saturday
#
# > 不平凡的周六～～～ 好怕好怕. 以后周六早上/中午得多吃点,不然晚上容易饿...
#
# > keep observing， keep thinking...
#
# > 补充缺失的知识,缺失的部分(经济学宏观/微观,金融,人际)... Gotta to do a lot of things.
#
# > 这个地区，这个地方可以如何互联网+，信息结合+，思考。。。 如何使用 计算机/信息 结合到某个产业上,
#
# > 人生规划，将来两三年怎么办。。。和将来十年... 安排 和 规划
#
# > 人际交往,认识更多的人,培养这方面的能力.
#
# > 对宏观长远,大方向上的把握,How? I am scared...
#
# > Just trust yourself, just do it. You have done so many things.
#
# > 改变是需要能力,需要坚持的,Can You???
#
# ---
# #### 1.29 & 1.30 on duty...
#
# ---
# # 20170122 Sunday
#
# > Need to be on work.
#
# > AutoHotKey 这个,手写的script有时候不稳定,是因为对要运行的情况不熟悉,不充分了解原理而导致的问题,对程序/流程更加熟悉了就不会有问题,因为这种小问题都能是轻易解决的. 就是移动下鼠标,导致焦点在输入框,然后输入就没有问题了.
#
# > Search 的时候,应该尽量使用自己学过的知识去解决问题.利用你的知识,大脑去优化方法,然后是利用索引,利用执行计划(工具)来找出更优的方法.
#
# ---
# #### 腾讯
# [想法](http://36kr.com/p/5057284.html)
# [36kr文章](http://36kr.com/p/5057328.html)
#
# 处理中间业务,贷款,这两个大头,什么鬼啊...代收代付, 读文章,写文章,思考,zifubao等互联网企业可能有传统行业的人才过去,他们了解银行是如何运作的,如何一步一步占领市场,量变到质变,所有马云才说银行不改革,他就要革命银行了...?! Keep reading, keep thinking, keep writing, keep communicating...
#
# ---
# #### 中间业务  柜面  前置 等等
# 中间业务，是指商业银行代理客户办理收款、付款和其他委托事项而收取手续费的业务。是银行不需动用自己的资金，依托业务、技术、机构、信誉和人才等优势，以中间人的身份代理客户承办收付和其他委托事项，提供各种金融服务并据以收取手续费的业务。银行经营中间业务无须占用自己的资金，是在银行的资产负债信用业务的基础上产生的，并可以促使银行信用业务的发展和扩大。中间业务占银行收入比重逐年加大
#
# ---
# #### 改版上线
# 小心,必须要在开发环境完整测试完才去上线
#
# ---
# #### 社交网络...
# 社交平台有很多划分依据，从关系的来源看，源于线上的基本都属于陌生人社交，源于线下的属于熟人社交。比如当下主流社交应用微信，更多是基于熟人通讯录建立关系；还有一种划分方法，一种是侧重内容的平台，比如微博、豆瓣、YY；
#
# 资本只会为看得清的商业模式买单，用户只会为发自内心的东西驻留。驱动社交最强大的两个东西，一个是长久形成的真实社会生活形成的强关系，一个是以兴趣、共同爱好形成的弱关系。
#
# #### 城市化率 与 共享经济 与 更加智能的交通
# 一个是提升私家车空座的使用率，一个是提升自行车的使用率。它们都减少了对城市交通的负担，让人与人之间的关系更加和谐。
#
# 其实，只要有真正的共享经济，就有真正的美好出行。
#
#
# ![Mount&Blade](http://a.36krcnd.com/photo/8661432889af4ea28aa3a1f626bf35a8.jpg!heading)
#
# # 20170123 Monday
#
# > You can do better...
#
# > 阿里和腾讯，一个电商第一，一个社交无敌。阿里抢占了大家的钱包，腾讯抢占了大家的时间。那到底是钱包重要呢？还是时间重要？两个都重要.
#
# > 围棋比赛将成为人工智能“奥运会”的雏形, 人工智能"奥与会",各种算法,数据,智慧,代码的比拼,也是很好玩的~
#
# > 未来，在时间这个战场上，有两门生意会特别值钱。第一，就是帮别人省时间，第二，就是帮别人把省下来的时间浪费在那些美好的事物上。
#
# > 强烈需求OCR这类辅助软件,深度学习下的Deep Learning下的准确率应该很高很高的.
#
# > Google glass AR/VR/OCR :Machine Learning / Aritficial Intelligence / Deep Learning
#
# > Alpha Go 的论文, 如何构建智慧,模式, Deep Network; Reinforce Learning
#
# > 人工特征,机器特征
#
# > 未来10年，我们将进入一个AI无所不在的世界。看不清的时候,看看大公司的实际投资,投入,研发方向就好了,他们决策应该也没有大问题...
#
# ---
# 乘数效应
#
# 冲正
#
# ---
# # 20170124 Tuesday
#
# > 供给与需求
#
# > 过去10年我们一直在做一件事，那就是打造移动优先的世界。而在接下来的10年时间里，我们将转到一个AI优先的世界。——Google CEO Sundar Pichai，2016年10月
#
# > 看更多好文章,[写更多好文章](http://36kr.com/p/5060022.html)
#
# > 乔布斯说过：人们不知道想要什么，直到你把它摆在他们面前。正因如此，苹果公司从不依靠市场研究。
#   张小龙也说过：需求只来自你对用户的了解，不来自调研，不来自于分析，也不来自于讨论。
#
# > 深刻的体会和洞察用户的行为; 场景代入和打开思维.
#
# >在硅谷，寻找下一个大事件是一个永恒不变的话题。改革创新是科技行业领先的关键因素，无法保持更新速度就会被淘汰。科技空间是无情的，在那里，财富是难以捉摸的，而失败却比比皆是。
#
# > Google Instant Apps VS 微信小程序
#
# > 全球银行业正在经历一场前所未有的数据化革命，传统意义上的银行渐行渐远，而一个更富活力与效率的数据化、信息化银行渐行渐近。以云计算、互联网、移动化、区块链和人工智能为代表的金融科技风起云涌，并迅速向金融领域渗透融合，金融脱媒和利率市场化加速演进，银行业务结构调整和行业跨界竞争加剧，出现了融资脱媒和支付脱媒的新环境、新格局。
#
# > 要修修统计学了,什么是计算口径?(统计学)
#
# ---
# #### Wolrd is changing?
# 认图片、辨声音、下围棋、玩德州扑克、开卡车……似乎越来越多人能玩的事情AI也能玩而且玩得比人还溜。但暂时有一部分人还是自我感觉安全的——程序员的工作AI还是很难胜任的对吧？毕竟这个东西需要逻辑思考，需要框架和流程设计，哪里是AI能一下子胜任的事情。但Google等公司认为，AI现在可以开始学习一些AI专家做的事情了，那就是写AI程序。
#
# 当下，随着金融市场环境的迅速普惠化，新金融业务也不断下沉到更加广泛的人群。由于这部分人群的强征信数据严重缺失，金融机构纷纷涉猎多元数据包括消费、社交、行为等“大数据”。然而，这些天然带有超高维、稀疏、低饱和等特点的数据也远远超出了线性回归或逻辑回归等模型所能处理的能力范围，这对传统风控提出了巨大的挑战。
#
# 集成学习模型框架很好地解决了这一问题，其核心在于针对不同领域数据使用不同机器学习或深度学习模型对数据进行处理和建模，产生一组“个体学习器”，集成模型通过将多个学习器进行组合，常可获取比单一学习器显著优越的泛化能力。可为什么说集成学习模型是金融风控新的杀手锏呢？这里简单介绍一下集成学习模型的概览，大致分类，主流算法以及在我们金融风控实际场景中到底发挥了怎样的价值。
# 概览
#
# 集成学习目前在全球各大机器学习、数据挖掘竞赛中使用非常广泛，其概念和思想也风靡学界和工业界。如果要对其进行分类，可以大致划分为模型融合和机器学习元算法两大类，前者其实是一个再学习的过程，将训练出的强学习器组合起来进一步提高性能，后者则是弱学习器的组合。
#
# ---
# #### Keep Reading...
# [InternetCompany](http://36kr.com/p/5062611.html)
#
# 融资需求下降才是最为重要的原因，背后对应的是GDP增速放缓的宏观影响。毕竟银行是跟着经济规律波动的...
#
# 《互联网金融模式研究》中提到：“在这种金融模式下，支付便捷，市场信息不对称程度非常低；资金供需双方直接交易，银行、券商和交易所等金融中介都不起作用；可以达到与现在直接和间接融资一样的资源配置效率，并在促进经济增长的同时，大幅减少交易成本。”
#
# 金融的需求
#
# 互联网思维的一个关键要素，就是从用户的需求出发去思考问题。那么我们不妨首先思考一下，用户的金融需求是什么？
#
# 从用户需求的角度出发，互联网金融和传统金融其实没什么差，一样是为了满足用户的三大基本金融需求：投资、融资、支付。
#
# - 投资：资金充裕的人想让钱生钱（存款、保险也是投资的一种）。
# - 融资：缺乏资金的人需要钱，融资则要付出成本（如借贷的利息和手续费），其实是用钱买钱。
# - 支付：金钱的流动。
#
# ![金融活动](http://a.36krcnd.com/photo/2015/dafa96a076758c9e0f57785350dda290.jpg!heading)
# [Source](http://36kr.com/p/218515.html)
#
# 直接融资（如发行股票、债券等）只涉及货币在不同经济主体之间的转移和交换，没有货币乘数效应，货币总量不会发生变化；而银行资产扩张（如发放贷款、购买债券和外汇等）会派生存款，增加全社会货币供给。
#
# ---
# # 20170125 Wednesday
#
# > 有则改之，无则加勉...
#
# > Professional service firms（下文简称PSF）指的是投行、一线咨询公司以及顶级律师事务所和会计事务所等一系列提供专业服务的乙方公司。这些公司大概是世界上智力密度最高的地方。
#
# > 但是一个好的分类器,一个好的数据集,正例与反例应该是差不多的,或者使用更强大的方式来解决 类别不平衡问题,引入cost sensitive技术等等.
#
# > 人与功能的交互，人与人的交互.
#
# > 雅虎的人工分类导航,到Google的机器算法搜索,从人->算法的,变化,感觉到计算能力与智能的强大...
#
# > 幸福的人都是相似的，不幸的人则各有各的不幸。
#
# > 不多不少,不重不漏.
#
# > 大量的黑色交易通过现金进行。大量的现金在金融体系外，无法监控、统计，已经严重影响到了各个国家的货币金融政策，影响各个国家的经济发展。
#
# > 机器自动产生数据,(监督数据,无监督数据),然后再用深度学习来学习这些物理世界的映射,大量数据+学习,应该能找到非常准确的Mapping,映射,规律,pattern...但是注意这个是归纳的保证,而不是演绎的保证.用来让机器学习人手动作也可以了...然后应用在驱动上...
#
# > **心智阶梯**是指为方便购买，消费者会在心智中形成一个优先选择的品牌序列——产品阶梯，当产生相关需求时，消费者将依序优先选购。在机器学习就是 Learning to rank?
#
# ---
# #### 自动适应算法,自己找规律的算法,自动聚类,
# 假设客户余额是正态分布,那么可以根据用户的信息自动找出这些分布吗? Latex 下的 ~ 需要特殊处理的
#
# Miss Ren, 有空了,学得更多了,数学/模型/AI/ML/DL了,就可以一起参加比赛了~
#
# $X_0 \sim N(u_0,\sigma_0^2); X_1 \sim N(u_1,\sigma_1^2); X_2 \sim N(u_2,\sigma_2^2)$
#
# ---
# #### 南海区政务数据资源共享
# 什么东西? 数据共享, 开放数据互联? 数据库开放? 开放数据,公开数据,共享数据和分析数据...需求,供给,服务?
#
# 一般不同开数据库吧? 安全,危险登,关键是如何使用现有的技术达到它们的需求?
#
# DW & ODS 的设计,层设计,目标是好用,易用,计算方便,多看看书,我好像有相关的书籍,然后如何结合到现在的分布式Hadoop上 ? 数据一般都分为了
# - 非结构化
# - 半结构化
# - 结构化
#
# 如何设计保存这些资料的 数据库,表;  或者 更加现今的 知识表示,图表示.?
#
# ---
# #### 机器学习...
# 在有噪音,有脏数据,也就是有真有假的情况下,如何使用算法找出中正确的隐变量? 学习到正确的模式?
#
# #### 国际象棋,围棋是 信息完全,信息完备的比赛, 但是扑克的不一定,那个是信息不完全的比赛,可以估计概率,但是概率可能把握不准...
#
# ---
# # 20170126 Thursday, Final Day In Company.
#
# > 有则改之,无则加勉...
#
# > 培养大方向思维...
#
# > We are drowning in information and starving for knowledge.
#
# > Mixture of Gausian, GMM. EM.
#
# > 迁移学习...
#
# > 来吧，来博弈把。。。Go Go
#
# ---
# #### What?
# **
# 在回答别人问题的时候。不一定要告诉他真实的答案。很多时候，告诉他一个符合他想象的答案，可能效果更好。因为不是每一个人，都有勇气去接受他不懂的东西，愿意去理解他未知的领域。对绝大多数人来说，更倾向用已有的想法，去解释看到的一切。
# **
#
# ---
# #### 微信 网页版都是可以的...
# [Website](https://wx2.qq.com/) 这里可以聊天,然后可以发送文件...哈!!!
#
#
# ![FromGuoKr](http://2.im.guokr.com/ScAdVO97f_o8IcuoHKMOhB-vDakT3GetlRyKrJlR-k3oAwAA7gIAAEpQ.jpg?imageView2/1/w/640/h/480)
#
# # 20170126 Lots of things happened...
#
# > What are you doing? IMSE... With her, with you?
#
# > Why can't you control your self...
#
# > For the first time... I ... pants...
#
# ---
#
# ---
# # 20170128
#
# > 新的一年,陪你开始,陪你结束...
#
# > 南海这边的小村已经确权了,意思是每个小村的分红份数是个常量, X/N, X是每年的收入,N份数是固定了,也就是不管多少人来,都没有股份了.
#
# ---
# #### 生物技术 与 信息技术 结合?
# 信息技术,超大规模集成电路很好,也到达nm级别,但是如何和生物体技术结合,使用生物能量ATP能量去工作,而不是现有的电池/能源管理,或者开发更加微小的新能源(核能?新能源方向?) 或者直接模仿使用生物能量来源,进入生物体内,类似 寄生/共生 的生物模式,扶助解决生物问题,医疗,疾病问题.
#
# #### 汽车产业 与 信息技术 结合?
# AR 增强现实,扶助驾驶,HUD衍射显示 数据/驾驶仓. 这边的市场还是很大的,结合 语音识别功能,AI部分,车载系统... 作为司机,更好的倒车系统,更好的倒车影像扶助, 信息融合, 更好利用 摄像头的图像 和 雷达图像信息... 光学颜色信息 和 雷达的深度信息...
#
# VR 虚拟显示,开发驾驶,学习的模拟系统?
#
# 原来隔壁村的几个小企业就是为大众生产汽车零部件的厂家,待遇不差诶...
#
# **有空真的得多问问,多听听老爸老妈,亲戚们,老同学们 的各种见闻,补充知识,一般来说大家看到的角度不同,信息量不同,偏见/误差也是有的,但是应该能够拟合到大部分正确的潜在信息**
#
# ---
# # 20170202
#
# > 斗地主又输了很多次啊,如何思考记忆数字,深度搜索,博弈树,虽然习惯思考问题,用算法/计算机去解决问题,但是自己也是要动脑去解决问题的~
#
# > What is there, is already there. Trust yourself. You can do it.
#
# > 感觉现在的 凤凰 自媒体 部分的语音部分已经是使用机器合成了，不需要人工读稿了，AI的一个应用之一？
#
# ---
# # 20170204 Saturday, Time to go back...
#
# > 不能怂，撸起袖子就是干～
#
# ---
# # 20170205 Sunday, First day at work...
#
# > Follow Jia Hui & MingJiu & Old drivers...
#
# > Follow Mei Jie...HaHa, We went to many departments... First day in year.
#
# > Try Hard to remember people, meet them, talk with them. Participate in more activities... Just say yes, do it.
#
# > Movie: Yes, Man.
#
# > 它以一座花园开始，汉座神圣的都市而告终... 如何理解这个句子,这个事物?
#
# > 读懂谷歌“贱卖”卫星图像公司的背后
#
# > **社会学 社会变迁的规律**
#
# > 只有背着的人,才知道背着铅球往前跑的感受,不能只听只想,去实践,去体验,去经历,去解释摧残与戏弄才会变得更加坚强,更加自信...
#
# ---
# #### What is Goolge.. etc Big Company Doing...
# 时刻要关注,大公司们的发展方向,未来5年,10年,20年的大方向问题... 各种东西都要看, T 字型 知识结构, 才能树
#
# 许多时候都是信息不对称, 别人利用信息不对称来欺负你的时候,你就要自己主动去找资料,主动去准备知识,来知道和他一样多或者比他知道更多,这是知识储备,还有是谈判的准备...
#
# 商业模式下的盈利模式...
#
# ---
# #### 人才的竞争 是最核心的?
# 大家都知道，所有城市未来的竞争都是人才的竞争，北京在全国城市中的资源和地位，让它获得了无与伦比的人才竞争优势。这样看，北京的产业升级之路会走得更快，这也就意味着城市财富增加的前景会非常美妙。这对政府、相关扶持产业，还有房地产业来说，当然是最大的好处。
#
# ---
# #### 租房的产业化?
# 高房价在上，大部分无力购房者将租房居住，这将促使长租公寓产业获得极大发展机遇，而且越来越细分，目前已经有实体在研发专门满足蓝领餐饮业打工者需求的公寓，未来物流业、商业零售业等等服务业人员的租房需求，都会有专门的长租产品来对接。
#
# 什么是 **一个理想化的城市人口结构** 从宏观全局的考虑VS从个体对社会的考虑...
#
# ---
# #### My Aqua Data Studio is too old.
# 版本太陈旧了,不好使用,体验不好,准备换新版本... 飞龙的DataStudio使用的是.bat文件打开的... 10.0...
#
# 原来10版本是使用bat文件启动的,启动的时候需要java的版本,应该是需要java7的环境,在java8就不行了,因此在java8的环境中启动Aqua Data Studio就失败了,方法是改变环境变量,把java7的路径放在前面...而是使用exe文件,
#
# Aqua Data Studio 12的绿色版就有exe版本的,所以不需要使用bat文件打开,没有问题...找到问题就好啦...
