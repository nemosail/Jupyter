# %% [markdown]
# ![Body&Soul](https://pic.36krcnd.com/avatar/201702/09005750/bual7ocofbykk90c.png!heading)
#
# # 20170206 Monday
#
# > Sleepless Night... You can't be afraid of those things. Trust yourself. You can make it.
#
# > Sing me to sleep...
#
# > **我们都深陷泥潭,但别忘记仰望星空了.**
#
# > Living life as if we had a choice.
#
# > 对称 与 不对称, 深入了解它,你就能够做很多想不到很神奇的事情了.
#
# > 倾注了更多更复杂劳动的事物具有更高的价值，这是比特币运行的哲学基础。
#
# > 数字货币,和电子货币不一样的地方,分布式,去中心化,关注开端吧~...关注前沿,要比别人快进入市场,才有机会啊,总是后知后觉是什么都没有的.
#
# ---
# #### Aqua Data Studio 已经更新到了12
# 使用的是exe入口,使用bat入口可能因为java版本问题而导致无法启动.
#
# **抬头看路,低头拉车** 不多不少,精确.
#
# #### 为什么数据表里面经常又多余的空格
# 后面为什么要跟这空格啊,天煞的,导致我怎样使用in啊...? 虽然使用 in的时候它们好像忽略了后续的' '空格了,但是不是好事情...有问题的.
#
# #### READ: Maker's Schedule, Manager's Schedule...
#
# ---
# # 20170207 Tuesday
#
# > 我们处在瞬息万变的变革时代，传统的企业大师如彼得德鲁克、福特们所崇尚的企业管理法则——精准、流程化，在如今反而会成为企业的“毒瘤”。 Is it true?
#
# > 任正非在《管理的灰度》一文中提出：“一个企业的清晰方向，是在混沌中产生的，是从灰色中脱颖而出的，方向是随时间与空间而变的，它常常又会变得不清晰。合理地掌握合适的灰度，是使各种影响发展的要素。”在任正非看来，“清晰的方向来自灰度。一个领导人重要的素质是方向、节奏。他的水平就是合适的灰度。坚定不移的正确方向来自灰度、妥协与宽容”。
#
# > 有了理论上的保证,就不会担心这个担心那个了,一定会达到,You can sleep tight at night.
#
# > 拜占庭将军问题,网络通信问题~ 这个问题基于现实,在抽象层,然后应用很广?
#
# > 自动驾驶,智能驾驶,网络,自动停放,自动去充电,自动去分布网络,这都是算法AI...需要做到的...
#
# ---
# #### 远程环境实在是太卡了
# 就使用最原始的windows界面把,不好看,但是速度快啊,不卡啊,节省时间,省心啊...
#
# 如何自带号码识别,号码映射,OCR,让机器识别来的号码,然后找个mapping,自动识别出来电对应的人物...
#
# ---
# #### AI/ML 智能交通...?
# 导语：智能交通正滚滚而来，无人船或将是下一个运输业的拐点所在。相较于传统船舶，无人船更安全、更有效率、也更便宜，还能解决困扰远航业已久的人才问题，它正吸引着越来越多的人投入其中。劳斯莱斯预计，第一艘完全无人驾驶船舶将在近年内实现商业运营。而完全自动航行的无人远洋货轮，将在10-15年内成为一种常态。
#
# 远程控制船舶和自动驾驶船舶是人工智能、数字通信技术发展的最新受益者。 传感器、通信技术和计算机的不断革新促进了一系列自动驾驶交通工具的兴起，如汽车、飞机、直升机、火车和本文的船舶。 目前，世界各地的公司和研究人员正努力将这些想法变成现实。
#
# #### 微信小程序 - 工具
# 可以减少实体按钮了,更好利用信息,利用资源,在等公交的时候,如果使用小程序提前告诉公交车要停,就不用挥手了.在车上的时候也可以使用手机小程序来提前告诉司机要下车,就不用挤去按实体按钮了.
#
# ---
# #### 区块链 技术, 电子化货币, 电子化应用,  blockchain 比特币 IBM的BlockChain也有, GOOGLE it, 看来大公司们对前沿都耕耘很深
# **区块链, BlockChain 不是数据计算的革命,是信任的革命. 然后让传统的支付,第三方支付,革命成区块链支付系统? 互联网企业应该很早到试错了,央行都启动了,说明什么,已经不是先知先觉,而是后知后觉,甚至不知不觉地等待革命暴风雨的到来?**
#
# 万物互联,这个技术如何推广,如何使用, 某个老总来聊天,以哪个载体存在,那种应用,应该是一个方向,一个推广方向.
#
# 拜占庭帝国想要进攻一个强大的敌人，为此派出了10支军队去包围这个敌人。这个敌人虽不比拜占庭帝国，但也足以抵御5支常规拜占庭军队的同时袭击。基于一些原因，这10支军队不能集合在一起单点突破，必须在分开的包围状态下同时攻击。他们任一支军队单独进攻都毫无胜算，除非有至少6支军队同时袭击才能攻下敌国。他们分散在敌国的四周，依靠通信兵相互通信来协商进攻意向及进攻时间。困扰这些将军的问题是，他们不确定他们中是否有叛徒，叛徒可能擅自变更进攻意向或者进攻时间。在这种状态下，拜占庭将军们能否找到一种分布式的协议来让他们能够远程协商，从而赢取战斗？这就是著名的拜占庭将军问题。
#
# ---
# #### 如何将机器学习里面的强大分类器应用都实际生活中,帮助人们去判别,鉴别
# 现实生活中的判定问题,分类问题, 例如如何分类一种植物,如何区分插花的品种,然后在还没开花,树还很小的时候就可以买了,不需要等到树长大,降低成本,同时避免买了假十八学士等等茶花树?
#
# 如何在广泛的治安录像里面找出犯罪嫌疑人(现在应该有这技术,但是由于DL深度学习的结果出来,然后可以更快,更准识别,判别)
#
# GBDT, RF, SVM, DNW... 许多分类器可以学习,可以应用,可以~~~
#
# ---
# #### 怎么算法课的又冒出来了
# 树型的计算方式,有重叠自子问题的,可以使用 记帐法 后者 动态规划法... Top-Down VS Bottom-Up, 自上而下,自下而上...
#
# ---
# # 20170208 Wednesday
#
# > 腾讯的黄金红包,想法,互联网+,活跃的思维? 将金融产品赋予社交娱乐化的特征，向来是扩大用户边界的管用手段，尽管非典型客群的净值和转化都不尽如人意，但是在亿级的市场面前，长尾的潜在价值是不言而喻的。
#
# > 如何挖掘长尾市场,市场的细分... 由于长尾市场的庞大性和个体低收益性,一般适合互联网技术密集型来处理,使用计算机程序来完成,而不是人力来完成,服务这个市场.
#
# > 既然你喜欢玩,给问题给你,如果有100RMB,然后换成1,5,10,20,50的散钱,一共又多少种不同的拆分方法? 你那么聪明,应该可以找到问题的解,然后如何找出算法,也就是找出解的过程? 将问题一般化,给出了M的总额,然后给出了N种不同额度的零钱,会有多少种拆分方法? F(M,N)
#
# > 天注定 Movie?
#
# > Add more entrances in GitHub. 当成自己的博客,记录/监督自己, Programming/MachineLearning/Economy
#
# ---
# #### 只看数据字典不够,还要去数据库查看行记录才行,问问业务,问问老员工
#
# 查询实在跑太慢了,就换思路啊,穷则思变啊,生于忧患,被迫去做得更好...
#
# ---
# #### Proof Of Work.  在于幸运/不幸 的是我们不能操纵时间. We Can't Manapulate Time.
# POW起源
#
# 工作量证明(Proof Of Work，简称POW)，简单理解就是一份证明，用来确认你做过一定量的工作。监测工作的整个过程通常是极为低效的，而通过对工作的结果进行认证来证明完成了相应的工作量，则是一种非常高效的方式。比如现实生活中的毕业证、驾驶证等等，也是通过检验结果的方式（通过相关的考试）所取得的证明。
#
# 工作量证明系统（或者说协议、函数），是一种应对拒绝服务攻击和其他服务滥用的经济对策。它要求发起者进行一定量的运算，也就意味着需要消耗计算机一定的时间。这个概念由Cynthia Dwork 和Moni Naor 1993年在学术论文中首次提出。而工作量证明（POW）这个名词，则是在1999年 Markus Jakobsson 和Ari Juels的文章中才被真正提出。
#
# B给A出了一个难题，或者A自己找来一个难题，A花费了10分钟时间证明一个问题，然后把答案发送给B，B只要1秒钟不到就验证了答案是否正确。
#
# 这样在计算机系统中，可以用于这样的情形：
#
# A请求一个B的服务，如果A可以段时间大量的请求，可能会造成B的崩溃，于是B对于服务的请求者出题，或者约定一种“解答-验证”协议，这个题需要花费一定的时间去计算，计算好了以后，发送个B验证，B瞬间可以验证完毕，验证通过，再给A提供服务。如果A是一个攻击者，这个时间花费×它要攻击的对象n是一笔可观的cpu计算量投入，因此可以有效阻止恶意攻击。
#
# 资源的占有,cpu计算资源,内存资源,存储资源,网络带宽资源等等~
#
# ---
# # 20170209 Thursday
#
# > 别停留在概念、价格和主观偏见的思考上,我相信弄明白一个事物背后的工作原理对于理解一个事物是非常重要的。
#
# > 就像是我们小时候会喜欢拆开玩具看里面是什么东西一样，了解它怎么工作的才能客观的看一个事物本身，才能有自己的观点，而不是总看着媒体发布的新闻和某些自己都一知半解的“专家”们的观点去理解这个东西。
#
# > 我知道我很好了,但是感觉对于你,还是不够好,还是欠缺了很多,有点担心有点害怕,但是没办法啦,尽力啦,尽人事~ 不去担心担忧了...Let it go.
#
# > [经济学,我们开始进入加息周期吗?客观规律是无法违背的,出来混,迟早要还的](http://www.bilibili.com/video/av8482665/)
#
# ---
# #### 坑爹啊,数据字典有时候是不完整的...
# Aqua Data Studio 下方查询结果的 正文(文本表示终于回来了...) 应该是在查询那里添加了...
#
# **注意 NULL 和 空字符串 和 '   ' 空格字符串 的区别和联系,这些小问题会让你翻车的~**
#
# ---
# #### 美林投资时钟理论
# Just read more, know more...
#
# 经济是如何运行,事物运行底层原理,How things work?[ZhiHu](https://www.zhihu.com/question/23117153)
#
# ---
# # 20170210 Friday. The day before YuanXiao...
#
# > 世界从存在开始便存在着各种问题，人们也在寻找着各种解决的方案。
#
# > 市场不管是在怎样的体制下形成，归根结底都离不开供应和需求的博弈。如今，当市场的供应主体由开发商转移到市场的个人后，原来熟知的游戏规则已经过时，这将带来怎样的变化?
#
# > 在散户主导的市场里，人性的贪婪和恐惧会不时参与进来。
#
# ---
# #### SQL, UPDATE, SET, CASE WHEN
# ```
# UPDATE a_table
# SET name = (
#     case fjjtzlx
#     when '优化型' then 'YHX'
#     when '强化收益型' then 'QHSYX'
#     when '债券型' then 'ZQX'
#     when '货币型' then 'HBX'
#     when '收益型' then 'SYX'
#     when '指数优化型' then 'ZSYHX'
#     when '增强型' then 'ZQX'
#     else fjjtzlx
#     end
# )
# ```
#
# ---
# # 20170211 Saturday
#
# > Need to fix the mouse... clicking problem, can be fixed...
#
# > Need to fix optical lens problem, growing bacterial...
#
# > Need to purchase some paper for writing, for work, for study...?
#
# > 量具...长度，哈哈哈，done; 质量？温度？湿度？ 这些就像物联网一样，然后使用嵌入式设备获得 体重，温度，湿度等信息，然后通过网络，通过微信小程序来传输数据，而不是使用蓝牙/APP等比较麻烦落后的东西，无联网之后，使用应该更加方便，更加工具化，用户更加友好。
#
# ![AiYueZhiCheng](http://g.hiphotos.baidu.com/news/w%3D638/sign=89419b328b26cffc692abcb181004a7d/b999a9014c086e062391d2e00b087bf40ad1cb64.jpg)
#
# # 20170213 Monday
#
# > SQL 查询效率,解决问题
#
# > 镜像的授权
#
# > 因为中国从古至今，真正的财富表现形式其实从未改变，那就是——土地。土地在农村是耕田，是农民的根本；在城市是房子，是居民最值钱的东西。所以古代的财富在地主手里，现在的财富在房东手里。
#
# > Mouse Fixed...Changed WeiDongKaiGuan...They are standard... 更换了 D2FC-FL-N China 的标准规格微动开关之后好了。
#
# ---
# #### 定位目标客户群,尽量减少计算量
# Join的时候尽量小表join小表,不要大表join 再 过滤...
#
# ---
# # 20170214 Tuesday, Valentine's Day
#
# > Happy Valentine's Day to all.
#
# > Will be in my sunflower field...
#
# > PC muscal? 上次看到的博物馆，科博摆，
#
# > If this night is not forver, at least we are together. I know I'm not alone. Anywhere, whenever, apart but still together, I know I'm not alone.
#
# ---
# #### A lot of things still undone, unknow...
# 又忘记如何行变列了...
#
# ---
# # 20170215 Wednesday
#
# > 多陪陪任妹子啦,她不容易,哎~
#
# > 唯有读书，能战胜这个爆炸的时代... 理性不足，或者说是对自身认知能力的高估，几乎是我们一切错误的根源。
#
# ---
# #### 行变列,经典SQL问题..
# [Solutions](https://my.oschina.net/boltwu/blog/508565)
# 大概就是 group by a.col, 然后sum(case when... ) count(case when... )
#
# #### 数据有问题的..
# 数据有重复,容易导致join join join 之后发散了,然后还重复数据,搽...
#
# 什么时候加Distinct,什么时候不加Distinct???
#
# ---
# #### 36kr Books Lists
# [books](http://36kr.com/p/5063663.html?from=related)
#
# ---
# # 20170216 Thursday
#
# > SQL查询太慢了,想办法加快速度,找出原因,找到问题所在,解决它.
#
# ---
# #### Neural Network
# 本质是学习一个变换,一个函数,模仿,逼近函数...真实值,当然如果准确知道函数本身,效果是最好的,但是由于现实时间太复杂,往往无法弄清函数真实面目,这时候学习/逼近函数就很有用处了[jobole](http://blog.jobbole.com/110144/)
#
# ---
# #### Pick up books and read 有NLP的处理工具
# [jobolesbook](http://blog.jobbole.com/106093/)
#
# ---
# #### 将大查询分割开来
# 找出目标客户,然后链接简单的acct_no, card_no,因为它是左表,一般需要distinct一下,防止数据发散...
#
# ---
# # 20170217 Friday
#
# > Please give me a second chance...
#
# > I was wrong. I was so wrong...Please, I promise you....
#
# > Time Arragement In Red Book... Think More, Write More, On Book, On Website.
#
# ---
# #### SQL 加入数学序号 ROW_NUMBER OVER( order by )
# HOW?
#
# 贷款年日均 VS 存款年日均 才更加正确把...
#
# Write some python programs to handles sql string... much better...
#
# ---
# # 20170218 Saturday
#
# > We have a class today...
#
#
# ---
# # 20170219 Sunday
#
# > Be with you, for my birthday...
#
# ![HaveToBeSmater](http://g.hiphotos.baidu.com/news/crop%3D0%2C2%2C800%2C480%3Bw%3D638/sign=985e4821b0014a9095711cfd94471520/d8f9d72a6059252d5263ea973d9b033b5bb5b929.jpg)
#
# # 20170220 Monday
#
# > 不担心,勇敢承担起责任.
#
# > 办理证件/护照等等这些,都要多问问老员工把,看看规章制度,毕竟这里的要求严格点...
#
# > 市盈率
#
# > There is stil many optitunities, 了解业务知识,了解经济,了解金融, Just be prepared...
#
# ---
# #### excel 版本坑爹的地方...
# 65536行的限制? 使用 xls2007 以上的就好了...?
#
# excel 固定表头,固定第0行, 选中第二行 - 视图 - “冻结窗格”下拉菜单中的“冻结拆分窗格”按钮
#
# [jobole](http://blog.jobbole.com/110194/)
# ---
# #### 多学习,多看看,[coolshell](http://coolshell.cn/articles/17583.html)
# ![doitims](http://wx3.sinaimg.cn/large/63918611gy1fcsemf9t5dj20jg08y7ah.jpg)
#
# ---
# # 20170221 Tuesday
#
# > 人生最难的就是在热爱和生计之间做选择，愿每个人这一生，既对得起梦想又担得起生活的责任。
#
# > La La Land? 致有梦想的疯子...
#
# ---
# #### What do you want? What can you do?
#
# grep 时候出现了 Binary file (standard input) matches 这个问题,问题在于grep认为我们给出的文件是一个二进制文件,但是我们的文件的确是文本文件,因此需要告诉grep使用文本文件模式, -a ... 查手册应该会有的...
#
# ---
# # 20170222 Wednesday
#
# > Where are we? What are we doing? 感觉好自私的基因啊...真心感觉把持不住...
#
# > 南海区 人才引进计划 Just Dota It... 1) 2) 3) 4) 按照他们写的总章来就行了...
#
# ---
# #### 全面 与 大局观
# 中长期的规划...[Can not lose](http://qijunjie.baijia.baidu.com/article/778182)
#
# ---
# #### 概率 拉普林斯平滑 修正 如何从数据里面找出这些规律? 发现问题?
# 从归纳来看,太阳一直都是从东边出来的,然后从归纳来看,明天从东边出来的概率是100%不? 但是我们貌似指导总有一天太阳不从东边出来了,这个概率不是很准确,如何修正? 拉普拉斯平滑?
#
# 或者一个大客户以前一直都是 借-还,信用良好,那么是不是以后的每次贷款都准时归还,或者他只是庞氏骗局,总有一天会失效?如何用数据去体现,去修正这个问题?
#
# ---
# # 20170223 Thursday
#
# > LeetCode, 有空就做题目...
#
# > Please give me a second chance..
#
# > 追求理性之美,简单之美.
#
# > 做好职业规划,人生规划,未雨绸缪...
#
# > 你也许无法掌握企业的命运，无法预测未来的危机，但是你至少应该为可能出现的问题做一点准备。慢慢发现又许多问题,许多东西,都是承担不起,承受不起,输不起了...
#
# > 电子货币,虚拟货币,数字货币
#
# >《货币的非国家化》?
#
# ---
# #### 写出好的文章...
# [写文章也不容易](http://kb.cnblogs.com/page/562830/)
#
# ---
# #### 比特币如何去理解,去下载原文,研读原文,其他人的理解,交流
# 1. 故事的开始: CPU时代;
# 2. 群众的觉醒: 显卡时代;
# 3. 巨头的诞生: ASIC时代;
#
# ---
# # 20170224 Friday
#
# > Row_Number, Rank, Dense_Rank SQL数据库排序,有点小细节的,可能没有数值,就是可能没有任何数据,可能数据有重复(100,100,100)这样的排序是?第一是,第二是,null?
#
# > Handle 人才引进计划, 也就是一个判定问题,什么的人是需要的,什么的人是不需要的, 01分类问题,如何达到更好的分类准确率,或者带上代价的评价指标.
#
# > 有时间,一定要多参加比赛? 跟他们,跟任妹子...?
#
# ---
# #### SQL 里面Exists是如何工作的?
# IN适合于外表大而内表小的情况；EXISTS适合于外表小而内表大的情况。?? 一直没有搞明白工作底层原理导致用起来不是那么心安理得,不是那么称心.
#
# ---
# # 20170225 Saturday
#
# > Go Home...
#
# > She is not comming yet...? But seem....?
#
# ---
# # 20170226 Sunday
#
# > Lots things happen...
#
# > 她喜欢就行...什么情况,能推导出什么? 我能都走多远,做到多厉害? 看不清...
#
#
# ![就像灵魂出鞘,从第三方角度看自身,看世界,人类也没什么了不起的](https://pic.36krcnd.com/avatar/201703/01092024/ojkj5dkcabauh5ja.jpg!heading)
#
# # 20170227 Monday
#
# > Suddenly comes to my mind...
#
# > <爱乐之城>和<悲惨世界>的契合度
#
# ---
# #### Like others stories, our life is like a story, filling a story...
# - 故事的开始:
# - 偶然的遇见:
# - 碰巧的相识:
# - 情愫的觉醒:
# - 夜短的仲夏:
# - 凛冽的北风:
# - 隐约的担心:
# - ?
#
# ---
# #### 轻资产 和 重资产
# 顺丰和通达系快递，其实是我国两种企业发展模式的典型代表。
#
# 先说通达系，他们采用加盟制，轻资产运营，其实是早期资本市场非常青睐的商业模式，最大的优势就是快速扩张。通过扩张实现规模，以规模降低价格，以价格为武器进一步碾压对手，看似是很符合逻辑的。
#
# 这也是我国经济崛起阶段的主流企业发展模式，民营制造业、代工企业、甚至是互联网公司，比如团购、外卖、杀毒、直播，普遍采用的都是这种思路，补贴、价格战、先占领了市场再说，只怕慢一步就永远没有机会了。
#
# 这套模式在过去的30年，很成功，很成功。
#
# 但在最近的这几年，似乎一切都变了，价格战不再吃香，卖低端手机的一落千丈，拍五毛钱特效电影的人人喊打，代工企业被迫远走他乡，规模换来的，不再是胜利，反而很有可能是产能过剩，成为供给侧改革的对象。
#
# 市场的主流价值需求转移，从价格转向了体验，体验的背后其实是这些东西在支撑：更高效率的工具，更节省时间的服务，更新鲜的创意……为了这个“更”字，用户愿意支付更贵的价格，这大概就是所谓的消费升级趋势。
#
# ---
# # 20170228 Tuesday
#
# > Take back the future...
#
# > Keeping Learning...终于下决心带上自己的显示器了,使用了DVI-D接口,直接接上主机就能双屏幕了,不需要任何修改...
#
# > Submitting materials...提交人才引进申请... Please give me a chance...
#
# ---
# #### Handle 查询
# 搞懂要查什么,查询理解-分析-计划-SQL-执行-查询这些可以用来干什么...?
#
# ---
# # 20170301 Wednesday
#
# > 我们与其抱怨国人的素质低下，不如通过制度将作恶的动机关在笼子里。
#
# > Pi Zero/ Pi Zero W/ ... 树莓派有好多版本,嘿嘿嘿,还有各种模仿树莓派的其他茶品...Just Search For It Before Action
#
# > 一念天堂，一念地狱.
#
# > Sing me to sleep... Livin' life as if we had a choice
#
# > Miss Ren 有散光拉？以后要注意啦，原来散光是那么痛苦的？注意灯光好了，她好生气，好害怕，不过聪明如我，赶紧想办法修复啊，陪她走走，抱抱她，不是说不开心就多抱抱好了啦，司机～，听她埋怨埋怨各种小事。。。嘿嘿嘿，还得变得更加聪明才行。。。
#
# ---
# #### 授权问题, 角色Character/Rolse
# 根数据库的授权类似... 用户  与  角色, 给角色权限, 然后给角色用户,这就很方便管理了,有空看看这部分资料..
#
# 全选 - 反选 == 全部不选?
#
# RPT做的不是十分好? 经常权限树很深,有权限但是没有向上层反馈,导致要进入很深才能去除...刚才才吐槽那家公司...权限是一级一级深入的,当点击最后的叶子节点,实体的时候,却没有自动给出到达这个叶子路径上的节点,然后我任了,最多我一个一个去点击,然后!!!码单,它点内部节点,自动把所有叶子节点都选中了,什么逻辑啊,什么破程序,是不是有病!!!然后就人肉运维,把不需要的一个一个删除,我的天啊,你们是干什么去了...
#
# ---
# #### 物联网 体重计 微信小程序
# 记录统计,监控 体重, 关注健康... 大方向,不管实现细节,考虑整体的可行性.
#
# ---
# #### 开通南海报表之后,发现这个问题进入报表时候:  IBM Cognos 8
# Cognos Viewer Security Rejection. Your request was rejected because it failed Cognos Viewer inupt validation.
#
# 然后Google这个问题,一般的答案是:  IE : Internet 选项 - 安全 - 自定义级别 - XSS筛选器 - 禁用 !
#
# Then problems shall be solved... 以后碰都这种通用问题得记录下来了,因为我不想我的时间浪费在这种小问题上,应该去解决更宏大的,更宏观的问题去,要有野心...
#
# #### Fix little broken door lock... 尝试修复年久失修的老门锁。。。石墨-固体润滑剂？
# 宿舍的门锁实在是比较老了，但是还是可用的，old but not obsolete... 它虽然老化了，但是只是需要保养与维护，还是很好用的。。。只需要加入一些铅笔碎，也就是石墨粉末，需要的是2B铅笔和刀子，刮下一些粉末，放倒钥匙里面，然后插进去旋转就好拉。。。对付这些机械的，老家伙就用老套路就行，百度一下，找找答案就行了。。。
#
# 石墨是碳的一种结晶形态,具有六方晶格,原子呈层状排列,同一层晶面上碳原子间的距离为0.142nm,相互之间是共价键结合;层与层之间的距离为0.34nm,原子间呈分子键结合.层与层之间的作用力很小故很容易在层间发生相对滑动.因为这些结构上的特点,导致它的强度\硬度很低,塑性也很差,但可以起到很好的减磨作用,是一种很好的固体润滑剂.
#
# 石墨在机械工业中常作润滑剂.润滑油往往不能在高速、高温、高压的条件下使用,而石墨耐磨材料可以在一200 ℃ 一2000 ℃ 温度并在很高的滑动速度下（loom / S ）不用润滑油工作.许多输送腐蚀介质的设备,广泛采用石墨材料制成活塞环、密封圈和轴承,它们运转时,勿需加入润滑油,石墨乳也是许多金属加工（拔丝、拉管）时的良好的润滑剂.
#
# 不需要记住具体的做法，细节的做法，关键是通用的找出问题节的思路，就是遇到这种问题，应该如何找解决方案，找出问题所在和解决它。。。算法 与 思想/思维， 灵活的思维，别固化～
#
# ---
# #### 无风险利率，很久前看过拉
# 无风险收益率的大小由纯粹利率（资金的时间价值）和通货膨胀补偿率两部分组成。
# 无风险收益率=资金时间价值（纯利率）+通货膨胀补偿率
# 无风险收益率的确定
# 无风险收益率的确定在基金业绩评价中具有非常重要的作用，各种传统的业绩评价方法都使用了无风险收益率指标。在我国股市目前的条件下，关于无风险收益率的选择实际上并没有什么统一的标准。在国际上，一般采用短期国债收益率来作为市场无风险收益率。
#
# ---
# # 20170302 Thursday
#
# > What you see is what you get...(word); What you think is what you get...(latex);
#
# > 所想即所得...(许多人的座右铭)... Instead of 所见即所得.
#
# > 眼睛看到的只是事物的表象,不要被表象所迷惑了,应该要找到事物的内在和根源,它的本质...
#
# ---
# #### 计算机视觉融入智能交通? [36kr](http://36kr.com/p/5065351.html)
# 智能汽车,自动入库,自动出库? 摄像头在交通系统中的作用是完成监控。但车辆的增加提高了人工视频监控的成本。举个例子，电脑显示屏最多有九路监视格，一个人盯三路，假设一个城市有三万路视频，则需要一万人盯着，容易造成疲劳和监控误差。传统的人工管控方式无法满足监控需求，而基于算法和深度学习的计算机视觉技术能做到这一点。使用AI/ML方式有效完成人脑集中型的重复劳动,从繁重重复的脑力劳动中释放人类...
#
# 就像Miss Ren提到的超级大脑一样,人脑很厉害,但是人脑很唯一,不可能复制这么多的人去帮忙干枯燥繁重压力大的事情,人类忙不来,也干不来,需要找出人脑的工作方式的原理,或者近似替代品,来完成这部分需要高度智慧的任务,但是又特别繁重,特别类的工作,这部分是机器应该替代的.
#
# ---
# # 20170303 Friday
#
# > 现在还是有太多不懂,然后被迫赶鸭子上架,只能对BangGe的SQL依葫芦画瓢... 肯定是要自己搞懂,然后用自己的理解去解决问题的啊..搽
#
# > 而一个底层青年如果认定自己不属于底层，他就会想办法脱离底层，只要能找到正确方法，他一定能脱离底层，实现阶级跨越。[baidu](http://hstl.baijia.baidu.com/article/787336)
#
# ---
# #### 汽车的自动驾驶
# L0 L1 L2 L3 L4 L5 分不同级别...几乎就是一步一步使用机器代替人类的驾驶技能,也就是全自动的方向了...在任何工况下都能等价或者超越人类...
#
# ---
# #### 许多不懂的东西真的只能多问,多理解
# 报表的权限,流程,可以先开给自己看看,自己尝试下,没有问题了,理解了,执行过流程了,就相对清晰多了.
#
# 解决问题要灵活,多想想,多尝试...
#
# 重武器  与  轻武器
#
# ---
# #### Mouse that can cross diff computers
# 如何写出程序,使用同一个鼠标,穿过不同的计算机,平台,就是原来不同的实体计算机需要单独的鼠标的控制,现在可以使用程序,使用同一个鼠标,如何无痕地进入不同的平台? Ideas that can change the world.
#
# ---
# # 20170304 Saturday
#
# > Thanks god, thanks to all. I am so graceful. Second changce... I won't make that kind of mistakes again...
#
# > Be smarter everyday...
#
# > Her period is much more than 28-30, why is that...? How to capture the pattern, and predict it well..
#
# > During these few days, mood can vary a lot, unstable, variance can be big...
#
# > Went to 从化,驴友找到的溪头村?,流溪河, 流溪湖 国家森林公园, 望谷温泉,但是他们说这个地方硫磺味没有那么重,不是特别好? 换个更加专业的地热泡温泉的地方?这个是主打私浴的?
#
# ---
# #### Note from A4 AT DORM
# - 积息计息法， 在周期内的每个时间间隔，得到的利息参与复利，当时间跑向无穷小，得到的是 e 自然增长;
# - 逐笔技术法， 在周期内利息不参与复利
#
# 科氏摆 还是没有搞懂它是如何工作的。。。
# ```
# //////////////////
# ——————————————————
#        /\
#       /  \
#      /    \
#     /      \
#    /        \
#   /          \
#  o    - - >   o
# ```
#
# Github应该有保存数据文件RawData的方式的。。。？Google IT.
#
# 中年危机。。。改为自己的现在，未来想想，人无远虑，必有近忧，  不能**买了负担不起的东西，上了输不起的赌桌**
#
# 卖手机的罗胖; 卖书的罗胖。。。傻傻分不清。。。
#
# 纸牌屋， 绝命毒师
#
# AI/ML 应用，野生动物识别系统，不再使用人工去监控了。。。
#
# What is 租赁？
#
# 最困难的两件事情：
# - 把思想装进别人的脑袋里;
# - 把别人的钞票装进自己口袋里;
#
# 下调事业保险费率，减少企业负担，营改增，减少企业负担，都是同样道理，希望企业有更多资金流动，熬过这段时间。。。
#
#
# HBO 《硅谷》 USE A.I. to optimise our world. Be better, be smater.
#
# 轻资本，重资本...
#
# INTEL无人见开发平台，IDE，UAV，高平台，然后给所有人来给这个UAV来编程，发挥群体的智慧，来给有限的平台提供无限的可能，完成各种各样的东西。
#
# 人有小目标，国有大计划， 撸起袖子加油干呗。
#
# 务实，务虚。。。 PC muscale?
#
# 药品报销怎么搞？ 额度一直都有吗？ Find it out.
#
# ( People, time ) create/generate -> money, value
#
# audible.com / The Art Of Learning
#
# 政府工作报告， 让百姓要有获得感， 稳增长，保就业.
#
# 实体 与 虚拟 不是对立不可调和的，而是可以成比例统一的
#
# 穷则独善其身，福则救济天下
#
# 财富，更要让别人尊重你，带动你的人们富起来，干起来。。。
#
# 静心解决问题拉，精心
#
# OS老师：人们都希望赚钱，赚大钱，快速赚大钱。。。
#
# 以前是实业救国，现在要实业强国
#
# 心态要好，坚韧不拔，不怕魑魅魍魉，不怕别人的指指点点，脸皮要厚的拉，怕什么，正面刚啊。
#
# 身心，身体 与 灵魂， 都是需要锻炼的。。。
#
# 固体润滑剂，石墨是碳的一种结晶状态，碳原子之间的距离为0.142nm,层与层之间为0.34nm，能相互滑动，是良好的固体润滑剂。
#
# 重力转向，以为飞船要入轨，需要是水平方向的分量，需要力来改变速度方向，使用燃料太浪费了，使用重力就很好，这个重力虽然没有做工，但是改变了我们刚开始速度的方向。。。
#
# A.I. assistent 语音，辅助 人类，教人类如何做菜。。。？ 释放了我们双手了。

# %%
# play with MD5 SHA256 AES; BlockChain ProofOfWork

import hashlib
import os

# MD5 part, it is easy, result is 32 charcaters in hex
keystr = '1314025'
m = hashlib.md5()
m.update(keystr)
CryKeyStr = m.hexdigest()

print(CryKeyStr)
# print(len(CryKeyStr))

# AES part, it is easy too?
from Crypto.Cipher import AES
import binascii

key = CryKeyStr
text = 'Sing me to sleep, now.'

# padding the text to mutiple of 16
pad = ' '
num_need = 16 - len(text) % 16
padded_text = text + pad * num_need
# print(len(padded_text))

iv = os.urandom(16)
aes_mode = AES.MODE_CBC
encryptor = AES.new(key, aes_mode, iv)
ciphertext = encryptor.encrypt(padded_text)
print(binascii.hexlify(ciphertext))

decryptor = AES.new(key, aes_mode, iv)
plaintext = decryptor.decrypt(ciphertext)
print(plaintext)

# SHA256 part, proof of work...
import hashlib

ledingStr = 'ProofOfWork'
paddingStr = '4131025'
middleStr = '43647805'

for start_num in range(0,99999999):
    sh = hashlib.sha256()
    
    org_str = ledingStr + middleStr + str(start_num)
    sh.update( org_str )
    hash_str = sh.hexdigest()
    
    if( hash_str[0:6] == '000000'):
        print(str(start_num))
        print(hash_str)
        
print('Searh numbers ends here...')
# Out:
# 36822ecf9ca0da06e53d095eaa33a160
# fc4d06e30af9dbb79772ca7c89c3807ca9dd0f5d016e0ceddf12bb0f3cbd4dee
# Sing me to sleep, now.
# 4131025
# 000000fbdc3f76d810c800369dc4efcc7c842f2c715090c14953cc0c5f00a978
# 4405397
# 000000581fb75120423d9a699b095c6e7c6d8c38f0d89fb75bbc27b2be7fff77
# 8917491
# 0000008e9fb69ad73a5988ab2ebe6030cba0a9019dc72bb6d2fb7275858644cb
# 13748552
# 0000000a1e29ccc4f1473ac494cb221329cddcb1b8ff4a0457707d6a3bd591a2
