# %% [markdown]
# ![to the moon](https://pic1.zhimg.com/e3a6a63812f4d69c877cfdb0b73590ec_b.jpg)
#
# # 20170405 Wednesday
#
# > 雄安，政策红利，人们对它的预期，千年计划，在更长的时间尺度上去观看？
#
# > 机会，更多是抓紧机会，平时更注重努力锻炼与成长， 机会 与 努力 的辩证统一...
#
# > 不动产登记。。。
#
# > 互联网+地铁 使用的形式是 互联网网上购票，线下取票的问题，但是为什么不能直接刷码过闸？ 成本问题？ 一本万利啊，所有城市地铁，公交都可以解决这个难题了，应该是无现金的社会啊，减少成本，更方便快捷。。。
#
# > 无现金社会...
#
# > 安居乐业，多少人能够安居，然后又有多少人能够乐业? 俺是graduate student啊，怎么可能就这样被你们束缚，俺要自由，俺要公平，俺要民主，俺什么都想要，不是不要，只是时候没到而已。。。
#
# > 感人的 To the moon 游戏，有空一起解解迷～
#
# > Stop and think, DFS/BFS 深度搜索，广度搜索， Are you confining yourself? Jump out and see and think. Are you opening it using the correct way? You can not calculate human madness -- by Aissic Newton.
#
# ---
# #### 使用Google+微软自带教程，将Excel打开成为独立的窗口，Simply Solved.
# [link](https://support.microsoft.com/en-us/help/2636670/how-to-open-excel-files-in-separate-windows-in-windows-7)
#
# #### 报表管理协同好不好用！明明应该提供查找功能的却没有提供查找功能，
# 但是根据使用经验来看，这个网页的xml就已经提供了所有的信息，也就是所有的报表并不需要主动点开的时候，它已经是获取到本地来了，要是会网络，网页编程，使用python就能搞出自己的搜索，嘿嘿。
#
# #### 写SQL还是使用全部大写好，大写大法好
# - 直接使caps，输入的时候就是使用大写;
# - notepad++ 全选，右键，转成大写;
#
# #### 把知识沉淀下来，太细节的不用管，不用记住，记住的是大方向的，通用思维式的，
# 其他使用工具，计算机，知识图谱，知识拓扑等方式表示，然后以后查询就好了，
#
# #### To The Moon
# > "你觉得天上的星星是什么呢？"
#
# > "我觉得是千千万万的灯塔，它们让那光芒照耀着其他灯塔，也照耀着我。"
#
# ---
# # 20170406 Thursday
#
# > Where are you going? **多学学数学系的家伙，大胆假设，小心求证，矛盾的对立统一**
#
# > 人民的名义，In the name of people?
#
# > 啊啊啊，忘记查看Oracle的邮件了，以后要根他们说好，有邮件，重要信息大家一起分享下，相互帮助。。。
#
# > 今晚得花时间去搞那个Oracle的环境了，不管是Linux和Windows，还有办公重要工具也要准备好拉，嘿嘿. Oracle Learning Library.
#
# > Handle 药物报销，问问老员工？ How to do it? 同仁堂的牛黄解毒片，安宫牛黄丸...
#
# ---
# #### DB2 在SQL中执行除法后，丢失精度，
# 注意可能数据类型带来的小问题，因为DECIMAL可能会丢失精度的。。需要的: CAST( num AS DOUBLE ) ，然后执行除法之后使用 ROUND(X,4) 等来控制精度输出。。。
#
# 以后要看清楚需求啊，不小心没有区分好余额和年日均。。。有时候他们需要的某个时点的余额，有时候是今年1.1到现在的年日均存款。。。
#
# 应该更加通用，更加智能，更加robust，然后完全自动化实现了，不需要我们程序员去参与，能够自动化计算完成的部分全部自动化，释放我们去做更加有趣，更加伟大的事情。。。干。
#
# ---
# #### 继续修复做好 DataStage 作业的，他们出现重复了，可能是SQL的原因，数据的原因，使用数据的原因
# 先定位问题，然后解决问题，做好记录，不能只低头拉车，更要抬头看路，不能被太多的负能力所束缚，需要看到更远更幸福，要相信啊！ Please Please.
#
# ---
# #### Question:
# 没有数据库的帮助，如何从一个结构化的数据文件txt/csv里面找出有重复的行，重复的数据，如何利用现有的工具做到这个效果？
#
# - 简单粗暴，使用excel啊，使用excel导入，相对与数据库，轻便，快捷，
# - 导入数据库？
#
# ---
# #### 俺要开车，开船，开飞机，开火箭，开曲率引擎，开跳跃，开任意门～
#
# ---
# # 20170407 Friday
#
# > From 林总，李总 等老司机们，当女票不开心的时候，用力抱紧她，不让她说话就好了～ 让她比上眼睛感受～ Also use kiss technique...
#
# > Anyway, 总不能丢失信心，要主动乐观地活着，不能向这个草单的世界低头。
#
# > 中国去资产泡沫的路程依然任重道远，不动产市场如黑洞一般的资本虹吸效应，继续让楼市吸纳着社会的大部分资金。
#
# > 转变视觉，从管理者，决策者的角度去思考，去观察，为什么这么做。。。
#
# ---
# # 20170408 Saturday
#
# > 突然之间 老赵工头 和 汪汪涛 说来佛山，带他们去看看，逛逛，人山人海，ofo骑千灯湖，附近的地点， H12 应该是湖12。。会玩
#
# > 不管怎么样，也要开心快乐地活着，要有理想，要又梦想，再不济也都投资自己，我老了笑着还能送他们那群混蛋上天！
#
# > 既然社会把我们年轻人逼迫成这样子，难道我们就只会默默承受码？我们反抗的时候你们会知道，逼成有才没道德有多可怕，你们有多黑暗，我们就能2倍的黑暗还回去。
#
# #### 中产要解忧，只能靠三件事：提升自我，防范风险，保持乐观。
# [Song ni men li kai, qian li zhi wai](http://hstl.baijia.baidu.com/article/818117)
#
# ---
# # 20170409 Sunday
#
# > 去他们家，问好多问题诶，腿软。。。
#
# > 有空还是多走走吧，多联系，多聊聊～
#
# > 愚蠢的人类从历史上学到的经验是，人类从没在历史中学到什么。。。
#
# > 但是还还是尝试用历史当为数据，使用模型，尝试去预测未来，虽然不准，已经是难能可贵了。。。
#
# > 吴军老师的《智能时代》和赫拉利的《未来简史》
#
# 在这个弱肉强食的世界，最激励我们的就是：渴望自由的人，拼尽所能。
#
# 如果说《海贼王》描绘了梦想的追寻，那《进击的巨人》就在描绘为了梦想的牺牲。
#
# # 20170410 Monday
#
# > 商业吹捧，互相吹捧。。。
#
# ---
# #### 投资自己呗，身心锻炼，
# 身体与灵魂，理论与实践，科学与技术。。。
#
# 《人民的名义》就是这么一部逆流而上的作品。
#
# 别的剧用小鲜肉，它用老戏骨；别的剧架空现实，它直面当下体制最大毒瘤之一——腐败。
#
# #### dw的目录依然打不开，尝试很多次了，没事
# 咱们用个work around，灵活点码，既然能够使用shell放到它的文件系统，它的文件树了，那么再搬到对应的目录就行了啊，没有问题的，买毛病，就是麻烦点，嘿嘿。。。
#
# ---
# # 20170411 Tuesday
#
# > 共享经济，共享单车，共享汽车，主要是解决了人们出行困难的现状，长途交通，中途交通，短途交通等等～
#
# > 赫总的致动手柄可以修修继续使用拉～下次去修复它，嘿嘿黑
#
# > 尽可能自动化，日常工作过程的沉重繁琐部分的自动化，使用AHK或者xdotool来模拟人的行为，或者直接python来了解程序底层，例如各种打卡补卡异常等等。。。
#
# > 国家高层，论如何卖了你的人民还让他们快乐地帮你数钱，其实也是一个博弈的过程，是你输我赢，还是互惠互利，资产财富如何分配问题，上层与下层的博弈，统治者与被统治者的博弈。。。
#
# > Alpha Go 又出来溜达溜达了，Catch up with them.
#
# ---
# 真正会花钱的女孩，都有会赚钱的思维。
#
# 她花的每一分钱，都是在投资自己的知识、能力、品位、眼界、格局。
#
# 优越的家庭环境使得他们不至于局促于眼前，而是把精力放在了更长远的积累和沉淀上，做出了在更大时间尺度上的正确选择。
#
# 归纳，很有用，但是注意不是演绎，逻辑的清晰准确，但是大方向应该没有问题的。
#
# ---
# #### 不再人工定义函数/估值函数，使用机器自己去得到特征，自己去找出最好的函数近似表达式。
# 单元变量回归 到 多元变量回归，一起听音乐，有的数据是点击喜欢，收藏，听多多少次，听的比例，这些多个变量**人工**合成一个分数来表达喜欢程度，这个人为因素太大，能不能使用深度学习的思维，就是不再使用人工提取特征，减少人工因素，使用机器自身去根据这些信息去学习，自己搞个估值函数，不再需要人工定义这个函数如何构成，如何计算，而是使用 数据 + 算法 的思维来自动构建函数，自动计算，这种应该是现在发展的方向了，但是以后呢？
#
# - 华为重视研发投入，联想重视贸易拓展
# - 华为从事的是永不停歇的产业，联想销售的是日薄西山的产品
# - 自己的领域必须是做到做精，其他在广度扩展，但是只是多了解，多实践而已。。
#
# ---
# #### We/They all should do
# [36kr](http://36kr.com/p/5068700.html?from=related)
# 最后我觉得作为企业家，我们最起码要做两件事：
#
# 第一要守住底线。底线是什么？最近有两个例子，一个是厦门公交车纵火事件，第二个是北京航站楼的爆炸事件。厦门公交车6月6日高考之前，一个人纵火，死了47个人，其中有八个是去高考的学生。这个纵火的人为自己的一点小事求爷爷告奶奶，没有人帮忙，他感觉到社会的冷漠。而在公交车上与他一同死去的40多个人没有人欺负过他。当社会上的一些成员受了很大委屈，碰到困难，其他的社会成员不愿意为他说一句话、给他一个眼神、拉他一把，让他觉得自己被边缘化之后、他就可能要报复社会，而全社会成员其实就是生存在同一辆公交车上，别人命运与你有关。所以作为做人的底线，尤其是对社会底层人士，我们要拒绝冷漠。哪怕不能给钱，也该为他说一句话、拉他一把。
#
# 第二是我们在促进社会阶层纵向流动问题上如何有作为。我创业是21年前，那个时候很穷，但是我一点也不恨社会，社会给了我很多机会，让我能够成长起来，改变我的社会阶层。
#
# 我呼吁，大家要运用自己的理想、运用公司的资源，更多地促进社会阶层的纵向流动，一旦阶层固化下来就会产生仇恨，底层的人就会起来反抗。一定要想办法让阶层能够纵向流动起来，这不单单是政府的责任，更加是每一个企业家、每一个学者、每一个知名人士的责任，也是我们每个人生命当中的应有之意。
#
# ---
# #### Is he reading the same material?
# 同样是35岁左右的职场人，有的人仍然是月薪1W，而有的人早就月薪10W+，总结下来，大牛和普通人主要有三个区别。
#
# - 接受挑战 vs 安于现状
#
# 大牛都愿意接受挑战，普通人往往安于现状，不愿意跳出舒适区。
# 做别人不想做的事情，扛下来别人不要的屎盆子，哪个大牛当初不是从接受各种挑战开始的呢？
# 从某种程度上说，接受挑战就是职场成长的最佳路径，所有成长快速的人，要么接受公司的临危受命，或出色完成责任以外的项目？这也就是成长的机会，就是升职、加薪的最佳通行证。
#
# - 找高手学习 vs 与低手找感觉
#
# 大牛擅长向比自己牛的人学习，普通人没有刻意寻找高手学习的意识，还有一些人，喜欢和不如自己的人在一起玩，找优越感。
# 有机会的时候，我都会问身边年薪几百万的职场大牛一个问题：你是如何成长成为今天的样子的？
# 其中，有一个答案是比较统一，他们在年轻的时候，会特别擅长找身边的高手，在高手身边，观察，模仿，研究TA们的成功因素，向高手学习，消化吸收后为己所用。
# 职场中的大牛往往有一个牛逼的老大带路，在老大身边学习各种宝典和攻略，可以避免很多坑，他们善于向高手咨询行业内的各种趋势和方法论，不断修炼。
# 如果工作中没有牛逼的老大，他们也会自己寻觅在自己领域的高手人带路。
# 在我看来，工作十年，月薪一万，还自我感觉不错，有几个可能性：
# ❶ 身边没有高手，认为自己已经是高手，感觉还不错。
# ❷ 身边有高手，绕道而行，你高你的，我玩我的。
# ❸ 享受繁重的工作，从来都没有时间和精力去考虑向高手学习这件事情。
# 说到“享受繁重”的工作，你还别不相信。
#
# - 总结规律 vs 机械重复
#
# 大牛都具备总结规律的本领，普通人沉浸在重复完成熟悉的事情。
# 总结规律。
# 无论在任何领域，接受任何工作，大牛都具备总结规律，熟悉模型，吃透规律的能力。然后，通过挑战实践，检验规律，校对规律，继续接受挑战实践，总结规律......
# 职业发展的规律就是：
# 一个人到一个岗位之后，用最快的时间，把岗位的能力要求抽象出来，找到关键点，聚焦到自己的能力，用最快速的时间达到并超越。然后找下个职位，重复，螺旋式成长。
# 对于“规律”的理解，每个人的经验和阅历不同都会有不同的理解，我将用一篇推送给大家介绍我认为职场中该如何总结规律，敬请期待。
#
# ---
# - 逐级打怪兽
#
# 持续（主动）接受挑战性任务，通过出色的完成挑战而成为你要成为的人，在实践的过程中可以提升技能，校对规律，实践出真知，实践是检验真理的唯一标准。
#
# - 持续找高人
#
# 找导师，向高手学习，不断吸取前人的精华，可以避过很多坑。开始可以是模仿自己的偶像，揣摩偶像的思维和行为模式，只要开始，就会有收获，你只要试一试。
#
# - 主动找攻略
#
# 找规律，善于总结，找到自己领域的核心模型，吃透每一个点，每一个模块，把企业对职位和人才的需求搞清楚之后，将自己的能力迅速提升，与之匹配，从而获得下一个机会，打怪兽。
#
# ---
# #### bikes...
# 公共自行车是“公共产品”
#
# 3公里以内的短途出行，没有任何交通工具能与自行车媲美。但在当今的都市，骑自行车有两大不便：一是日常出行距离动辄十几公里需要乘坐其它交通工具而且不便携带自行车；二是到达目的地后自行车成为累赘（主要是怕丢）。
#
# 自行车租赁能很好的解决上述“痛点”，扬其长、避其短，有效弥补公共交通系统的不足。但用户的痛点解决了，商家却“痛”了：租赁是重资产、重运营生意，用户骑一二公里自行车愿意支付的费用却少之又少（最好免费）。“重资产+重运营+超低客单价”，这样的“生意”稳赔不赚。
#
# “社会效益好、经济效益差”是“公共产品”（Public good）的重要特征，如义务教育、环境绿化、公共交通等。企业不是慈善组织，提供公共产品是政府的基本职能。通俗地讲：能赚钱的事儿企业抢着干，赔钱的事儿只能找政府，于是就有了公共自行车。
#
# 面向个人的企业，面向其他企业的企业，面向政府的企业... 有很大差别的，应该把全面，全局，系统，看待整个过程。。。Can You?
#
# ---
# #### Bank?  立足现在，回顾过去，展望未来啊， 马尔可夫，马式性
# 银行利润下滑的的根本原因是：
# - 企业的有效信贷需求萎缩，导致银行的资产收益率水平下滑。
# - 利率市场化步伐推进，银行净息差水平收窄，五大行利息净收入降幅在6%-9%。
# - 金融脱媒也降低了实体经济对银行信贷的需求，企业可以通过发债、新三板、IPO等多渠道融资了。
# - 商业银行的不良贷款上升，计提风险拨备也要冲减掉一部分利润。
#
# 随着互联网金融的迅速发展，让各上市银行发现，拥有过多的物理网点和柜员是累赘，而不是优势。信息技术的提升，带来客户习惯改变，是银行瘦身的主要原因。现如今，越来越多的客户通过电子化渠道接受金融服务。
#
# ---
# #### 搞搞分布式数据库，Hadoop，搞搞分布式货币，数字货币
# 学习学习
#
# share everything / share nothing
#
# Hadoop 生态， 可以处理 结构化，半结构化，非结构化， 但是它同时有自己的缺陷，看清优点和缺点.
#
# YARN 资源管理，资源调度，管理即服务，城市资源/规划管理，等等
#
# ETL 相当于在Hadoop生态里面的数据整合，相当于传统的ETL的Datastage部分
#
# 机器学习模块 Mahout, MLlib
#
# 图Graph
#
# 流式处理， spark, storm
#
# 行式存储 / 列式存储， HBase 应用场景， 宽表/窄表
#
# HDFS MR Spark/RDD
#
# ---
# # 20170412 Wednesday
#
# > 数理逻辑去解决对应的问题，余额上升，但是年日均会上升码？
#
# > 人才引进申请怎么搞。。。？ 好像区分了 佛山市 + 南海区 两个部分？ ASK PEOPLE...
#
# > 解决ScreenShot问题，通讯工具自带的截图太烂了，两个屏幕就不能截屏了，使用输入法的截图工具，需要下载单独的插件，离线安装.
#
# > Append SMZDM 什么值得买 的上面 办公 效率提升软件 | Xsearch | Everything | 日历 |
#
# ---
# #### 程序 与 人， 上帝视觉，都是时间与空间
# 我们集体攀爬社会阶层，归根结底，想争夺的是生存的选择权：时间+空间的自由。
#
#
# ---
# # 20170413 Thursday
#
# > A sense of lost.
#
# > 许多事情，许多想法是自己一闪而过而实现的，而不是谁谁谁的套路。。。You know when you say that. It hurts a lot...
#
# > When you are unhappy, tired, montyly comes, 需要哄着你，把自己不开心的想法藏起来了，免得的你更加不开心，宁愿自己扛着，也不希望你知道，可是，还这样说，好hurts...
#
# > 知道了这些市场效应/社会效应，更需要智慧去破局啊，去博弈...
#
# ---
# #### 我们这些人终将无家可归？
# 上学的时候受到的教育是不要拜金，知识才是财富；搞研究的时候受到的教育是不要浮躁要坐得住冷板凳；入职的时候领导讲搞科研不是升官发财，心要静……。[Source](http://mp.weixin.qq.com/s?__biz=MzI5NDExMjg0OA==&mid=2651317377&idx=1&sn=d30bd77f608b823e24548fe2a4668a33&chksm=f7949fbec0e316a848ebd277745daf7a21b7883b616cdc1631f3506418f6343b02fca52fea11&scene=21#wechat_redirect)
#
# 博士们大多数都选择了与自己专业对口的研究机构，而硕士们多去公司，本科同学往往做和专业不相关的事情。回头看看，背景很相似，结论也很相似，A sense of 真实。。。
#
# 我都照做了。可是现实是？ Lose everything...? You have to believe...You will kill them all oneday.
#
# ---
# # 20170414 Friday
#
# > Will you guys give us some chances? 为什么不多给机会，多给希望给年轻人们？ 依旧是吃人的社会。。。
#
# > 应该了解，知道这个系统是如何工作的，这样遇到问题就不会乱，能够清晰地解决问题了。。。
#
# > 从滴滴共享出租车，到共享单车，再到共享汽车和和共享充电宝……共享经济之风正扑面吹来，另据一些媒体报道，共享房子也呼之欲出。从房子到汽车，再到充电宝这样的小物件，但凡人们生活中能够使用到的物品，都相继被共享经济攻陷。毫无疑问，火爆的共享经济正处在一个无底限高速扩张的状态。
#
# ---
# #### 我们已被碎片化时间操控。
# 那些成功的APP产品，无不在乔布斯的顶层设计之下，对碎片化的时间占领，例如国内典型的今日头条，在其碎片化阅读风靡国内后，所有新闻客户端、浏览器、甚至搜索引擎，都统一掉头转向了碎片化阅读时间的占领。
#
# 我们从一座岛屿跳到另一座岛屿，我们情绪是随时被操控的，时而愤怒，时而感动，时而暴躁，时而松懈，如果一个人定力不够，则更容易深陷其中。
#
# 世界无限可能的，但是你却可以在有限的时间与空间下，用尽全力去创造出些许可能，这不就是生命力嘛。
#
# 无论阶层流动日益固化，人民币贬值、房价飞升、学区房摇号的今天，正在继续错过各种风口红利的我们这一代。
#
# 有钱没钱，都要保持住对这个世界探索的热情，在你出身设限的情况下，创造出更多的可能，这是你生命意义的所在。
#
# ---
# #### 共享1.0还如火如荼，2.0又要怎么玩？ web1.0 web2.0
# 时间，空间的分开复用，时分复用.
#
# ---
# #### 有空多学习吧. [枯燥,does not matter](http://36kr.com/p/5070851.html)
# 工作满三年，你的同学、同事可能都会有完全不同的境遇，有的人“青云直上”，已经做着 Leader 的工作；有的人，则泯然于众人矣……
#
# 那么十年后呢？十年后的你，会告诉现在的自己些什么？你可曾后悔浪费的时光，羡慕于同龄人的成就？是什么杀死了当年那个心怀抱负的你。
#
# 我们都说勤奋靠谱，是年轻人必备的品质。但还有一些更隐晦的东西，会成为个人的竞争壁垒，这个就是知识结构。完整、不断更新的知识结构，是一个事半功倍的竞争武器。
#
# 我们都被碎片化的信息所包围，如何将其体系化，形成个人的认知体系呢？知识体系始于纷繁，但其最终所发挥的作用——恰恰在于“少即是多”，并且具有更强大的力量。今天的这篇文章来自于经纬董事总经理熊飞与黄云刚内部分享的一部分，这两位“85 后年轻人”非常实用地给出了一些建议和方法，希望对你有所启发。
#
# ---
# # 20170416 Sunday
#
# > 太久的小米充电宝没有激活，经常只能冲入2格电量，以为是它坏了，后来充足了32小时，它满格了满4格电量了，可能是真的要长时间充电来激活它？ Don't know, let's see, we will see.
#
# # 20170417 Monday
#
# > 腾讯的复制可以成功，但是它的成功不一定可以复制。。。
#
# > 生成性学习，判别性学习，给出正例来学习，还是给出正例/反例来学习，有点像真假钱来判别问题，只看真钱 和 真假都看。。。
#
# > NPV 净现值，它是一个值; IRR 内部回报率，它是一个率，反应的是项目的收益率情况.
#
# > 对啊，你是一个巨人，可是站在泥潭中。。。
#
# > 说实话，两个屏幕要比一个好多了。。。主要各个窗口之间来回切换，覆盖展示，把人搞迷糊了，也搞得效率低了，容易反错误，司机就因为只有一个屏幕，切换，搞了不少乌龙。..
#
# ---
# #### 等比数列通项，求和，忘记拉...
#
# $a_n = a_1 \cdot q^{n-1}$
#
# $a_1 = a_1 $
#
# $a_2 = a_1 \cdot q $
#
# $a_3 = a_1 \cdot q^2 = a_2 \cdot q $
#
# $a_4 = a_1 \cdot q^3 = a_3 \cdot q = a_2 \cdot q^2 $
#
# $S_n = a_1 + a_2 + a_3 + a_4 ... + a_n $
#
# $S_n = a_1 \cdot \frac{1-q^n}{1-q} $ 注意到n表示是有多少数相加，小心off by one error
#
# ---
# #### 地税 国税
# 分税制。。。? search for it.
#
#
# ---
# #### 36kr... 会玩
# 先让一部分人福起来，先让一部分看到未来。。。然后，想法很美好的，只是现实是拍拍拍地打脸。。。
#
# 因为中央、地方政府都看GDP。
# 为什么政府只看GDP？因为其他指标不好量化（你说老百姓幸福指数怎么算？），GDP最好算，为官一任，目标是什么？升官呀！当然找最好算，也是最好做的来，数字搞上去，官也升上去了，民生呢？我人都走了，管他洪水涛天！
#
# ---
# #### 知乎，各个平台，付费知识的推广？它会违背互联网的最早的开放/共享/分享的初衷码？
# 量子世界：不只是物理
#
# 谈谈微积分的学习方法
#
# 线性代数入门：从方程到映射
#
# 从几何学看数学之美
#
# 如何学好本科数学
#
# ---
# #### Venture Capital = VC
# 风险投资，更像创业投资。。。
#
# NPV = Net Present Value， 净现值. 由于项目会在将来带来不规则的现金流，可能出金，也可能入金，将这些金额根据贴现利率折算到现在当前（由于资金的时间价值，知道他的利率就可以穿梭时空，时间机器）,由于有很多笔，然后加起来，求和，看看相当于当前赚了还是亏了，注意到这个是个数值，>0说明赚了，< 0 就算亏了，单只是折算之后的等价，实际是必须要经过这段时间才能得到的回报值，创造价值/利润是离不开时间的。
#
# IRR = Internal Reuturn Rate，内部回报率.注意到这个数字是个率，对比的也是贴现利率,它反应的是将NPV为0的时候得到的回报率，大概就是这个率要比普通利率高的时候，说明这个投资回报更高，比无风险利率等要来得高，是更好的投资。。。
#
# ---
# # 20170418 Tuesday, Oracle Training In GuangZhou, Day 1
#
# > Learn something. Youtube 上有 OracleRWP Training? Inspiration not only from work, but also from daily life.
#
# > Real-World Performance 2016 ... PPT & DEMO... Xdata? 发现问题，思考过程，解决问题的通用思路...
#
# > Oracle 工程，人社的。 海南, 天津, 中车株洲，安利,移动，白云机场
#
# > DBA...Database Administrator
#
# > 系统做得好，分析得好，可能会有很大的提升 X10, X100, X1000...What?  系统，方法论，问题出现在哪里，瓶颈在哪。
#
# > 用户组，邮件，User Group...
#
# > 时间花在了哪里，在CPU 还是IO 还是等待锁。。。数据库有报告？可以查询。
#
# > 培训材料培训..问题
#
# ---
# #### 优化明显，用户体验会好很多，甚至改变业务流程
# - 创建约束，键，等等 利用优化器自己来优化SQL查询。。。索引，分区，列式存储
# - row by row -> set base.
#
# #### Online Video Series
# - Extreme OLTP
# - Extreme DW
#
# Database Time, DB time...
#
# oracle process base architure...? 一个链接就会开启一个 process 进程，process太多了，cpu资源不够用...
#
# POC, 平均响应时间，一致性，方差怎么样，响应时间的分布.
#
# **要有数据，用数据来支撑。 AWR 等待事件, 首先看看 cpu 负载情况，用数据，数字来描述，驱动**
#
# [video source](www.oracle.com/goto/oll/rwp)
#
# TPS - transaction per second, 每秒的交易，指标，衡量系统吞吐？
#
# 等待时间，TPS， **统计信息，看看 时间/运算/资源 都去哪了**
#
# 胖客户端，瘦客户端， Java框架，PL/SQL， 资源分配，资源调度，如何分配好运算资源，全局，系统，
#
# 在接近数据的地方处理数据，可能可以减少时间，
#
# ---
# #### Transaction processing 书。。。？
#
# ---
# #### Firefox Java 插件，不能使用吗
#
# ---
# #### 从AWR看出问题在哪里，时间大部分花在了哪里，然后去看PL/SQL代码部分去解决它。
#
# 减少 loop 循环，注意在循环里面干什么。。。
#
# #### ORACLE: Wait Event
#
# 数据库的集合运算， union minus intersect 都比较耗时，需要排序比较结果 | union all 应该不需要的.
#
# 分析函数，analytic function, partition分区，
#
# ![Linux world of tools, build your own one](https://s0.cyberciti.org/uploads/faq/2017/04/new-nixcraft-illustration.png)
#
# # 20170424 Monday
#
# > PL/SQL Developer 使用Oracle本身提供的工具，会好用一下，有**SQL命令窗口，就像sqlplus || 解析计划窗口 **，能用Oracle特性
#
# > 蓉菇凉的微信又出问题拉，Why? 有空Search & Solve it.
#
# > Keep Calm & Carry On.
#
#
# ---
# #### 需要找到 开发环境 和 生产环境 的EM(Enterprise Manager), 得到SQL Monitering, 和 AWR 报告入口
#
# ---
# #### 解决问题，要用正确的方式去解决问题，跳出局部思维，跳出局部最优解，找到问题的根源，直接找全局最优方式去解决
# 不能固步自封，不要给自己设定上下限制，想法设法去优化，不能停止，各个方向都尝试下，就像优化算法一样，还没到理论的极限，就继续搞下去.
#
# ---
# #### Jupyter 左手作家，右手程序员 很不错，很好，但是不是最好的，还可以更好，更加Extreme.
# 但是网页上去编辑，不方便啊，要是有vim支持就好了，就是使用vim来编辑，更加不需要动鼠标了
#
# ---
# #### Let AutoHotKey 自启动，就是不需要自己开机后不需要主动去添加 键盘快捷键
#
# ---
# #### 貌似GitHub的查找功能不是太好用？ Git Clone到本地，然后使用本地的查找引擎啊，Xsearch 等等工具
# 这样就不用忍受GitHub的破查找功能了，多去走走，多去沟通交流，多冥想/联想，就能找到更好的问题解决方案拉，优化&最优化。
#
# **然后想了想，linux自带的工具箱貌似就已经具有这个功能，或者组装一下就得到效率很高，又很好用的的了。。。**
#
# ---
# #### Firefox Flash 插件自动化。。
# 什么时候才能扔掉Flash啊，哎，这些应该都给HTML自己搞定就好了，然后几大浏览器支持就ok...
#
# Python也许是非常好的解决方式，也许linux的shell+工具本身就够用了？？？
#
# ---
# #### 强力清洗机，可以把东西洗得好干净好干净。。。
# 一半干净，一般原样，弄死强迫症
#
# ---
# #### 全民阅读 图书 公共图书馆 就像支付入口只是一个必要的  基础设施
# 公共图书馆的建设，线性思维，参考，看看跑在前面的国家，现在也许需要更多非传统的思维，共享经济，如何改变人均读书少，看书少的情况？
#
# ---
# # 20170425 Tuesday
#
# > 时间都去哪了～ 还没好好～就老了
#
# > SQL执行 时间都去哪呢～ 空间都去哪呢～
#
# > 星环科技培训， SOA培训
#
# > 蓉菇凉要注意身体啊，按时吃饭，作息要规律，锻炼她，有策略，有方法地把她的身体素质练上来。。。
#
# ---
# #### 使用datastudio 来导入数据，很可能是row by row的，
# 应该使用数据库本身的功能来导入数据，不能row by row，太慢了。。。需要使用效率更加高的工具，更快，更好用才行嗯。
#
# CS basic，fundation 存储体系的 速度 + 价格
#
# 搬数据很重，那就搬运算。。。
#
# 测试 POC
#
# COST，成本，代价
#
# ```
# -       寄存器， 机器周期，应该在 ns 左右
# --      L1 L2 Cache 应该也在 ns
# ---     内存 us
# ----    磁盘 ms
# -----   网络 接近s 了？
# ```
#
# ---
# #### 星环科技 大数据平台厂商 具有研发能力？
# 平安也使用它？  招行，广发 华为hadoop平台？
#
# 金融应用案例:
# 1. 历史数据查询，
# 2. 精准营销，
# 3. 风险控制
# 4. 用户关系，担保拓扑，关系图
# 5. 贷后管理，
# 6. ...
#
#
# 可扩展性，当用户增多的时候，请求增多的时候，横向扩展性好;
#
# 在线准实时，实时， 30mins 就搞定了 etl/elt 的贴源操作数据存储，能够比较快得到解决，减少etl跑批时间？
#
# 银行，保险，证券。。。
#
# 用户画像， 客户流失分析， 它的客户案例， 报表
#
# 都是先 学习/模仿/创新 来的
#
# Stream, 流， 在线， 实时...
#
# 升级， 培训， 全栈工程师? The whole system.
#
#  ————————————————————————————————————————
#
#   应用  ||  Data Mining, Machine Learning, SQL，研发，算法
#
#  ————————————————————————————————————————
#
#   平台  ||  运维，底层开发？
#
#  ————————————————————————————————————————
#
# SQL 支持怎么样？ 流处理 Stream 实时 ？ 图 Graph
#
# R 去自助分析， 666， R底层是分布式了？ 还是 Java ？ 还是 Python/Scala ?
#
# ML 贷后管理，支持决策，商圈分析，热点分析， ATM 选点， 担保链分析，
#
# 批处理 OLAP; 在线实时 OLTP
#
# NLP 自然语言处理， spark 2.1 接口代码
#
# 处理 结构化，半结构化，非结构化
#
# ods 近期监控， dw 长期预测，决策
#
# CDC hadoop 可以替换掉传统的 etl 流程？
#
# 线上 VS 线下
#
# 贷款流程， 全电子流程，方便， 传统，流程长，慢， 电子化，快  客户来源渠道，营销
#
# 扩散，病毒营销 B - C ; C - C
#
# 社交网络， 客户与客户传播，传播模型，这个图里面的某个重要节点.
#
#
# ---
# ### SOA 面向服务的体系架构
# MVC
#
# 大数据  与  docker
#
# 元数据 管理平台，
#
# cognos 集成，网页端？ 前端吗？
#
# 数据库到文件，c/proc ?
#
# ---
# # 20170426 Wednesday
#
# > 只要思想不滑坡，方法总比困难多。 -- From HHJ
#
# > 终极就是 知识的存储 知识的使用， Google 的知识图谱？ 如何保存，如何召回，如何使用？
#
# > 老爸老妈教我还是对的，动手和动脑，不能懒，多苦也要扛着，撸起袖子就是干。。。
#
# > small tools, build big world, solve big problems. IDEAS, Learn From Them...
#
# > 维生素C 泡腾片 貌似对口腔溃疡，牙肉肿 有作用。。。
#
# > 宿舍那个加水就能贴上的磨砂窗贴好好用～ 神奇的淘宝。。。
#
# ---
# #### Recursively Search File Content Under Linux/Windows, Windows has software, Linux has tools.
# ```
# grep command: Recursively Search All Files For A String
#
# The syntax is:
# cd /path/to/dir
# grep -r "word" .
#
# --------------------------------------------------------
# find command: Recursively Search All Files For A String
#
# find command is recommend because of speed and ability to deal with filenames that contain spaces.
#
# cd /path/to/dir
# find . -type f -exec grep -l "word" {} +
# find . -type f -exec grep -l "seting" {} +
# find . -type f -exec grep -l "foo" {} +
# find /search/dir/ -type f -name "*.c" -print0 | xargs -I {} -0 grep "foo" "{}"
#
# ## Search /etc/ directory for 'nameserver' word in all *.conf files ##
# find /etc/ -type f -name "*.conf" -print0 | xargs -I {} -0 grep "nameserver" "{}"
# ```
#
# ---
# # 20170427 Thursday
#
# > 在互联网不断催化下，劳动力密集产业集中向技术密集和智力密集型转化，以无形资产形态存在的知识资本，在生活中的作用越来越凸显，于是催生出了一个新的知识消费模式。
#
# > 信息过载，召回信息->搜索引擎; 生产者/消费额->推荐引擎，在信息过载，信心爆炸的时代，个人的处理能力不足够了，需要使用计算更快，更加聪明的算法去处理信息，利用信息... 淘宝-item based collborate; 什么值得买-user based collborate filtering...CF
#
# > We are drowning in information but starved for knowledge...
#
# ---
# #### 人们思维的转变
# 人们思维转变的体现，随着中国经济发展，在人们物质需求基本得到满足后，开始转向提升精神消费。特别是小白中阶层，为了追求更快的自我提升，进行碎片化的学习显然很有必要。在这种情况下，付费内容无疑是最能满足他们的产品，越来越多的小白中愿意去为了优质内容付费。Web1.0 -> Web2.0 -> Web3.0
#
# 单向生产者/消费者;  双向生产者/消费者可以相互转换;  UGC,PGC，专业的知识生产。
#
# ---
# #### 理性/灵活的思维，了解你工具，用好你的工具，使用好的工具，生产力的提升啊~
# Notepad++ 正则表达式，替换，在选择范围替换， ^ -> '\t' 相当于python的一个block缩进。。。漂亮。
#
# ---
# # 20170428 Friday
#
# > Where are you going?
#
# > VR应用， 房子设计，虚拟，体验，在动工动手之前就尝试看结果,experience before build... 往时间前面偷看
#
# > Notepad++ 可以为它写pulugins...实现我自己想要的功能，缩进！
#
# > “工业革命把人类从手工劳动中解放出来，而信息革命将人类从脑力劳动中解放出来，但是机器学习则是让计算机解放了自己。如果没有机器学习，程序员将成为革命进程的瓶颈；有了它，进度就不成问题。”——Pedro Domingos, “终极算法”
#
# ---
# #### Designing Chips？ 基础学科，需要长时间积累，理论，技术，人?
# AMP, Algorithm, Machines, People
#
# 由于石油进口依赖度持续攀升，保障能源安全早已上升到国家战略层面。但其实，在芯片领域，中国的进口依赖度更高。
#
# 根据官方的统计数据，中国芯片进口的花费已经连续两年超过原油，过去十年，累计耗资高达1.8万亿美元。即便按照较低的汇率折算，也已经远超10万亿元人民币。
#
# ---
# #### Transaction... 事物的特性，ACID特性，在OLTP是非常有用的，必要的
#
# ---
# #### 碎片化时间，经常被中断的时间，相对少的连续长时间静心干一样事情
# 在这个信息爆炸的时代，人们已然被大量、快速并且简短的信息所包围。然而，我们相信：过多“快餐”式的阅读只会令人“虚胖”，缺乏实质的内涵。
#
# ---
# ####  突然发现firefox上面的网页截图工具好好用，截图的所有必须的功能都实现了，几乎是最优了。。。
#
# ---
# #### 时代，技术，理论 的变革，革命性事物出现 将会颠覆人们对世界的认知，思维方式。。。
# 大数据的时代已经来临。数据带来的狂潮就犹如又一次工业革命一样席卷着人类。在大数据的时代，人类对世界的理解方法从有限具体向抽象过渡，这也就是为什么算法比代码更加重要的原因。
#
# ---
# #### 依赖自动推导，也就是当一个字段，发生变化的时候，告诉你那些也应该发生变化？
#
# ---
# #### BrainFuck
#
# Brainfuck
#
# An Eight-Instruction Turing-Complete Programming Language
#
# ---
# #### SIT UAT
#
# 在企业级软件的测试过程中，经常会划分为三个阶段——单元测试，SIT和UAT，如果开发人员足够，通常还会在SIT之前引入代码审查机制（Code Review）来保证软件符合客户需求且流程正确。下面简单介绍一下SIT和UAT的基本情况。
#
# SIT(System Integration Testing)系统集成测试，也叫做集成测试，是软件测试的一个术语，在其中单独的软件模块被合并和作为一个组测试。它在单元测试以后和在系统测试之前。集成测试在已经被单元测试检验后进行作为它的输入模式，组织它们在更大的集合，和递送，作为它的输出，集成系统为系统测试做准备。集成测试的目的是校验功能、性能和可靠性要求，配置在主设计项目中。
#
# UAT(User Acceptance Testing)用户验收测试，通常是由最终软件的用户（通常这些用户不了解软件的具体逻辑，而对业务逻辑却相当熟悉）进行的测试，因此是面向最终用户的测试，结束之后通常就可以发布生产环境了。
#
# 区别与联系：
#
# SIT是集成测试
#
# UAT是验收测试
#
# 从时间上看，UAT要在SIT后面，UAT测试要在系统测试完成后才开始。
#
# 从测试人员看，SIT由公司的测试员来测试，而UAT一般是由用户来测试。它们两个之间的专注点是不一样的.UAT主要是从用户层面这些去考虑和着手测试,而SIT主要是系统的各个模块的集成测试.这在整个软件过程理论的基础知识中相当重要的.理论上讲SIT是由专业的测试人员去完成,UAT是由用户去做的.
#
# 如果按照规范来的话,做UAT测试的人一定是要对业务很精通的,并且是具有代表性的用户,关注的东西就是业务流程是否通畅是否符合业务的需要.以需求分析文档为重要参考,还有一些用户的操作习惯等等一系列的东西.
#
# ---
# #### 快手的口号是“记录与分享”; 土豆就类似口号——“每个人都是生活的导演”。
# 去快手看看，社会百态，草根们的生活？ 世界这么大，多少人也这样那样活着？
