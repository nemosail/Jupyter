# %% [markdown]
# ![就像灵魂出鞘,从第三方角度看自身,看世界,人类也没什么了不起的](https://pic.36krcnd.com/avatar/201703/01092024/ojkj5dkcabauh5ja.jpg!heading)
#
# # 20170227 Monday
#
# > Suddenly comes to my mind...
#
# > <爱乐之城>和<悲惨世界>的契合度
#
# ---
# #### Like others stories, our life is like a story, filling a story...
# - 故事的开始:
# - 偶然的遇见:
# - 碰巧的相识:
# - 情愫的觉醒:
# - 夜短的仲夏:
# - 凛冽的北风:
# - 隐约的担心:
# - ?
#
# ---
# #### 轻资产 和 重资产
# 顺丰和通达系快递，其实是我国两种企业发展模式的典型代表。
#
# 先说通达系，他们采用加盟制，轻资产运营，其实是早期资本市场非常青睐的商业模式，最大的优势就是快速扩张。通过扩张实现规模，以规模降低价格，以价格为武器进一步碾压对手，看似是很符合逻辑的。
#
# 这也是我国经济崛起阶段的主流企业发展模式，民营制造业、代工企业、甚至是互联网公司，比如团购、外卖、杀毒、直播，普遍采用的都是这种思路，补贴、价格战、先占领了市场再说，只怕慢一步就永远没有机会了。
#
# 这套模式在过去的30年，很成功，很成功。
#
# 但在最近的这几年，似乎一切都变了，价格战不再吃香，卖低端手机的一落千丈，拍五毛钱特效电影的人人喊打，代工企业被迫远走他乡，规模换来的，不再是胜利，反而很有可能是产能过剩，成为供给侧改革的对象。
#
# 市场的主流价值需求转移，从价格转向了体验，体验的背后其实是这些东西在支撑：更高效率的工具，更节省时间的服务，更新鲜的创意……为了这个“更”字，用户愿意支付更贵的价格，这大概就是所谓的消费升级趋势。
#
# ---
# # 20170228 Tuesday
#
# > Take back the future...
#
# > Keeping Learning...终于下决心带上自己的显示器了,使用了DVI-D接口,直接接上主机就能双屏幕了,不需要任何修改...
#
# > Submitting materials...提交人才引进申请... Please give me a chance...
#
# ---
# #### Handle 查询
# 搞懂要查什么,查询理解-分析-计划-SQL-执行-查询这些可以用来干什么...?
#
# ---
# # 20170301 Wednesday
#
# > 我们与其抱怨国人的素质低下，不如通过制度将作恶的动机关在笼子里。
#
# > Pi Zero/ Pi Zero W/ ... 树莓派有好多版本,嘿嘿嘿,还有各种模仿树莓派的其他茶品...Just Search For It Before Action
#
# > 一念天堂，一念地狱.
#
# > Sing me to sleep... Livin' life as if we had a choice
#
# > Miss Ren 有散光拉？以后要注意啦，原来散光是那么痛苦的？注意灯光好了，她好生气，好害怕，不过聪明如我，赶紧想办法修复啊，陪她走走，抱抱她，不是说不开心就多抱抱好了啦，司机～，听她埋怨埋怨各种小事。。。嘿嘿嘿，还得变得更加聪明才行。。。
#
# ---
# #### 授权问题, 角色Character/Rolse
# 根数据库的授权类似... 用户  与  角色, 给角色权限, 然后给角色用户,这就很方便管理了,有空看看这部分资料..
#
# 全选 - 反选 == 全部不选?
#
# RPT做的不是十分好? 经常权限树很深,有权限但是没有向上层反馈,导致要进入很深才能去除...刚才才吐槽那家公司...权限是一级一级深入的,当点击最后的叶子节点,实体的时候,却没有自动给出到达这个叶子路径上的节点,然后我任了,最多我一个一个去点击,然后!!!码单,它点内部节点,自动把所有叶子节点都选中了,什么逻辑啊,什么破程序,是不是有病!!!然后就人肉运维,把不需要的一个一个删除,我的天啊,你们是干什么去了...
#
# ---
# #### 物联网 体重计 微信小程序
# 记录统计,监控 体重, 关注健康... 大方向,不管实现细节,考虑整体的可行性.
#
# ---
# #### 开通南海报表之后,发现这个问题进入报表时候:  IBM Cognos 8
# Cognos Viewer Security Rejection. Your request was rejected because it failed Cognos Viewer inupt validation.
#
# 然后Google这个问题,一般的答案是:  IE : Internet 选项 - 安全 - 自定义级别 - XSS筛选器 - 禁用 !
#
# Then problems shall be solved... 以后碰都这种通用问题得记录下来了,因为我不想我的时间浪费在这种小问题上,应该去解决更宏大的,更宏观的问题去,要有野心...
#
# #### Fix little broken door lock... 尝试修复年久失修的老门锁。。。石墨-固体润滑剂？
# 宿舍的门锁实在是比较老了，但是还是可用的，old but not obsolete... 它虽然老化了，但是只是需要保养与维护，还是很好用的。。。只需要加入一些铅笔碎，也就是石墨粉末，需要的是2B铅笔和刀子，刮下一些粉末，放倒钥匙里面，然后插进去旋转就好拉。。。对付这些机械的，老家伙就用老套路就行，百度一下，找找答案就行了。。。
#
# 石墨是碳的一种结晶形态,具有六方晶格,原子呈层状排列,同一层晶面上碳原子间的距离为0.142nm,相互之间是共价键结合;层与层之间的距离为0.34nm,原子间呈分子键结合.层与层之间的作用力很小故很容易在层间发生相对滑动.因为这些结构上的特点,导致它的强度\硬度很低,塑性也很差,但可以起到很好的减磨作用,是一种很好的固体润滑剂.
#
# 石墨在机械工业中常作润滑剂.润滑油往往不能在高速、高温、高压的条件下使用,而石墨耐磨材料可以在一200 ℃ 一2000 ℃ 温度并在很高的滑动速度下（loom / S ）不用润滑油工作.许多输送腐蚀介质的设备,广泛采用石墨材料制成活塞环、密封圈和轴承,它们运转时,勿需加入润滑油,石墨乳也是许多金属加工（拔丝、拉管）时的良好的润滑剂.
#
# 不需要记住具体的做法，细节的做法，关键是通用的找出问题节的思路，就是遇到这种问题，应该如何找解决方案，找出问题所在和解决它。。。算法 与 思想/思维， 灵活的思维，别固化～
#
# ---
# #### 无风险利率，很久前看过拉
# 无风险收益率的大小由纯粹利率（资金的时间价值）和通货膨胀补偿率两部分组成。
# 无风险收益率=资金时间价值（纯利率）+通货膨胀补偿率
# 无风险收益率的确定
# 无风险收益率的确定在基金业绩评价中具有非常重要的作用，各种传统的业绩评价方法都使用了无风险收益率指标。在我国股市目前的条件下，关于无风险收益率的选择实际上并没有什么统一的标准。在国际上，一般采用短期国债收益率来作为市场无风险收益率。
#
# ---
# # 20170302 Thursday
#
# > What you see is what you get...(word); What you think is what you get...(latex);
#
# > 所想即所得...(许多人的座右铭)... Instead of 所见即所得.
#
# > 眼睛看到的只是事物的表象,不要被表象所迷惑了,应该要找到事物的内在和根源,它的本质...
#
# ---
# #### 计算机视觉融入智能交通? [36kr](http://36kr.com/p/5065351.html)
# 智能汽车,自动入库,自动出库? 摄像头在交通系统中的作用是完成监控。但车辆的增加提高了人工视频监控的成本。举个例子，电脑显示屏最多有九路监视格，一个人盯三路，假设一个城市有三万路视频，则需要一万人盯着，容易造成疲劳和监控误差。传统的人工管控方式无法满足监控需求，而基于算法和深度学习的计算机视觉技术能做到这一点。使用AI/ML方式有效完成人脑集中型的重复劳动,从繁重重复的脑力劳动中释放人类...
#
# 就像Miss Ren提到的超级大脑一样,人脑很厉害,但是人脑很唯一,不可能复制这么多的人去帮忙干枯燥繁重压力大的事情,人类忙不来,也干不来,需要找出人脑的工作方式的原理,或者近似替代品,来完成这部分需要高度智慧的任务,但是又特别繁重,特别类的工作,这部分是机器应该替代的.
#
# ---
# # 20170303 Friday
#
# > 现在还是有太多不懂,然后被迫赶鸭子上架,只能对BangGe的SQL依葫芦画瓢... 肯定是要自己搞懂,然后用自己的理解去解决问题的啊..搽
#
# > 而一个底层青年如果认定自己不属于底层，他就会想办法脱离底层，只要能找到正确方法，他一定能脱离底层，实现阶级跨越。[baidu](http://hstl.baijia.baidu.com/article/787336)
#
# ---
# #### 汽车的自动驾驶
# L0 L1 L2 L3 L4 L5 分不同级别...几乎就是一步一步使用机器代替人类的驾驶技能,也就是全自动的方向了...在任何工况下都能等价或者超越人类...
#
# ---
# #### 许多不懂的东西真的只能多问,多理解
# 报表的权限,流程,可以先开给自己看看,自己尝试下,没有问题了,理解了,执行过流程了,就相对清晰多了.
#
# 解决问题要灵活,多想想,多尝试...
#
# 重武器  与  轻武器
#
# ---
# #### Mouse that can cross diff computers
# 如何写出程序,使用同一个鼠标,穿过不同的计算机,平台,就是原来不同的实体计算机需要单独的鼠标的控制,现在可以使用程序,使用同一个鼠标,如何无痕地进入不同的平台? Ideas that can change the world.
#
# ---
# # 20170304 Saturday
#
# > Thanks god, thanks to all. I am so graceful. Second changce... I won't make that kind of mistakes again...
#
# > Be smarter everyday...
#
# > Her period is much more than 28-30, why is that...? How to capture the pattern, and predict it well..
#
# > During these few days, mood can vary a lot, unstable, variance can be big...
#
# > Went to 从化,驴友找到的溪头村?,流溪河, 流溪湖 国家森林公园, 望谷温泉,但是他们说这个地方硫磺味没有那么重,不是特别好? 换个更加专业的地热泡温泉的地方?这个是主打私浴的?
#
# ---
# #### Note from A4 AT DORM
# - 积息计息法， 在周期内的每个时间间隔，得到的利息参与复利，当时间跑向无穷小，得到的是 e 自然增长;
# - 逐笔技术法， 在周期内利息不参与复利
#
# 科氏摆 还是没有搞懂它是如何工作的。。。
# ```
# //////////////////
# ——————————————————
#        /\
#       /  \
#      /    \
#     /      \
#    /        \
#   /          \
#  o    - - >   o
# ```
#
# Github应该有保存数据文件RawData的方式的。。。？Google IT.
#
# 中年危机。。。改为自己的现在，未来想想，人无远虑，必有近忧，  不能**买了负担不起的东西，上了输不起的赌桌**
#
# 卖手机的罗胖; 卖书的罗胖。。。傻傻分不清。。。
#
# 纸牌屋， 绝命毒师
#
# AI/ML 应用，野生动物识别系统，不再使用人工去监控了。。。
#
# What is 租赁？
#
# 最困难的两件事情：
# - 把思想装进别人的脑袋里;
# - 把别人的钞票装进自己口袋里;
#
# 下调事业保险费率，减少企业负担，营改增，减少企业负担，都是同样道理，希望企业有更多资金流动，熬过这段时间。。。
#
#
# HBO 《硅谷》 USE A.I. to optimise our world. Be better, be smater.
#
# 轻资本，重资本...
#
# INTEL无人见开发平台，IDE，UAV，高平台，然后给所有人来给这个UAV来编程，发挥群体的智慧，来给有限的平台提供无限的可能，完成各种各样的东西。
#
# 人有小目标，国有大计划， 撸起袖子加油干呗。
#
# 务实，务虚。。。 PC muscale?
#
# 药品报销怎么搞？ 额度一直都有吗？ Find it out.
#
# ( People, time ) create/generate -> money, value
#
# audible.com / The Art Of Learning
#
# 政府工作报告， 让百姓要有获得感， 稳增长，保就业.
#
# 实体 与 虚拟 不是对立不可调和的，而是可以成比例统一的
#
# 穷则独善其身，福则救济天下
#
# 财富，更要让别人尊重你，带动你的人们富起来，干起来。。。
#
# 静心解决问题拉，精心
#
# OS老师：人们都希望赚钱，赚大钱，快速赚大钱。。。
#
# 以前是实业救国，现在要实业强国
#
# 心态要好，坚韧不拔，不怕魑魅魍魉，不怕别人的指指点点，脸皮要厚的拉，怕什么，正面刚啊。
#
# 身心，身体 与 灵魂， 都是需要锻炼的。。。
#
# 固体润滑剂，石墨是碳的一种结晶状态，碳原子之间的距离为0.142nm,层与层之间为0.34nm，能相互滑动，是良好的固体润滑剂。
#
# 重力转向，以为飞船要入轨，需要是水平方向的分量，需要力来改变速度方向，使用燃料太浪费了，使用重力就很好，这个重力虽然没有做工，但是改变了我们刚开始速度的方向。。。
#
# A.I. assistent 语音，辅助 人类，教人类如何做菜。。。？ 释放了我们双手了。
