# %% [markdown]
# > 放长线，钓大鱼，Can you?
#
# # 20161031 Monday
#
# > 表情包战争的汪洋大海; Python多线程; Git Server On Windows; 休眠睡眠; Happy Halloween! GitHub自动变黄了
#
# ---
# #### Python 多线程，
#
# GIL: 理解Python里面的多线程，为什么是鸡肋，为什么有时候可以提高效率，为什么有时候又不行？一个Python进程由于又Global Interpretor Lock的存在，线程只能在获取这个排他锁的时候才能运行，导致在现代的多核心多线程的机器上，一个Python进程的线程是分时进行的，而不是并发进行，所以对于计算密集型的程序，多线程并没有多少的提升，本质还是只用到了一个处理器，没有最大化利用硬件;但是对于IO密集型的进程，大部分线程在等待IO的时候，这时候不会阻塞进程，因为可以运行的线程会一直运行，因此提高了效率，更多更准确要Google, StackOverflow去把。。。
#
# - 单线程： 读数据 - 处理数据 - 读数据 循环; 730seconds;
#
# - 双线程： 读数据 - 处理数据/同时开始读数据; 632seconds;
#
# 启动两个线程之后，时间应该接近取数时间了，Python用于开发原型，测试，的确很合适，原型满意了就可以使用效率更高的编译型语言了。
#
# #### 使用线程后，如何保证程序正确，线程安全与线程不安全。
#
# ---
# #### Robot Operation System
# 机器人操作系统（The Robot Operating System，简称 ROS）
#
# 一个和 ROS 类似的硬件系统——H-ROS 出现了，这是一个构建机器人硬件组件的新标准，它为制造商提供相应工具，用于构建可互操作的机器人组件，这样机器人间就可以方便地互换或替换组件。
#
# 通用组件 与 特殊用途组件， 通用与特殊， 具像与抽象
#
# ---
# #### Windws 休眠与睡眠 [好文解释](http://bbs.ithome.com/thread-218941-1-1.html)
#
# 睡眠还保持着开机状态的，休眠是关机了，但是再次开机之后和关闭时的系统状态是一样的
#
# 睡眠还是保持着系统运行数据在内存中，而休眠则将内存中的数据保存在硬盘中（应该是虚拟内存）
#
# Windows 貌似真的有设置的： 控制面板 - 硬件和声音 - 电源选项 - 更改计划设置 - 更改高级电源设置 - 睡眠 - 休眠设置时间
#
# ---
# #### Git Server On [Windows](https://github.com/msysgit/msysgit/wiki/Setting-up-a-Git-server-on-Windows-using-Git-for-Windows-and-CopSSH)
# 这个教程不太好用，只是告诉了你框架，主要方向，还需要其他细节才能成功的，比如权限管理，用户目录设置，git仓库目录设置，git程序存放目录，程序的共享库等等，但是算是解决了，在本机上搭建了git server，需要验证，需要迭代。
#
# ---
# 遇到问题与解决问题：
# - 制作高质量视频成本高，产出低，怎么办？让广大网民制作，运用起广大社会上闲置的资源;
# - 人多出租车不够用怎么办？让广大闲置车辆运行起来;
#
# - RTX是可以导出聊天记录，妈妈再也不用担心我忘记怎么做东西了。。。
#
# 如何配置资源，如何运用可用资源，优化问题，决策问题，都是要思考/冥想/去解决问题的。
#
# **社会发展，自动化，程序化，其实就是free释放每天重复劳动的部分，让更多人有时间去创造价值更难更高的事物。**
#
# **为什么要框架，为什要这样子做，因为不按照一定的规则完成，世界将会是杂乱无章的蜘蛛网<数据仓库>，因此需要输入人力，力量，规则来限制熵的自发增大，否在就会混乱不堪**
#
#
#
# # 20161101 Tuesday
#
# > 黑客与画家; Unix编程艺术
#
# ---
# #### Updating flash for firefox on debian
# damn flash, we have to get rid of it...
# 1. check flash and other plugin status on [firefoxpluginsite](https://www.mozilla.org/en-US/plugincheck/)
# 2. download newest version from flash [website](https://get.adobe.com/cn/flashplayer/)
# 3. get the rpm version
# 4. install the rpm version [Debian Installing RPM](http://blog.csdn.net/thomastang2012/article/details/6329566)
# 5. check again [firefoxpluginsite](https://www.mozilla.org/en-US/plugincheck/) and shall work fine
# 6. 当出错时候，说明没支持好，用tar.gz格式下载，然后看readme就可以了，注我用的plugin目录/usr/lib/mozilla/plugins[s](http://blog.csdn.net/wangyuchun_799/article/details/46995675)
# 7. check again about:plugins
#
# #### Python 是有多种方式连接数据库获取数据的
# - cx_Oracle，但是貌似使用oci，所以是要安装oracle客户端？！
# - pandas
#
# Python [multiprocess vs multithreads](http://www.oracle.com/technetwork/articles/embedded/vasiliev-python-concurrency-087536.html)
#
# 表空间：
# 是一个或多个数据文件的集合，所有的数据对象都存放在指定的表空间中，但主要存放的是表， 所以称作表空间。
#
# 分区表：
# 当表中的数据量不断增大，查询数据的速度就会变慢，应用程序的性能就会下降，这时就应该考虑对表进行分区。表进行分区后，逻辑上表仍然是一张完整的表，只是将表中的数据在物理上存放到多个表空间(物理文件上)，这样查询数据时，不至于每次都扫描整张表。
#
# #### Installing [Launchy](http://www.iplaysoft.com/launchy.html)
# [官方网站](http://www.launchy.net)
# - windows, just exe will be fine
# - linux? Debian! Install launchy : sudo apt-get install launchy
# windows 和 linux 安转软件的机制不一样，为什么。。。
#
# 电影： 社交网络;断线;解除好友;好友请求;玩命直播;黑镜：天佑吾主;黑镜：急转直下;
#
# #### U盘为啥有时候出问题
# U盘使用了exfat格式，在Debian写入速度惊人，但是常常发现eject之后文件损坏或者文件系统都出错了，后来发现是写入缓存的问题，写入的数据放到缓存区就返回了，但是数据实际还没写入到u盘，导致还在写书据的时候就弹出了，在Debian貌似不是很好判断是否全部写入。。。find its explaintation...
#
# #### 关于gzip压缩
# AIX是带有了gzip压缩工具了，windows自带应该没有，需要下载一下gzip.exe(JustGoogle)使用。。。
#
# linux 下的用法： gzip -k 用来不删除源文件（压缩或者非压缩）
#
# Unix/Aix/Windows下应该: gzip -c a.txt > a.txt.gz
#
# #### 程序对资源占用，宏观了解程序，用于优化
# 1. cpu 占用率
# 2. 内存 占用率
# 3. 网络 占用率
#
# 发现我的python程序使用cx_Oracle通过网络连接数据库时候，网络使用率才30%左右，为什么不能继续上升，他们的能到70%, 100% ?
#
# Python 给出了len(str)应该是只字符串字符数，然后 sys.getsizeof(str) 给出的字节数。。。应该
#
# 是不是windows \n \r的区别而导致的问题。。。文本文件打开 和 二进制打开文件， 不同系统行为可能不一样的，偷偷加上\r和偷偷删除\r
#
# [解释](http://blog.csdn.net/crazyingbird/article/details/7174499)
# [wiki解析](https://en.wikipedia.org/wiki/Newline#History)
#
# You could try to grep for CRLF code, octal:
#
#     grep -U $'\015' myfile.txt
#
# or hex:
#
#     grep -U $'\x0D' myfile.txt
#
# 数据库里面的 Varchar(k) k表示的是字符长度把,stack over flow 有相关资料。
#
# # 20161102 Wednesday
#
# > 业精于勤，荒于嬉；行成于思，毁于随
#
# ---
#
# Linux 里面有个/tmp的文件夹，应该是给程序使用的，透彻了解他，就可以嘿嘿嘿了。
#
# ---
# 新到了ikbc的c87的机械键盘，在防伪网站查询过，然后也在[键盘测试网站](http://www.keyboardtester.com/)上几乎把能测试的键盘都测试过了，都没有所谓的臭轴，也就是每个轴/按键都是可以使用的，还在测试学习中。。。
#
# ---
# 通知短信的程序没有太多问题，主要是看看 那几个配置文件，还有源代码里面的目录，然后主要发现是一个sql语句的问题。生成短信文件后，文件消失非常快，并不是没有生成文件，而是生成后被拿走了。。。就看不见了。
# 在生产环境操作要非常小心，just be careful.
#
# 可能需要修改job_date这个参数，如何正确修改这个参数而又不错过/多发短信，每天都清空记录吗？
#
# 如果只是记录当前的状态，也就是 比较 上一次 和 这一次 的状态， 历史 vs 现在 vs 未来， 好像可以了，不会越来越多数据。
#
# 短信内容区分模块，done
#
# 当程序长时间运行的时候，程序变脸/占用内存就成了必须考虑的东西，不能内存泄漏，不能让程序浪费一点内存，不然随着时间流失，收敛状态是占用光系统资源，这样随意在限制资源的系统中不会带来系统性破坏，但是程序就不能正常运行了。。。deamon写的不容易诶。
#
# 对于 每次都全部错误检查的，只记录上一次的状态就够了，为什么，看看每一轮的检测，分类讨论，上一轮的检查就包含充分的信息了，而不用记录上上轮之前的历史记录，马尔可夫性质，知道现在，将来与过去无关。
#
# 对于一天只会检查一次的timeout，没有问题的。
#
# 对于一天检查一次成功的，需要技巧，两个变量，一个记录今天是否检测，另外一个变量检测是否发送短信，然后记录这一次的查询状态。
#
# ---
# 为什么我的git 服务器经常使用 `git push -u orgin master` 的时候，就会提示输入密码，然后又说could read from remote repository.
# 貌似解决了，可能是copssh智能同时有一个连接的原因，导致无法继续连接，重新启动copssh服务就好了，不再需要密码了。
#
#
# # 20161103 Thursday
#
# > 3,2,1 Wake up from nightmares, fight back, kill them!
#
# > 把心和格局放大点。
#
# > 我们都活在阴沟里，但仍有人仰望星空。
#
# > 需要控制我的commit次数，不要成为vcs的奴隶，mind should be free.
#
# > Writing a long term running deamon program is much toughter than I think.
#
# > LWT: 开发部分是不是都应该要有自己的代码Review？
#
# ---
# ####  1password
# 同学推荐使用的密码管理工具，应该还是挺好使用的，应该支持移动端/PC端，还在了解/熟悉中
#
# #### Shell脚本
# 需要想清楚 失败 / 僵死 / 超时 / 成功 的区别与联系，搞懂了需求试下那就和容易了
#
# #### 淘宝的拆红包-传播模型-病毒式-扩散式
#
# #### 终于搞懂了AIX下的 date 命令的用法：
# Things work differently than you think. Read more materials.
#
# TZ是一个系统的环境变量，记录了系统所在的时区，aaa可以为任意字符串
#
# 在AIX系统中TZ是个系统变量，然后date +"%Y%m%d %H:%M:%H" 这样的时候实际打印的是标准伦敦时间，也就是0时区的时间，而我们使用的是东八区的时间，所以date会根据TZ这个系统变量来修正输出，当在TZ=aaa8时候，表示是在0时区后往后8个时区的时间，就是-的意思，而TZ=aaa-8表示是比西一区早8个小时的地区的时间，也就是+，看来编程也需要地理知识。。。
#
# Try at AIX:
# ```
# TZ=aaa0 date +"%Y%m%d %H:%M:%S"
# TZ=aaa1 date +"%Y%m%d %H:%M:%S"
# TZ=aaa-1 date "%Y%m%d %H:%M:%S"
# echo "TZ"
# ```
#
# #### Python 网络编程，让我的工作自动化
# 可以看到，在待办部分，经常都是重复性的工作，只要权限确认好，步骤都是统一管理的，也就是可以使用程序来工作了，因为现在明显觉得不应该用人类去干这些事情啊，人类应该是自由的，去解决问题，而不是重复劳动。人类应该从繁琐无聊的重复劳动中解放出来，去实现更有趣，更有价值的事物诶！
#
# #### 只保留最近7天的log信息
# 因为知道了TZ的含义就可以使用grep的功能来删除和保留日志，目的就是保留最近7天的log信息，这样log文件在long term run之后文件大小都不会怎么变化的。
#
# #### 存在变量覆盖警告这东西的麽？
#
# #### Longmarch 5? 长征5号。
# 虽然错过直播了，好漂亮，真的好漂亮啊～～
#
# #### Jupyter Notebook 在list目录的时候如何反序排列，有选项吗？不行就去修改源代码。
#
#
# # 20161104 Friday
#
# > Why my dreams becom so vive? so real? What went wrong...
#
# ---
# 有一次debug，但是每一次开发完，debug能自动化吗？如何做到自动化测试，就是我开发完，然后用上次的测试用例，自动化回归测试就好了，怎么实现，业界也是这样做的吗？减轻人类重复劳动诶？
#
# 在 写日志的时候，可以对内容进行替换将\n换成“ ”，这样就不用担心因为换行带来的问题了。
#
# ---
# #### 短信不好看，如何调整短信格式，使他好看啊。。坑，我不懂用户界面的诶。
# 注意时间，错误作业的应该只有开始，僵死作业也是只有开始的，成功作业呢？
#
# ---
# VoCore2：一颗硬币大小的Linux计算机,
#
#
#
# # 20161105 Saturday
#
# > 打羽毛球，对方哪里难受打哪里，需要的是观察和走位，步伐。
#
# 冬天牛奶很冷怎么办？ 想办法加热，但又不破坏营养. 像加热酒一样，外围是温水，里面是牛奶，玻璃杯子，然后罐子。。。
#
# Jupyter日记在使用git的merge之后，又出现问题了，提示不是JSON的格式文件，导致无法解释，无法打开日记，问题在于merge的时候不小心弄错格式，少了个[/]/{/}/，等符号导致无法打开，因此使用文本文件格式打开让，然后参照之前正常日记的JSON的格式修正就好了，刚看到这麽多的文字+代码还是很害怕的，但是实际这就是源码，从小堆起来就是了，一步一步就容易找到错误。
