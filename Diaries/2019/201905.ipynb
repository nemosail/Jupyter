# %% [markdown]
# # 20190506 Monday
#
# > 完成日志版本的采集 加工 和推送... 运行部执行了 机器s 的收集，加工整理入库，分库分表了、采集，加工，推送。
#
# > celery,  团队的分工协作
#
# > 阿里云 DataWorks
#
# > 采集  和 推送 的时候 需要考虑到 分库分表的情形，这个之前可能没有提那么明显
#
# > 更长期的 project, 需要有 master plan， 更要有 detail plan...
#
# > 向导模式 和 脚本模式, 向导模式简单可行， 而脚本模式使用更复杂、高级的功能.
#
# > DATAX 只是一个 实现工具， 抽象类，可以有多种工具
#
# ```
# 在实际的软件开发过程中，经常会碰到如下场景：某个模块负责产生数据，这些数据由另一个模块来负责处理（此处的模块是广义的，可以是类、函数、线程、进程等）。产生数据的模块，就形象地称为生产者；而处理数据的模块，就称为消费者。
#
# 单单抽象出生产者和消费者，还够不上是生产者消费者模式。该模式还需要有一个缓冲区处于生产者和消费者之间，作为一个中介。生产者把数据放入缓冲区，而消费者从缓冲区取出数据，如下图所示：
#
# 生产者消费者模式是通过一个容器来解决生产者和消费者的强耦合问题。生产者和消费者彼此之间不直接通讯，而通过消息队列（缓冲区）来进行通讯，所以生产者生产完数据之后不用等待消费者处理，直接扔给消息队列，消费者不找生产者要数据，而是直接从消息队列里取，消息队列就相当于一个缓冲区，平衡了生产者和消费者的处理能力。这个消息队列就是用来给生产者和消费者解耦的。------------->这里又有一个问题，什么叫做解耦？
#
# 解耦：假设生产者和消费者分别是两个类。如果让生产者直接调用消费者的某个方法，那么生产者对于消费者就会产生依赖（也就是耦合）。将来如果消费者的代码发生变化，可能会影响到生产者。而如果两者都依赖于某个缓冲区，两者之间不直接依赖，耦合也就相应降低了。生产者直接调用消费者的某个方法，还有另一个弊端。由于函数调用是同步的（或者叫阻塞的），在消费者的方法没有返回之前，生产者只好一直等在那边。万一消费者处理数据很慢，生产者就会白白糟蹋大好时光。缓冲区还有另一个好处。如果制造数据的速度时快时慢，缓冲区的好处就体现出来了。当数据制造快的时候，消费者来不及处理，未处理的数据可以暂时存在缓冲区中。等生产者的制造速度慢下来，消费者再慢慢处理掉。
# ```
#
# > WSL: Windows Subsystem for Linux? what is this?
#
# > https://blessing.studio/wsl-guide/
#
# > 为啥与人打交道， 是指数增长的？ What about programmers，与机器打交道，是线性的还是 指数的？
#
# > 投资股票的人大多会有一个习惯，那就是在生活中看到喜欢的产品，会去找一下这个产品背后的公司是否为上市公司，是否有投资机会。对于好产品来说，我们不仅要做他的顾客，还要做他的股东。  Rihgt， 看到 火爆的 复4，可以联想它背后的CN公司，会不会有不错的行情， 看到某个很好的产品，可以联想，-消费+投资， 消费好的产品，同时投资他们的股票？ 一种习惯，但是是否一定盈利，就得看水平。。。 知识变现。。。
#
# > 股权结构， How can they do that...https://xqimg.imedao.com/16a68a2979e8e7e3fd8fb002.png!custom660.jpg
#
# > SQL 美化工具...?
#
# ---
# > 后期的职业，技能？ find one... 增长，线性增长，指数增长的 能力。。。
#
# > 他们的数据表， 有个字符串 的判断，还是使用 int整形判断好， 字符串判断太容易出现问题了， int 就是int，不像字符串还有其他看不见的字符等等，带来很大问题， 状态，标志，等等，都是 int表示好，最多加不变的维表
#
# ---
# # 20190516 Thursday
#
# > 平时需要注意积累。。。  集思录， 东方财富， 同花顺，他们的数据都做得挺好，怎样实现？ How 设计 & 具体实现
#
# > 调度对 任务执行的 智能告警， 1.到点了，还没执行成功，警告； 2.还没到点，但是根据历史数据，可以提前预警，任务可能无法完成了。。。
#
# ---
# # 20190516 POC?
# ```
# Yellowbrick Data开发了一种基于闪存硬件和软件的系统架构，用于处理本机闪存查询。该设备包括一个专为闪存和集成CPU、存储和网络而设计的分析数据库，数据可以直接从闪存移动到CPU。
#
# Yellowbrick Data表示，它的系统运行速度比传统数据仓库系统快140倍，可用于零售和广告分析、安全分析和欺诈检测、金融交易分析、电子健康记录处理和其他应用等任务。
# ```
#
# ---
# # 20190516 Stkprice
#
# ```
# select dcdate, stkcode, pre_close, open, high, low, CLOSE
# from a_share_daily_indicator
# where stkcode = '000002'
# order by dcdate asc
# ```
#
# > 《创新者的窘境》
#
# > 需要支持 交易日历， 支持自然日， 支持交易日...
#
# ---
# # 20190523 Thursday
#
# > 体检 @香港大学深圳分院...
#
# > 20190523 从左往右都是质数的一天。。。哈哈哈，也是恰好 365 的一天。。。。right?
#
# > 在数据库中， 存储过程 和 函数 的区别， 存储过程 是能够 增删改查的， 但是函数只能 查的，不会增加、删除，更新
#
# ```
# 本来想写写如何成为一名优秀的大数据平台开发工程师，但说实话，这个话题太简单了！虽然我没有被Jeff dean大神附体，也不好意思腆着脸自认为有资格指点江山。但是，讲道理，谁不会呢？
#
# 好比，炒股票，不就是低买高抛吗，玩互联网，不就是拉流量去变现吗？
#
# 而要想成为一名优秀的大数据平台开发工程师，只要做到深度与广度并重，钻研技术，理解产品，能搭架构，能解Bug，那就妥妥的了。
#
# 道理如此简单，还需要多解释么？而我们，大概不是轻松的碾压了巴菲特，就是早已经顺利的在风口起飞了！
# ```
#
# > 20190525 Why 肚子通 again？ what problem is that? need to clearly solve it...
#
# ---
# # 20190528 Tuesday
#
# > 3Blue1Brown 是如何做这么漂亮的动态图的？ 学习他们，使用他们，became one of my skill that turn cash 变现？
#
# > Keep recording history, like DataWareHouse， OLAP 发现，记录 医疗轨迹，健康轨迹，统计、分析，肯定有很大的汇报的.
#
# > 大家都只想要九尺之台，而不想始于垒土?
#
# > 水果自由， 水果指数，猪肉价格指数，各种生活基本用品的指数 index 去记录，去反映问题。。。一阶的，二阶的？ MANIM
#
# ---
# > 记录在 SZ 这段日子， 租的各种经历，bad experience，遇到个各种问题，开阔的眼界？是否能够简单的c2c， 或者找到真正的隐藏变量。。。然后应用？ right？ 如何搞到produce material，驾驭 produce material， right?
#
#
# > IP address - databsename - schema - table
#
# > PCIE 4.0 SSD ->　速度接近内存了？？？　ＷＴＦ? That can change things...
#
#
# > 中登会有新增投资者指标？ 新入市的，新开账户数指标。。。?
#
# > Records:  20190420 rjr, belly,  hurts, 腹部疼痛，发冷，脸色白 and go to NanHai Hospital， 20190501 out?
#
# > Records:  20190524 rjr， belly hurts, 依旧腹部痛， what? First People Hospitial.... may need to go to guangzhou
#
# > 腹部痛 得非常注意，生活中的生活疼痛，必须学会分级，定性，那种痛是必须要立刻就医，找原因的， 腹部痛；胸口痛等等。。。Learn and remember...
