# %% [markdown]
# # 20190304 Keep Learning.
#
# > Keep Reading Books: 德鲁克 管理的实践
#
# > 还有套路贷款。。。？
#
# > 第一性原理，亚里士多德：“在任何一个系统中，存在第一性原理，是一个最基本的命题或假设，不能被省略，也不能被违反。”简单地说就是追寻事物的本质，来寻找解决问题的办法。
#
# > 你所用的锚，方法、规则，很可能是过时的，错误的，然后可能给你带来了收益，长远来看可能是大坑啊，时刻不能忘记风险，控制风险，时刻在学习，与时俱进，自我否定，多种思想，从线性思维到面的思维，到立体思维。。。
#
# > 别忘记了第一性原理，你来这了是干什么的，这个市场本质是什么，你把它看做投机，还是看做投资？ 那种更接近本质，更长远？ 博傻就是赌博啊，赌博你有考虑风险吗，损失吗？
#
# > 如果国债逆回购的周期相对存在， 季末 3/6/9 年末 12 春节，是否可以 直接根据日期信息实现小程序提醒？ 这是一个服务， 也可以获取市场公开信息，然后相对实时地通知？ 也是服务的形态， Service, REST API 对各个连接端提供服务。
#
# > 我们将必须相当聪明，以逃离我们过去的聪明。  成功取决于利润，利润来源于发展，而发展则依赖于新的思维和新的技术。
#
# ---
# # 20190305 Tuesday
#
# ```
# 为了达到价值层的跃升，每天做好本分的工作是不够的，你必须去探索和尝试新的可能性。
#
# 创业者都选择了一种“可能性”，而且是一种能给他们带来长期安全感和归属感的可能性。这种可能性，会让他们在财富和自由上获得比别人更高概率的成功回报。
#
# 如果你是做技术的，在业余时间钻研产品设计，那他就具备成为一个懂技术的产品经理的可能性。
#
# 如果你是做运营的，在业务时间研究写作，建立新媒体运营能力，那他就拥有了成为一个自媒体品牌的可能性。
#
# 具备“可能性”，是这个时代能够突破原有价值圈层的有效方法。创业的人，就是把自己置身于这种可能性之中。
#
# 那些厉害的人，你看到的是他们平时工作，甚至按时结束工作。但你看不到的是，他们在利用额外的时间为自己创造各种“可能性”。
#
# 在工作之余，让自己具备主业能力之外的其他技能的人，也让自己具备了这种“可能性”。
#
# 前段时间特别流行的词“斜杠青年”，就是在形容一个人的多样化能力。
#
# 如果当下你还没有成功，也不要紧，只要你开始了，只要你在坚持和尝试，那你已经比别人具备了更大的“可能性”。
#
# 时间，会给你带来最好的回报。
#
# 《商业的本质》《思考快与慢》
# ```
#
# > 证券市场的指数数据， 指数 PE PB TTM 红利率等基本指标，哪里计算和公布的？ 自己可以量化计算？
#
# > M型社会导致了M型消费——顶级的百货公司逆势增长，面向中间阶层的百货商店全部惨淡经营，但走低价路线的零售业态（百元商店、便利店等）迎来了大发展。同样的事情在美国也发生过：1970年代，美国迈入M型社会结构。此后，以中产阶级为主要顾客群的量贩店走向没落，而以中低阶层为目标客户的折扣零售商店却兴起了。
#
# > M型社会－中产阶级消失的危机与商机  --- Book
#
# > 使用数据说话，很多文章都会列出数据来支持，提示等，然而，这些数据来源是？ 数据源是公开数据？ wind数据，然后作者自己加工整理，给出 代码 和做法？ 这样也是一种小v 的套路啊。。。
#
# > 晚上早点睡，就真的不困了。。。。
#
# > 知识图谱，不仅仅是平面的，还有是时间线的，立体的。或者更多维度的.
#
# > 什么是投资中最重要的事？回答赚钱的，大多都被市场的浪潮冲刷的不知所踪。投资最重要的事是，躲坑。本金去往哪里前，请先看清前路的坑。
#
# > Some data, numbers, 13.5w total cost, about 550 per month, 20years? current risk free interest rate is 3%, what is your decision, judgment... 投资考虑，收益，考虑风险啊， 同时考虑啊，夏普比率？ 风险溢价
#
# > 可转债这个标的， 很特殊， T+0交易，然后可以还本付息，也可以转成股票？
#
# > 休息好，睡眠太重要了。。。 要学会选择，判断好的东西， 譬如离开马路远一点，然后靠近小区里一点，然后方位好，安静的。。。 足够的睡眠，质量好的睡眠太重要了。。。想办法搞好它.
#
# ---
# > 机会是跌出来的，钱不是大风吹来的，如何判断，如何控制风险，这个才是能力啊，在市场上打滚，得到的一些规则，能够沿用吗？回过时失效吗？ 如何才能与时俱进啊？
#
# > 什么才是合理的估值，什么是便宜的筹码，什么是贵的筹码。 懂得真正判断，不仅从绝对值，还有从收益率，才是正确的价格观，财商。。。 怎样衡量价格，值不值。。。
#
# > 从 中证指 的指数 编制，成分，看历史，看数据，就能看出很多东西了。。。
#
# > 从 中证指 或者 MSCI 等的行业指数编制，构成，历史，各自的规律，周期，波动，也许就有点特征了。
#
# ---
# > 正确的财富观，估计值，懂得什么才是真正的贵，真正的便宜，不仅从总量的角度，而是从多个角度
#
# > Sqlserver 的存储过程， 使用变量的时候，也是不需要使用 exce 包起来了。。都能直接 构建 sql 语句的， 什么时候不需要拼接SQL， 什么时候必须拼接SQL， 这个影响关系非常大。 能不拼接，尽量不拼接啊.
#
# > There is no reason to use dynamic SQL if you don't need to. Dynamic SQL increases the complexity of your SQL programming by magnitudes, and you should stay way if you can. Particularly if you are an inexperienced programmer or DBA. 确实是，尽量不用拼接的SQL，这样不好维护，不好阅读，还写得痛苦，在SQL的世界，存储过程里面，肯定是直接使用变量就行了，不需要花大力气去拼接SQL， 直接 select @var1, @var2 from table where dddate = @date and cust = @cust 这种形式，而不是拼接动态SQL。。。除非拼接动态SQL会带来质的飞跃.
#
# ---
# # 20190311 Monday
#
# ![ceshi](https://xqimg.imedao.com/15035d705545a63fe2d6ada4.png!custom660.jpg)
#
# > PE，PB， PE是市盈率，但是一般是线性静态的，容易受波动而误估算；PB是市净率，相对稳定，波动相对少，但是都是可以fake啊。。。 而且不同的行业他们的评估方式，锚是不一样的，甚至到个股，都是不一样的，不能轻易用一条简单规则去套资本市场，没有silver bullet，没有唯一的指标。。。 抽象的宏观方法论是没有问题的，但是落地到具体的投资就不一样了。。。
#
# > 投资逻辑有很多很多，需要尽早建立、验证属于自己的，才能成熟起来。 PE/PB 等指标的正确运用，才能对股价有准确的评估.
#
# > 19年2月22日，最高层明确提出金融是国家重要的核心竞争力，并作出 “深化金融供给侧改革，推动金融业高质量发展，增强金融服务实体经济能力”这一讲话内容。
#
# > 城市规划，设计，安排，从宏观整体，长期的发展看待，而不是短时，贪心的视野。。。
#
# > 把简单的事情做到极致，就像 相对简单，菜式相对少的餐饮、才能更好推广，但是复杂、广博的就麻烦了，厨房不好控制，不好扩张了，也是边际效益？
#
# > 资产配置，学习啊， 理财， CFA的理论+实践。。。 股票、债券等等。。
#
# > 201812 201901 的时间段，低谷，是否可以吸收筹码， 看交易量，看成交额，看整体行情，看 券商 的金丝雀。。。然后？
#
# > 悦万城的中影，soso，爆米花还特别贵。。。。
#
# > 环境没有 Python 3.6， 需要准备环境
#
# ```
# 1. 下载 python 3.6 包，现在系统没有 pip
# 2. 解压包
# 3. 配置安装目录
# 4. make && make install, 可能需要配置源
# 5. 修改 pip 的配置，使用源
#
# 安装 airflow 过程，也算是 一波三折啊，有不少小坑 要踩过去，小心点，要了解到每一步是干什么的，知其然而且知其所以然，问题就不大了
#
# 安装mysql，
#
# 安装mysql驱动，cx_oracle驱动，安装 oracle basic client获得库 等等
#
# 写简单的 dag代码，写简单的同步python代码，应该问题就不大了
# ```
#
# - 大多数人判断错了，而你自己判断对了。。。
# - 大家都判断对了，你走得更快。。。
#
# 还是对这个世界的理解，如何才能深刻理解这个世界，这个国情？看到本质，看它的过去，看它的现在，看它的将来？
#
# > app.py 文件有 Ad Hoc Query Data Profiling 关闭掉它？ 可以增强安全性， 超级用户才可以看见，但是普通用户不允许
#
# > microsoft solution framework
#
# > 老年人大学？ 他们也可以上学，学习各种新潮的东西？
#
# ```
# 买指基的原则:
# 1. 宽基与行业结合
# 2. 选朝阳行业
# 3. 适当配置海外股指或大宗商品指数用于对冲
# 4. 最重要的一点，上述品种均应在低估值时定投买入
# 剩下的，交给时间
# ```
#
# > 如何判断指数是在低估的状态？ 定性分析，更要定量分析的啊， 应该有网页、应用的入口，用于 横向、纵向分析指数的地方，看长期的均值？ 不，看 PE的长期中位数，均值， PB的长期中位数，均值。。。找这样的地方，找入口，找基本面方法等等，安静心态。
#
# > C2C, 将老外们的创新想法，产品，工具，理念 copy 2 c，落地，本土化，利用这个wall的势搽，顺势而为，把握了市场。。。老外们的互联网是在那个地方，那种地方讨论，活跃，最创新的想法，交流在哪里？
#
# > 场内的 ，对于业余投资者，投资最重要的不是收益最大化，而是在自己睡得安稳基础上，尽可能简单易行，取得一个稳妥的收益。所以，“资产配置+再平衡”是最适合我们的方案。。。。。。  现金类+债券+股票。。。资产大类，分配。。。还是场内快...
#
# > 投资跟跑马很像，很多新手起跑就提速，越跑越慢，而老马们则是按照自己的计划配速，先慢后快，越跑越快。到终点时，老马们的成绩一般都会比预期差不了两三分钟，而新手往往跑崩，甚至不能完赛。投资是马拉松，不是百米，不想慢慢赚钱是绝大部分人亏钱的主要原因。 难怪他们那么喜欢长跑，跑马拉松。。。。This is why?
#
# > “做号集团”对流量的洞察、平台的算法、编辑的喜好了解的比自媒体透彻多了。公众号后面的灰产，庞大。。。围绕着某个补贴来，最后还是搞坏了市场。。。？
#
# > Algorithm 之路 http://jeffe.cs.illinois.edu/teaching/algorithms/#book  Go For IT...
#
# > When AUC suitable when ROC suitable...https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc?hl=zh-cn???
#
# ```
# 准确率 - accuracy
# 精确率 - precision
# 召回率 - recall
# F1值 - F1-score
# ROC曲线下面积 - ROC-AUC （area under curve）
# PR曲线下面积 - PR-AUC
# ```
#
# > “正交”的原则设计出了Logger, Appender, Formatter这些类。
#
# > 券商 Brokers 用到的上市公司  恒生电子、 顶点软件、 金证。。。 From ZZH? 在熊市的末，机会才会来，他们才变得值钱，因为对未来的现金流折现。。。是有价值的，便宜的筹码， 要真正学会什么是便宜，和贵。。。牛市的初期，中期， 券商、围绕券商行业的龙头企业。。。 都有异动。。。
#
# > 基金从业资格，那几个 课程， keep learning
#
# > 2PC, 3PC, Paxo 算法，分布式算法，应该学学分布式的啊。。。哎
#
# ---
# # 20190318 Finance, Investment Logic
#
# > 券商的交易系统分两部分，后台的核心交易系统和前端的客户端系统，一般的核心交易系统都是被三家把持着：金证、恒生、顶点。其中金证和恒生各30%几的份额、顶点的份额最小，也有部分券商使用金仕达的柜台，比如海通证券。前端客户端，pc部分同花顺用的最多，然后是通达信，大智慧等。移动端杭州中焯异军突起，占据了40%以上的份额(他的老大也是从恒生出来的)。包括华泰证券等很多大券商都是使用他们的系统，当然同花顺依然是占据很大份额，但是具体数据没有。
#
# > 这也许就是了解行业，知道行业的特性，属性，逻辑，了解行业，还了解企业。。。了解内在的投资逻辑，也了解外在的投资逻辑。。。 但是对于金融的锚，稳定吗？你是正确的吗？ 怎样的投资策略，资产配置，组合才能 收益，风险考虑到？  熊市的时候，人们绝望的时候，怎样做，牛市的时候怎样做？
#
# > 啃论文是最有效的方法，要掌握这门算法肯定得付出一些精力的。能耐心去看Lamport的两篇论文 "The Part-Time Parliament" 和 “Paxos Made Simple”，得到的理解程度肯定要比单纯阅读简化资料高得多。是的啃论文是最有效的，但却不是最高效的。理解运作过程也好，推导过程也好，大家的回答都是为了帮助大家更高效的掌握这门算法。
#
# ```
# 股票市场短期来看是投票机,长期来看是称重机是华尔街教父本杰明·格雷厄姆说的。
# 　　格雷厄姆说："市场短期是一台投票机，但市场长期是一台称重机。"
# 　　市场的短期表现，实际上是报价的结果，就好像在一群人的投票下，产生了“涨”“跌”的结果。有“利多”或“利空”的消息，市场应声而上，或应声而下。都体现了这种“投票”结果。对于短期交易的人来说，重点不在于研究价值的多少，重点在于研究人们的情绪会导致怎样的投票结果，利用这来获利。
# 　　市场长期来看，则是一台称重机。股票价格在长期上看，还是会遵从价值的原则，价值就是股票的质量，或者称重量。股价短期可以过分高和低，但从长远看，不会远远离开其价值太远，它有多少价值，就有多少重量，就趋向于有多少的市场价格。
#
# 格雷厄姆说，短期来看股票市场是一台赌博机器，但长期来看它是一台称重机.
# 。
#
# ```
#
# > 树莓派的另外一个竞争对手？ Jetson Nano Developer Kit 可以运行 Linux，并支持大量人工智能框架（当然包括英伟达自家的），配备了 4GB 的 RAM、千兆以太网、摄像头和其他附件所需的I/O。
#
# > 《暴裂无声》
#
# > 尼采的那句：“与魔鬼战斗的人，应当小心自己不要成为魔鬼。当你远远凝视深渊时，深渊也在凝视你。”
#
# > 不仅要观察到这个现象，更要想想背后的逻辑.
#
# > 为什么A股，可以打新套利？？？
#
# ```
# 他们也是有想法，逻辑去做的，然后用IT工具来帮助， 战略上的，战术上的
#
# 无风险套利，
# 务必同一时间同一标的一买一卖，
# 所以刚才的操作会有时间周期的偏差。
# 套利需同时进行，
# 所以交易标的就不能是新发行的，
# 而是已在二级市场交易的。
# 打个比方：
# 你手里持有100股某股票价格飞涨到11元，
# 而可转债因为大家了解的少价格仅为100元，
# 所以你将手头上持有的或借来的股票卖出，
# 得到1100元，
# 同时买入10张可转债付出1000元，
# 净赚100元，
# 然后拿出10张可转债向公司换购100股股票，
# 继续持有不变或还给券商。
# 完成套利。
#
# 而完成套利的前提
# 我务必要介绍一个名词：溢价率
#
# 溢价率=（转债市价/转股价值-1）*100%
# 名词我就不多解释了，
# 就是通过溢价率你会发现，
# 现股价和转股价中间差值。
# 而溢价率越高，套利的收益越高。
# 你可以在此网站上搜寻，
# https://www.jisilu.cn/data/cbnew/#cb
#
# 套利，从方法，分析，思考深度，信息流速度，散户打不赢机构是大概率事件.
# ```
#
# > 大湾区的规划文档，资料，规划、地理位置等等，会成为未来的 藏宝图？？？
