# %%
import numpy as np
import math
from matplotlib import pyplot as plt
     
xmin = 0
xmax = 10
x = np.linspace(xmin,xmax,num = 100)
# print(x)

y1 = np.sqrt( 1 + x )
y2 = ( 1 + x ) / 2

ymin = 0
ymax = np.max([y1,y2])

plt.axis([xmin, xmax, ymin, ymax])
plt.plot(x,y1,'r.')
plt.plot(x,y2,'b+')
plt.show()
# print(y1)
# print(y2)

# %% [markdown]
# #### 国庆节日
# ```
# 28 day 0 evening, not handle well, need to feed well and good washroom
# 29 day 1 Take Pictures
# 30 day 2 Walk around seashore, seafood, so-so
# 1 day 3 meet friends, go back fs
# 2 day 4 stay home, rest,
# 3 day 5 school mate, go to several house selling, go back dz
# 4 day 6 countryside, do something, go back fs
# 5 day 7 go to shunde for hao
# 6 day 8 school mate, go to house selling again, dinner jinjiangyue with her, not ok...
# 7 day 9 pictures ok, fix idea one, go to sz
# ```
#
# ---
# # 20181008 Monday， Found Problems，锻炼锻炼
#
# > 修复下统计口径，出现小问题
#
# > 按时间维度去安排事情
#
# > 按个人维度去安排
#
# > 按项目维度去安排
#
# > TOD。。。transit-orient-development 公共交通导向开发... 他们为什么这么做，原因是一个，多个？
#
# > 需要坚持锻炼啊，这是给自己最大的保障，最大的节流，看看医疗这座大山，跨过一个大山已经是小成功了。。。
#
# > if zfgjj is a instrument to redistribute wealth, 0-1 gamebaling, just not to stand on the lose side, stand on the wind side, get somemoney, earn something... right?
#
# > 优选法，统筹法，都是最优化的概念吗？？？
#
# > 去哪里查看数据，统计数据？？ 历史对比，知道自己所处的阶段
#
# > 夏洛特烦恼 的 滴滴哒哒。。。那个
#
# > 互联网 + 教育，家教市场，管理系统，平台，联系 老师 学生，评价...等等等， 线上+线下教育，推荐教育好视频等等？ how to teach better, teach well...
#
# > 把个人看做一个公司单元， 资产负债表，现金流量表，利润表？？？ 如何对自己的金融状况进行分析，进行归因？
#
# ```
# 开心麻花的赚钱思路，同样能够用在我们身上。
#
# 开心麻花最早期做舞台剧，加上创始人，一开始只有7个人。
#
# 这是用体力赚钱：一边编排剧目，一遍想办法拉人来看戏。
#
# 但赚大钱是要跟着趋势走的。
#
# 这几年电影行业上行，开心麻花看到了机会，主动去踩节奏。
#
# 开展大电影业务，连获票房口碑，比如夏洛特烦恼、羞羞的铁拳、西虹市首富。
#
# 影片大卖后，它的赚钱思路接着升级。
#
# 不再依赖卖产品（电影、话剧），而是升级成靠商业模式，去赚资本市场的钱。
#
# 比如2015年，电影夏洛特烦恼票房超14亿，年底它正式挂牌新三板。
#
# ```
#
# > housing problem in china...we need a lot of experience and perspective...
#
# ---
# # 20181009 Tuesday
#
# > 关于数据推送方案的，确实有个标准方案比较好啊。。。
#
# > 收益类的经验教训，都是使用统一单一来源，同一个口径，进行相加减，就不会出现奇怪的问题。。。 使用其他方案计算同一个口径，这样适合用来校验对比。。。
#
# > 个人重要资料备份。。。 移动硬盘一份，两台电脑，百度网盘一份... 有更好的解决方案吗？
#
# > SQL 的连乘， select exp(sum(log(x))) from data_set group by id; 数学的对数变换
#
# > 思考下战略的方面如何实现，路线，不仅XX，还要XX； 不仅要努力拉车，还得抬头看路.
#
# > 一对组合标准差，也就是衡量一个离散个体组合而成的系统的variance，多样性，但是个体有自己的variance，个体之间有相关性..  《平均的终结》这本书
#
# > 对冲的本质是保守的，对冲仅仅是为了降低风险。只有在害怕风险的情况下，才值得去做对冲。如果风险不大，那集中才有力量。
#
# > 学别人的理论，听别人的讲解固然重要，但关键还是要找到适合自己的方法和理论。每个失败者都是从自己的教训中吸取经验，聪明人则会从别人的经验中获益。除了在实战中磨砺以外，应该把主要精力放在研究市场、数据、图表和现象上，总结出符合市场规律、真正有实战价值的东西。
#
# > 投资是你对世界的认知在二级市场的变现...
#
# ```
#
# 投资的本质是认知的变现（深度好文）
#
# 前些日子跟投了摩拜的VC大佬头脑风暴，聊到投资的本质的时候，最后不约而同地总结为认知变现。今晚跟在上市公司做并购的老友吃饭，又谈到这一话题，觉得还是有进一步思考的空间，因此在此从以下几个方面做一些简单总结，跟各位探讨。
#
# 1、投资即决策，而决策差异背后的根本是认知水平（“认知是大脑的决策算法”）：投资就是对未来的不确定性下注，投资的过程就是不断地在胜率和赔率之间做平衡。一人一世界，每个人看到的世界都是不一样的，每个人对同一投资机会的认知也分不同的维度，不同维度的认知意味着各自完全不同的胜率选择。没有高确定性为前提的高赔率，是赌博。但市场普遍认知到的高确定性，在通常情况下又不可能给你高赔率。所以问题的本质其实是你是否有超越市场大多数人的认知，适时的判断出市场的错误定价，以高胜率去做高赔率的决策。马云所说的，任何一次机会的到来，都必将经历四个阶段：“看不见”、“看不起”、“看不懂”、“来不及”，也是同样的逻辑。
#
# 2、认知是多维度的：成功的投资需要完整的体系支撑，多维度的认知可以从不同的层面优化你投资体系的胜率和赔率指标。比如对行业和企业经营的认知：行业空间、竞争格局、价值链分布、核心竞争力、增长驱动因素等；交易系统的认知：仓位管理、风险管理等；投资思维的认知：安全边际、复利等。当然，不同人在整个体系的不同环节的认知能力是有差异的，需要选择性的修炼边际收益最高的部分，也可以通过团队合作让自己的某一部分优质认知最大程度上发挥价值。
#
# 3、投资很难赚到你不信的那份钱：知道和相信之间有很大的距离，而真正的认知是相信，甚至信仰，我们先看几个数字：
#
# a、王者荣耀刷遍朋友圈，我相信大部分人都知道，但截止到今天，腾讯股价今年的涨幅是72.3%，涨幅超越绝大多数资产的收益率，而绝大多数人也只是感慨下大腾讯好牛逼啊而已；
#
# b、相信大多数人通过各种渠道学习了很多关于google、亚马逊、Facebook、苹果、腾讯、阿里巴巴等这些明星公司的核心竞争力、企业文化、商业模式、创始人风格等各方面的知识，都知道他们很牛，但如果把六支股票做一个组合去复盘，过去三年的年化的平均回报也高达百分之好几十；
#
# 这些现象背后移动互联网对人们生活方式、商业模式的深刻改变，新生一代的消费习惯的升级等原因，我们大多数人都知道，但能否真正的从知道到相信，进一步转化为可以投资的认知，则少之又少。
#
# 4、如何提高从认知到投资的转化率：
#
# 对于我们大多数非专业投资人来讲，对于自己所从事多年的行业认知水平肯定是超越市场上大多数的人，因此对多年在某种特定行业中的积累、独特认知和趋势判断放在投资的视角思考，完全可以把这种深度认知轻松变形。比如，“2010年google退出中国，很容易判断最大的收益方是百度，事实上百度那一年股价确实翻倍了。比如爱玩游戏的人可以关注暴雪，了解手机行业的人可以关注高通，从事k12的人可以关注学而思、新东方。”
#
# 我一直说，在过去的6-7年时间里面，除了一线城市的房价（是否参与的背后也是认知的差异），我们还错过了两拨超过10倍的投资机会。一次是智能手机从10%不到的渗透率提高到65%的浪潮（2010-2013年中），相关产业链的公司都是动辄几倍的涨幅，其中生产触摸屏的欧菲光短短一年上涨近10倍；另外一波是智能手机渗透率超过65%之后带来的移动互联网浪潮，在一二级市场都雨后春笋般的出现了大量高效率的投资机会，其中变现最快、同时也跟大多数人的生活紧密相关的手游行业规模短短4年时间就增长了10倍（2012年-2016年从60亿左右增长到了600多亿），其中诞生的牛股就不言而喻， 一直到今天的王者荣耀。
#
# 相信，这两拨大的浪潮和机会绝大多数的80后、90后都是亲身经历、感同身受，因此如果你把这种身边的熟知现象，工作中对行业的积累通过深度思考转为真正的认知，再通过投资工具实现变现，那就是属于你的投资机会。
#
# 当然，创业也属于认知变现的范畴（李善友曾说，创始人的认知边界是企业真正的边界），只是其要求更高，除了需要具备超越市场的认知外，还需要战略、组织等一系列综合能力。而投资，特别是二级市场的投资，其交易成本基本可以忽略不计，是大多数人认知变现最佳的路径。（一级市场投资门槛更高，交易成本也更为复杂）
#
# 当然，真正的如何全方位的提高认知能力又是一个宏大的话题，下次有机会再探讨。
#
# 附其他几点认识：
#
# 公司研究的核心是空间、结构、深度、角度；交易策略的核心是概率、赔率和预期差；投资体系的核心是对象，时机，力度；而投资最本质的核心是价值、安全边际和复利。这几个环节是同心圆，越后面的越靠内环。内环决定战略和原则，外环确定策略和技术；内环是道，外环是术；内环解决了What和Why，外环实现了落地的How；内环不牢靠是闷头乱撞，外环不扎实是夸夸其谈。
#
# 市场的高波动不代表高风险，反之市场的平静也不等于均衡。
#
# 公司的不确定性到底来自哪里？我想主要是：1，未来市场需求与当前预期之间的差异；2，公司战略制定及执行过程中出现的问题；3，对经营产生重要影响的各种不可控因素（如原材料波动，汇率波动，政策重大变化，颠覆性技术革新等）；4，竞争烈度的大幅提升；5，随着时间的拉长使一切事物不可控进而不可测。
#
# 对于上述一到三的对策，其实是解铃还须系铃人。优秀的企业家和管理团队是提升这三项确定性的根本依靠；对于四，更重要的是生意属性上的根本特征，已非简单事在人为的范畴；对于五，唯一需要的就是对生命周期的敬畏和对安全边际的重视，其应对本质已在企业自身之外。
#
# 投资人的主动性努力不外乎以下几点
#
# 第一，寻找中长期经营提升确定性高的企业；第二，寻求中短期赔率好的价格；第三，构建能平衡黑天鹅风险和研究的有效回报的投资组合；第四，持续学习争取每年进步一点点；第五，保持身心健康，做好以上循环并耐心等待。其它的，基本就交给国运了。
#
# 资产配置的重要性有多大？我觉得第一它是重要的，但它一定是在一个长期的刻度上才显示出这种优势；第二，所谓的配置一定要有足够的力度才有效果，优质的配置机会但你只配了很轻的资产，也没什么意义；第三，资产配置本身并不必然导致升值，它是分担风险，这两者区别很大。最后，配置的重要性与单一资产的规模成正比，大部分的人问题不是配置而是规模。
#
# 繁荣总是静悄悄的发生，而灾难总是在大吵大闹中降临。
#
# 市场时刻都热点繁多，新闻每天都有惊悚头条，但咱做投资的真要有点儿满清太祖那“任尔几路来我只一路去”的劲头。与真实的价值为伍，站在概率和赔率的有利面，透彻理解并执行复利法则，其它的何必管它那么多？大多数的所谓对策都没有存在的必要，大部分刺激的新闻都与投资没关系。其实过度的关注反映的是内心的焦虑，这是种病，而且不好治。
#
# 投资成长中有两个临界点，在第一个临界点之前是艰辛的学习，用勤奋都不足以描述，简直是废寝忘食的恶补。完成这个阶段的时间因人而异，但1万小时定律是最起码的。过了这个基础临界点后，反思和质疑开始产生价值（之前别瞎反思），实践和总结推动着越过第二个临界点，但悟性和天资可能让一些人永远翻不过去。两次质变之后，将开始享受学习积累和资产积累的双重复利。
#
# 一部经典谍战剧里有个特工说过一句话：“在我们这个行当里，怀疑，是最好的品质”。那么，在投资这个行当里，最好的品质又是什么呢？如果一定要选择一个的话，我想是理性。
#
# 理性让世界有序，感性让世界多彩。理性让我们区别于动物，感性让人区别于机器。理性催生了科学，感性孕育了艺术。理性可以培养和训练，感性多是自然的萌发。失去理性很难美好的生活，失去感性很难拥有真正的生命。
#
# 投资的窍门就是巧方法+笨功夫。
#
# 巧方法是指方法论体系，让你事半功倍，做到高效聪明的整合信息碎片形成完整认识；笨功夫，就是踏踏实实花时间花精力一点点去阅读、 搜集和积累。市场里80%的人被笨功夫这层就淘汰了，基本失去超额收益的入围资格。剩下的又有一半儿被巧方法挡住了，原地打转收益与付出无法匹配。所以相当赢家，既要甘于“笨”又要善于“巧”。
#
# 总有朋友对我说：看你每天晃来晃去的，投资就那么轻松啥都不用干？我说当然不是，只不过我们工作的形态不同。一般工作的繁忙很容易识别，但投资工作其实就是三件事：学习、思考、做决定。除了学习研究是较容易看到的，更重要的“思考”和“做决定”完全可以一点儿外在表现都没有，但其实它们才是最重要的可积累无形资产。
#
# 职业投资人的社交很单纯，不需要维系多余的社会关系。在主动筛选后能沉淀下来的是三种人：第一种是有料。某一方面的学识好，能弥补自己的知识短板开拓思维，与之交流有益；第二种是有趣。或风趣豁达或古灵精怪，与之交往总能给生活带来一抹亮色；第三种是有品。就是能信任靠得住，价值观相近可坦率的说心里话。当然如果能多条兼顾，自然是交友的精品。
#
# 投资很难赚到你不信的那份钱。往小了说，对一个公司没有充分的信心，最多只能赚到财务数据直接相关的那点儿钱，再远点长点的钱是不可能赚到的。往大了说，对国家未来从心底悲观，那么最多赚到几个波段的小聪明的钱，要赚大钱也很难了。格局、历史感这些东西在99%的时候都很虚，但在1%的重要决策时刻往往就是强大信念的真正支撑点。
# ```
#
# ---
# # 20181010 Wednesday
#
# > 人有三种，第一种，自己能干成事的。第二，能带着一群人干成事的，第三，能审时度势的，一眼看到底.
#
# > 招商银行第一次转型是零售引领，让招商银行在一卡通、信用卡业务方面领跑；第二次轻型是轻型银行，走节约资本的精细化之路，一举在财富管理、零售存款、私人银行、零售信贷、消费金融、信用卡等业务领域，零售业务占到半壁江山。目前提出第三次转型，将金融科技、互联网视为业务再次腾飞的助推剂，向网络化、数据化、智能化的转变，建设fintech银行.
#
# ①阿尔法收益（Alpha）代表选股和择时的收益。也就是超越市场，主动投资的收益。对应主动型基金。
#
# ②贝塔收益（Beta）代表组合与市场相关的收益。也就是跟随市场，被动投资的收益。对应被动型的指数基金.
#
# > 一个离散系统的风险/不确定性度量，每个单元有自己的风险/不确定性度量，然后两两单元之间有相关系数，协方差，那么如何衡量这个离散系统的风险和不确定性度量...
#
# > 现有的文档管理模式可用，doc excel pdf等静态文件还没到好用，像DW那样才是好用。。。
#
# > 思考，架构师就是要抬头看路，找出更好的解决方法，选择更好的解决方案
#
# > 原来是程序+配置，修改配置参数而修改程序的行为，灵活，程序不用变; 数据库的存储过程也可以，把配置放在表里面，然后通过修改表的数据来修改存储过程的行为。。。666
#
# > 赌博中的 凯利公式？？？
#
# > 马来西亚的仙本那 + Japan 不过需要错峰出行，控制现金流，最大化享受效果。。?
#
# > 加入 Apache Pulsar 和 Trinity 这两个的调研
#
# > Twitter开源DistributedLog，对比Kafka和雅虎Pulsar
#
# ---
# # 20181011 Thursday
#
# > 模拟盘how? Where? Play with the market
#
# > 阿里巴巴的数学建模比赛，其实也是 Kaggle的模式啊， 企业抛出实际问题，利用网络群体的力量去解决实际问题。。。还是很新颖的解决实际问题思路。。。
#
# ---
# # 20181012 Friday
#
# > datax 目前只支持 python 2.7, JDK 1.8, datax 需要一定的环境...
#
# > datax 配置好环境 JDK1.8, python2.7 之后， 需要些配置文件json，这个json文件需要按照官方的口径去完成
#
# > DataX 有presql, postsql, 在 reader的地方可以加入 常量 dcdate "20181001", "201810121447" 注意不能有特殊符号？ 生成的 json 文件要注意，不然会有问题。。。
#
# ```
# Important
#
# Q: GpdbWriter 执行 postSql 语句报错，那么数据导入到目标数据库了吗?
#
# A: DataX 导入过程存在三块逻辑，pre 操作、导入操作、post 操作，其中任意一环报错，DataX 作业报错。由于 DataX 不能保证在同一个事务完成上述几个操作，因此有可能数据已经落入到目标端。
#
# Q: 按照上述说法，那么有部分脏数据导入数据库，如果影响到线上数据库怎么办?
#
# A: 目前有两种解法，第一种配置 pre 语句，该 sql 可以清理当天导入数据， DataX 每次导入时候可以把上次清理干净并导入完整数据。 第二种，向临时表导入数据，完成后再 rename 到线上表。
#
# Q: 为什么没有gpdbreader插件
#
# A: 使用postgresqlreader即可。
#
# Q: 为什么不用postgresqlwriter插件，而要开发一个新的插件gpdbwriter？
#
# A: 对于GPDB 的Append optimized table 和 HAWQ，单条记录插入的效率非常低，而gpdbwriter插件使用copy to语句而不是insert into语句，性能有巨大提升。
# ```
#
#
# #### IPP， Intelligence Plan for Personal Life
# 智能的个人生活计划，大概就是真正的移动智能助手，看到，听到，感受到人所处的环境，了解商品，ｄｗ记录人的最近几个月，几年的生活轨迹，大商品，小商品，食物，水果的的推荐，根据个人历史，根据群体历史等等．．．　能感受物价，时间／空间的物价等等．．．
#
# ---
# # 20181015 Monday
#
# > 长寿性企业特点：人生活离不开的行业（吃、穿、住、行、药、用等），选择龙头企业，定期检查跟踪。
#
# > 编程 programming 也是服务终端用户的，跟着用户走。。。
#
# > Kindle，推送，图书的知识图谱，用于数据推荐，书籍分类整理，这样可以做好软服务。。。
#
# > 吴军 的好多书都没有看完 <见识> “人生是一条河，每个人总希望自己这条河能够更宽一点、更深一点、更长一点。要做到更深，是靠自己的修行和对世界的理解；而要做到更宽，则是要和一些志同道合的人在一起共同做一些事情。”
#
# > 线上，网络的知识， 线下，图书的知识， 线下，实体店的经济认识...
#
# > 单个股票是可以超越10%的涨跌幅的，有条件下，一般是不会超过10%，但是新股，复牌，还有数值误差，可能导致是>10%的严格指标...
#
# ---
# # 20181016 Tuesday
#
# ```
# 国内券商行业自诞生以来，一直存在着收入高度依赖经纪业务的弊端。据中国证券业协会统计，最近5年经纪业务收入占券商总收入的比重高达44.8%。近年来在互联网大潮的冲击下，加之同业竞争导致的佣金快速下滑，多家龙头券商纷纷提出了经纪业务要向全面财富管理转型的目标。那么，券商向财富管理转型的“抓手”到底在哪里呢？
#
# 客户资产配置的三个问题
#
# 追本溯源，投资者买卖股票只是其资产配置的一种方式，其全部资产可能分布在银行存款、定期理财、基金、股票等资产之中。从客户的角度看，要做好资产配置就要解决三个问题：
#
# 一是如何了解各资产的现状及未来走势，即如何获得有效的资讯；
#
# 二是资金在各类资产间的配置比例及海量产品中的优选搭配，即如何获得有益的投资建议；
#
# 三是如何通过更低费用的渠道进行购买，即如何最低成本的交易。
#
# 纵观这几年的降佣大战，券商实质上都在围绕第三个问题做文章。这也导致行业佣金水平逐年大幅下滑，至2016年已降至不足万4，而且新的《证券经纪业务管理办法》出台还会进一步拉低佣金水平。券商“杀敌一千、自损八百”的佣金价格战已走到了穷途末路。
#
# 与此相对，更多的互联网平台则着眼于客户需求，发力解决第一个和第二个问题。从实际效果看成效明显。以同花顺为例，通过大盘行情、个股资讯等专注为客户提供有效资讯（解决第一个问题），月度活跃用户上升至3000万（易观：2016年12月数据），且增速远超主流券商；以东方财富及下属的天天基金网、股吧等为代表，通过论坛交流、投资组合等专注提供或分享投资建议（解决第二个问题），月活也超过1100万（易观：2016年12月数据）。更有甚者，通过收购券商后进行彻底的互联网改造，东方财富证券已成为去年经纪业务市场份额增幅最大的券商。互联网平台已不再是门口的野蛮人，而有可能通过非价格战的“跨维度打击”成为券商行业的颠覆者。
#
# “在线时长”是互联网平台逆袭的关键！
#
# 咋一看，券商大规模的降低客户佣金是对客户的让利，却为何被互联网平台逆袭？这是因为：客户的股票投资决策过程不是一蹴而就，而是由四个阶段组成，包括资讯关注、投资学习、决策执行阶段，如果决策的执行效果尚可，还会有个路径依赖阶段。
#
# 在这四个阶段中，客户的主要停留时间集中在资讯关注（第一阶段）和投资学习（第二阶段），尤其是学习并形成投资决策阶段停留时间最长。反倒是决策执行阶段往往在很短时间内完成，例如股票投资的下单操作。据华东某券商的调研显示（样本量达到7万），已开户却从未交易的客户普遍认为“股票交易是重度决策。他们有通过股票交易来获取利益的意向，但却难以下定首次进行股票操作的决心”。为此，他们会通过社交媒体、资讯平台，尤其是像东方财富、大智慧、雪球等一些知名财经媒体/论坛，跟踪众多“过来人”的言论，查看“牛人”荐股，尝试网站推荐的组合等，摸索或照搬形成自己的投资决策。也有很多投资意愿在这个决策摸索阶段被消磨殆尽，最终没有转化成有效的交易。
#
# 由此可见，券商的价格战固然为客户创造了价值，但客户更需要的是能够提供完整资讯基础上的投资决策支持。进一步讲，如何获取有效资讯、如何获得有益投资建议已真正成为股票交易的“上游”。谁掌握了“上游”，谁就能占有更多的客户停留时间，谁就能真正建立起客户粘性。一个典型的案例就是几两年“同花顺”先给大券商导流，积攒客流后待价而沽，进而向出价高的中小券商导流。而券商靠价格战换来的客户，在APP上的日均停留不会超过10分钟，而且还很容易就被价格更低的同业掠夺，客户粘性非常之低。
#
# 特色服务是获取“在线时长”的关键！
#
# 即将出台的《经纪业务管理办法》导致的佣金水平进一步降低，将倒逼券商将竞争焦点转向以特色服务为代表的“在线时长”争夺。那么，券商有哪些可供选择的特色服务呢？
#
# 首先，回归金融本质，回归经纪业务为客户提供优质交易服务的根本。所谓“了解你的客户”，这不光是口号，又有多少券商真正了解自身客户的股票交易以至资产配置需求呢？未来靠低佣金无法留住客户的情况下，券商行业必将强化以客服中心为依托的基础服务建设，了解客户、关怀客户、提供更多人性化服务，实现客户财富增长基础上的共同成长。
#
# 其次，提供专业的决策支持平台是增加客户“在线时长”的关键。决策支持平台实质上是结合券商自身特点，并积极借鉴互联网平台资产配置特色打造的资讯+社交+投顾平台。决策支持平台包括了以个股资讯精选、行业研报集成、牛人论坛解盘为代表的多层次信息采集、分析服务，还包括基于客户大数据画像的信息定制和精准推荐服务。以东方财富网、同花顺为代表的证券社区类平台正是通过资讯挖掘+社交分享+决策建议，占据了中小投资者的海量“在线时长”。而雪球的快速发展也印证了决策支持平台对提升“在线时长”的价值。
#
# 第三，基于大数据的智能财富管理是传统券商差异化服务的“杀手锏”。以智能投顾为代表的财富管理工具在国内仍处初级阶段，模型、算法相对不够成熟。因其较高的专业性，互联网平台在这方面的尝试尚未有显著成效。这就为券商的财富管理转型之路提供了绝佳的发展机会。如何能有效利用券商在财富管理、金融数据和人力资源等方面积累的优势资源，迅速占领智能投顾市场并形成特色服务，必将成为券商向综合财富管理转型的重要抓手。
#
# 综上，券商行业未来竞争的焦点将由佣金价格战转移至用户“在线时长”争夺。而取胜的关键“抓手”就在于完善的券商基础服务、优质的决策支持平台和绩效良好的智能投顾服务。券商转型时不我待。未来竞争不仅会发生在券商同业之间，更可能是提供差异化优质服务的券商与提供特色资产配置服务的互联网平台间的一决雌雄！
# ```
#
# ---
# # 20181017 Wednesday
#
# > PPT 可以做出很多图片，框架，架构等等，但是小问题是不是向量图，伸缩之后图像变形，如何使用PPT可以构建向量图？或者类似的工具，方便好用，素材够？
#
# > datax 也有最简单的 transformer... 简单的 substring, filter, groovy... 等等
#
# > Xshell + Xftp 才好好用，哈
#
# > 锚定效应：你的答案我做主。。。
#
# > 心理账户，阿里巴巴，淘宝，天猫，特别会利用心理学啊。。。 也特别会使用杠杠，少量金钱，撬动大量注意，然后解决问题，整个流程看就是 阿里花了小价钱解决了大问题，外面也大家欢喜，这类'共赢'模式...
#
# > 消费者不是爱买便宜的商品，而是喜欢占便宜的感觉...
#
# ```
# 1.人们极易受到“锚定效应”的影响，即使专业人员也不例外。
#
# 2.一个简单的商品名就能落实一个“锚”。
#
# 3.“锚定效应”出现的原因在于人们需要一个参照物。
#
# 4."A+n"套路之所以奏效也要归功于“锚定效应”的存在。
#
# 5.熟识“锚定效应”，三思而后行，努力成为一个不被别人操纵的聪明人。
#
# ```
#
# > Weekly, time on the road, 看视频，听书...
#
# > 方便面的没落，外卖的崛起，(他们在隐藏层，深层次抽象，其实是有关联的，不一定是线性相关，更多是非线性相关，信息论)，跨越维度的打击，我消灭你，与你何干。。。
#
# > markdown 的图片，图库，图床问题，存储图片的url失效了，图片就看不见了，能不能实现给了图片，然后自动计算出，深度学习的抽象表示，类似这个图片的DNA，用这个小小的DNA可以快速查找到原来的图片，至少相似的图片?
#
# > 博士能够探索溯源创新，硕士能够研究和时间，学士能解决问题终身学习... 都是与人性做对抗啊。
#
# > At night, 晚上不能开着手机，看手机，看知乎，因为手机的光线，内容，容易睡不着，睡不好， fix it...
#
# > 分众传媒，在电梯间的广告中间商，很多人都被迫看。。。
#
# ---
# # 20181018 Thursday
#
# > 屠龙少年。。。最终成为了恶龙？
#
# > 财富管理，资产配置，核心在哪里，区别在哪里。。。你的竞争力在哪里...
#
# > 开放系统，对外提供 REST API
#
# > 教训与成长，货币的时间价值啊，多为后面考虑，能做到更优，人无远虑必有近忧啊，有些事情就是要争分夺秒的，锱铢必较的.
#
# > 准备好自身，然后抓住机会，do it.
#
# ```
# DAG工作流类调度系统所服务的往往是作业繁多，作业之间的流程依赖比较复杂的场景，比如大数据开发平台的离线数仓报表处理业务，从数据采集，清洗，到各个层级的报表的汇总运算，到最后数据导出到外部业务系统，一个完整的业务流程，可能涉及到成百上千个相互交叉依赖关联的作业。
#
# 所以DAG工作流类调度系统关注的重点，通常会包括：
#
# 足够丰富和灵活的依赖触发机制：比如时间触发任务，依赖触发任务，混合触发任务
#
# 而依赖触发自身，可能还要考虑，多亲依赖，长短周期依赖（比如小时任务依赖天任务，或者反过来），依赖范围判定（比如所依赖任务最后一次成功就可以触发下游，还是过去一个星期的所有任务都成功才可以触发下游），自身历史任务依赖，串并行触发机制等等。
# ```
#
# ---
# # 20181019 Friday
#
# > 锻炼 presentation, PPT,演讲，沟通，交流
#
# > datax 对 mysql 的支持，可能是由于 驱动版本的问题
#
# ---
# # 20181022 Monday
#
# > 开会前问好 大佬们时间， 预约
#
# > 开会当天发一个邮件提醒，因为会议太多...
#
# > AI on 视频制作， AI on 图像PS， AI on 图像增强， 其实这个领域，可以做得东西很多的。。。
#
# > 没有现成的工具，自己造啊， 有现成的工具，没有模板，自己做啊。。。 Dota it.
#
# > https://www.phodal.com/， 多去看看，多去了解，不如你就认为，这个世界就是这样在的，原来世界根本不是这样子的，fix the error, try to find the truth.
#
# ---
# # 20181023 Tuesday
#
# > 可视化，数据可视化，算法可视化，如何使用通俗易懂的 图形图像、视频来解决就 超级好了， 要是有类似编程的方式，或者简单拖拉拽的方式实现就好了， PS和AE和AI等等的工具相对重，主要是需要不少的学习成本，每个个体、客户都有自己的需求和想法，但是不太懂如何自己表达出来，也不太懂如何具体实现... 这个分级的市场需求也很大哈.
#
# > 面对理论，厉害的人，需要更加抽象，更加理论，需要拔高找上限，极限的；
#
# > 面对普罗大众，需要讲，他们看得见的，他们摸得着，想得到的，落地接地气的。
#
# ---
# # 20181024 Wednesday
#
# > 移动真的超级坑，wuchi啊，订阅的时候只显示20/20G一个月的用量，然后就订阅成48个月？日，肯定不爽，打电话给客户，先淡定谈需求，取消，摆道理，先礼后兵，谈不妥就闹，明显的不合理条款，霸王条款，不平等条约，投诉消费. dota it.
#
# bs相对b的几何超额收益率应该为 $\frac{bs-b}{1+b} = \frac{1+bs}{1+b}-1$；同时需要注意到bs的含义为资产配置，不进行选股效应的，所以bs的收益可以表示为 $bs=\sum_{i=1}^{i=n}{w_i \cdot b_i}$；根据b的定义 $b=\sum_{i=1}^{i=n}{W_i \cdot b_i}$，所以几何超额收益 $\frac{bs-b}{1+b} = \frac{\sum_{i=1}^{i=n}{w_i \cdot b_i} - \sum_{i=1}^{i=n}{W_i \cdot b_i} }{1+b}= \frac{\sum_{i=1}^{i=n}{(w_i - W_i) \cdot b_i}}{1+b} = \frac{\sum_{i=1}^{i=n}{(w_i - W_i)(b_i-b)}}{1+b} $，注意到这里由于有$\sum_{i=1}^{i=n}{w_i}=1,\sum_{i=1}^{i=n}{W_i}=1,\sum_{i=1}^{i=n}{W_i \cdot b_i}=b$，两个的求和其实是相等的，但是每个细项是不等的，相当于 10=2+3+5=2-5+13 ，对10进行求和式的分解，其实有很多种分解方法，只要总的结果是一样的，每种分解的方式存在不同没有任何问题，但是这么多种方法中，那种方法相对基准方法更好，或者在所有方法中最好？这就需要一定的评判依据，可以根据行业知识来挑选评比出更好的分解方式。
#
# > 指数编制公司，那么指数编制规则在哪里可以找到呢？答案就是——指数编制公司的官网。先说说指数编制公司，就全球来说，最大的指数编制公司是明晟公司（MSCI），富时罗素（FTSE）排第二，这两个今年都跟把中国A股纳入到了各自的指数体系当中。中国最大的两家指数编制公司分别是中证指数公司和国证指数公司，几乎涵盖了90%以上的指数。
#
# > rocketmq 直接独立部署不需要直接使用hadoop生态
#
# > kafka 可以不依赖 hadoop，但是需要 zookeeper
#
# 有license，直接在现有的平台新增组件服务，但是要根据情况增加硬件节点，增加硬件节点需要增加licesnse费用，按年订阅；
# 没有license就有2种选择:
# - 直接安装apache社区的某个版本kafka
# - 新建一个只有kafka的cdh集群，借用现有的license让功能可以使用，但是厂商可能无法提供售后支持
#
# 直接开源版本的 kafka 还是 confluent？ kafka直接加zookeeper就行，不需要直接和hadoop集群强关联
#
# > 写了简单的Java程序， 使用8.0 的驱动程序，开源成功读取数据库； 使用5.1.30的也是无法链接到数据库... 使用5.1.47应该是可以链接到数据库了... ri啊。。。驱动版本，驱动的大版本不一样，驱动的小版本不一样。。。 总体来说 mysql版本到8.X.X了，需要的驱动要 5.1.40+ 8.0.0驱动才行了，这个其实在 google Stack Overflow mysql官方文档应该可以找到了.
#
# > “最优停止理论”还可以广泛用于面试、买房、购物等，婚姻只是一个小小的应用领域。
#
# > 时间加权 和 金钱加权， 金钱加权更加接近实际世界，但是使用多期brinson归因，确实会变成时间加权的收益率分解，分期是否一定和金钱加权的矛盾，无法解决， 还是可以这个多期brinson归因也可也使用金钱加权的方式去归因？
#
# > 多期计算的时候，不要用收益率、净值而连成、链接得到，要考虑现金流，也就是多期的时候能否设计出计算方式来等于 简单迪茨方法？期间多次出入金，多次现金流的影响。。。?
#
# > AI on 图像图层提取， AI on 视频里面的图层提取， 图层的概念， 物体识别，同类识别
#
# ---
# 和　同学聊天，　ｓｊｓ　很好啊．．． 音乐餐厅，we have an idea, right... ? 咱们结婚吧...
#
# > 类似 audiable.com　他们通勤的时间去听书．．更好的体验，更好的统计和分析．．．
#
# ---
# # 20181029 Monday
#
# > 未来也许只有三类机器学习工程师有前途，一类是能改进和创造新的算法的，这是算法大师，二是做机器学习平台的，含功能，算法和数据，这是产品大师，三是能够深刻理解客户需求的，在某个行业有足够业务和数据底蕴，因此能够利用高效的平台工具创造价值的，这是应用大师。
#
# > 在我的思维模式里，做任何事情，都一定要遵循第一性原理，即首先要去弄明白事物的本质是什么，它最底层最根本的核心原理和逻辑是什么。只有这样，我们才能拨开事物的表象，穿透重重迷雾，看到事情的本质，抵达事物的核心，提高做事的正确率和效率。股票投资也一样，投资股票要做的第一件事情，不是去开立股票账户，而是去思考和琢磨，股票的本质是什么，股票投资的收益从哪里来。
# ---
# # 20181030 Tuesday
#
# > Think before you do... 先想想有没有更好的解决方案，系统性管理起来
#
# > 会议不能飘，抓住目标，内在的含义，解决问题。
#
# ```
# 凯利看了新闻之后，他想到这个如何使具备一定内幕消息但是同时有一部分杂音的赌徒最大化长期获益的问题，可以使用他们实验室关于咨询学和噪音传递研究的公式来解决。于是，他以一个赛马的模型，推出了凯利公式的雏形。
#
#
# 凯利的理论是这样的，对于有一定内幕消息的赛马人来说，第一个自然的想法当然是放入全部的资金，但是这样就会造成万一输掉血本无归的惨境。而在凯利想要解决的这个问题中，在任何一个时刻输掉全部资金显然是不符合最大化累积收益的需求的。
#
#
# 真正应该关心的是长期累积的收入，对于累积的收益来说，最后的结果只和输赢的局数有关，而和输赢的顺序无关。所以他推出了一个最佳的投入仓位比，来最大化长期的累积收益：
#
#
# bet = edge / odds = 预期获益／获益回报
#
# edge=bp-q
# ```
#
# > 让 reinforcement learning  VS 凯利公式，就是让机器去学习赌博，尝试去获得累计收益额的最大值，凯利公式应该是数学理论的上限，那么 reinforcement learning 应该能够找到接近这个上线的结果too？
#
# ---
# # 20181031 Wednesday
#
# 特征工程随想，日常的特征工程，对应样本 $x=[x_1,x_2,...x_k]$,　这位样本　x　和它在每一个特征维度上的数值，日常的特征工程是在这个 x1,x2...xk　上面做文章，根据业务知识或者工程知识来做加减乘除等等的一些列函数变换，加工出新的特征来，但是如果我们仔细看那　样本矩阵 X，
# 由于是由 多个样本堆叠起来，形成了 nxk 的矩阵，这样的时候，从行来观察，是有ｎ个样本，ｋ个特征；从列来看，有ｋ个样本，ｎ个特征；这个跟推荐系统的 user-iteｍ　的看法类似的， ucf, icf的思路；我们可以从　行的角度去做特征工程，　也可以从列的角度去做特征工程吗？只是不新增加特征，而是 n -＞ f(n)　的变换，维度不变，变化的是特征的数值，类似对特征的归一化，最大最小，０均值１方差，但是是否有自动找到最好的变换函数ｆ，使得分类／回归的效果好？使用某种目标函数，是的变换后的特征最好表示？？　从离散的角度去做，然后选择；从联系的角度去做，然后找出使得目标函数最优的变换函数？ 是否有通用的，一定的准则，标准，来衡量变换的特征分布，什么样的分布式好的分布？？？
#
# 1.基于规则的，RBO，规则的变换，有限的，离散的，然后选择；
# 2.基于代价的，CBO，自动的优化变换，找到一类函数，然后选择这类函数里面最好的；
#
# > 老大们要求普及声纹识别技术，先是市场的民营、互联网公司普及，然后时间长了，他们体验过，考察过，就落地到这些相对‘稳’的企业。。。是要求，规定
#
# > 随想，观察到现在一二线城市的实际情况，年轻人们的生活状态，生活环境，应该知道他们需要什么实体产品，虚拟产品，需要这个热风机+紫外线+O3来清理排序梳理衣服，好看杀毒消菌烫平，很好的产品，根据粉丝效应，流量经济来做？
