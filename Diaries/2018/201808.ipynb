# %% [markdown]
# # 20180801 Wednesday
#
# > 开始要统计分析 自己的 收入支出情况了...
#
# > SZ公积金的需要办理，需要开通关联卡等等，公积金的业务每个城市都不一样，为啥啊，那么复杂吗，可以使用其他办法去解决吗？用你学过的知识去改变颠覆，就像Elon Musk一样...可以手机办理了？ 支付宝、微信的业务，其实各种业务，搬人的成本要比搬数据的成本高很多，电子化，数字化，不仅用户体验好，足不出户，办完业务；现在移动互联，手机普及是时代所带来的背景，顺势而为啊。。。
#
# > GR的FD...EFD，太糟糕的体验，如何反抗?
#
# 昨天说了说看懂“拼多多”你就看懂中国了，很多人开始在雪球上和微信上喷我，我觉得吧，纯粹鸡同鸭讲。有个别人纯粹不看文章来喷我，他们老说拼多多是假货，我说拼多多背后是什么？我们要从拼多多火了这个表象看到为什么中国，为什么中国农民面临如此恶劣的商业环境，我们要怎样解决？
#
# 发现问题就喷，我也会，但是我们重要的是解决问题。
#
# [PDD是最了解CN国情的，整体系统地认识这个国情，对症下药。。。](https://xueqiu.com/1062883669/111315363)
#
# 嘴炮没有任何意义，穿越迷雾，根据现象看清背后的本质，看清社会本质才更有利于我们投资.
#
# 我很赞成巴菲特所说的一句话，他说美国最大的秘密就是在于有一套释放人才潜能的体系，他说美国只有四百万人口的时候，中国有六千万人口，当时美国为什么能迅速超过中国，就是因为能够把人的潜能释放开来。
#
# 巴菲特多年一直押美国的国运，坚守美国，持美国的最优质资产，获得巨大回报。
#
# 他对美国最厉害的秘密武器的解读是正确的。
#
# 能够把人的潜能焕发出来，这是一个国家真正的生机所在
#
# ---
# # 20180802 Thursday
#
# > Our Darkest Hour 我们的至暗时刻。。。Overcome it.
#
# > 变与不变，静态和动态，抓住不同的场景下的不同策略，发现不同场景下共同的规律模式。
#
# ---
# # 20180803 Friday
#
# > ABCD, A For AI, B For BlockChain, C For Cloud Services, D For Data
#
# > [Article For ABCD](http://blog.jobbole.com/114005/?utm_source=blog.jobbole.com&utm_medium=relatedPosts)
#
# > 原来 Crash Course 是一个系列的。。。 不止 CS... 《Crash Course》系列课程...
#
# > 我在 法律的边缘思考了一下。。。放弃了。。
#
# > 那个老师的 普拉提，是由 滚动，腰部，对脊椎好的，那个要好好学，系统训练啊。。。
#
# > https://www.oschina.net/news/53672/what-non-programming-books-should-programmers-read reed books
#
# https://www.youtube.com/user/crashcourse/playlists
#
# https://space.bilibili.com/1950746/#/  个人的单打独斗，家庭作坊模式，走向群体的企业模式...
#
# https://space.bilibili.com/290704043/#/  www.v2ex.com 群体，圈子，不同的人群的聚类...广阔的视野...
#
# https://www.epubit.com/ 异步图书社区...
#
# ---
# # 20180804 Saturday & Sunday, HBD
#
# > she came to SZ, GZS -> FT, FT -> GZS, still ok
#
# > 和她去尝试 盒马鲜生，她点少了，哈哈哈，要不就是她的评估函数出问题了，要不就是她为了省一点。。啊哈哈
#
# > 想想还有哪里逛的，哪里好吃的，再去逛逛，再去吃，哈哈哈
#
# ---
# # 20180806 Monday
#
# > small bugs found 。。。 withdraw 小问题
#
# > GT集，简称 抢局，抢集，主要是对比价格，对比市场价，SZ站，SZB站，FT站，SZD站，应该是抢局的亲儿子，但是SZX就不是亲儿子了，所以很多事情都可以解释了，很多设计不合理，不高效，背后都有它的逻辑，只是你们是否了解到而已... Ask a question, why not improve its speed... 为啥不提速，为啥是T的速度，但是CDG的价格？不合理啊，不合理在哪里？不在自然科学的限制，而是社会科学，ZZ，TZ，capital集团之间的矛盾和限制，导致了目前这个看起来不合理的解，实质就是在全系统全因算限制的解了。。。 考虑市场、ZZ等多个因素后的定价，不容易啊，但是总是有办法解决的，是吗？
#
# > [history](https://xueqiu.com/5308627460/111625469) 历史很有趣的，它不会完全重复自身，却处处看到它的影子，看书，看历史，然后结合自己所在的时间线，历史车轮的大环境，学习他们一样玩这个游戏，and defeat them...
#
# ---
# # 20180807 Tuesday
#
# > 模仿口径统计 笔数
#
# > 游戏，转换角色的游戏，可以在同一个场景中切换不同的NPC来进行交互...
#
# > docker 很重要啊，我尝试要换 VPS，其实配置是一样的，但是每次都花我的不少时间去运维，能不能把这些相似的提取出来，自动运维．．．这些都是相当重复的工作，完全可以使用　代码，机器自动运行起来...
#
# > 世界上就只有税收和死亡不能避免．．．
#
# ---
# # 20180808 Wednesday
#
# > You need to security you VPS on the open/malicious Internet...
#
# - stop root login directly, use normal user login and then sudo or su
# - change your ssh server port
# - audit your server
#
#
# 《投资最重要的事》的作者霍华德曾经举了一个信奉有效市场的金融学教授和学生散步的例子：
# “地上是10美元钞票吗？”学生问。
# “不，那不可能是10美元钞票，”教授回答道，“即使有，之前肯定早已被人捡起来了。”
#
# 教授走了。学生捡起了钞票，去买了杯啤酒喝了
#
# > [keep reading books](https://xueqiu.com/5308627460/111778538) 重要的是，持续成长学习的能力，
#
# > WIFI 越来越常见，就像空气水电煤，但是缺由于多种原因不好用，信号不好，隔断等等，有没有诊断，看到现象，然后再归因的工具？　对比方式去迭代求解？　换一种，第一原则去　剖析分析问题．．． like Elon Musk
#
# > 更多的指标，更多的公司内部指标，开源的指数编制，用群体的智慧来反映这个　证券市场　的实际温度，通过迭代方式去优化，更加完美的指数，解决基准不准的问题，然后打败那些　伪主动投资者．．．　　好多种方式去玩这个游戏啊．．．　平台...
#
# ---
# # 20180809 Thursday
#
# > AI芯片，是另外一篇蓝海吗？能够超越他们吗？ 从 CPU -> GPU -> FPGA -> ASIC... 似乎我们能做得东西也很多啊...
#
# > note 非交易日是没有数据的... 不会执行任务，不像银行跑批，需要每天都执行
#
# > 云工厂, 云工工业 公司？ 互联网+传统工业？ 36kr 有不少好的想法...
#
# > 获取当前月的 第一天 和 当前月的 最后一天，一般需要 sql 函数来执行
#
# > can ABCD... blockchain 改变我们这所谓的 fair 问题吗，公开问题吗？
#
# > 无状态的函数， HASKELL 的思维，函数式的做法，很好用啊。。。好犀利啊。。。
#
# > 真正架构师，真的做出东西，梳理好，方便，精简，有弹性。。。
#
# > 从新零售 到 新制造， 新工厂...
#
# > market + stkcode 要在一起，不能分开。。。 tacode+ofcode 也要在一起不能分开
#
# > Tools, 小程序， 小工具， 小代码...我刚开始尝试推广自己网站的时候，读了《牵引力》（Traction）一书, 额外的收入?
#
#
#
# ```
# PostgreSQL 的当前日期坐在月份的最后个自然日 (注意区分交易日)
# 	select cast(to_char((date_trunc('MONTH', to_date(p_date,'YYYYMMDD')) + INTERVAL '1 MONTH - 1 day')::date, 'YYYYMMDD') as integer)
# 		into v_month_enddate ;
# ```
#
# ---
# # 20180810 Friday
#
# > 自然语言处理， NLP...
#
# ---
# # 20180810 Friday & Saturday & Sunday
#
# > Go Back Home... 动车晚点，所以不能去坑口坐广州－Home 的车，只能去桂城的地铁站，邮电局－２０９．．．
#
# > 要帮她，一起搞好那个 excel 表格．．．一项一项填满...
#
# > 修 电脑了，大概　260，跟上次差不多，估计是由于过热造成的芯片问题，焊接问题．．．保养电子产品啊...保养你的工具...
#
# > 需要看各种电器了，收集讯息，收集方式，然后决策...
#
# > 多去走走，多看，多听，才知道世界并不是你想象中的那样．．．
#
# > 把自己的想法装进别人的脑袋，从别人口袋取出钱到自己口袋... 最困难的事情，做好它就不担心了，一步一步做好啦
#
# ---
# # 20180813 Monday
#
# > PPT 调研情况，介绍调研情况... 数据交换平台，调度系统，数据湖 三个都涉及一下.
#
# > 思路介绍一遍
#
# > 数据上生产，然后校验数据
#
# > 30% 的时间和思路去做思考，怎样的平台才是大家都想用，都能用的...
#
# ---
# ## 电视机
#
# > Sony KD-55X9000E, KD-55X9000F，看新型号
#
# 2.5米以内５０寸以下，2.5~3米适合５５寸，3米到3.5米适合６５寸.
#
# 分辨率　使用 ４Ｋ,　长宽比例 16:9 ? 16:10? 多少寸
#
# 屏幕材质，RGB真4K，IPS硬屏
#
# 发光原理，　真伪 4K
#
# 智能电视注意　：　处理器能力，内存２ＧＢ以上，开关广告
#
# 流的面板刷新率为60Hz，一般看剧、看直播就够用了；稍微好一些的是120Hz，经常看球赛、打游戏的小伙伴可以考虑。
#
# ---
# # 20180814 Tuesday
#
# > 上生产，测试...
#
# > 那年夏天，我们出发去寻找梦想，我带着疑问，阿飞带着枪，胖子带着梳子，敢死队带着疯狂... 瞎看什么回来了。。。
#
# > 久石让 的 太阳照常升起，还挺好听的...
#
# > <太阳照常升起> 很晦涩，但是姜文不愿意在影片之外多说什么。 我喜欢某一类电影和文学作品，他们虽然表面上很晦涩，但想表达的东西其实很完整地包藏在作品之中，全盘呈现给观众和读者。解开谜底的要是其实早隐藏在谜面之中。解读这样的作品，只要去细读作品本身就好了，不用求助作品外的花絮。。。
#
# > 解密游戏，就像克兰道尔？阿克沙？ Game of more broad，把这个解密游戏看得更加广泛，其实人碰到的许多问题都是这个解密游戏的范畴，解决这一套问题的思路，是方法论？
#
# > 我们都其实很幸福，有很多很好的影视作品，书记，网上都能唾手可得，但是同时也是充满了抖音等吸收大量流量时间的存在，能学到的东西其实很多很多，眼界可以开很宽阔。。。推翻现在的醉生梦死很那，但追寻真实真相不更美好吗？ the sun also rise...
#
# > How to use ML/AI to find their problems，老鼠仓，内幕消息，操作市场？ Can we do it?
#
# > 无意义的争吵就像挠痒，只会变本加厉...
#
# ---
# ## 空调
#
# 变频　和　定频，主要是　需不需要重启机器
#
# 比如一匹的空调它的制冷量为2500W，能效比为3.8，那么它的输入功率简单的来说就等于2500/3.8=657，这个数值越小，耗电越低。每一个空调，无论是挂机，还是柜机，制冷量和能效比这二个数值都有写。注意，我说的是简单算法，因为上面我提到过定频与变频机的差别，如果达到设定温度会处于关机或者待机状态。所以，刚才举的例子，一匹的空调，能效比3.8，算出的输入功率为657，那么应该1.6小时左右一度电，真实情况是1.6小时用不了一度电。
#
# 你的客厅是40平，并且与餐厅相联，大多数的房子，客厅的密封性都做的不好，买空调宜大不宜小，就像风扇距离远了，吹不到风一样。所以，你的客厅至少要选择2.5P以上的柜机，或者3P的制冷量
#
# 卧室的密封要好，10平选择1P，15平选择1.5P的挂机。
#
# 最好的位置是垂直你脚的方向，吹向床和电视柜中间过道的方向。
#
# 安装室外机首先要注意空调百叶是不是过密，如果过密的话不仅会费电，而且一旦天气过冷或者过热都会导致空调会死机。和这个时候你需要和物业沟通，将百叶减半。
#
# 在正常的家庭，一平米用到180-250瓦特的制冷量就够了。举个例子，在一个10平米的房间，按照200瓦特一平米来算，差不多需要2000瓦的制冷量。一匹空调的制冷量大概是两千三百多瓦，所以配一个一匹的空调足够了。如果你想保险点，就做个1.5匹的。
#
# 有许多因素会影响空调的制温效果，其中最主要的楼层、西晒、西窗、户型等几项，那么如何精确计算房间需要的空调功率大小呢？首先将每平方米需要的制冷量定为150W；如果顶层、西晒占其中一条，按照每平方米200W计算；如果有西窗或者既顶层又西晒，每平方米至少250W。
#
# 空调这东西三分看货品，七分靠安装！尤其是变频空调！ 注意安装时候需要　防震动的垫子，出水管．
#
# 空调安装主要涉及到的服务主要包括钻孔、吊挂室外机、挂机与压缩机连接的铜管等。通常铜管按米来收费，不同安装条件下使用的铜管长度也会有所差异，安装费用可能会有所出入，一些大型家电卖场和电商网站都会承诺免费安装，但安装过程中的耗材，还需要用户承担一些费用。
#
# 那么支架肯定是要另外收费的，而且价格贵，质量未必好，我建议你们去淘宝上买质量好一点的支架，到时候你给师傅有点小费，让他帮你装。
#
# 淘宝上这种支架估计1.5匹60元就能搞定，但是如果你要在连锁店或者京东买，那么得200一副。
#
# 空调参数，重量外机..
#
# ---
# # 20180815 Wednesday
#
# > “现存的市场由两种海洋所组成：即红海和蓝海。红海代表现今存在的所有产业，也就是我们已知的市场空间；蓝海则代表当今还不存在的产业，这就是未知的市场空间。 ” 在红海中，每个产业的界限和竞争规则为人们所知。随着市场空间越来越拥挤，利润和增长的前途也就越来越黯淡。各竞争者已经打的头破血流 残酷的竞争也让红海变得越发鲜血淋漓。与之相对的是，蓝海代表着亟待开发的市场空间，代表着创造新需求，代表着高利润增长的机会。尽管有些蓝海完全是在已有产业边界以外创建的，但大多数蓝海则是通过在红海内部扩展已有产业边界而开拓出来的。
#
# > 里拉贬值，导致的有了一段套利的时间空间，羊毛党来薅羊毛了，如何防范未然？？？ 异常检测，警告？
#
# ---
# # 20180816 Thursday
#
# > 核对，校验，如何搞一个 统一的 测试方案？ 回归测试？ how to solve the problem systematically???
#
# > the sun also rise... 阿廖沙，别害怕，火车停下来，天亮啦...
#
# > laugh in the face of danger...
#
# ---
# # 20180817 Friday
#
# > 大家都被专家惹怒了，不生二胎还得变相罚款，然后云绿帽子？ 不过冷静，只能说对面太配合，送热点，送流量，静下心，写点更有深度的文章，也乘一下对手给的风口，岂不是美滋滋。。。哈哈哈... 我们都是被迫的，但是如何改变？ 大部分都只能适应，想着反抗？？？
#
# > 我们也许也需要‘一次文艺复兴’启蒙，真正认识‘人’的价值，真正认识到个体的权利，‘人’和‘人力资源’是有本质区别的。。。
#
# > 魔幻现实的是，你提交的金钱，权力，最终却用来了control,press,constrain你们自己。。。somewhat redicious, but it has its deep reasons...
#
# > 为什么用净值比较？ 而不是直接使用 累计收益率 a 和 累计收益率 b 比较
#
# 累计收益率: ( a - b ) / b, 有问题， 比如 a = 0.01, b = - 0.01 , ((0.01 - (-0.01)) / (-0.01 ) = -2
#
# 净值比较： ((1+a) - (1+b)) / (1+b), 比如 a = 0.01, b = - 0.01 , ((0.01+1) - (1-0.01)) / (1-0.01 ) = 0.02
#
# > 思考，思考得更广（灵活），更深（专业）， 人生总会遇到各种各样的问题，各种烂摊子，思考着想办法去解决它就好了
#
# # 20180818 & 20180819 Saturday&Sunday
#
# > 搞定空调了，４＝3+1 格力，都是润慧，金贝；　其实自由度可以很高，自己想干嘛干啥，买啥都行，但是我们的国度，教育好像没有那么多的自由度教育，更多的自由度，我们反而不懂得玩这个游戏了．．．　可以很多种组成方法的，不怕....　有ｅｘｃｅｌ表格，可以线上，线下对比下．．．算是碰上了　８１８　的优惠？
#
# > 热水器也应该定下来了...
#
# > 20180823 那个电器超市店庆，可以去看看？ 看看我们选择的有没有优惠...?
#
# > 学会去选择，比较，比较的优化方法．．．还有第一性原理的优化方法....
#
# > Miss.Ren 需要　涂手臂，会长细菌？　还有坚持锻炼，俯卧撑＋拉伸　一周要有２次，跑步要科学，热身-跑步－拉伸...
#
# > Find way to finish it??? Small Secret...
#
# > 投资是你对世界的理解的变现... and ?
#
# > 林深时见鹿，海蓝时见鲸...
#
# ---
# # 20180820 Monday
#
# > 复制的sql加工，数据加工，其实可以做到 解耦 和分离，业务知识数据 和 计算代码分离，用 config表的形式解耦，代码简单容易维护，业务提取出来单独处理...
#
# > 在一个集中式存储库内安全地存储、分类和分析所有数据。
#
# > 发布权限，给不同的角色
#
# ---
# # 20180821 Tuesday
#
# > 注意自己的身体啊，早点休息 11-30 就要关灯关手机。。。不能任性
#
# > 常备一些小药物，维生素C，维C银翘片，感冒颗粒等等。。。
#
# > 多吃水果，多喝水，运动，关注自己的生活，来回动车带口罩啊
#
# > 吃橘子。。橘子特别好。。。
#
# > kkndme， 天涯的作家， True Or False... 为什么他们的理解这么厉害...
#
# > 数据湖， iot ，传感器数据， 如何系统地学习 异常点检测？
#
# ```
# 什么是魔幻现实？
#
# 从一件很荒诞的事情中能看到很深刻的人生。
# ```
#
# > web浏览器上面　跑个 windows ... 搞个 linux...　更多的是一种思想，模拟．．．
#
# > 在自己的日常开发，运维过程，有很多很好想法的工具都还没有落地，没有智能对比助手，智能去重复，简单ｓｑｌ的ＤＭＬ；　智能的测试，回归测试等等，要是都能够自动化，智能化，就会大大提高社会生产力．．．
#
# > 感冒了，才觉得要对自己的身体好一点，要求更加严格一点。。。 有个叮当送药，o2o 的形式，如何才有自己的核心技术，核心竞争力，护城河？跟医保社保合作？在线刷卡？ 收 0.001 的手续费？？？ 维护系统正常运行，然后bat来敲门，大不了开源贡献，为社会贡献，，，要有 mobike的心态，哈哈...
#
# > 中高档洗衣机外加一个独立烘干机?
#
# 干衣分直排，冷凝，热泵三种，价格依次递增， 不知道洗衣机一般自带的干衣功能是哪种， 直排是会有水蒸气排出的，冷凝和热泵和空调的工作原理类似。 之前做功课，除了容量差别，一般洗衣机自带的干衣效果不会好过独立的， 褶皱程度和干衣耗时都差点..
#
# 烘干机 有紫外线消毒的型号...3-5KG够了... 一体的烘干机不一定有 8KG烘干，一般8KG洗衣，3KG烘干..
#
# 价格， 排风式<冷凝式<热泵式 大概是 1:2:4 关系
#
# 烘干效果， 排风式<冷凝式<热泵式
#
# 排风式，接近淘汰了，一般不好用， 在冷凝和热泵之间选一个吧...
#
# 功耗, 热泵<冷凝<排风， 热泵功耗低很多， 热泵的 3,5,8KG ，5KG住够了
#
# 洗衣机  不用烘干功能了，但是选择支持叠放的机器，方便后续加入烘干机
#
# 博世 Seris 6，博世（BOSCH） 9公斤 变频 滚筒洗衣机 全触摸屏 静音活氧除菌 随心控时（银色）XQG90-WAU287680W
#
# WAU287500W
#
# 6399, 但是有优惠 满1000-100， 也就是 6399-600=5799 可以到手 估计可以 5200～5700 到手？
#
# 要问问是否支持叠放
#
# ---
# # 20180822 Wednesday
#
# 冰箱 风冷，多循环，变频，不窜味，
#
# 多开门，风冷直冷，混冷，多单独循环，零度保鲜
#
# 压缩机分进口的还是国产的。一般进口的要好一点。冰箱的使实际尺寸，买之前先测量自己家的门能不能购进来
#
# 博世 西门子 0度保鲜。。。
#
# 博世（BOSCH）569升 变频混冷无霜对开门冰箱 零度保鲜 独立控湿（玫瑰金）BCD-569W(KAF96A66TI)
#
#  BOSCH 博世 KAF96S80TI 混冷多门冰箱（0度保鲜）
#
#  西门子 KF86NAA21C
#
#  ---
#  # 20180823 Thursday
#
#  > sick...
#
#  ---
#  # 20180824 Friday
#
# 斯坦福Andrew Ng的《Machine Learning》、台大林田轩的《机器学习基石》和《机器学习技法》。Andrew的课程简单，省去了很多的数学推导和证明，但很全面，对机器学习中的算法作了很多总结与比较。
#
# ---
# # 20180825 Saturday 20180826 Sunday
#
# > 选择了 能率的 热水器
#
# > 博世的 洗衣机 和 冰箱, seems done?
#
# > Fill sick for a few days... 感冒了好几天，需要更加注意自己的身体了，需要关注平时的细节。 不能乱来, 坚持跑步，普拉提
#
# > 多吃 百香果， 它有很多维生素，能增强抵抗力，from miss ren... 知识啊。。。
#
# > 平时可以多备一些常用药品在身边。。。学会照顾自己...
#
# > That day morning, day to remember, we learn to do interesting things, start to know how to handle the problem...
#
# > we are no longer ...
#
# ---
# # 20180827 Monday
#
# > 不要害怕他，害怕麻烦，不然事情就完成不了了，do it...
#
# ---
# # 20180828 Tuesday
#
# > 只使用 kafka connect 就可以完成 批 和 流 了？
#
# > Data Pipeline做的就是把不同子系统的数据收集起来进行清洗和整合，提取出具有价值的数据，然后交给数据分析师或数据工程师。可以说，Data Pipeline将各个数据孤岛打通，加速了信息流通。
#
# > VIP.com 的 Saturn 是分布式定时调度系统...
#
# > 百香果，好好吃，还营养，确实应该多问问, what is this thing? why people are interested in it? how can i levearage it?
#
# > 抓着她去 跑步，拉伸，拉伸，运动，吃百香果
#
# ---
# # 201808230 Thursday
#
# > 多认识人好啊，方差变大，多样性变大，问问题好很多啊。。。
#
# > workflow调度, 工作流调度， datapipeline 工作调度
#
# > 华住 又又又 泄露信息了，严重啊，注意自己的密码策略，要足够安全健壮，不仅要自己做好，自己的LD也要啊。 做好长期跟骗子做斗争、博弈的过程，做一个做好事的坏人，不能做被欺负的好人，反抗，动动脑子反抗啊，看清这个现实，然后想办法去解决，反抗就好了，有啥难的，阿廖沙，别害怕。 Don't Panic...
#
# > 把我们的任务以来关系画成 有向无环图，发现了很多有趣的作图工具
#
# > 处理调度系统， 定时调度系统， DAG调度系统， 处理依赖的关系，图，拓扑图，排序，
#
# ```
# 工具很多，方法很多，找到合适的来做就好了
# http://www.dagitty.net
# https://dagrejs.github.io/project/dagre-d3/latest/demo/interactive-demo.html
# http://echarts.baidu.com
# https://cran.r-project.org/web/packages/ggdag/vignettes/intro-to-dags.html
# ```
