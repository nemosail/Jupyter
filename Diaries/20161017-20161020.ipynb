# %% [markdown]
# # 20161017 Monday
#
# > 人机接口
#
# ---
# 好喝只是表面的。。。[配料+评测](http://www.15yan.com/story/4GAYzOZ7idq/)
#
# HHJ又出现多实例失败，是因为没有编译
#
# 下载Moia日志，看日志查错
#
# 工程变量不对。。。需要在 designer 修改作业参数， 然后修改数据源参数，然后修xls/moia上参数
#
# 监控作业的的确需要的是 执行权限。。否在无法失败重做
#
# Datastage 出现 bulk load error 可以改成 insert 查看，可能是写入数据失败了，是因为源数据的问题，原来为非空的，但是数据为' '导致去空格之后就为null了，无法插入数据库，导致的写入数据错误.
#
# ---
# 终于解决了IE下载一直 停在0% 的问题。。。在于IE的Internet设置[百度经验](http://jingyan.baidu.com/article/90bc8fc8678f97f653640c91.html)
#
# ---
# #### 共享经济
# 共享经济的本质是通过整合线下的闲散物品或服务者，让他们以较低的价格提供产品或服务。对于供给方来说，通过在特定时间内让渡物品的使用权或提供服务，来获得一定的金钱回报。而要想真正搭建共享经济平台，资源过剩是根基，共享平台是介质，算法是手段，按需分配是原则，获得回报是结果。这其中，算法是极其重要的。如果没有算法，广泛的共享经济也就无所谈起。
#
#
# # 20161018 Tuesday
#
# > 傻白甜，真的只是看起来是傻白甜。
#
# ---
# 在**任务**监控可以在 忽略事件依赖 - 状态重置 - 可以改时间
#
# 在**批次**监控，可以查看依赖 - 状态重置 让其重新运行
#
# 在**作业**监控，可以查看作业运行成功情况
#
# # 20161019 Wednesday
# > GNT=Gross National Time； 时间才是真正的战场
#
# ---
# 能改改企业ETL管理里面的资源视图，提供搜索定位功能吗？ 在作业监控，尝试时候可以忽略时间依赖让其运行。。。
#
# ---
# 需要更深入了解需求，对脚本的控制也是必要的，毕竟长时间运行，注意脚本对系统资源的占用与压力：特别是数据库压力：
# 1. 能一次性查询的就一次性查询，不要分开多次查询，尽量减少对数据库的查询;
# 2. 对于重新跑的作业，加上job_end_date作业完成时间，用来区分 新旧/重跑的作业;
# 3. 由于查询的表格是 实时状态表，不会有历史数据，所以不用担心job_date的情况，看懂sql语句后去掉job_date;
#
# ---
# 罗胖的[GNT](http://36kr.com/p/5054747.html)
#
# 我们面对的其实是信息过剩下的信息不足
#
# # 20161020 Thursday
#
# ---
# [Karl Marx](http://www.bilibili.com/video/av6746777/)：资本论。。。理论？ His theory will be part of the answer.
# > 哲学家们到目前为止只是用不同的方式解读了世界，然而关键是如何去改变它.
#
# 1. Work can be one of the sources of our greatest joys.
# 2. Human become expendable.
# 3. Workers get paid little while capitalist get rich. 原始积累, primitive accumucation.
# 4. Capitalism is unstable.
# 5. Capitalism is bad bor capitalist. 商品拜物教-
