# %% [markdown]
# ## Something About Github
# Github作为一个social coding 网站，其作用远远超过了一个简单的VCS（版本控制系统）。
#
# 因此，要想充分利用Github，就不能闭门造车，而要站在巨人的肩膀上。
# GitHub上牛的组织:
# yahoo
# google
# amazon
# ...
#
#
# 以下是个人推荐follow的github牛人：
#
# Github的创作者：
#
# mojombo(Tom Preston-Werner)
#
# defunct(Chris Wanstrath)
#
# pjhyett(PJ Hyett)
#
# schacon(Scott Chacon)
#
#
#
# cocos2d-iphone的创作者：
#
# ricardoquesada(Ricardo Quesada)
#
# Learn Cocos2D的作者：
#
# LearnCocos2D(Steffen Itterheim)
#
# cocos2d-x的作者：
#
# walzer(王哲)
#
#
# 至于其它的牛人，只要看看这些牛人在关注哪些人就知道了。
#
#
#
# 值得watch的repo：
#
# html5-boilerplate（专业的前端网站开发模板，使用HTML5JISHU）
#
# cocos2d-iphone(cocos2d-iphone，基于objective-C的iphone2d游戏开发引擎，无需多介绍了)
#
# cocos2d-x（cocos2d-iphone的C++版本，跨平台2d游戏开发引擎）
#
# cocos2d-javascript（cocos2d-iphone的HTML5版本）
#
# cocos2d-iphone-extensions(cocos2d-iphone的拓展功能)
#
# Ruby,
#
# rails,
#
# Go,
#
# mongo,
#
# jquery,
#
# ...
#
# 此外，Github官方还提供了根据Interesting, Popular Forked和Popular Watched对repo进行排序，从而找到一些很不错的repo
#
# [Github repos](https://github.com/repositories)
