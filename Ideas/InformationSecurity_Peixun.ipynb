# %% [markdown]
# > 20161022 Friday
#
# 52NLP.net / 52ML.net
#
# Book: <欺骗的艺术> 社会工程学
#
# 安全模型，SDL，安全开发，黑盒/白盒， 黑帽/白帽;
#
# 理想：
# 1. 不存在安全漏洞;
# 2. 能低于各种攻击;
# 3. do what is intended;
#
# 个人的小型分布式计算系统;
#
# 验证输入
# SQL注入
# XSS
#
# ActiveX安全性
#
# 不安全函数： strcpy; strcat。。。。
#
# 安全编译，代码扫描， FN FN 误报/漏报
#
# 方法学： Fuzz 测试，已有大量的测试用例，去测试，去看返回结果评估;
#
# Google新的验证码识别，人机识别
#
# 安全设计原则：
# 1. 最小特权
# 2. 输入不可信
# 3. 权限管理
# ...
#
# SQL注入，由于拼接SQL所带来的，需要检查输入，字符编码的变换，编程宽编码等等，预编译等等，执行了用户的输入，不应该
#
# XSS脚本： 持久XSS，反射XSS
#
# 为什么短域名不能乱点，因为因此了许多url的信息
#
#
# 用户（恶意用户，普通用户）输入不可信;
#
# 过滤器，用统一过滤器处理/编码用户输入 -> 转移成宽字符， 自动编码器
#
# ADsafe插件， 浏览器XSS过滤器
#
# CSRF 越权操作，解决： 检查Refer，一次性令牌，加入认证过程，不让程序执行，用Getfrom不从url上获取数据
#
# email为什么不能乱点，知道为什么了吧？
#
# WebShell
#
# XML， XPath注入，类是SQL注入
#
# JSON劫持，
#
# 随机数，安全随机数，熵收集器,伪随机加密
#
# 用-正则表达式来严格限制输入内容
#
# 安全测试工具
# Burp suite | Fiddler
#
# PPT where
#
# stream: game: hacker life
#
# 工具 Launchy
#
# swap last4
# Weixin:
# 186 3961 7049
# QQ:
# 928885416
